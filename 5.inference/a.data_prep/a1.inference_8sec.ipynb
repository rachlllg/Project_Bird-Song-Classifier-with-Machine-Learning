# %% [markdown]
# # Import Libraries

# %%
# For drive access
from google.colab import drive
drive.mount('/content/drive')

# Standard libraries
import numpy as np
import pandas as pd
import time

# For audio
import librosa

# For preprocessing
import tensorflow as tf

# for saving the dataframe to disk
import pickle
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Self Defined Class Methods For Feature Extraction

# %% [markdown]
# minor changes were made to the class to adjust for use on the test data

# %%
class Framed:

  def __init__(self,
               dataframe,
               sr=16000,
               window_size_s=5.0,
               hop_size_s=2.5,
               do_augment=False
               ):
    """
    Instantiate the Framed class, create train and val dfs.

    The extract_framed() method is automatically called when the class is
    instantiated to extract the framed audios and add to the train and val dfs.

    Parameters:
      dataframe (pd.DataFrame): DataFrame containing audio file information.
      sr (int): Sample rate of the audio files.
      window_size_s (float): Window size in seconds for framing the audio.
      hop_size_s (float): Hop size in seconds for framing the audio.
      augment (bool): Whether to apply augmentation to the audio.
    """
    # instantiate class
    self.sr = sr
    self.frame_length = int(window_size_s * sr)
    self.frame_step = int(hop_size_s * sr)
    self.df = dataframe

    # only training data could be augmented, validation is never augmented
    self.extract_framed(self.df, augment=do_augment)


  ########################################
  # augment function is called by extract_framed function if do_augment=True
  ########################################
  def augment(self, audio_array):
    """
    Apply random augmentation if needed.

    Parameters:
      audio_array (npy): Training audio array.

    Returns:
      audio_array (npy): Augmented audio array.
    """
    choice = np.random.choice(['original','noise','shift','pitch'])

    # if the audio is short (less than 7 seconds in duration), stretch it first
    if len(audio_array) <= 7*self.sr:
      audio_array = librosa.effects.time_stretch(y=audio_array, rate=np.random.uniform(low=0, high=1))
    # if the audio is not short, apply a random augmentation at random magnitude
    elif choice == 'noise':
      noise_amp = np.random.normal(loc=0.0, scale=0.05)*np.amax(audio_array)
      audio_array = audio_array + noise_amp*np.random.normal(size=audio_array.shape[0])
    elif choice == 'shift':
      shift_range = int(np.random.uniform(low=-5, high=5)*1000)
      audio_array = np.roll(audio_array, shift_range)
    elif choice == 'pitch':
      audio_array = librosa.effects.pitch_shift(y=audio_array, sr=self.sr, n_steps=np.random.uniform(low=0, high=1))
    else:
      audio_array = audio_array

    return audio_array


  ########################################
  # extract_framed function is called when the class is instantiated to extract the framed audios
  ########################################
  def extract_framed(self, dataframe, augment):
    """
    Load audio files from the given DataFrame, extract framed audios,
    and add the framed audios to the given DataFrame

    Parameters:
      dataframe (pd.DataFrame): DataFrame containing audio file information.
      augment (bool): Whether to apply augmentation to the audio.
    """
    # load audios
    audios = []
    for filename in dataframe['filename_npy']:
      audio = np.load('/content/drive/MyDrive/Projects/test_npy/' + filename)
      # if augment is true, call the augment function to apply augmentation to the audio
      if augment:
        audio = self.augment(audio)
      audios.append(audio)
    assert len(audios) == len(dataframe)

    # extract framed audios
    framed = []
    for audio in audios:
      framed_audio = tf.signal.frame(audio, self.frame_length, self.frame_step, pad_end=False)
      framed.append(framed_audio)
    assert len(framed) == len(audios)

    # add framed audios to df
    dataframe['framed'] = framed

# %% [markdown]
# # Load csv data

# %%
df = pd.read_csv('/content/drive/MyDrive/Projects/clean_test_df_w_npy.csv')

df.head()
# Out:
#   primary_label   type  latitude  longitude  rating              filename  \
# 0        barswa  blank   53.2509     5.5980     4.0   barswa/XC721711.ogg
# 1        comsan   call   48.8306     2.1999     4.0   comsan/XC496602.ogg
# 2       eaywag1  blank   43.3298     4.8364     4.0  eaywag1/XC718445.ogg
# 3       eaywag1   call   37.1357    -7.6138     4.5  eaywag1/XC481360.ogg
# 4        barswa  blank   19.3551   -99.0467     5.0   barswa/XC698512.ogg
#
#      duration country continent          filename_npy
# 0   19.069375      NL    EUROPE   barswa/XC721711.npy
# 1   28.995938      FR    EUROPE   comsan/XC496602.npy
# 2    7.340438      FR    EUROPE  eaywag1/XC718445.npy
# 3  151.944000      PT    EUROPE  eaywag1/XC481360.npy
# 4   18.703688      MX  AMERICAS   barswa/XC698512.npy

# %%
len(df)
# Out:
# 448

# %% [markdown]
# # Extract test dfs with framed audios

# %% [markdown]
# Drop the audios less than 8 seconds in length first

# %%
filtered = df[df['duration'] < 8.0]

filtered
# Out:
#     primary_label   type   latitude   longitude  rating              filename  \
# 2         eaywag1  blank  43.329800    4.836400     4.0  eaywag1/XC718445.ogg
# 6         eaywag1   call  48.744800   -1.563800     4.0  eaywag1/XC614965.ogg
# 14         barswa   song  49.071500 -106.530900     3.5   barswa/XC186847.ogg
# 16        eaywag1   call  41.487500    2.365300     5.0  eaywag1/XC672267.ogg
# 19         comsan   call  51.353200   -0.146100     4.0   comsan/XC575672.ogg
# 20         comsan   call  48.722100   -3.573800     3.0   comsan/XC469853.ogg
# 41         comsan   call  59.315800   18.058800     3.0   comsan/XC558727.ogg
# 44         comsan  blank  43.741200   -7.867000     4.0   comsan/XC736767.ogg
# 50         comsan   call  50.719300    3.222800     3.0   comsan/XC552598.ogg
# 55        eaywag1  blank  43.329800    4.836400     4.0  eaywag1/XC718444.ogg
# 58         comsan   call  39.469600   -0.352200     2.0   comsan/XC552846.ogg
# 92        eaywag1  blank  51.699700    5.616600     4.5  eaywag1/XC754341.ogg
# 93         comsan  blank  16.781600   42.674500     5.0   comsan/XC746421.ogg
# 94        eaywag1   call  44.656200   -1.255300     5.0  eaywag1/XC526333.ogg
# 115        comsan   call  51.430900   -2.851800     3.0   comsan/XC586341.ogg
# 119       eaywag1   call  65.808100   29.652900     5.0  eaywag1/XC602792.ogg
# 147        comsan  blank  41.684300   41.730300     3.0   comsan/XC699302.ogg
# 151       eaywag1   call  39.313100   -9.216800     1.0  eaywag1/XC586874.ogg
# 170        comsan   call  50.166400    1.716700     4.0   comsan/XC681230.ogg
# 174        barswa   call  41.303000    2.128100     4.0   barswa/XC432107.ogg
# 176        comsan   call  37.117800   -8.682800     0.0   comsan/XC500457.ogg
# 181        comsan   call  50.754200    4.567200     1.0   comsan/XC552592.ogg
# 182        comsan   call  42.328487    2.551244     3.0   comsan/XC587862.ogg
# 192        comsan   song  37.117800   -8.682800     0.0   comsan/XC500677.ogg
# 198        comsan   call  50.719300    3.222800     2.0   comsan/XC556798.ogg
# 202        comsan   call  52.056700    1.148200     3.0   comsan/XC582037.ogg
# 211        comsan  blank  56.454500    9.633100     5.0   comsan/XC745494.ogg
# 217       eaywag1   call  37.095100   -6.038600     3.0  eaywag1/XC284641.ogg
# 219        barswa   call  23.828000  120.792900     4.0   barswa/XC567606.ogg
# 242        comsan   call  43.610800    3.876700     4.0   comsan/XC582118.ogg
# 256        barswa   call  51.915000   16.848000     4.5   barswa/XC589374.ogg
# 267        comsan   call  39.469600   -0.352200     4.0   comsan/XC553366.ogg
# 288        barswa   call        NaN         NaN     3.0   barswa/XC179260.ogg
# 289       eaywag1   call  52.689300   12.248100     2.5  eaywag1/XC176331.ogg
# 292       eaywag1   call  58.847600   26.947900     4.5  eaywag1/XC669888.ogg
# 294        barswa   call  54.578900   11.928400     4.0   barswa/XC377901.ogg
# 296       eaywag1   call  41.224300    1.725400     5.0  eaywag1/XC677346.ogg
# 297        comsan   call  53.671900   -1.785200     4.0   comsan/XC667400.ogg
# 298        comsan   call  48.886000    2.354200     2.0   comsan/XC581424.ogg
# 299        barswa   call  41.224300    1.725400     5.0   barswa/XC649113.ogg
# 305        comsan   call  54.238600   -0.419600     4.0   comsan/XC636687.ogg
# 313        comsan   call  52.336500   13.809200     2.0   comsan/XC190288.ogg
# 318        barswa   song  46.798500    1.305000     3.5   barswa/XC645074.ogg
# 325        comsan  blank  52.239300   -6.346400     5.0   comsan/XC736199.ogg
# 352        comsan   call  51.430900   -2.851800     3.0   comsan/XC586339.ogg
# 353        barswa   call  50.119100   18.972100     3.5   barswa/XC570975.ogg
# 367        barswa   call  19.255000  -99.025400     4.0   barswa/XC645556.ogg
# 370       eaywag1   call  41.697000   -8.851000     0.0  eaywag1/XC441023.ogg
# 384       eaywag1  blank  37.135700   -7.613800     4.0  eaywag1/XC732657.ogg
# 396        barswa   call  52.876900   10.287500     4.0   barswa/XC672484.ogg
# 398        comsan   call  47.294600    9.555700     2.0   comsan/XC635181.ogg
# 419       eaywag1   call  53.534200    8.603200     3.0  eaywag1/XC589090.ogg
# 425        comsan  blank  58.810500   22.868000     4.5   comsan/XC725160.ogg
# 426        comsan   call  50.719300    3.222800     1.0   comsan/XC556788.ogg
# 435        barswa   call  41.200400  -73.879900     1.0   barswa/XC144361.ogg
# 436        comsan  blank  53.671900   -1.785200     5.0   comsan/XC735661.ogg
#
#      duration  country continent          filename_npy
# 2    7.340438       FR    EUROPE  eaywag1/XC718445.npy
# 6    5.250000       FR    EUROPE  eaywag1/XC614965.npy
# 14   6.739625       CA  AMERICAS   barswa/XC186847.npy
# 16   5.903688       ES    EUROPE  eaywag1/XC672267.npy
# 19   7.026000       GB    EUROPE   comsan/XC575672.npy
# 20   6.269000       FR    EUROPE   comsan/XC469853.npy
# 41   6.191000       SE    EUROPE   comsan/XC558727.npy
# 44   5.825000       ES    EUROPE   comsan/XC736767.npy
# 50   5.433500       BE    EUROPE   comsan/XC552598.npy
# 55   5.146125       FR    EUROPE  eaywag1/XC718444.npy
# 58   6.765750       ES    EUROPE   comsan/XC552846.npy
# 92   6.034000       NL    EUROPE  eaywag1/XC754341.npy
# 93   5.256000       SA      ASIA   comsan/XC746421.npy
# 94   5.976000       FR    EUROPE  eaywag1/XC526333.npy
# 115  6.060000       GB    EUROPE   comsan/XC586341.npy
# 119  6.269000       FI    EUROPE  eaywag1/XC602792.npy
# 147  5.459000       GE      ASIA   comsan/XC699302.npy
# 151  5.590000       PT    EUROPE  eaywag1/XC586874.npy
# 170  6.112000       FR    EUROPE   comsan/XC681230.npy
# 174  5.041625       ES    EUROPE   barswa/XC432107.npy
# 176  6.112687       PT    EUROPE   comsan/XC500457.npy
# 181  6.974687       BE    EUROPE   comsan/XC552592.npy
# 182  5.694687       ES    EUROPE   comsan/XC587862.npy
# 192  5.276750       PT    EUROPE   comsan/XC500677.npy
# 198  6.765750       BE    EUROPE   comsan/XC556798.npy
# 202  6.582000       GB    EUROPE   comsan/XC582037.npy
# 211  5.485750       DK    EUROPE   comsan/XC745494.npy
# 217  7.810625       ES    EUROPE  eaywag1/XC284641.npy
# 219  5.976000       TW      ASIA   barswa/XC567606.npy
# 242  5.355000       FR    EUROPE   comsan/XC582118.npy
# 256  6.168000       PL    EUROPE   barswa/XC589374.npy
# 267  6.948563       ES    EUROPE   comsan/XC553366.npy
# 288  7.627000  UNKNOWN   UNKNOWN   barswa/XC179260.npy
# 289  6.112687       DE    EUROPE  eaywag1/XC176331.npy
# 292  7.200000       EE    EUROPE  eaywag1/XC669888.npy
# 294  7.131437       DK    EUROPE   barswa/XC377901.npy
# 296  7.392000       ES    EUROPE  eaywag1/XC677346.npy
# 297  6.635125       GB    EUROPE   comsan/XC667400.npy
# 298  5.929000       FR    EUROPE   comsan/XC581424.npy
# 299  6.974000       ES    EUROPE   barswa/XC649113.npy
# 305  5.564000       GB    EUROPE   comsan/XC636687.npy
# 313  7.915125       DE    EUROPE   comsan/XC190288.npy
# 318  7.176000       FR    EUROPE   barswa/XC645074.npy
# 325  6.120000       IE    EUROPE   comsan/XC736199.npy
# 352  7.053000       GB    EUROPE   comsan/XC586339.npy
# 353  7.560000       PL    EUROPE   barswa/XC570975.npy
# 367  5.592000       MX  AMERICAS   barswa/XC645556.npy
# 370  7.235938       PT    EUROPE  eaywag1/XC441023.npy
# 384  5.088000       PT    EUROPE  eaywag1/XC732657.npy
# 396  7.549000       DE    EUROPE   barswa/XC672484.npy
# 398  5.929812       AT    EUROPE   comsan/XC635181.npy
# 419  5.616000       DE    EUROPE  eaywag1/XC589090.npy
# 425  6.635000       EE    EUROPE   comsan/XC725160.npy
# 426  7.889000       BE    EUROPE   comsan/XC556788.npy
# 435  7.026937       US  AMERICAS   barswa/XC144361.npy
# 436  6.870250       GB    EUROPE   comsan/XC735661.npy

# %%
df.drop(filtered.index, inplace=True)

# %%
assert len(df[df['duration'] < 8.0]) == 0

# %%
# %%time

framed = Framed(df,
               window_size_s=8.0,
               hop_size_s=4.0,
               do_augment=False)
# Out:
# CPU times: user 3.75 s, sys: 3.06 s, total: 6.81 s
# Wall time: 2min 57s

# %% [markdown]
# # Save the df with framed audios for future use

# %%
framed.df.head()
# Out:
#   primary_label   type  latitude  longitude  rating              filename  \
# 0        barswa  blank   53.2509     5.5980     4.0   barswa/XC721711.ogg
# 1        comsan   call   48.8306     2.1999     4.0   comsan/XC496602.ogg
# 3       eaywag1   call   37.1357    -7.6138     4.5  eaywag1/XC481360.ogg
# 4        barswa  blank   19.3551   -99.0467     5.0   barswa/XC698512.ogg
# 5        comsan   call   56.0851    47.2602     5.0   comsan/XC492456.ogg
#
#      duration country continent          filename_npy  \
# 0   19.069375      NL    EUROPE   barswa/XC721711.npy
# 1   28.995938      FR    EUROPE   comsan/XC496602.npy
# 3  151.944000      PT    EUROPE  eaywag1/XC481360.npy
# 4   18.703688      MX  AMERICAS   barswa/XC698512.npy
# 5   44.512687      RU    EUROPE   comsan/XC492456.npy
#
#                                               framed
# 0  ((tf.Tensor(1.0793006e-05, shape=(), dtype=flo...
# 1  ((tf.Tensor(-1.02154445e-05, shape=(), dtype=f...
# 3  ((tf.Tensor(-1.7517013e-06, shape=(), dtype=fl...
# 4  ((tf.Tensor(-2.801371e-06, shape=(), dtype=flo...
# 5  ((tf.Tensor(-1.2049219e-05, shape=(), dtype=fl...

# %%
with open('/content/drive/MyDrive/Projects/test_csv_pkl/test_df_8_sec.pkl', 'wb') as file:
  pickle.dump(framed.df, file)

del file

# %% [markdown]
# ## reload the pickle files to confirm they are the same as the original df

# %%
with open('/content/drive/MyDrive/Projects/test_csv_pkl/test_df_8_sec.pkl', 'rb') as file:
  loaded_df = pickle.load(file)

del file

# %%
loaded_df.head()
# Out:
#   primary_label   type  latitude  longitude  rating              filename  \
# 0        barswa  blank   53.2509     5.5980     4.0   barswa/XC721711.ogg
# 1        comsan   call   48.8306     2.1999     4.0   comsan/XC496602.ogg
# 3       eaywag1   call   37.1357    -7.6138     4.5  eaywag1/XC481360.ogg
# 4        barswa  blank   19.3551   -99.0467     5.0   barswa/XC698512.ogg
# 5        comsan   call   56.0851    47.2602     5.0   comsan/XC492456.ogg
#
#      duration country continent          filename_npy  \
# 0   19.069375      NL    EUROPE   barswa/XC721711.npy
# 1   28.995938      FR    EUROPE   comsan/XC496602.npy
# 3  151.944000      PT    EUROPE  eaywag1/XC481360.npy
# 4   18.703688      MX  AMERICAS   barswa/XC698512.npy
# 5   44.512687      RU    EUROPE   comsan/XC492456.npy
#
#                                               framed
# 0  ((tf.Tensor(1.0793006e-05, shape=(), dtype=flo...
# 1  ((tf.Tensor(-1.02154445e-05, shape=(), dtype=f...
# 3  ((tf.Tensor(-1.7517013e-06, shape=(), dtype=fl...
# 4  ((tf.Tensor(-2.801371e-06, shape=(), dtype=flo...
# 5  ((tf.Tensor(-1.2049219e-05, shape=(), dtype=fl...

# %%
columns = ['primary_label', 'type', 'latitude', 'longitude', 'rating', 'filename', 'duration', 'country', 'filename_npy']

# %%
assert framed.df[columns].equals(loaded_df[columns])

# %% [markdown]
# Tensor objects cannot be directly compared using pd.equals() so they are compared one by one in below script

# %%
count = 0

for index in range(0,len(framed.df)):
  if not np.any(tf.equal(framed.df['framed'].iloc[index], loaded_df['framed'].iloc[index])):
    count +=1

assert count == 0
