# %% [markdown]
# # Import Libraries

# %%
# For drive access
from google.colab import drive
drive.mount('/content/drive')

# Standard libraries
import numpy as np
import pandas as pd

# for loading the pickle files with features and labels
import pickle

# For audio
from IPython.display import Audio
import librosa

# For modeling
import tensorflow as tf
from sklearn.metrics import classification_report

# For visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load features and labels from train and val pickle

# %%
with open('/content/drive/MyDrive/Projects/train_val_features_pkl/train_val_8_sec_audio_features_not_avgpooled.pkl', 'rb') as file:
  audio_df = pickle.load(file)

# %%
audio_df
# Out:
# {'train': {'mfcc': array([[[0.2926833 , 0.5472208 , 0.51762646, ..., 0.42902297,
#            0.5246572 , 0.39747417],
#           [0.38219857, 0.63193434, 0.4692648 , ..., 0.4789598 ,
#            0.5143834 , 0.35231233],
#           [0.4352324 , 0.62795496, 0.4937711 , ..., 0.53823024,
#            0.5205363 , 0.36665156],
#           ...,
#           [0.6295364 , 0.3740691 , 0.4684327 , ..., 0.74904454,
#            0.6659465 , 0.13212648],
#           [0.6729512 , 0.37194872, 0.47004578, ..., 0.63276273,
#            0.6894711 , 0.25973636],
#           [0.6984098 , 0.35604227, 0.50428545, ..., 0.49908003,
#            0.694181  , 0.40737295]],
#
#          [[0.571982  , 0.52721703, 0.35377806, ..., 0.31411108,
#            0.45345846, 0.5325761 ],
#           [0.57278824, 0.51283437, 0.33133256, ..., 0.44663262,
#            0.59104645, 0.5540432 ],
#           [0.5442881 , 0.50030595, 0.39622635, ..., 0.4177069 ,
#            0.63780564, 0.5152073 ],
#           ...,
#           [0.65820706, 0.30996823, 0.5541669 , ..., 0.3272183 ,
#            0.67594415, 0.37952572],
#           [0.55198324, 0.45880285, 0.6117153 , ..., 0.3045411 ,
#            0.6040039 , 0.2133086 ],
#           [0.47530848, 0.5978474 , 0.5095156 , ..., 0.32938066,
#            0.5845121 , 0.43895328]],
#
#          [[0.7978938 , 0.2568429 , 0.43546572, ..., 0.43030724,
#            0.43849736, 0.42188978],
#           [0.7662014 , 0.25891137, 0.39701158, ..., 0.5694269 ,
#            0.5710539 , 0.42619675],
#           [0.7192114 , 0.23281348, 0.49096993, ..., 0.72567195,
#            0.55556244, 0.33746177],
#           ...,
#           [0.5616844 , 0.47193855, 0.47496653, ..., 0.40325606,
#            0.6460507 , 0.3992835 ],
#           [0.637675  , 0.43434197, 0.44582096, ..., 0.28660327,
#            0.72113395, 0.4044888 ],
#           [0.6874016 , 0.41598967, 0.45974106, ..., 0.2920211 ,
#            0.8479563 , 0.3843705 ]],
#
#          ...,
#
#          [[0.3217525 , 0.6881845 , 0.48000094, ..., 0.59206927,
#            0.74486995, 0.55143815],
#           [0.5426938 , 0.6778939 , 0.41601896, ..., 0.7395768 ,
#            0.7553704 , 0.47949517],
#           [0.59666324, 0.6607961 , 0.4709517 , ..., 0.73276883,
#            0.7016298 , 0.4657311 ],
#           ...,
#           [0.6395872 , 0.71056587, 0.5853568 , ..., 0.46401277,
#            0.64115125, 0.48693323],
#           [0.63390076, 0.7141628 , 0.5673788 , ..., 0.47245952,
#            0.48211706, 0.5692038 ],
#           [0.63172424, 0.69852054, 0.5903194 , ..., 0.50481737,
#            0.5573676 , 0.66070366]],
#
#          [[0.6914642 , 0.71377504, 0.39913929, ..., 0.57215583,
#            0.45173353, 0.49472663],
#           [0.69487584, 0.70868874, 0.40198043, ..., 0.69470924,
#            0.53920835, 0.6262043 ],
#           [0.66651314, 0.6739543 , 0.46362418, ..., 0.70973766,
#            0.5931354 , 0.61188835],
#           ...,
#           [0.60295427, 0.707848  , 0.536386  , ..., 0.53722155,
#            0.57293046, 0.47105172],
#           [0.6006154 , 0.72017705, 0.50518787, ..., 0.4792548 ,
#            0.51115537, 0.49641013],
#           [0.5960094 , 0.70707476, 0.48459497, ..., 0.45196575,
#            0.6186346 , 0.60358286]],
#
#          [[0.67346656, 0.7210153 , 0.5060047 , ..., 0.5705455 ,
#            0.49910307, 0.4772731 ],
#           [0.6678432 , 0.720808  , 0.45569578, ..., 0.65077525,
#            0.53326356, 0.5335313 ],
#           [0.63857067, 0.6967014 , 0.4817975 , ..., 0.675209  ,
#            0.6000869 , 0.59436566],
#           ...,
#           [0.61522543, 0.6990228 , 0.5028586 , ..., 0.4935642 ,
#            0.61613715, 0.5054803 ],
#           [0.6177405 , 0.7108036 , 0.4846519 , ..., 0.44536754,
#            0.53255624, 0.5205585 ],
#           [0.6179831 , 0.70123994, 0.48564783, ..., 0.43177015,
#            0.5783832 , 0.5263324 ]]], dtype=float32),
#   'chroma': array([[[0.73383594, 0.69802487, 0.54096204, ..., 1.        ,
#            0.608227  , 0.48766178],
#           [1.        , 0.9552251 , 0.97629696, ..., 0.819532  ,
#            0.46592206, 0.4471012 ],
#           [0.70929813, 0.856629  , 1.        , ..., 0.9266538 ,
#            0.5471759 , 0.3217781 ],
#           ...,
#           [0.88756543, 0.4946972 , 0.0864549 , ..., 0.22002427,
#            0.10811816, 0.53788805],
#           [1.        , 0.20042695, 0.16474293, ..., 0.17202397,
#            0.26110023, 0.83525467],
#           [0.90538883, 0.38594005, 0.5073254 , ..., 0.5220612 ,
#            0.7847499 , 1.        ]],
#
#          [[0.229046  , 0.16785018, 0.31864116, ..., 0.418515  ,
#            0.38013583, 0.45450932],
#           [0.10696242, 0.05362201, 0.17352895, ..., 0.13921109,
#            0.12649179, 0.19284795],
#           [0.09754786, 0.03310031, 0.07604828, ..., 0.05064095,
#            0.06268156, 0.09602583],
#           ...,
#           [0.24475525, 0.45408043, 0.83302605, ..., 0.05314327,
#            0.18526138, 0.2805035 ],
#           [0.08646167, 0.38773277, 0.8255288 , ..., 0.0313557 ,
#            0.06599664, 0.08877482],
#           [0.6355827 , 0.49046612, 0.4782703 , ..., 0.61005807,
#            1.        , 0.62264   ]],
#
#          [[0.9527174 , 0.6517912 , 1.        , ..., 0.20430964,
#            0.53656095, 0.91746473],
#           [0.6809198 , 0.79247546, 1.        , ..., 0.20608044,
#            0.3752266 , 0.6624584 ],
#           [0.22394416, 0.9766228 , 1.        , ..., 0.29581028,
#            0.16772322, 0.17033473],
#           ...,
#           [0.7538224 , 0.20673002, 0.14345545, ..., 0.5413501 ,
#            0.42209476, 0.43086848],
#           [0.2879784 , 0.0433191 , 0.0333375 , ..., 0.16351902,
#            0.14486517, 0.21927443],
#           [0.2606343 , 0.02818089, 0.02646846, ..., 0.08534104,
#            0.08157288, 0.22000772]],
#
#          ...,
#
#          [[1.        , 0.5075606 , 0.3643616 , ..., 0.46753508,
#            0.5181549 , 0.82220215],
#           [0.75011694, 0.40670243, 0.23636323, ..., 0.34903422,
#            0.33158213, 0.5658228 ],
#           [0.6620617 , 0.49264944, 0.37212887, ..., 0.42530674,
#            0.48871762, 0.50091463],
#           ...,
#           [0.47907886, 0.5681733 , 0.6849798 , ..., 0.9351088 ,
#            0.6223058 , 0.4530788 ],
#           [0.6037054 , 0.57480985, 0.8478139 , ..., 1.0000001 ,
#            0.9806911 , 0.8639272 ],
#           [0.330637  , 0.46738312, 1.0000001 , ..., 0.5264327 ,
#            0.6019139 , 0.47685713]],
#
#          [[0.7212241 , 0.6510515 , 0.49622202, ..., 0.42471525,
#            0.62083757, 0.54442513],
#           [0.7963582 , 0.9396931 , 0.7933524 , ..., 0.8130368 ,
#            0.8064168 , 0.7425875 ],
#           [0.60769   , 0.89288026, 1.        , ..., 0.96361125,
#            0.7946369 , 0.6225406 ],
#           ...,
#           [0.7738935 , 0.55971414, 0.7861116 , ..., 1.        ,
#            0.72889286, 0.82642055],
#           [0.6680029 , 0.4654429 , 0.5945168 , ..., 1.0000001 ,
#            0.5256816 , 0.5611079 ],
#           [0.90391827, 0.71218765, 0.71311766, ..., 0.99999994,
#            0.664123  , 0.67750007]],
#
#          [[1.        , 0.7363702 , 0.75878894, ..., 0.5759158 ,
#            0.5487739 , 0.9241918 ],
#           [1.        , 0.90941614, 0.7891846 , ..., 0.7688592 ,
#            0.5679903 , 0.8910592 ],
#           [0.47667533, 0.51785684, 0.59323484, ..., 0.7292442 ,
#            0.5910429 , 0.5156206 ],
#           ...,
#           [0.7927784 , 0.8835067 , 1.        , ..., 0.54843056,
#            0.36869946, 0.6075551 ],
#           [0.8109695 , 1.        , 0.89819205, ..., 0.82382023,
#            0.53969693, 0.7465627 ],
#           [0.5711932 , 0.5911646 , 0.7132408 , ..., 0.6430262 ,
#            0.5621957 , 0.6215854 ]]], dtype=float32),
#   'rms': array([[[0.00066166],
#           [0.00108187],
#           [0.00132881],
#           ...,
#           [0.04247803],
#           [0.04479152],
#           [0.04258918]],
#
#          [[0.00843364],
#           [0.00863268],
#           [0.00953967],
#           ...,
#           [0.04465197],
#           [0.04720594],
#           [0.00180491]],
#
#          [[0.0945745 ],
#           [0.12310638],
#           [0.15316504],
#           ...,
#           [0.02636078],
#           [0.02628713],
#           [0.02671736]],
#
#          ...,
#
#          [[0.00261697],
#           [0.00429666],
#           [0.00528861],
#           ...,
#           [0.02439404],
#           [0.0186677 ],
#           [0.01447811]],
#
#          [[0.01063585],
#           [0.01215442],
#           [0.01393843],
#           ...,
#           [0.00716951],
#           [0.00646511],
#           [0.00508991]],
#
#          [[0.0099481 ],
#           [0.01280325],
#           [0.01470958],
#           ...,
#           [0.00779135],
#           [0.00702508],
#           [0.00562738]]], dtype=float32),
#   'spectral_centroid': array([[[0.43021879],
#           [0.35183347],
#           [0.34781837],
#           ...,
#           [0.52712466],
#           [0.55913132],
#           [0.57462391]],
#
#          [[0.43822888],
#           [0.43232722],
#           [0.44510553],
#           ...,
#           [0.62451555],
#           [0.61696158],
#           [0.40656783]],
#
#          [[0.64503138],
#           [0.62792118],
#           [0.66633629],
#           ...,
#           [0.49295281],
#           [0.50166412],
#           [0.4961109 ]],
#
#          ...,
#
#          [[0.33329476],
#           [0.31788902],
#           [0.31750112],
#           ...,
#           [0.26185072],
#           [0.27195403],
#           [0.28777192]],
#
#          [[0.28686683],
#           [0.27937374],
#           [0.2835901 ],
#           ...,
#           [0.29240491],
#           [0.29233926],
#           [0.28699176]],
#
#          [[0.27946243],
#           [0.26233429],
#           [0.24775679],
#           ...,
#           [0.28449501],
#           [0.29198551],
#           [0.29002803]]]),
#   'melspectrogram': array([[[0.24356848, 0.19709486, 0.19181323, ..., 0.14215577,
#            0.14264905, 0.16532534],
#           [0.40376735, 0.3655113 , 0.42287964, ..., 0.23766714,
#            0.1897651 , 0.1521129 ],
#           [0.45815992, 0.46074304, 0.4943219 , ..., 0.2976507 ,
#            0.25157702, 0.2118563 ],
#           ...,
#           [0.49117148, 0.43984422, 0.43819213, ..., 0.6310359 ,
#            0.56908995, 0.5044948 ],
#           [0.46418417, 0.4439577 , 0.45830843, ..., 0.6673047 ,
#            0.62528354, 0.5652833 ],
#           [0.4987093 , 0.456418  , 0.46511737, ..., 0.6581471 ,
#            0.6399298 , 0.5732062 ]],
#
#          [[0.4543748 , 0.4756736 , 0.4632044 , ..., 0.41978696,
#            0.3437417 , 0.3016634 ],
#           [0.45686582, 0.45135322, 0.46586612, ..., 0.41686812,
#            0.36826977, 0.29667157],
#           [0.45796975, 0.44600147, 0.44945693, ..., 0.42953232,
#            0.3780449 , 0.31478083],
#           ...,
#           [0.53641915, 0.46677327, 0.46015307, ..., 0.7154856 ,
#            0.7200803 , 0.60636497],
#           [0.51489085, 0.44360733, 0.45077553, ..., 0.54932797,
#            0.59599185, 0.46856165],
#           [0.50560594, 0.42767835, 0.43264443, ..., 0.3394151 ,
#            0.31403804, 0.25334805]],
#
#          [[0.4970015 , 0.4928741 , 0.47974336, ..., 0.78759706,
#            0.7498659 , 0.7231643 ],
#           [0.4755374 , 0.46717736, 0.4660268 , ..., 0.7653399 ,
#            0.7495806 , 0.694723  ],
#           [0.45806897, 0.47078794, 0.4709153 , ..., 0.8058598 ,
#            0.7909299 , 0.7564884 ],
#           ...,
#           [0.49385324, 0.44783697, 0.46114796, ..., 0.4956058 ,
#            0.46170318, 0.38592994],
#           [0.4859912 , 0.46393633, 0.47618708, ..., 0.55451417,
#            0.5702215 , 0.4863054 ],
#           [0.5273504 , 0.5001548 , 0.50836205, ..., 0.5773054 ,
#            0.60384905, 0.5157382 ]],
#
#          ...,
#
#          [[0.3514245 , 0.34866   , 0.32154053, ..., 0.15999717,
#            0.13954413, 0.17613167],
#           [0.50815594, 0.50543916, 0.5237822 , ..., 0.3366097 ,
#            0.32153517, 0.32495368],
#           [0.558628  , 0.5878562 , 0.6032868 , ..., 0.39959395,
#            0.38615382, 0.3934602 ],
#           ...,
#           [0.780533  , 0.6560871 , 0.6240686 , ..., 0.5234435 ,
#            0.49361798, 0.38953286],
#           [0.7499489 , 0.613906  , 0.59531116, ..., 0.5071019 ,
#            0.43975508, 0.3849932 ],
#           [0.7196118 , 0.5921148 , 0.565887  , ..., 0.4851054 ,
#            0.4135834 , 0.38994557]],
#
#          [[0.6109494 , 0.6206902 , 0.61200386, ..., 0.42749023,
#            0.41519445, 0.43781918],
#           [0.6411831 , 0.6318178 , 0.63249946, ..., 0.429544  ,
#            0.41518798, 0.42299882],
#           [0.6684967 , 0.6355276 , 0.63343793, ..., 0.44025874,
#            0.41929087, 0.43441528],
#           ...,
#           [0.6507423 , 0.61017406, 0.6335789 , ..., 0.3631066 ,
#            0.38515967, 0.42551026],
#           [0.61023897, 0.5893043 , 0.615956  , ..., 0.35835356,
#            0.4061381 , 0.42431673],
#           [0.5904546 , 0.578876  , 0.5727197 , ..., 0.3613688 ,
#            0.40224642, 0.40074635]],
#
#          [[0.6635772 , 0.62118745, 0.64088583, ..., 0.45560822,
#            0.39278215, 0.41715443],
#           [0.6625777 , 0.6242373 , 0.64697003, ..., 0.43134996,
#            0.39039868, 0.3984837 ],
#           [0.6775949 , 0.6223249 , 0.6149095 , ..., 0.4144279 ,
#            0.39025593, 0.40155146],
#           ...,
#           [0.6397346 , 0.613194  , 0.62155163, ..., 0.3954093 ,
#            0.39272565, 0.38059273],
#           [0.6048291 , 0.62069327, 0.62521505, ..., 0.39358556,
#            0.40497494, 0.38601157],
#           [0.5949067 , 0.5863329 , 0.590046  , ..., 0.3845084 ,
#            0.40410328, 0.38128677]]], dtype=float32),
#   'label': array([0, 0, 0, ..., 2, 2, 2])},
#  'val': {'mfcc': array([[[0.03438473, 0.5409663 , 0.49516892, ..., 0.47214267,
#            0.54059166, 0.31063035],
#           [0.156398  , 0.5936351 , 0.34219292, ..., 0.5281046 ,
#            0.4928256 , 0.45432433],
#           [0.27276182, 0.5529174 , 0.35612273, ..., 0.520854  ,
#            0.5686558 , 0.47363648],
#           ...,
#           [0.53652716, 0.533416  , 0.3665663 , ..., 0.36028466,
#            0.5355693 , 0.3084178 ],
#           [0.54577094, 0.54470825, 0.35483423, ..., 0.40590182,
#            0.4965055 , 0.34188586],
#           [0.5508863 , 0.53994864, 0.3564601 , ..., 0.43862337,
#            0.47689667, 0.32920602]],
#
#          [[0.41281384, 0.67141247, 0.65520215, ..., 0.37753204,
#            0.5337289 , 0.45304573],
#           [0.61477315, 0.7969459 , 0.4981349 , ..., 0.59867835,
#            0.59102464, 0.68530947],
#           [0.67084944, 0.77747846, 0.53579843, ..., 0.7273464 ,
#            0.61758906, 0.62314296],
#           ...,
#           [0.7601433 , 0.66117793, 0.5779958 , ..., 0.6609509 ,
#            0.68418646, 0.5143307 ],
#           [0.7423201 , 0.725596  , 0.5517128 , ..., 0.62154275,
#            0.6082248 , 0.5371979 ],
#           [0.74019575, 0.74327356, 0.53127474, ..., 0.54929096,
#            0.6353032 , 0.44752052]],
#
#          [[0.34304124, 0.7915419 , 0.598637  , ..., 0.38757032,
#            0.44805235, 0.3161977 ],
#           [0.59942603, 0.7608812 , 0.5384848 , ..., 0.53995186,
#            0.54124606, 0.5021793 ],
#           [0.65236187, 0.71998066, 0.5805178 , ..., 0.6230264 ,
#            0.60933435, 0.5061622 ],
#           ...,
#           [0.64055467, 0.7219373 , 0.6331161 , ..., 0.46207854,
#            0.5755408 , 0.49926198],
#           [0.6480728 , 0.74492353, 0.6308691 , ..., 0.47223875,
#            0.5534381 , 0.5032821 ],
#           [0.6469756 , 0.7327585 , 0.6370018 , ..., 0.5462244 ,
#            0.59276986, 0.4655675 ]],
#
#          ...,
#
#          [[0.74778503, 0.7209703 , 0.40612832, ..., 0.5918846 ,
#            0.6513869 , 0.5332755 ],
#           [0.7457434 , 0.7114381 , 0.39589864, ..., 0.6633295 ,
#            0.64677393, 0.5809252 ],
#           [0.7131096 , 0.6798183 , 0.44682613, ..., 0.6490638 ,
#            0.59542394, 0.5189707 ],
#           ...,
#           [0.69847393, 0.71101874, 0.5096783 , ..., 0.65995574,
#            0.56425035, 0.47228584],
#           [0.7035257 , 0.7315591 , 0.48594677, ..., 0.60101634,
#            0.5738688 , 0.4946204 ],
#           [0.7055297 , 0.70799476, 0.46933103, ..., 0.49718615,
#            0.6547618 , 0.5425098 ]],
#
#          [[0.2908501 , 0.7189217 , 0.4210609 , ..., 0.34758058,
#            0.3391745 , 0.6465228 ],
#           [0.4968081 , 0.7353206 , 0.38010958, ..., 0.48473963,
#            0.43648642, 0.6562871 ],
#           [0.5429973 , 0.701936  , 0.42638344, ..., 0.54729   ,
#            0.49788263, 0.548462  ],
#           ...,
#           [0.53224087, 0.7414206 , 0.5025408 , ..., 0.48724097,
#            0.5497386 , 0.5259569 ],
#           [0.5396178 , 0.76640326, 0.49725193, ..., 0.4311356 ,
#            0.49491715, 0.4492576 ],
#           [0.5452116 , 0.76659644, 0.5120657 , ..., 0.43508086,
#            0.5092749 , 0.39250734]],
#
#          [[0.35528255, 0.5790772 , 0.56944543, ..., 0.45860705,
#            0.5517407 , 0.4264643 ],
#           [0.41365486, 0.7147431 , 0.52766097, ..., 0.6032357 ,
#            0.5893611 , 0.46952924],
#           [0.47077656, 0.7510897 , 0.5992972 , ..., 0.6085386 ,
#            0.64177614, 0.5471046 ],
#           ...,
#           [0.5042781 , 0.92240477, 0.73465073, ..., 0.42743266,
#            0.6194316 , 0.4052591 ],
#           [0.4641732 , 0.8738564 , 0.76589763, ..., 0.391493  ,
#            0.59199184, 0.43708456],
#           [0.44472247, 0.78773165, 0.7542114 , ..., 0.35484043,
#            0.6443579 , 0.5087153 ]]], dtype=float32),
#   'chroma': array([[[0.7646548 , 0.6593877 , 1.        , ..., 0.7147495 ,
#            0.7372933 , 0.5769873 ],
#           [1.        , 0.9776191 , 0.7299414 , ..., 0.20515485,
#            0.25375524, 0.4779138 ],
#           [1.0000001 , 0.9596754 , 0.82782555, ..., 0.5209368 ,
#            0.5438989 , 0.7936685 ],
#           ...,
#           [0.16291276, 0.14363815, 0.17468452, ..., 0.20659253,
#            0.23780039, 0.16433807],
#           [0.2022269 , 0.16572295, 0.19001824, ..., 0.13031365,
#            0.15897165, 0.1746402 ],
#           [0.14170276, 0.14602776, 0.20580296, ..., 0.14098944,
#            0.10827189, 0.16469386]],
#
#          [[0.8470788 , 1.        , 0.9584479 , ..., 0.5541986 ,
#            0.60589206, 0.7429723 ],
#           [0.73648524, 0.7767946 , 0.95988184, ..., 0.79856175,
#            0.68244904, 0.71300286],
#           [0.7221496 , 0.60955745, 0.710658  , ..., 0.96438843,
#            0.8706302 , 0.85046685],
#           ...,
#           [0.67400604, 0.63110614, 0.8122476 , ..., 0.7028029 ,
#            0.6089538 , 0.49003288],
#           [0.60263884, 0.40273157, 0.5151347 , ..., 0.6125045 ,
#            0.5007707 , 0.49264178],
#           [0.75435615, 0.35312733, 0.3339029 , ..., 0.50700265,
#            0.6434145 , 0.6333055 ]],
#
#          [[0.21815085, 0.24457382, 0.286702  , ..., 1.        ,
#            0.816597  , 0.49451017],
#           [0.14038104, 0.203232  , 0.36619595, ..., 0.84946656,
#            0.42996433, 0.30546373],
#           [0.26832697, 0.38324547, 0.59156364, ..., 0.85665125,
#            0.5147319 , 0.47055075],
#           ...,
#           [0.213635  , 0.22972344, 0.38984865, ..., 0.32367027,
#            0.3919436 , 0.24894355],
#           [0.2586603 , 0.286459  , 0.35752532, ..., 0.21823199,
#            0.23316927, 0.2673995 ],
#           [0.43330297, 0.5084328 , 0.33426496, ..., 0.20642486,
#            0.11039441, 0.2744891 ]],
#
#          ...,
#
#          [[0.7150665 , 0.6856525 , 0.72564256, ..., 0.5490038 ,
#            0.9175502 , 0.7872274 ],
#           [0.78217745, 0.7306153 , 0.73654264, ..., 0.70680183,
#            1.        , 0.94257677],
#           [0.79001683, 0.87175167, 0.8301966 , ..., 0.9434979 ,
#            0.9721074 , 1.        ],
#           ...,
#           [0.72140193, 0.6670173 , 0.6496824 , ..., 0.7078034 ,
#            0.6309728 , 0.811846  ],
#           [0.54813915, 0.5793646 , 0.7561379 , ..., 0.51952004,
#            0.6629236 , 0.94050825],
#           [0.35745636, 0.37443233, 0.60613006, ..., 0.34727755,
#            0.6361132 , 0.60757905]],
#
#          [[0.12920445, 0.24731807, 0.5391454 , ..., 0.50280094,
#            0.3234261 , 0.10417072],
#           [0.3272184 , 0.37468094, 0.49829358, ..., 0.5354412 ,
#            0.5043049 , 0.2658642 ],
#           [0.63557154, 0.5032978 , 0.67034566, ..., 0.7182885 ,
#            0.78906685, 0.6150083 ],
#           ...,
#           [0.5055485 , 0.62709343, 0.45350704, ..., 0.5924449 ,
#            1.        , 0.9164598 ],
#           [0.20694374, 0.32452282, 0.28471586, ..., 0.48183307,
#            1.0000001 , 0.49888673],
#           [0.18903567, 0.2551217 , 0.31590292, ..., 0.54448265,
#            1.        , 0.45031857]],
#
#          [[0.6099855 , 0.52973676, 0.4314404 , ..., 0.88568044,
#            0.8219632 , 0.76208293],
#           [0.65957516, 0.6353318 , 0.5847457 , ..., 0.93063444,
#            0.7951908 , 0.7416253 ],
#           [0.5383141 , 0.57087344, 0.45381156, ..., 1.        ,
#            0.63993496, 0.60679996],
#           ...,
#           [0.55252045, 0.72652733, 1.        , ..., 0.9905569 ,
#            0.9756369 , 0.8603448 ],
#           [0.90918326, 0.7175546 , 0.5232939 , ..., 0.448994  ,
#            0.69994086, 1.        ],
#           [0.7308196 , 0.539653  , 0.53606564, ..., 0.771013  ,
#            0.8287663 , 0.8902378 ]]], dtype=float32),
#   'rms': array([[[6.8254682e-05],
#           [2.1939805e-04],
#           [4.2839046e-04],
#           ...,
#           [5.1447935e-03],
#           [4.9803653e-03],
#           [4.1735838e-03]],
#
#          [[4.2074233e-02],
#           [1.0621951e-01],
#           [1.3893212e-01],
#           ...,
#           [3.8427278e-02],
#           [3.5975665e-02],
#           [2.7774476e-02]],
#
#          [[8.2113249e-03],
#           [1.2631006e-02],
#           [1.4442490e-02],
#           ...,
#           [1.4388610e-02],
#           [1.3500358e-02],
#           [1.0931141e-02]],
#
#          ...,
#
#          [[1.6571838e-02],
#           [1.7655212e-02],
#           [1.8854775e-02],
#           ...,
#           [1.8490607e-02],
#           [1.7254055e-02],
#           [1.4439104e-02]],
#
#          [[2.1392710e-03],
#           [3.3970729e-03],
#           [3.9917743e-03],
#           ...,
#           [5.4435227e-03],
#           [4.9514584e-03],
#           [4.2695017e-03]],
#
#          [[3.7546651e-03],
#           [4.8651174e-03],
#           [2.3346646e-02],
#           ...,
#           [5.7112973e-02],
#           [3.4126684e-02],
#           [2.2383185e-02]]], dtype=float32),
#   'spectral_centroid': array([[[0.54656741],
#           [0.37865166],
#           [0.39853728],
#           ...,
#           [0.40867808],
#           [0.42846209],
#           [0.40883235]],
#
#          [[0.16096673],
#           [0.09768898],
#           [0.09134934],
#           ...,
#           [0.36211678],
#           [0.27002135],
#           [0.2145442 ]],
#
#          [[0.1888723 ],
#           [0.21536217],
#           [0.2383076 ],
#           ...,
#           [0.26032311],
#           [0.25610704],
#           [0.25796355]],
#
#          ...,
#
#          [[0.27016079],
#           [0.2702707 ],
#           [0.28097238],
#           ...,
#           [0.26516819],
#           [0.26124954],
#           [0.27352084]],
#
#          [[0.26946555],
#           [0.24700455],
#           [0.25418389],
#           ...,
#           [0.22423094],
#           [0.21413   ],
#           [0.20466403]],
#
#          [[0.2321004 ],
#           [0.15440951],
#           [0.11527369],
#           ...,
#           [0.03329018],
#           [0.03617943],
#           [0.02736049]]]),
#   'melspectrogram': array([[[0.08103681, 0.06281257, 0.04899508, ..., 0.0126223 ,
#            0.01625842, 0.02704358],
#           [0.16806442, 0.15293223, 0.20864499, ..., 0.06657875,
#            0.05336493, 0.05504674],
#           [0.2551819 , 0.26873422, 0.27525806, ..., 0.1596486 ,
#            0.15128297, 0.15508932],
#           ...,
#           [0.43946368, 0.43952537, 0.46801436, ..., 0.3903185 ,
#            0.38137046, 0.37939993],
#           [0.4319826 , 0.45017073, 0.4815686 , ..., 0.39779127,
#            0.3901048 , 0.37982506],
#           [0.43024457, 0.43739873, 0.4742092 , ..., 0.37816513,
#            0.39697692, 0.37451804]],
#
#          [[0.53607374, 0.4760657 , 0.40242267, ..., 0.18058312,
#            0.15626639, 0.16649419],
#           [0.7286438 , 0.675462  , 0.6663515 , ..., 0.34260413,
#            0.3336767 , 0.32324892],
#           [0.79932505, 0.74715483, 0.7510541 , ..., 0.4049864 ,
#            0.38409263, 0.38859048],
#           ...,
#           [0.7754409 , 0.7459701 , 0.7681694 , ..., 0.6363764 ,
#            0.60821825, 0.5042228 ],
#           [0.75374657, 0.74040216, 0.7729754 , ..., 0.53729707,
#            0.54528797, 0.48106566],
#           [0.74752945, 0.72839457, 0.7563726 , ..., 0.47744092,
#            0.50094575, 0.43916273]],
#
#          [[0.47513065, 0.4804721 , 0.48405796, ..., 0.14679098,
#            0.14400697, 0.17451447],
#           [0.6261809 , 0.6455195 , 0.6954016 , ..., 0.36581507,
#            0.36516973, 0.38317612],
#           [0.6764163 , 0.70619637, 0.72770447, ..., 0.44338867,
#            0.44211918, 0.4616505 ],
#           ...,
#           [0.74071205, 0.7133362 , 0.7141671 , ..., 0.43368593,
#            0.43644074, 0.4478911 ],
#           [0.71385306, 0.7088312 , 0.7003579 , ..., 0.41723558,
#            0.44375277, 0.45729327],
#           [0.70436656, 0.6966621 , 0.66690505, ..., 0.41670942,
#            0.44353658, 0.44696856]],
#
#          ...,
#
#          [[0.65482044, 0.6923055 , 0.6991818 , ..., 0.4506169 ,
#            0.45181042, 0.45589545],
#           [0.6723259 , 0.6762383 , 0.70000386, ..., 0.4615677 ,
#            0.44838136, 0.4410908 ],
#           [0.6718765 , 0.67232054, 0.69023204, ..., 0.47749022,
#            0.44604304, 0.4478292 ],
#           ...,
#           [0.741146  , 0.68560064, 0.716449  , ..., 0.4458004 ,
#            0.45347685, 0.4565132 ],
#           [0.71345043, 0.6707683 , 0.7173933 , ..., 0.43744653,
#            0.45205736, 0.45527977],
#           [0.6896811 , 0.6387804 , 0.67879313, ..., 0.43941015,
#            0.4580866 , 0.44885725]],
#
#          [[0.3551227 , 0.36077967, 0.3018945 , ..., 0.11696076,
#            0.10553074, 0.09938878],
#           [0.48231995, 0.51379275, 0.4967989 , ..., 0.267012  ,
#            0.25197464, 0.23644072],
#           [0.52727455, 0.5874976 , 0.5684792 , ..., 0.32170337,
#            0.29986417, 0.29666954],
#           ...,
#           [0.56999373, 0.59020483, 0.63190985, ..., 0.31018773,
#            0.30086726, 0.2727328 ],
#           [0.566043  , 0.59311724, 0.6545093 , ..., 0.30493787,
#            0.30859476, 0.27837676],
#           [0.5720775 , 0.58068264, 0.6326221 , ..., 0.3074007 ,
#            0.31826603, 0.28362423]],
#
#          [[0.44032022, 0.32846272, 0.27843177, ..., 0.20607656,
#            0.20754921, 0.23159951],
#           [0.5932946 , 0.4400355 , 0.41283402, ..., 0.21269244,
#            0.19590807, 0.20477784],
#           [0.6576391 , 0.61296743, 0.5495226 , ..., 0.26351595,
#            0.24070883, 0.24391842],
#           ...,
#           [0.8416464 , 0.7804614 , 0.7176689 , ..., 0.20745748,
#            0.19683123, 0.18305326],
#           [0.76600313, 0.70242727, 0.63311094, ..., 0.20600492,
#            0.20316136, 0.18749917],
#           [0.7492351 , 0.6074891 , 0.4814969 , ..., 0.20228267,
#            0.2117855 , 0.20504546]]], dtype=float32),
#   'label': array([0, 0, 1, ..., 2, 1, 2])}}

# %%
with open('/content/drive/MyDrive/Projects/train_val_features_pkl/train_val_8_sec_non_audio_features.pkl', 'rb') as file:
  non_audio_df = pickle.load(file)

# %%
non_audio_df
# Out:
# {'train': {'type': array(['blank', 'blank', 'blank', ..., 'blank', 'blank', 'blank'],
#         dtype='<U5'),
#   'continent': array(['AFRICA', 'AFRICA', 'AFRICA', ..., 'EUROPE', 'EUROPE', 'EUROPE'],
#         dtype='<U8'),
#   'rating': array([5., 5., 5., ..., 5., 5., 5.]),
#   'label': array([0, 0, 0, ..., 2, 2, 2])},
#  'val': {'type': array(['song', 'call', 'call', ..., 'blank', 'call', 'call'], dtype='<U5'),
#   'continent': array(['EUROPE', 'EUROPE', 'EUROPE', ..., 'EUROPE', 'EUROPE', 'EUROPE'],
#         dtype='<U8'),
#   'rating': array([3.5, 5. , 4. , ..., 5. , 3. , 3. ]),
#   'label': array([0, 0, 1, ..., 2, 1, 2])}}

# %% [markdown]
# ## confirm the audio features and non_audio features labels line-up

# %%
assert np.array_equal(audio_df['train']['label'], non_audio_df['train']['label'])

# %%
assert np.array_equal(audio_df['val']['label'], non_audio_df['val']['label'])

# %% [markdown]
# # Shuffle the data

# %%
def shuffle_data(audio_features, non_audio_features):
  input_len = len(audio_features['label'])
  input_indices = np.random.permutation(input_len)
  audio_features = {key: np.array([audio_features[key][i] for i in input_indices]) for key in audio_features}
  non_audio_features = {key: np.array([non_audio_features[key][i] for i in input_indices]) for key in non_audio_features}

  return audio_features, non_audio_features

# %%
audio_df['train'], non_audio_df['train'] = shuffle_data(audio_df['train'], non_audio_df['train'])

# %%
for key in audio_df['train'].keys():
  display(key)
  display(audio_df['train'][key].shape)
  display(audio_df['train'][key][:5])
# Out:
# 'mfcc'
# (4763, 251, 20)
# array([[[0.6831663 , 0.5929136 , 0.53691167, ..., 0.4454615 ,
#          0.29569203, 0.5300293 ],
#         [0.68208945, 0.571792  , 0.504587  , ..., 0.6371889 ,
#          0.4049796 , 0.5381129 ],
#         [0.6526171 , 0.5514721 , 0.55114627, ..., 0.7763733 ,
#          0.42884982, 0.5741422 ],
#         ...,
#         [0.63545215, 0.5167248 , 0.72968334, ..., 0.66762096,
#          0.44959253, 0.7061733 ],
#         [0.6489433 , 0.5131046 , 0.72684944, ..., 0.5804359 ,
#          0.4500671 , 0.59251463],
#         [0.6516156 , 0.51605314, 0.67196417, ..., 0.56867266,
#          0.43407208, 0.41794068]],
#
#        [[0.77090144, 0.5633397 , 0.44750988, ..., 0.36372244,
#          0.47935772, 0.6066712 ],
#         [0.7687094 , 0.5571646 , 0.4361108 , ..., 0.6111939 ,
#          0.5475237 , 0.6708364 ],
#         [0.73958874, 0.5358136 , 0.49239874, ..., 0.6544896 ,
#          0.58571094, 0.6061154 ],
#         ...,
#         [0.6968399 , 0.5428623 , 0.58974713, ..., 0.32365328,
#          0.61003953, 0.6470494 ],
#         [0.69118834, 0.5630867 , 0.5994376 , ..., 0.2964441 ,
#          0.5556493 , 0.48460883],
#         [0.68436086, 0.5415647 , 0.59406155, ..., 0.4028023 ,
#          0.50401896, 0.41306552]],
#
#        [[0.75341856, 0.3343674 , 0.44527382, ..., 0.45480546,
#          0.8055067 , 0.43145433],
#         [0.79357547, 0.26852542, 0.4253092 , ..., 0.6196686 ,
#          0.666156  , 0.5930237 ],
#         [0.78716105, 0.23256648, 0.47526145, ..., 0.7114021 ,
#          0.63948256, 0.58878636],
#         ...,
#         [0.50628686, 0.6297636 , 0.5556158 , ..., 0.4758177 ,
#          0.5322715 , 0.56162953],
#         [0.5116738 , 0.63981414, 0.573615  , ..., 0.3825898 ,
#          0.47569013, 0.5742805 ],
#         [0.51984173, 0.63319826, 0.6013931 , ..., 0.42795542,
#          0.56125164, 0.63937485]],
#
#        [[0.77815247, 0.78913784, 0.54649884, ..., 0.4186842 ,
#          0.42803124, 0.47073227],
#         [0.7603397 , 0.75913274, 0.49624   , ..., 0.5382505 ,
#          0.4796446 , 0.5310641 ],
#         [0.724319  , 0.71115106, 0.5179998 , ..., 0.5704091 ,
#          0.5232506 , 0.5242068 ],
#         ...,
#         [0.5818194 , 0.65195477, 0.5130858 , ..., 0.40521735,
#          0.5938205 , 0.39945456],
#         [0.5872052 , 0.6625008 , 0.51927817, ..., 0.35622582,
#          0.55382067, 0.25230777],
#         [0.5845252 , 0.65390426, 0.54636157, ..., 0.3938933 ,
#          0.5514503 , 0.24526758]],
#
#        [[0.15153575, 0.5466083 , 0.51802444, ..., 0.4321458 ,
#          0.53040135, 0.40444314],
#         [0.12490249, 0.566639  , 0.5162608 , ..., 0.5980461 ,
#          0.60843736, 0.5154121 ],
#         [0.29210263, 0.64732665, 0.51782364, ..., 0.68677974,
#          0.5515006 , 0.33306482],
#         ...,
#         [0.38548172, 0.7292214 , 0.52071804, ..., 0.49920958,
#          0.672445  , 0.57410467],
#         [0.39478862, 0.74041134, 0.53894484, ..., 0.3807772 ,
#          0.59265995, 0.51604795],
#         [0.39974457, 0.7249568 , 0.54164463, ..., 0.30138442,
#          0.6047769 , 0.41233823]]], dtype=float32)
# 'chroma'
# (4763, 251, 12)
# array([[[0.47692588, 0.87671316, 1.        , ..., 0.4342559 ,
#          0.97700906, 0.28842098],
#         [0.6350445 , 1.        , 0.5305065 , ..., 0.11924674,
#          0.26881692, 0.11062346],
#         [0.34903747, 1.0000001 , 0.90807927, ..., 0.03223189,
#          0.03605267, 0.03657101],
#         ...,
#         [0.03101421, 0.16565822, 0.55594707, ..., 0.01315344,
#          0.00534319, 0.00633229],
#         [0.09727717, 0.23937108, 0.24316292, ..., 0.02012673,
#          0.00860553, 0.0137417 ],
#         [0.31741247, 1.        , 0.33456075, ..., 0.0220832 ,
#          0.01636278, 0.02791071]],
#
#        [[0.27409467, 0.23424813, 0.24876799, ..., 1.        ,
#          0.62414324, 0.4321466 ],
#         [0.48698992, 0.5710593 , 0.75497663, ..., 1.        ,
#          0.80624527, 0.68306273],
#         [0.6453987 , 0.82221717, 1.        , ..., 0.6908648 ,
#          0.62402076, 0.5532968 ],
#         ...,
#         [0.47138986, 0.21097618, 0.21093288, ..., 0.57520777,
#          0.6139954 , 1.        ],
#         [0.61509496, 0.32644576, 0.29058015, ..., 0.55270886,
#          0.6378856 , 1.        ],
#         [0.75287825, 0.7548613 , 0.7465096 , ..., 0.99999994,
#          0.9822643 , 0.73957705]],
#
#        [[0.6473609 , 0.32122087, 0.09311338, ..., 0.5228693 ,
#          0.6137004 , 0.64900815],
#         [1.        , 0.6170989 , 0.10078928, ..., 0.941146  ,
#          0.6585682 , 0.9152451 ],
#         [0.68767303, 0.41475117, 0.0544053 , ..., 1.        ,
#          0.38955617, 0.5324785 ],
#         ...,
#         [0.43958044, 0.46449098, 0.5393201 , ..., 0.47418267,
#          0.4474413 , 0.442546  ],
#         [0.18962175, 0.35383528, 0.36511222, ..., 0.23289016,
#          0.20419382, 0.18677777],
#         [0.219772  , 0.3827583 , 0.40660453, ..., 0.31854522,
#          0.25067532, 0.21063809]],
#
#        [[0.55364376, 0.469726  , 0.21206757, ..., 0.7907936 ,
#          0.99999994, 0.66811746],
#         [1.        , 0.50652635, 0.24013658, ..., 0.6937658 ,
#          0.8151226 , 0.83488286],
#         [0.8630418 , 0.33088174, 0.18911253, ..., 0.42740452,
#          0.5069134 , 1.        ],
#         ...,
#         [0.9862752 , 0.5688267 , 0.7190333 , ..., 0.67919576,
#          0.69946915, 0.88232464],
#         [1.        , 0.5812832 , 0.5877802 , ..., 0.4666331 ,
#          0.58081156, 0.83355695],
#         [0.8500219 , 0.72210264, 0.70480967, ..., 0.6219738 ,
#          0.6542417 , 0.7833536 ]],
#
#        [[0.594837  , 0.577557  , 0.5791272 , ..., 0.7696011 ,
#          0.78107345, 0.6126079 ],
#         [0.56337786, 0.7940695 , 0.78673   , ..., 0.57081044,
#          0.4268613 , 0.4482161 ],
#         [0.87292826, 1.0000001 , 0.91371477, ..., 0.502563  ,
#          0.5315244 , 0.78021264],
#         ...,
#         [0.33969095, 0.31387913, 0.48041037, ..., 0.575338  ,
#          0.6543688 , 0.5233354 ],
#         [0.51678985, 0.49962267, 0.825708  , ..., 0.9263355 ,
#          0.8919658 , 0.69797766],
#         [0.7671784 , 0.6943092 , 0.74897504, ..., 0.99999994,
#          0.96849424, 0.7953998 ]]], dtype=float32)
# 'rms'
# (4763, 251, 1)
# array([[[1.7665230e-02],
#         [2.3952743e-02],
#         [2.8676100e-02],
#         ...,
#         [5.1343754e-02],
#         [4.6676006e-02],
#         [3.2581639e-02]],
#
#        [[2.4950773e-02],
#         [3.0088762e-02],
#         [3.1617116e-02],
#         ...,
#         [1.8561905e-02],
#         [1.7588610e-02],
#         [1.3796791e-02]],
#
#        [[2.0626543e-01],
#         [2.8964704e-01],
#         [3.5658410e-01],
#         ...,
#         [7.1079126e-03],
#         [5.3204410e-03],
#         [3.7989761e-03]],
#
#        [[3.4948051e-02],
#         [3.6011666e-02],
#         [3.6903970e-02],
#         ...,
#         [5.7316641e-03],
#         [5.3087655e-03],
#         [4.4198381e-03]],
#
#        [[1.4060759e-05],
#         [4.1964438e-04],
#         [1.9150038e-03],
#         ...,
#         [1.4259657e-03],
#         [1.3758448e-03],
#         [1.0501563e-03]]], dtype=float32)
# 'spectral_centroid'
# (4763, 251, 1)
# array([[[0.48459963],
#         [0.51239413],
#         [0.55377329],
#         ...,
#         [0.6423274 ],
#         [0.64443749],
#         [0.60034007]],
#
#        [[0.46375164],
#         [0.44663405],
#         [0.45759842],
#         ...,
#         [0.48608021],
#         [0.48488517],
#         [0.48098449]],
#
#        [[0.5092699 ],
#         [0.54444934],
#         [0.57766578],
#         ...,
#         [0.33065641],
#         [0.34356091],
#         [0.33158849]],
#
#        [[0.18557752],
#         [0.20123776],
#         [0.22541543],
#         ...,
#         [0.33292593],
#         [0.35013368],
#         [0.36042991]],
#
#        [[0.55450094],
#         [0.40953158],
#         [0.28295752],
#         ...,
#         [0.20988938],
#         [0.22556058],
#         [0.23735941]]])
# 'melspectrogram'
# (4763, 251, 20)
# array([[[0.62504613, 0.60645986, 0.55630255, ..., 0.598813  ,
#          0.474999  , 0.4715277 ],
#         [0.628418  , 0.58631325, 0.5516411 , ..., 0.6048072 ,
#          0.47963944, 0.4671735 ],
#         [0.6596749 , 0.5732873 , 0.55097115, ..., 0.67303634,
#          0.463417  , 0.47695476],
#         ...,
#         [0.712374  , 0.59185183, 0.55484056, ..., 0.75160396,
#          0.6198435 , 0.55520296],
#         [0.68342906, 0.57171226, 0.54648113, ..., 0.71480674,
#          0.6294566 , 0.57042193],
#         [0.64713377, 0.5542209 , 0.54172647, ..., 0.6617803 ,
#          0.57976997, 0.50779307]],
#
#        [[0.6276749 , 0.6495252 , 0.6167956 , ..., 0.6263487 ,
#          0.5740843 , 0.57538855],
#         [0.6675365 , 0.6607009 , 0.6294015 , ..., 0.6249488 ,
#          0.5805205 , 0.5679474 ],
#         [0.69629663, 0.6661577 , 0.6244748 , ..., 0.64381206,
#          0.58438814, 0.5800264 ],
#         ...,
#         [0.689269  , 0.6567782 , 0.6295051 , ..., 0.55744636,
#          0.5672254 , 0.5486362 ],
#         [0.6579228 , 0.65557975, 0.62330574, ..., 0.5359539 ,
#          0.57750237, 0.5483819 ],
#         [0.6604338 , 0.6272168 , 0.58124244, ..., 0.5295118 ,
#          0.57466125, 0.5391605 ]],
#
#        [[0.6547057 , 0.4890929 , 0.48875248, ..., 0.64923096,
#          0.65175873, 0.5598721 ],
#         [0.69134575, 0.45239294, 0.48866907, ..., 0.7360047 ,
#          0.7700283 , 0.6687712 ],
#         [0.6810348 , 0.4499316 , 0.47648907, ..., 0.8036488 ,
#          0.8175701 , 0.75516135],
#         ...,
#         [0.65228784, 0.46354097, 0.50431454, ..., 0.3514771 ,
#          0.35303366, 0.35189188],
#         [0.61035943, 0.46492913, 0.5054115 , ..., 0.34234983,
#          0.36655086, 0.35696027],
#         [0.6241821 , 0.48239264, 0.48452348, ..., 0.3344254 ,
#          0.36640194, 0.36309287]],
#
#        [[0.7677084 , 0.8036073 , 0.74761283, ..., 0.4768275 ,
#          0.4609766 , 0.48903015],
#         [0.7530221 , 0.79878724, 0.75979984, ..., 0.4697971 ,
#          0.45818445, 0.47214708],
#         [0.73746777, 0.8009938 , 0.7340217 , ..., 0.4918657 ,
#          0.4587351 , 0.4782421 ],
#         ...,
#         [0.66164035, 0.5936936 , 0.5687002 , ..., 0.40411425,
#          0.36391917, 0.35279635],
#         [0.6474892 , 0.5887425 , 0.5589019 , ..., 0.43953937,
#          0.41091955, 0.34301245],
#         [0.6379907 , 0.57135606, 0.5423058 , ..., 0.47460693,
#          0.44990078, 0.32898217]],
#
#        [[0.13117987, 0.06514704, 0.02784628, ..., 0.00457567,
#          0.02040786, 0.02267998],
#         [0.30833557, 0.12128431, 0.10073024, ..., 0.03124928,
#          0.01860189, 0.01614904],
#         [0.48783097, 0.3533489 , 0.3252465 , ..., 0.17791438,
#          0.10056645, 0.08353388],
#         ...,
#         [0.5771314 , 0.46856335, 0.46924126, ..., 0.18399256,
#          0.15563166, 0.14496171],
#         [0.55527997, 0.45724255, 0.45804065, ..., 0.2057358 ,
#          0.18894494, 0.16827178],
#         [0.55344844, 0.42404348, 0.40799993, ..., 0.21398652,
#          0.2055986 , 0.17494464]]], dtype=float32)
# 'label'
# (4763,)
# array([1, 0, 0, 0, 0])

# %%
for key in non_audio_df['train'].keys():
  display(key)
  display(non_audio_df['train'][key].shape)
  display(non_audio_df['train'][key][:5])
# Out:
# 'type'
# (4763,)
# array(['song', 'song', 'both', 'song', 'call'], dtype='<U5')
# 'continent'
# (4763,)
# array(['EUROPE', 'AMERICAS', 'EUROPE', 'EUROPE', 'ASIA'], dtype='<U8')
# 'rating'
# (4763,)
# array([4.5, 3. , 5. , 4.5, 4. ])
# 'label'
# (4763,)
# array([1, 0, 0, 0, 0])

# %%
audio_df['val'], non_audio_df['val'] = shuffle_data(audio_df['val'], non_audio_df['val'])

# %%
for key in audio_df['val'].keys():
  display(key)
  display(audio_df['val'][key].shape)
  display(audio_df['val'][key][:5])
# Out:
# 'mfcc'
# (2430, 251, 20)
# array([[[0.60736156, 0.5236882 , 0.50165933, ..., 0.49467102,
#          0.5521229 , 0.35984367],
#         [0.60613585, 0.5302393 , 0.44283968, ..., 0.66058874,
#          0.6189791 , 0.40108734],
#         [0.5731026 , 0.5249975 , 0.49937668, ..., 0.66736054,
#          0.6310194 , 0.42959955],
#         ...,
#         [0.5648463 , 0.53384393, 0.53603375, ..., 0.56641376,
#          0.47962302, 0.43652374],
#         [0.58220553, 0.545521  , 0.51468575, ..., 0.5645658 ,
#          0.44923827, 0.4128548 ],
#         [0.5890244 , 0.51676226, 0.52040446, ..., 0.5095955 ,
#          0.4431579 , 0.4529477 ]],
#
#        [[0.04757321, 0.5533783 , 0.5236086 , ..., 0.41997758,
#          0.55591893, 0.47346288],
#         [0.02094185, 0.5375777 , 0.4808089 , ..., 0.5422347 ,
#          0.55688024, 0.54338837],
#         [0.19114172, 0.47221273, 0.34016225, ..., 0.49580705,
#          0.63151795, 0.43581176],
#         ...,
#         [0.46464425, 0.49159396, 0.36009547, ..., 0.47423568,
#          0.55938774, 0.42548728],
#         [0.4679255 , 0.50985813, 0.3303873 , ..., 0.4413073 ,
#          0.4770635 , 0.40889534],
#         [0.48512626, 0.50881296, 0.33999783, ..., 0.37617114,
#          0.44166297, 0.33910498]],
#
#        [[0.7047834 , 0.7912003 , 0.5833197 , ..., 0.5135992 ,
#          0.48871115, 0.42061213],
#         [0.7113026 , 0.7752712 , 0.54398525, ..., 0.6144946 ,
#          0.55816066, 0.49556312],
#         [0.6146671 , 0.74740255, 0.6067238 , ..., 0.66270924,
#          0.62072307, 0.5242381 ],
#         ...,
#         [0.62319624, 0.71127313, 0.67235225, ..., 0.5618697 ,
#          0.73649263, 0.624208  ],
#         [0.625559  , 0.7297457 , 0.6860897 , ..., 0.525677  ,
#          0.64584386, 0.5435302 ],
#         [0.6283432 , 0.73358506, 0.69936126, ..., 0.4977395 ,
#          0.7105956 , 0.5438176 ]],
#
#        [[0.7946644 , 0.8753416 , 0.63243586, ..., 0.4036259 ,
#          0.44603762, 0.4607045 ],
#         [0.77339435, 0.86543465, 0.55858976, ..., 0.5886641 ,
#          0.55961704, 0.53485996],
#         [0.7339501 , 0.8169132 , 0.5948589 , ..., 0.63718176,
#          0.6337291 , 0.5668042 ],
#         ...,
#         [0.7127957 , 0.84023964, 0.6756858 , ..., 0.55100715,
#          0.57462615, 0.5300465 ],
#         [0.7148092 , 0.8633132 , 0.6941942 , ..., 0.5634569 ,
#          0.5794892 , 0.52998817],
#         [0.73019046, 0.85398734, 0.69305056, ..., 0.6048712 ,
#          0.70765066, 0.5248102 ]],
#
#        [[0.6876706 , 0.743718  , 0.40120763, ..., 0.52640134,
#          0.4579593 , 0.47150993],
#         [0.6825739 , 0.7206344 , 0.38432518, ..., 0.64192957,
#          0.5363703 , 0.5127195 ],
#         [0.652406  , 0.68960124, 0.44621205, ..., 0.65422964,
#          0.57152116, 0.48942578],
#         ...,
#         [0.65943277, 0.69912153, 0.490319  , ..., 0.55129004,
#          0.5502463 , 0.5014594 ],
#         [0.663025  , 0.71327627, 0.46733463, ..., 0.48837385,
#          0.530483  , 0.45136374],
#         [0.66588736, 0.69902134, 0.4576707 , ..., 0.4220122 ,
#          0.6461036 , 0.4147984 ]]], dtype=float32)
# 'chroma'
# (2430, 251, 12)
# array([[[1.        , 0.8785356 , 0.22204152, ..., 0.3311117 ,
#          0.32635486, 0.3102124 ],
#         [0.968414  , 1.        , 0.29680362, ..., 0.25711238,
#          0.28643575, 0.40929344],
#         [1.0000001 , 0.9937924 , 0.5555225 , ..., 0.5368786 ,
#          0.46743223, 0.8375584 ],
#         ...,
#         [0.14016698, 0.22006738, 0.221937  , ..., 1.        ,
#          0.6898149 , 0.2052103 ],
#         [0.11222105, 0.17757256, 0.22568592, ..., 0.7996965 ,
#          0.39905998, 0.15756844],
#         [0.12615055, 0.16981886, 0.2535396 , ..., 0.7312468 ,
#          0.3652335 , 0.16882361]],
#
#        [[0.616698  , 0.6783533 , 0.873255  , ..., 1.        ,
#          0.97777915, 0.6717883 ],
#         [0.5484498 , 0.5976579 , 0.6948002 , ..., 1.        ,
#          0.9545332 , 0.61943966],
#         [0.4112646 , 0.8613884 , 1.        , ..., 0.56730384,
#          0.67591417, 0.50784737],
#         ...,
#         [0.7673054 , 0.8260773 , 0.9524818 , ..., 0.62916636,
#          0.7445956 , 0.60917664],
#         [0.68263865, 0.8103214 , 1.        , ..., 0.56290257,
#          0.74416566, 0.79829204],
#         [0.53647363, 0.5881738 , 0.78092206, ..., 0.44969562,
#          0.5899433 , 0.83311045]],
#
#        [[0.93048626, 1.        , 0.9524931 , ..., 0.6720866 ,
#          0.7376877 , 0.8596353 ],
#         [0.72303075, 0.9187606 , 1.        , ..., 0.8284834 ,
#          0.7660718 , 0.7136997 ],
#         [0.545064  , 0.44808003, 0.4622731 , ..., 1.        ,
#          0.90826666, 0.7270375 ],
#         ...,
#         [0.906201  , 0.76107746, 0.62169343, ..., 0.44299597,
#          0.6958167 , 1.        ],
#         [0.9211464 , 0.75164133, 0.6347586 , ..., 0.73892623,
#          0.77403784, 1.        ],
#         [0.751389  , 0.7196757 , 0.62594086, ..., 0.830332  ,
#          0.71760225, 0.7586098 ]],
#
#        [[0.2913888 , 0.41014665, 0.6516965 , ..., 0.5038437 ,
#          0.5885698 , 0.3986278 ],
#         [0.25135738, 0.3019707 , 0.5674261 , ..., 0.3688462 ,
#          0.45984307, 0.37725037],
#         [0.4640978 , 0.4284385 , 0.5208627 , ..., 0.30602795,
#          0.4053799 , 0.36638603],
#         ...,
#         [0.6383818 , 0.5275731 , 0.6447424 , ..., 0.5072373 ,
#          0.69208384, 0.6948757 ],
#         [0.7507736 , 0.5149451 , 0.5468331 , ..., 0.52057123,
#          0.6297267 , 0.97726166],
#         [0.4927262 , 0.39180067, 0.33315495, ..., 0.45064735,
#          0.3991352 , 0.53314227]],
#
#        [[0.8337271 , 0.70840496, 0.77671075, ..., 0.5952522 ,
#          0.49187922, 0.72264576],
#         [1.        , 0.70393527, 0.72908896, ..., 0.55570495,
#          0.41156542, 0.65849686],
#         [0.7835472 , 0.7502752 , 0.6991676 , ..., 0.63744485,
#          1.        , 0.8160037 ],
#         ...,
#         [0.6843945 , 1.        , 0.79643387, ..., 0.48664692,
#          0.5654902 , 0.6221382 ],
#         [0.69500613, 1.        , 0.62332565, ..., 0.41045064,
#          0.79897964, 0.85662174],
#         [0.6179501 , 1.        , 0.40641415, ..., 0.26907888,
#          0.5094756 , 0.49585453]]], dtype=float32)
# 'rms'
# (2430, 251, 1)
# array([[[4.57111094e-03],
#         [4.72569047e-03],
#         [4.88307094e-03],
#         ...,
#         [5.69090201e-03],
#         [5.48938056e-03],
#         [4.83821239e-03]],
#
#        [[2.78365405e-07],
#         [4.39661926e-05],
#         [9.04211251e-04],
#         ...,
#         [2.31666211e-03],
#         [2.13860231e-03],
#         [1.70903362e-03]],
#
#        [[5.83346300e-02],
#         [6.16376810e-02],
#         [7.72752166e-02],
#         ...,
#         [3.40738967e-02],
#         [3.22043374e-02],
#         [2.40894184e-02]],
#
#        [[7.13391751e-02],
#         [7.46910945e-02],
#         [7.68597946e-02],
#         ...,
#         [7.41095617e-02],
#         [6.89243525e-02],
#         [5.64089529e-02]],
#
#        [[9.26215667e-03],
#         [1.04167312e-02],
#         [1.10445591e-02],
#         ...,
#         [1.22679295e-02],
#         [1.14667667e-02],
#         [9.63381492e-03]]], dtype=float32)
# 'spectral_centroid'
# (2430, 251, 1)
# array([[[0.51545053],
#         [0.49874055],
#         [0.51456638],
#         ...,
#         [0.49110592],
#         [0.47582734],
#         [0.47576837]],
#
#        [[0.55908266],
#         [0.55742316],
#         [0.48030338],
#         ...,
#         [0.44890365],
#         [0.45020048],
#         [0.42894007]],
#
#        [[0.13519012],
#         [0.12938562],
#         [0.08993516],
#         ...,
#         [0.19031238],
#         [0.20836148],
#         [0.18866565]],
#
#        [[0.10619909],
#         [0.11159842],
#         [0.1286047 ],
#         ...,
#         [0.11420143],
#         [0.11145737],
#         [0.10910237]],
#
#        [[0.25562478],
#         [0.26730435],
#         [0.27439192],
#         ...,
#         [0.27788894],
#         [0.27964845],
#         [0.27986811]]])
# 'melspectrogram'
# (2430, 251, 20)
# array([[[5.0653738e-01, 5.0819194e-01, 4.9984506e-01, ...,
#          4.5328444e-01, 4.6571514e-01, 4.8631823e-01],
#         [5.0549555e-01, 4.9489939e-01, 5.1116335e-01, ...,
#          4.4759238e-01, 4.6275455e-01, 4.6871954e-01],
#         [5.1773083e-01, 5.0902176e-01, 5.0214756e-01, ...,
#          4.5207074e-01, 4.6167907e-01, 4.6903095e-01],
#         ...,
#         [5.7134700e-01, 4.8327020e-01, 4.7995239e-01, ...,
#          4.4161072e-01, 4.4415718e-01, 4.4335017e-01],
#         [5.5832738e-01, 5.0648618e-01, 4.9554807e-01, ...,
#          4.3560365e-01, 4.6133488e-01, 4.4631451e-01],
#         [5.6290996e-01, 5.1270920e-01, 4.6899495e-01, ...,
#          4.3124685e-01, 4.6573690e-01, 4.4420120e-01]],
#
#        [[8.3953500e-02, 6.7171156e-02, 4.9416304e-02, ...,
#          2.2506118e-03, 1.3942599e-02, 2.7866840e-02],
#         [8.0637395e-02, 2.0151794e-02, 4.6203077e-02, ...,
#          2.0647049e-04, 2.5390983e-03, 1.0812223e-02],
#         [8.0293238e-02, 5.2304506e-02, 9.9805474e-02, ...,
#          1.4321572e-01, 1.5638709e-01, 1.1272025e-01],
#         ...,
#         [2.2386348e-01, 3.3478487e-01, 4.7118196e-01, ...,
#          3.8457340e-01, 4.0094084e-01, 3.5103732e-01],
#         [2.1195978e-01, 3.1199270e-01, 4.6106291e-01, ...,
#          3.7450853e-01, 4.0290070e-01, 3.4366578e-01],
#         [2.7949649e-01, 3.2357413e-01, 4.4650847e-01, ...,
#          3.7315208e-01, 3.9457104e-01, 3.2926553e-01]],
#
#        [[7.6655072e-01, 7.2591531e-01, 6.7341888e-01, ...,
#          4.1854548e-01, 4.2784542e-01, 4.3699878e-01],
#         [7.8091162e-01, 7.3466420e-01, 6.9344544e-01, ...,
#          4.2716536e-01, 4.3948838e-01, 4.3651509e-01],
#         [7.8195655e-01, 6.9475806e-01, 6.3982368e-01, ...,
#          3.7916794e-01, 3.8388741e-01, 3.9819530e-01],
#         ...,
#         [8.2274836e-01, 6.8390089e-01, 6.4008659e-01, ...,
#          4.2723766e-01, 4.4955578e-01, 4.4111809e-01],
#         [7.7292961e-01, 6.6651922e-01, 6.4317089e-01, ...,
#          4.1172862e-01, 4.6632850e-01, 4.4683662e-01],
#         [7.6135284e-01, 6.5464586e-01, 6.3074446e-01, ...,
#          4.0326339e-01, 4.5681176e-01, 4.3603432e-01]],
#
#        [[8.3806717e-01, 8.2800674e-01, 8.0748254e-01, ...,
#          4.5990875e-01, 4.6207497e-01, 4.8886964e-01],
#         [8.1176424e-01, 8.1515127e-01, 8.2029516e-01, ...,
#          4.4079939e-01, 4.4736710e-01, 4.6112275e-01],
#         [7.8708076e-01, 8.1528348e-01, 8.1506908e-01, ...,
#          4.5092052e-01, 4.5148316e-01, 4.7206897e-01],
#         ...,
#         [8.6641133e-01, 8.2045370e-01, 8.2975769e-01, ...,
#          4.6283311e-01, 4.4354877e-01, 4.4333509e-01],
#         [8.3375233e-01, 8.1242293e-01, 8.2092649e-01, ...,
#          4.2662027e-01, 4.4815448e-01, 4.4563201e-01],
#         [8.3350182e-01, 8.0199677e-01, 8.0183023e-01, ...,
#          4.2866221e-01, 4.5014405e-01, 4.4867393e-01]],
#
#        [[5.9407890e-01, 6.4901239e-01, 6.6339290e-01, ...,
#          3.9678714e-01, 3.7824476e-01, 4.2837092e-01],
#         [5.9047496e-01, 6.5653467e-01, 6.6829097e-01, ...,
#          4.0291145e-01, 3.8716239e-01, 4.0947837e-01],
#         [6.0544848e-01, 6.5056157e-01, 6.5998763e-01, ...,
#          4.1666162e-01, 3.9026517e-01, 4.0935224e-01],
#         ...,
#         [6.5952575e-01, 6.4743561e-01, 6.6063923e-01, ...,
#          4.2688319e-01, 4.1246012e-01, 4.0823784e-01],
#         [6.4608842e-01, 6.3105237e-01, 6.6158497e-01, ...,
#          4.1802722e-01, 4.2888996e-01, 4.1051564e-01],
#         [6.3342381e-01, 5.8507168e-01, 6.3195145e-01, ...,
#          4.1312081e-01, 4.3875557e-01, 4.0016785e-01]]], dtype=float32)
# 'label'
# (2430,)
# array([1, 1, 1, 1, 2])

# %%
for key in non_audio_df['val'].keys():
  display(key)
  display(non_audio_df['val'][key].shape)
  display(non_audio_df['val'][key][:5])
# Out:
# 'type'
# (2430,)
# array(['call', 'call', 'call', 'call', 'blank'], dtype='<U5')
# 'continent'
# (2430,)
# array(['EUROPE', 'EUROPE', 'EUROPE', 'EUROPE', 'EUROPE'], dtype='<U8')
# 'rating'
# (2430,)
# array([4., 5., 2., 0., 5.])
# 'label'
# (2430,)
# array([1, 1, 1, 1, 2])

# %% [markdown]
# # Create sample weights based on rating

# %%
training_sample_weights = non_audio_df['train']['rating']

training_sample_weights
# Out:
# array([4.5, 3. , 5. , ..., 3. , 4. , 3.5])

# %%
validation_sample_weights = non_audio_df['val']['rating']

validation_sample_weights
# Out:
# array([4., 5., 2., ..., 5., 4., 4.])

# %%
training_sample_weights = np.where(training_sample_weights > 3.0, 0.6, 0.4)

training_sample_weights
# Out:
# array([0.6, 0.4, 0.6, ..., 0.4, 0.6, 0.6])

# %%
validation_sample_weights = np.where(validation_sample_weights > 3.0, 0.6, 0.4)

validation_sample_weights
# Out:
# array([0.6, 0.6, 0.4, ..., 0.6, 0.6, 0.6])

# %% [markdown]
# # 1D CNN Models

# %%
train_results = {}
val_results = {}

# %%
classes = ['barswa', 'comsan', 'eaywag1']

# %% [markdown]
# ## Create 1D CNN model function

# %%
def build_model(audio_features,
                learning_rate=0.001):

  tf.keras.backend.clear_session()

  # set audio features input layer
  inputs = tf.keras.layers.Input(shape=(audio_features.shape[1],audio_features.shape[2]), name='Audio_Features')

  # add first convolution layer to the model
  features = tf.keras.layers.Conv1D(
              filters=32,
              kernel_size=5,
              strides=1,
              padding='same',
              data_format='channels_last',
              name='conv_1',
              activation='relu',
              kernel_regularizer=tf.keras.regularizers.l2(0.02))(inputs)

  # add first max pooling layer
  features = tf.keras.layers.MaxPool1D(pool_size=2, name='pool_1')(features)

  # add second convolution layer to the model
  features = tf.keras.layers.Conv1D(
              filters=64,
              kernel_size=5,
              strides=1,
              padding='same',
              name='conv_2',
              activation='relu',
              kernel_regularizer=tf.keras.regularizers.l2(0.02))(features)

  # add second max pooling layer
  features = tf.keras.layers.MaxPool1D(pool_size=2, name='pool_2')(features)

  # add a fully connected layer (need to flatten the output of the previous layers first)
  features = tf.keras.layers.Flatten()(features)

  features = tf.keras.layers.Dense(
      units=1024,
      name='fc_1',
      activation='relu')(features)

  # add dropout layer
  features = tf.keras.layers.Dropout(rate=0.5)(features)

  # add the last fully connected layer
  # this last layer sets the activation function to "None" in order to output the logits
  # note that passing activation = "softmax" will return class memembership probabilities but
  # in TensorFlow logits are prefered for numerical stability
  # set units=3 to get a 3 output unit (remember it's 3 species)
  outputs = tf.keras.layers.Dense(
      units=3,
      name='fc_2',
      activation=None)(features)

  # build model and print summary
  model = tf.keras.Model(inputs=[inputs],
                          outputs=outputs,
                          name='Birds')

  print(model.summary())

  # compile model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), #set from_logits=True because our last layer does not apply softmax
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

  return model

# %%
def visualize(model_history, best_epoch):
  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
  # visualize the loss
  axes[0].plot(model_history.history['loss'][:best_epoch+1], color='purple', label='train_losses')
  axes[0].plot(model_history.history['val_loss'][:best_epoch+1], color='orange', label='val_losses')
  axes[0].set_xlabel('Epoch')
  axes[0].set_ylabel('Loss')
  axes[0].set_title('Loss Progression')
  axes[0].legend()

  # visualze the accuracy
  axes[1].plot(model_history.history['accuracy'][:best_epoch+1], color='purple', label='train_accuracy')
  axes[1].plot(model_history.history['val_accuracy'][:best_epoch+1], color='orange', label='val_accuracy')
  axes[1].set_xlabel('Epoch')
  axes[1].set_ylabel('Accuracy')
  axes[1].set_title('Accuracy Progression')
  axes[1].legend()

  plt.show()

# %% [markdown]
# ## With mfcc & chroma

# %% [markdown]
# ### create features

# %%
training_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['chroma']), axis=-1)

training_features
# Out:
# array([[[0.6831663 , 0.5929136 , 0.53691167, ..., 0.4342559 ,
#          0.97700906, 0.28842098],
#         [0.68208945, 0.571792  , 0.504587  , ..., 0.11924674,
#          0.26881692, 0.11062346],
#         [0.6526171 , 0.5514721 , 0.55114627, ..., 0.03223189,
#          0.03605267, 0.03657101],
#         ...,
#         [0.63545215, 0.5167248 , 0.72968334, ..., 0.01315344,
#          0.00534319, 0.00633229],
#         [0.6489433 , 0.5131046 , 0.72684944, ..., 0.02012673,
#          0.00860553, 0.0137417 ],
#         [0.6516156 , 0.51605314, 0.67196417, ..., 0.0220832 ,
#          0.01636278, 0.02791071]],
#
#        [[0.77090144, 0.5633397 , 0.44750988, ..., 1.        ,
#          0.62414324, 0.4321466 ],
#         [0.7687094 , 0.5571646 , 0.4361108 , ..., 1.        ,
#          0.80624527, 0.68306273],
#         [0.73958874, 0.5358136 , 0.49239874, ..., 0.6908648 ,
#          0.62402076, 0.5532968 ],
#         ...,
#         [0.6968399 , 0.5428623 , 0.58974713, ..., 0.57520777,
#          0.6139954 , 1.        ],
#         [0.69118834, 0.5630867 , 0.5994376 , ..., 0.55270886,
#          0.6378856 , 1.        ],
#         [0.68436086, 0.5415647 , 0.59406155, ..., 0.99999994,
#          0.9822643 , 0.73957705]],
#
#        [[0.75341856, 0.3343674 , 0.44527382, ..., 0.5228693 ,
#          0.6137004 , 0.64900815],
#         [0.79357547, 0.26852542, 0.4253092 , ..., 0.941146  ,
#          0.6585682 , 0.9152451 ],
#         [0.78716105, 0.23256648, 0.47526145, ..., 1.        ,
#          0.38955617, 0.5324785 ],
#         ...,
#         [0.50628686, 0.6297636 , 0.5556158 , ..., 0.47418267,
#          0.4474413 , 0.442546  ],
#         [0.5116738 , 0.63981414, 0.573615  , ..., 0.23289016,
#          0.20419382, 0.18677777],
#         [0.51984173, 0.63319826, 0.6013931 , ..., 0.31854522,
#          0.25067532, 0.21063809]],
#
#        ...,
#
#        [[0.75839806, 0.738902  , 0.45989856, ..., 0.44012195,
#          0.296583  , 0.34553298],
#         [0.7458645 , 0.7183633 , 0.42753008, ..., 0.21976015,
#          0.25673494, 0.40422282],
#         [0.7583987 , 0.58011323, 0.5584154 , ..., 0.5544204 ,
#          0.7464317 , 0.5889769 ],
#         ...,
#         [0.6371682 , 0.6285711 , 0.5300583 , ..., 0.3833019 ,
#          0.40409416, 0.4144288 ],
#         [0.66542506, 0.6158067 , 0.5307447 , ..., 0.9230332 ,
#          0.6909939 , 0.5981325 ],
#         [0.65818405, 0.6321564 , 0.55590814, ..., 0.9825871 ,
#          0.73071134, 0.63178533]],
#
#        [[0.6903993 , 0.27471635, 0.20926896, ..., 0.11955583,
#          0.14621322, 0.13937107],
#         [0.6517042 , 0.26937437, 0.13883993, ..., 0.2341702 ,
#          0.3609875 , 0.34827796],
#         [0.5938367 , 0.24614182, 0.1327964 , ..., 0.27484307,
#          0.29845127, 0.47954434],
#         ...,
#         [0.6101424 , 0.24159512, 0.13504323, ..., 0.12641472,
#          0.14428243, 0.2059934 ],
#         [0.6268731 , 0.2898204 , 0.13103324, ..., 0.16918288,
#          0.12740257, 0.18316865],
#         [0.63534236, 0.32786077, 0.17737713, ..., 0.39189407,
#          0.33105606, 0.4752832 ]],
#
#        [[0.57134223, 0.3582979 , 0.5959228 , ..., 0.12121844,
#          0.99999994, 0.65278697],
#         [0.528876  , 0.3004045 , 0.5669832 , ..., 0.04387528,
#          0.44588757, 0.8563552 ],
#         [0.45296973, 0.28502917, 0.529702  , ..., 0.03109312,
#          0.08370419, 0.44490317],
#         ...,
#         [0.35696495, 0.5035879 , 0.35562232, ..., 0.49518177,
#          0.34123093, 0.3191443 ],
#         [0.36979246, 0.5072726 , 0.26958677, ..., 0.22124113,
#          0.10989622, 0.08482651],
#         [0.37493837, 0.49631387, 0.28284302, ..., 0.08821637,
#          0.06788597, 0.03683891]]], dtype=float32)

# %%
training_features.shape
# Out:
# (4763, 251, 32)

# %%
validation_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['chroma']), axis=-1)

validation_features
# Out:
# array([[[0.60736156, 0.5236882 , 0.50165933, ..., 0.3311117 ,
#          0.32635486, 0.3102124 ],
#         [0.60613585, 0.5302393 , 0.44283968, ..., 0.25711238,
#          0.28643575, 0.40929344],
#         [0.5731026 , 0.5249975 , 0.49937668, ..., 0.5368786 ,
#          0.46743223, 0.8375584 ],
#         ...,
#         [0.5648463 , 0.53384393, 0.53603375, ..., 1.        ,
#          0.6898149 , 0.2052103 ],
#         [0.58220553, 0.545521  , 0.51468575, ..., 0.7996965 ,
#          0.39905998, 0.15756844],
#         [0.5890244 , 0.51676226, 0.52040446, ..., 0.7312468 ,
#          0.3652335 , 0.16882361]],
#
#        [[0.04757321, 0.5533783 , 0.5236086 , ..., 1.        ,
#          0.97777915, 0.6717883 ],
#         [0.02094185, 0.5375777 , 0.4808089 , ..., 1.        ,
#          0.9545332 , 0.61943966],
#         [0.19114172, 0.47221273, 0.34016225, ..., 0.56730384,
#          0.67591417, 0.50784737],
#         ...,
#         [0.46464425, 0.49159396, 0.36009547, ..., 0.62916636,
#          0.7445956 , 0.60917664],
#         [0.4679255 , 0.50985813, 0.3303873 , ..., 0.56290257,
#          0.74416566, 0.79829204],
#         [0.48512626, 0.50881296, 0.33999783, ..., 0.44969562,
#          0.5899433 , 0.83311045]],
#
#        [[0.7047834 , 0.7912003 , 0.5833197 , ..., 0.6720866 ,
#          0.7376877 , 0.8596353 ],
#         [0.7113026 , 0.7752712 , 0.54398525, ..., 0.8284834 ,
#          0.7660718 , 0.7136997 ],
#         [0.6146671 , 0.74740255, 0.6067238 , ..., 1.        ,
#          0.90826666, 0.7270375 ],
#         ...,
#         [0.62319624, 0.71127313, 0.67235225, ..., 0.44299597,
#          0.6958167 , 1.        ],
#         [0.625559  , 0.7297457 , 0.6860897 , ..., 0.73892623,
#          0.77403784, 1.        ],
#         [0.6283432 , 0.73358506, 0.69936126, ..., 0.830332  ,
#          0.71760225, 0.7586098 ]],
#
#        ...,
#
#        [[0.21232843, 0.50565416, 0.5384836 , ..., 0.2594713 ,
#          0.38533688, 0.3959729 ],
#         [0.18918383, 0.47696787, 0.48546806, ..., 0.3240752 ,
#          0.35431045, 0.51744485],
#         [0.18889385, 0.46165472, 0.49905002, ..., 0.36075228,
#          0.26302177, 0.34560797],
#         ...,
#         [0.23163903, 0.40094036, 0.5147005 , ..., 0.22896253,
#          0.24305563, 0.5041051 ],
#         [0.24128944, 0.40316302, 0.47045222, ..., 0.1840967 ,
#          0.14336939, 0.13464358],
#         [0.2519635 , 0.4036435 , 0.49215075, ..., 0.33450636,
#          0.21515046, 0.24516   ]],
#
#        [[0.73500824, 0.6793757 , 0.3677523 , ..., 0.40106627,
#          0.3789666 , 0.1924467 ],
#         [0.72632223, 0.6617692 , 0.33811408, ..., 0.93584406,
#          0.7759951 , 0.5269695 ],
#         [0.6860943 , 0.6175082 , 0.36775792, ..., 1.        ,
#          0.8385056 , 0.6393118 ],
#         ...,
#         [0.6673135 , 0.6213924 , 0.46979403, ..., 0.64811933,
#          0.5486526 , 0.652197  ],
#         [0.6732626 , 0.6353789 , 0.45923656, ..., 0.87408906,
#          0.9331765 , 0.71713674],
#         [0.6788246 , 0.6315694 , 0.47706696, ..., 0.7050995 ,
#          0.80429703, 0.52211994]],
#
#        [[0.72578764, 0.8235316 , 0.6612087 , ..., 0.55268323,
#          0.49394807, 0.5952369 ],
#         [0.7234839 , 0.7895137 , 0.6005234 , ..., 0.5303093 ,
#          0.43927178, 0.4080374 ],
#         [0.6911776 , 0.74431884, 0.63975877, ..., 0.5240184 ,
#          0.53424007, 0.43504563],
#         ...,
#         [0.64536965, 0.7733905 , 0.629168  , ..., 1.        ,
#          0.3627997 , 0.41877767],
#         [0.67905456, 0.7232691 , 0.6606823 , ..., 0.7755177 ,
#          0.44088802, 0.49232656],
#         [0.7221329 , 0.6537676 , 0.6544845 , ..., 0.7213394 ,
#          0.40520185, 0.4257652 ]]], dtype=float32)

# %%
validation_features.shape
# Out:
# (2430, 251, 32)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_features,
                    learning_rate=0.001)

history = model.fit(
   x=training_features,
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(validation_features,
                    audio_df['val']['label'],
                    validation_sample_weights
                    ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Audio_Features (InputLayer  [(None, 251, 32)]         0
#  )
#
#  conv_1 (Conv1D)             (None, 251, 32)           5152
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)           0
#
#  conv_2 (Conv1D)             (None, 125, 64)           10304
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)            0
#
#  flatten (Flatten)           (None, 3968)              0
#
#  fc_1 (Dense)                (None, 1024)              4064256
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 3)                 3075
#
# =================================================================
# Total params: 4082787 (15.57 MB)
# Trainable params: 4082787 (15.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 19s 104ms/step - loss: 1.1253 - accuracy: 0.5774 - weighted_accuracy: 0.5882 - val_loss: 0.8415 - val_accuracy: 0.5329 - val_weighted_accuracy: 0.5433
# Epoch 2/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.6108 - accuracy: 0.7355 - weighted_accuracy: 0.7465 - val_loss: 0.6162 - val_accuracy: 0.7008 - val_weighted_accuracy: 0.7104
# Epoch 3/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.4733 - accuracy: 0.8060 - weighted_accuracy: 0.8159 - val_loss: 0.5087 - val_accuracy: 0.7782 - val_weighted_accuracy: 0.7876
# Epoch 4/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.3896 - accuracy: 0.8381 - weighted_accuracy: 0.8470 - val_loss: 0.4988 - val_accuracy: 0.7687 - val_weighted_accuracy: 0.7747
# Epoch 5/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.3493 - accuracy: 0.8537 - weighted_accuracy: 0.8614 - val_loss: 0.4892 - val_accuracy: 0.7704 - val_weighted_accuracy: 0.7691
# Epoch 6/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.3070 - accuracy: 0.8807 - weighted_accuracy: 0.8864 - val_loss: 0.3958 - val_accuracy: 0.8366 - val_weighted_accuracy: 0.8408
# Epoch 7/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.2915 - accuracy: 0.8732 - weighted_accuracy: 0.8790 - val_loss: 0.3868 - val_accuracy: 0.8235 - val_weighted_accuracy: 0.8296
# Epoch 8/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.2708 - accuracy: 0.8841 - weighted_accuracy: 0.8893 - val_loss: 0.4238 - val_accuracy: 0.7626 - val_weighted_accuracy: 0.7668
# Epoch 9/100
# 149/149 [==============================] - 16s 105ms/step - loss: 0.2621 - accuracy: 0.8875 - weighted_accuracy: 0.8928 - val_loss: 0.3934 - val_accuracy: 0.7770 - val_weighted_accuracy: 0.7938
# Epoch 10/100
# 149/149 [==============================] - 13s 91ms/step - loss: 0.2463 - accuracy: 0.8944 - weighted_accuracy: 0.9001 - val_loss: 0.3894 - val_accuracy: 0.7630 - val_weighted_accuracy: 0.7764
# Epoch 11/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.2385 - accuracy: 0.8946 - weighted_accuracy: 0.9014 - val_loss: 0.3532 - val_accuracy: 0.8276 - val_weighted_accuracy: 0.8399
# Epoch 12/100
# 149/149 [==============================] - 16s 108ms/step - loss: 0.1998 - accuracy: 0.9206 - weighted_accuracy: 0.9250 - val_loss: 0.3430 - val_accuracy: 0.8099 - val_weighted_accuracy: 0.8257
# Epoch 13/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.2016 - accuracy: 0.9164 - weighted_accuracy: 0.9208 - val_loss: 0.3396 - val_accuracy: 0.8305 - val_weighted_accuracy: 0.8372
# Epoch 14/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.1878 - accuracy: 0.9223 - weighted_accuracy: 0.9263 - val_loss: 0.3572 - val_accuracy: 0.8185 - val_weighted_accuracy: 0.8298
# Epoch 15/100
# 149/149 [==============================] - 15s 100ms/step - loss: 0.1762 - accuracy: 0.9290 - weighted_accuracy: 0.9321 - val_loss: 0.4911 - val_accuracy: 0.7778 - val_weighted_accuracy: 0.7897
# Epoch 16/100
# 149/149 [==============================] - 15s 100ms/step - loss: 0.2202 - accuracy: 0.8999 - weighted_accuracy: 0.9036 - val_loss: 0.3286 - val_accuracy: 0.8379 - val_weighted_accuracy: 0.8475
# Epoch 17/100
# 149/149 [==============================] - 15s 98ms/step - loss: 0.1717 - accuracy: 0.9301 - weighted_accuracy: 0.9347 - val_loss: 0.3497 - val_accuracy: 0.8370 - val_weighted_accuracy: 0.8465
# Epoch 18/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1644 - accuracy: 0.9339 - weighted_accuracy: 0.9381 - val_loss: 0.3299 - val_accuracy: 0.8317 - val_weighted_accuracy: 0.8381
# Epoch 19/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.1533 - accuracy: 0.9410 - weighted_accuracy: 0.9439 - val_loss: 0.3418 - val_accuracy: 0.8181 - val_weighted_accuracy: 0.8310
# Epoch 20/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1433 - accuracy: 0.9452 - weighted_accuracy: 0.9484 - val_loss: 0.3063 - val_accuracy: 0.8412 - val_weighted_accuracy: 0.8539
# Epoch 21/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1417 - accuracy: 0.9456 - weighted_accuracy: 0.9489 - val_loss: 0.3260 - val_accuracy: 0.8494 - val_weighted_accuracy: 0.8551
# Epoch 22/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1330 - accuracy: 0.9526 - weighted_accuracy: 0.9548 - val_loss: 0.3752 - val_accuracy: 0.7971 - val_weighted_accuracy: 0.8099
# Epoch 23/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1370 - accuracy: 0.9492 - weighted_accuracy: 0.9516 - val_loss: 0.3341 - val_accuracy: 0.8449 - val_weighted_accuracy: 0.8495
# Epoch 24/100
# 149/149 [==============================] - 17s 113ms/step - loss: 0.1187 - accuracy: 0.9628 - weighted_accuracy: 0.9655 - val_loss: 0.3370 - val_accuracy: 0.8469 - val_weighted_accuracy: 0.8530
# Epoch 25/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1113 - accuracy: 0.9633 - weighted_accuracy: 0.9659 - val_loss: 0.3682 - val_accuracy: 0.8144 - val_weighted_accuracy: 0.8295
# Epoch 26/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1098 - accuracy: 0.9633 - weighted_accuracy: 0.9654 - val_loss: 0.3403 - val_accuracy: 0.8317 - val_weighted_accuracy: 0.8416
# Epoch 27/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1140 - accuracy: 0.9591 - weighted_accuracy: 0.9612 - val_loss: 0.4385 - val_accuracy: 0.8012 - val_weighted_accuracy: 0.8147
# Epoch 28/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1128 - accuracy: 0.9620 - weighted_accuracy: 0.9640 - val_loss: 0.3645 - val_accuracy: 0.8391 - val_weighted_accuracy: 0.8472
# Epoch 29/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1025 - accuracy: 0.9649 - weighted_accuracy: 0.9683 - val_loss: 0.3274 - val_accuracy: 0.8267 - val_weighted_accuracy: 0.8377
# Epoch 30/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1012 - accuracy: 0.9660 - weighted_accuracy: 0.9688 - val_loss: 0.3833 - val_accuracy: 0.8267 - val_weighted_accuracy: 0.8383
# Epoch 31/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1024 - accuracy: 0.9656 - weighted_accuracy: 0.9685 - val_loss: 0.4605 - val_accuracy: 0.7720 - val_weighted_accuracy: 0.7912
# best_epoch:  20

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
train_yhat = model.predict(training_features)

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_chroma'] = model.evaluate(training_features, audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 2s 15ms/step
# 149/149 [==============================] - 2s 15ms/step - loss: 0.1668 - accuracy: 0.9620 - weighted_accuracy: 0.9620

# %%
val_yhat = model.predict(validation_features)

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_chroma'] = model.evaluate(validation_features,audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 1s 19ms/step
# 76/76 [==============================] - 2s 20ms/step - loss: 0.5646 - accuracy: 0.8494 - weighted_accuracy: 0.8494

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.92      0.99      0.96      1603
#       comsan       0.97      0.95      0.96      1578
#      eaywag1       1.00      0.94      0.97      1582
#
#     accuracy                           0.96      4763
#    macro avg       0.96      0.96      0.96      4763
# weighted avg       0.96      0.96      0.96      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.80      0.91      0.85      1032
#       comsan       0.85      0.83      0.84       618
#      eaywag1       0.93      0.78      0.85       780
#
#     accuracy                           0.85      2430
#    macro avg       0.86      0.84      0.85      2430
# weighted avg       0.86      0.85      0.85      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# ## With mfcc & rms

# %% [markdown]
# ### create features

# %%
training_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['rms']), axis=-1)

training_features
# Out:
# array([[[0.6831663 , 0.5929136 , 0.53691167, ..., 0.29569203,
#          0.5300293 , 0.01766523],
#         [0.68208945, 0.571792  , 0.504587  , ..., 0.4049796 ,
#          0.5381129 , 0.02395274],
#         [0.6526171 , 0.5514721 , 0.55114627, ..., 0.42884982,
#          0.5741422 , 0.0286761 ],
#         ...,
#         [0.63545215, 0.5167248 , 0.72968334, ..., 0.44959253,
#          0.7061733 , 0.05134375],
#         [0.6489433 , 0.5131046 , 0.72684944, ..., 0.4500671 ,
#          0.59251463, 0.04667601],
#         [0.6516156 , 0.51605314, 0.67196417, ..., 0.43407208,
#          0.41794068, 0.03258164]],
#
#        [[0.77090144, 0.5633397 , 0.44750988, ..., 0.47935772,
#          0.6066712 , 0.02495077],
#         [0.7687094 , 0.5571646 , 0.4361108 , ..., 0.5475237 ,
#          0.6708364 , 0.03008876],
#         [0.73958874, 0.5358136 , 0.49239874, ..., 0.58571094,
#          0.6061154 , 0.03161712],
#         ...,
#         [0.6968399 , 0.5428623 , 0.58974713, ..., 0.61003953,
#          0.6470494 , 0.01856191],
#         [0.69118834, 0.5630867 , 0.5994376 , ..., 0.5556493 ,
#          0.48460883, 0.01758861],
#         [0.68436086, 0.5415647 , 0.59406155, ..., 0.50401896,
#          0.41306552, 0.01379679]],
#
#        [[0.75341856, 0.3343674 , 0.44527382, ..., 0.8055067 ,
#          0.43145433, 0.20626543],
#         [0.79357547, 0.26852542, 0.4253092 , ..., 0.666156  ,
#          0.5930237 , 0.28964704],
#         [0.78716105, 0.23256648, 0.47526145, ..., 0.63948256,
#          0.58878636, 0.3565841 ],
#         ...,
#         [0.50628686, 0.6297636 , 0.5556158 , ..., 0.5322715 ,
#          0.56162953, 0.00710791],
#         [0.5116738 , 0.63981414, 0.573615  , ..., 0.47569013,
#          0.5742805 , 0.00532044],
#         [0.51984173, 0.63319826, 0.6013931 , ..., 0.56125164,
#          0.63937485, 0.00379898]],
#
#        ...,
#
#        [[0.75839806, 0.738902  , 0.45989856, ..., 0.47925678,
#          0.4124774 , 0.0231342 ],
#         [0.7458645 , 0.7183633 , 0.42753008, ..., 0.5178576 ,
#          0.4746655 , 0.02917222],
#         [0.7583987 , 0.58011323, 0.5584154 , ..., 0.509192  ,
#          0.433525  , 0.08086979],
#         ...,
#         [0.6371682 , 0.6285711 , 0.5300583 , ..., 0.57411486,
#          0.40220731, 0.01109741],
#         [0.66542506, 0.6158067 , 0.5307447 , ..., 0.4797628 ,
#          0.3518664 , 0.00946815],
#         [0.65818405, 0.6321564 , 0.55590814, ..., 0.4686575 ,
#          0.3437901 , 0.00824792]],
#
#        [[0.6903993 , 0.27471635, 0.20926896, ..., 0.69468   ,
#          0.4989151 , 0.02759135],
#         [0.6517042 , 0.26937437, 0.13883993, ..., 0.5807995 ,
#          0.5230801 , 0.02848949],
#         [0.5938367 , 0.24614182, 0.1327964 , ..., 0.6233793 ,
#          0.51421726, 0.03389978],
#         ...,
#         [0.6101424 , 0.24159512, 0.13504323, ..., 0.66301745,
#          0.31478655, 0.03445767],
#         [0.6268731 , 0.2898204 , 0.13103324, ..., 0.58928066,
#          0.31412172, 0.03460433],
#         [0.63534236, 0.32786077, 0.17737713, ..., 0.609863  ,
#          0.3947153 , 0.02899204]],
#
#        [[0.57134223, 0.3582979 , 0.5959228 , ..., 0.49955964,
#          0.41801837, 0.02310807],
#         [0.528876  , 0.3004045 , 0.5669832 , ..., 0.578803  ,
#          0.39213565, 0.02121984],
#         [0.45296973, 0.28502917, 0.529702  , ..., 0.6585318 ,
#          0.44583637, 0.02436587],
#         ...,
#         [0.35696495, 0.5035879 , 0.35562232, ..., 0.6053577 ,
#          0.41010246, 0.00126841],
#         [0.36979246, 0.5072726 , 0.26958677, ..., 0.5803329 ,
#          0.36484334, 0.00116942],
#         [0.37493837, 0.49631387, 0.28284302, ..., 0.64517653,
#          0.3926701 , 0.0011289 ]]], dtype=float32)

# %%
training_features.shape
# Out:
# (4763, 251, 21)

# %%
validation_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['rms']), axis=-1)

validation_features
# Out:
# array([[[6.0736156e-01, 5.2368820e-01, 5.0165933e-01, ...,
#          5.5212289e-01, 3.5984367e-01, 4.5711109e-03],
#         [6.0613585e-01, 5.3023928e-01, 4.4283968e-01, ...,
#          6.1897910e-01, 4.0108734e-01, 4.7256905e-03],
#         [5.7310259e-01, 5.2499747e-01, 4.9937668e-01, ...,
#          6.3101941e-01, 4.2959955e-01, 4.8830709e-03],
#         ...,
#         [5.6484628e-01, 5.3384393e-01, 5.3603375e-01, ...,
#          4.7962302e-01, 4.3652374e-01, 5.6909020e-03],
#         [5.8220553e-01, 5.4552102e-01, 5.1468575e-01, ...,
#          4.4923827e-01, 4.1285479e-01, 5.4893806e-03],
#         [5.8902442e-01, 5.1676226e-01, 5.2040446e-01, ...,
#          4.4315791e-01, 4.5294771e-01, 4.8382124e-03]],
#
#        [[4.7573209e-02, 5.5337828e-01, 5.2360862e-01, ...,
#          5.5591893e-01, 4.7346288e-01, 2.7836541e-07],
#         [2.0941854e-02, 5.3757769e-01, 4.8080891e-01, ...,
#          5.5688024e-01, 5.4338837e-01, 4.3966193e-05],
#         [1.9114172e-01, 4.7221273e-01, 3.4016225e-01, ...,
#          6.3151795e-01, 4.3581176e-01, 9.0421125e-04],
#         ...,
#         [4.6464425e-01, 4.9159396e-01, 3.6009547e-01, ...,
#          5.5938774e-01, 4.2548728e-01, 2.3166621e-03],
#         [4.6792549e-01, 5.0985813e-01, 3.3038729e-01, ...,
#          4.7706351e-01, 4.0889534e-01, 2.1386023e-03],
#         [4.8512626e-01, 5.0881296e-01, 3.3999783e-01, ...,
#          4.4166297e-01, 3.3910498e-01, 1.7090336e-03]],
#
#        [[7.0478338e-01, 7.9120028e-01, 5.8331972e-01, ...,
#          4.8871115e-01, 4.2061213e-01, 5.8334630e-02],
#         [7.1130258e-01, 7.7527118e-01, 5.4398525e-01, ...,
#          5.5816066e-01, 4.9556312e-01, 6.1637681e-02],
#         [6.1466712e-01, 7.4740255e-01, 6.0672379e-01, ...,
#          6.2072307e-01, 5.2423811e-01, 7.7275217e-02],
#         ...,
#         [6.2319624e-01, 7.1127313e-01, 6.7235225e-01, ...,
#          7.3649263e-01, 6.2420797e-01, 3.4073897e-02],
#         [6.2555897e-01, 7.2974569e-01, 6.8608969e-01, ...,
#          6.4584386e-01, 5.4353023e-01, 3.2204337e-02],
#         [6.2834322e-01, 7.3358506e-01, 6.9936126e-01, ...,
#          7.1059561e-01, 5.4381758e-01, 2.4089418e-02]],
#
#        ...,
#
#        [[2.1232843e-01, 5.0565416e-01, 5.3848362e-01, ...,
#          4.4392207e-01, 3.2891846e-01, 1.2136235e-04],
#         [1.8918383e-01, 4.7696787e-01, 4.8546806e-01, ...,
#          5.3096414e-01, 3.9892709e-01, 1.4865652e-04],
#         [1.8889385e-01, 4.6165472e-01, 4.9905002e-01, ...,
#          5.6151217e-01, 4.4452658e-01, 1.4593863e-04],
#         ...,
#         [2.3163903e-01, 4.0094036e-01, 5.1470047e-01, ...,
#          6.1173582e-01, 4.3710482e-01, 5.3044420e-04],
#         [2.4128944e-01, 4.0316302e-01, 4.7045222e-01, ...,
#          5.2380311e-01, 4.1380581e-01, 5.3560222e-04],
#         [2.5196350e-01, 4.0364349e-01, 4.9215075e-01, ...,
#          5.9089351e-01, 4.3870094e-01, 4.8636523e-04]],
#
#        [[7.3500824e-01, 6.7937571e-01, 3.6775231e-01, ...,
#          4.3342009e-01, 4.6941707e-01, 1.3260327e-02],
#         [7.2632223e-01, 6.6176921e-01, 3.3811408e-01, ...,
#          4.7873050e-01, 4.7082561e-01, 1.4620285e-02],
#         [6.8609428e-01, 6.1750817e-01, 3.6775792e-01, ...,
#          4.8672393e-01, 3.8489062e-01, 1.5620336e-02],
#         ...,
#         [6.6731352e-01, 6.2139243e-01, 4.6979403e-01, ...,
#          5.3701514e-01, 3.7462148e-01, 1.3410048e-02],
#         [6.7326260e-01, 6.3537890e-01, 4.5923656e-01, ...,
#          4.7440630e-01, 3.7806824e-01, 1.2106514e-02],
#         [6.7882460e-01, 6.3156939e-01, 4.7706696e-01, ...,
#          5.6890577e-01, 3.8024384e-01, 9.8557677e-03]],
#
#        [[7.2578764e-01, 8.2353163e-01, 6.6120869e-01, ...,
#          5.6684524e-01, 5.3783631e-01, 3.5698596e-02],
#         [7.2348392e-01, 7.8951371e-01, 6.0052341e-01, ...,
#          5.8473307e-01, 5.8094090e-01, 3.7953109e-02],
#         [6.9117761e-01, 7.4431884e-01, 6.3975877e-01, ...,
#          5.8926588e-01, 5.9131777e-01, 3.9246187e-02],
#         ...,
#         [6.4536965e-01, 7.7339047e-01, 6.2916797e-01, ...,
#          6.7133087e-01, 4.9175021e-01, 2.4810322e-02],
#         [6.7905456e-01, 7.2326910e-01, 6.6068232e-01, ...,
#          6.1073655e-01, 5.5632514e-01, 2.1835847e-02],
#         [7.2213292e-01, 6.5376759e-01, 6.5448451e-01, ...,
#          7.1492308e-01, 5.6704760e-01, 1.7866442e-02]]], dtype=float32)

# %%
validation_features.shape
# Out:
# (2430, 251, 21)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_features,
                    learning_rate=0.001)

history = model.fit(
   x=training_features,
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(validation_features,
                    audio_df['val']['label'],
                    validation_sample_weights
                    ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Audio_Features (InputLayer  [(None, 251, 21)]         0
#  )
#
#  conv_1 (Conv1D)             (None, 251, 32)           3392
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)           0
#
#  conv_2 (Conv1D)             (None, 125, 64)           10304
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)            0
#
#  flatten (Flatten)           (None, 3968)              0
#
#  fc_1 (Dense)                (None, 1024)              4064256
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 3)                 3075
#
# =================================================================
# Total params: 4081027 (15.57 MB)
# Trainable params: 4081027 (15.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 18s 107ms/step - loss: 1.1350 - accuracy: 0.4955 - weighted_accuracy: 0.5053 - val_loss: 0.7662 - val_accuracy: 0.5613 - val_weighted_accuracy: 0.5864
# Epoch 2/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.6956 - accuracy: 0.6003 - weighted_accuracy: 0.6141 - val_loss: 0.6643 - val_accuracy: 0.5774 - val_weighted_accuracy: 0.5855
# Epoch 3/100
# 149/149 [==============================] - 12s 83ms/step - loss: 0.5820 - accuracy: 0.6752 - weighted_accuracy: 0.6922 - val_loss: 0.6679 - val_accuracy: 0.5391 - val_weighted_accuracy: 0.5671
# Epoch 4/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.5272 - accuracy: 0.7048 - weighted_accuracy: 0.7210 - val_loss: 0.5745 - val_accuracy: 0.6634 - val_weighted_accuracy: 0.6905
# Epoch 5/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.4657 - accuracy: 0.7655 - weighted_accuracy: 0.7787 - val_loss: 0.5788 - val_accuracy: 0.6724 - val_weighted_accuracy: 0.7014
# Epoch 6/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.3884 - accuracy: 0.8228 - weighted_accuracy: 0.8321 - val_loss: 0.4465 - val_accuracy: 0.8247 - val_weighted_accuracy: 0.8330
# Epoch 7/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.3514 - accuracy: 0.8482 - weighted_accuracy: 0.8569 - val_loss: 0.4317 - val_accuracy: 0.8169 - val_weighted_accuracy: 0.8225
# Epoch 8/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.3097 - accuracy: 0.8715 - weighted_accuracy: 0.8776 - val_loss: 0.3949 - val_accuracy: 0.7963 - val_weighted_accuracy: 0.8138
# Epoch 9/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.3063 - accuracy: 0.8661 - weighted_accuracy: 0.8712 - val_loss: 0.4245 - val_accuracy: 0.8058 - val_weighted_accuracy: 0.8151
# Epoch 10/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2754 - accuracy: 0.8839 - weighted_accuracy: 0.8898 - val_loss: 0.4414 - val_accuracy: 0.7967 - val_weighted_accuracy: 0.8028
# Epoch 11/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.2620 - accuracy: 0.8957 - weighted_accuracy: 0.8997 - val_loss: 0.4145 - val_accuracy: 0.7457 - val_weighted_accuracy: 0.7714
# Epoch 12/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.2673 - accuracy: 0.8864 - weighted_accuracy: 0.8916 - val_loss: 0.3787 - val_accuracy: 0.7691 - val_weighted_accuracy: 0.7923
# Epoch 13/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2507 - accuracy: 0.8891 - weighted_accuracy: 0.8931 - val_loss: 0.3266 - val_accuracy: 0.8461 - val_weighted_accuracy: 0.8519
# Epoch 14/100
# 149/149 [==============================] - 16s 110ms/step - loss: 0.2252 - accuracy: 0.9074 - weighted_accuracy: 0.9117 - val_loss: 0.3728 - val_accuracy: 0.8218 - val_weighted_accuracy: 0.8258
# Epoch 15/100
# 149/149 [==============================] - 15s 98ms/step - loss: 0.2025 - accuracy: 0.9229 - weighted_accuracy: 0.9278 - val_loss: 0.3011 - val_accuracy: 0.8712 - val_weighted_accuracy: 0.8760
# Epoch 16/100
# 149/149 [==============================] - 15s 98ms/step - loss: 0.2081 - accuracy: 0.9152 - weighted_accuracy: 0.9200 - val_loss: 0.3045 - val_accuracy: 0.8605 - val_weighted_accuracy: 0.8650
# Epoch 17/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.2008 - accuracy: 0.9156 - weighted_accuracy: 0.9216 - val_loss: 0.3656 - val_accuracy: 0.8300 - val_weighted_accuracy: 0.8411
# Epoch 18/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1989 - accuracy: 0.9192 - weighted_accuracy: 0.9237 - val_loss: 0.3700 - val_accuracy: 0.8140 - val_weighted_accuracy: 0.8152
# Epoch 19/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1731 - accuracy: 0.9370 - weighted_accuracy: 0.9404 - val_loss: 0.2865 - val_accuracy: 0.8770 - val_weighted_accuracy: 0.8817
# Epoch 20/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1895 - accuracy: 0.9213 - weighted_accuracy: 0.9266 - val_loss: 0.3017 - val_accuracy: 0.8712 - val_weighted_accuracy: 0.8801
# Epoch 21/100
# 149/149 [==============================] - 15s 97ms/step - loss: 0.1743 - accuracy: 0.9292 - weighted_accuracy: 0.9340 - val_loss: 0.2797 - val_accuracy: 0.8770 - val_weighted_accuracy: 0.8818
# Epoch 22/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1728 - accuracy: 0.9284 - weighted_accuracy: 0.9324 - val_loss: 0.2786 - val_accuracy: 0.8724 - val_weighted_accuracy: 0.8791
# Epoch 23/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1720 - accuracy: 0.9288 - weighted_accuracy: 0.9341 - val_loss: 0.5472 - val_accuracy: 0.7321 - val_weighted_accuracy: 0.7521
# Epoch 24/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1664 - accuracy: 0.9309 - weighted_accuracy: 0.9368 - val_loss: 0.2788 - val_accuracy: 0.8547 - val_weighted_accuracy: 0.8695
# Epoch 25/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1581 - accuracy: 0.9385 - weighted_accuracy: 0.9425 - val_loss: 0.2730 - val_accuracy: 0.8844 - val_weighted_accuracy: 0.8895
# Epoch 26/100
# 149/149 [==============================] - 16s 105ms/step - loss: 0.1486 - accuracy: 0.9427 - weighted_accuracy: 0.9472 - val_loss: 0.3260 - val_accuracy: 0.8469 - val_weighted_accuracy: 0.8572
# Epoch 27/100
# 149/149 [==============================] - 15s 100ms/step - loss: 0.1533 - accuracy: 0.9358 - weighted_accuracy: 0.9411 - val_loss: 0.2651 - val_accuracy: 0.8679 - val_weighted_accuracy: 0.8770
# Epoch 28/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1474 - accuracy: 0.9433 - weighted_accuracy: 0.9483 - val_loss: 0.3007 - val_accuracy: 0.8399 - val_weighted_accuracy: 0.8537
# Epoch 29/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.1463 - accuracy: 0.9391 - weighted_accuracy: 0.9445 - val_loss: 0.2698 - val_accuracy: 0.8605 - val_weighted_accuracy: 0.8738
# Epoch 30/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1910 - accuracy: 0.9089 - weighted_accuracy: 0.9153 - val_loss: 0.2949 - val_accuracy: 0.8510 - val_weighted_accuracy: 0.8624
# Epoch 31/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1612 - accuracy: 0.9334 - weighted_accuracy: 0.9378 - val_loss: 0.3012 - val_accuracy: 0.8156 - val_weighted_accuracy: 0.8349
# Epoch 32/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1489 - accuracy: 0.9410 - weighted_accuracy: 0.9455 - val_loss: 0.2656 - val_accuracy: 0.8802 - val_weighted_accuracy: 0.8867
# Epoch 33/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1368 - accuracy: 0.9456 - weighted_accuracy: 0.9503 - val_loss: 0.3151 - val_accuracy: 0.8193 - val_weighted_accuracy: 0.8383
# Epoch 34/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1403 - accuracy: 0.9395 - weighted_accuracy: 0.9434 - val_loss: 0.2576 - val_accuracy: 0.8519 - val_weighted_accuracy: 0.8674
# Epoch 35/100
# 149/149 [==============================] - 14s 97ms/step - loss: 0.1283 - accuracy: 0.9513 - weighted_accuracy: 0.9562 - val_loss: 0.2570 - val_accuracy: 0.8840 - val_weighted_accuracy: 0.8885
# best_epoch:  24

# %%
train_yhat = model.predict(training_features)

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_rms'] = model.evaluate(training_features, audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 3s 21ms/step
# 149/149 [==============================] - 2s 15ms/step - loss: 0.2160 - accuracy: 0.9486 - weighted_accuracy: 0.9486

# %%
val_yhat = model.predict(validation_features)

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_rms'] = model.evaluate(validation_features, audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 1s 15ms/step
# 76/76 [==============================] - 1s 15ms/step - loss: 0.4668 - accuracy: 0.8844 - weighted_accuracy: 0.8844

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.92      0.96      0.94      1603
#       comsan       0.96      0.95      0.96      1578
#      eaywag1       0.97      0.94      0.95      1582
#
#     accuracy                           0.95      4763
#    macro avg       0.95      0.95      0.95      4763
# weighted avg       0.95      0.95      0.95      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.86      0.89      0.88      1032
#       comsan       0.88      0.89      0.88       618
#      eaywag1       0.92      0.87      0.89       780
#
#     accuracy                           0.88      2430
#    macro avg       0.89      0.88      0.89      2430
# weighted avg       0.89      0.88      0.88      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# ## With mfcc & spectral_centroid

# %% [markdown]
# ### create features

# %%
training_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['spectral_centroid']), axis=-1)

training_features
# Out:
# array([[[0.68316633, 0.59291363, 0.53691167, ..., 0.29569203,
#          0.5300293 , 0.48459963],
#         [0.68208945, 0.57179201, 0.50458699, ..., 0.40497959,
#          0.53811288, 0.51239413],
#         [0.6526171 , 0.55147213, 0.55114627, ..., 0.42884982,
#          0.57414222, 0.55377329],
#         ...,
#         [0.63545215, 0.51672482, 0.72968334, ..., 0.44959253,
#          0.7061733 , 0.6423274 ],
#         [0.64894331, 0.51310462, 0.72684944, ..., 0.4500671 ,
#          0.59251463, 0.64443749],
#         [0.65161562, 0.51605314, 0.67196417, ..., 0.43407208,
#          0.41794068, 0.60034007]],
#
#        [[0.77090144, 0.56333971, 0.44750988, ..., 0.47935772,
#          0.60667121, 0.46375164],
#         [0.76870942, 0.55716461, 0.43611079, ..., 0.54752368,
#          0.67083639, 0.44663405],
#         [0.73958874, 0.53581363, 0.49239874, ..., 0.58571094,
#          0.6061154 , 0.45759842],
#         ...,
#         [0.69683993, 0.5428623 , 0.58974713, ..., 0.61003953,
#          0.64704943, 0.48608021],
#         [0.69118834, 0.56308669, 0.59943759, ..., 0.55564928,
#          0.48460883, 0.48488517],
#         [0.68436086, 0.5415647 , 0.59406155, ..., 0.50401896,
#          0.41306552, 0.48098449]],
#
#        [[0.75341856, 0.33436739, 0.44527382, ..., 0.80550671,
#          0.43145433, 0.5092699 ],
#         [0.79357547, 0.26852542, 0.42530921, ..., 0.66615599,
#          0.59302372, 0.54444934],
#         [0.78716105, 0.23256648, 0.47526145, ..., 0.63948256,
#          0.58878636, 0.57766578],
#         ...,
#         [0.50628686, 0.6297636 , 0.55561578, ..., 0.5322715 ,
#          0.56162953, 0.33065641],
#         [0.51167381, 0.63981414, 0.57361501, ..., 0.47569013,
#          0.5742805 , 0.34356091],
#         [0.51984173, 0.63319826, 0.6013931 , ..., 0.56125164,
#          0.63937485, 0.33158849]],
#
#        ...,
#
#        [[0.75839806, 0.73890197, 0.45989856, ..., 0.47925678,
#          0.4124774 , 0.24081867],
#         [0.74586451, 0.71836329, 0.42753008, ..., 0.51785761,
#          0.47466549, 0.24125327],
#         [0.75839871, 0.58011323, 0.55841541, ..., 0.50919199,
#          0.433525  , 0.45421178],
#         ...,
#         [0.63716823, 0.62857109, 0.53005832, ..., 0.57411486,
#          0.40220731, 0.37071089],
#         [0.66542506, 0.6158067 , 0.53074467, ..., 0.47976279,
#          0.35186639, 0.42920803],
#         [0.65818405, 0.63215637, 0.55590814, ..., 0.46865749,
#          0.34379011, 0.38910207]],
#
#        [[0.69039929, 0.27471635, 0.20926896, ..., 0.69467998,
#          0.49891511, 0.56738513],
#         [0.65170419, 0.26937437, 0.13883993, ..., 0.58079952,
#          0.52308011, 0.53871955],
#         [0.59383672, 0.24614182, 0.13279641, ..., 0.62337929,
#          0.51421726, 0.52246208],
#         ...,
#         [0.61014241, 0.24159512, 0.13504323, ..., 0.66301745,
#          0.31478655, 0.46416792],
#         [0.62687308, 0.2898204 , 0.13103324, ..., 0.58928066,
#          0.31412172, 0.4812604 ],
#         [0.63534236, 0.32786077, 0.17737713, ..., 0.60986298,
#          0.39471531, 0.46897234]],
#
#        [[0.57134223, 0.35829791, 0.59592283, ..., 0.49955964,
#          0.41801837, 0.6671895 ],
#         [0.52887601, 0.30040449, 0.56698322, ..., 0.578803  ,
#          0.39213565, 0.69059374],
#         [0.45296973, 0.28502917, 0.52970201, ..., 0.65853179,
#          0.44583637, 0.73152152],
#         ...,
#         [0.35696495, 0.5035879 , 0.35562232, ..., 0.60535771,
#          0.41010246, 0.43124377],
#         [0.36979246, 0.5072726 , 0.26958677, ..., 0.58033288,
#          0.36484334, 0.41420753],
#         [0.37493837, 0.49631387, 0.28284302, ..., 0.64517653,
#          0.39267009, 0.40765066]]])

# %%
training_features.shape
# Out:
# (4763, 251, 21)

# %%
validation_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['spectral_centroid']), axis=-1)

validation_features
# Out:
# array([[[0.60736156, 0.5236882 , 0.50165933, ..., 0.55212289,
#          0.35984367, 0.51545053],
#         [0.60613585, 0.53023928, 0.44283968, ..., 0.6189791 ,
#          0.40108734, 0.49874055],
#         [0.57310259, 0.52499747, 0.49937668, ..., 0.63101941,
#          0.42959955, 0.51456638],
#         ...,
#         [0.56484628, 0.53384393, 0.53603375, ..., 0.47962302,
#          0.43652374, 0.49110592],
#         [0.58220553, 0.54552102, 0.51468575, ..., 0.44923827,
#          0.41285479, 0.47582734],
#         [0.58902442, 0.51676226, 0.52040446, ..., 0.44315791,
#          0.45294771, 0.47576837]],
#
#        [[0.04757321, 0.55337828, 0.52360862, ..., 0.55591893,
#          0.47346288, 0.55908266],
#         [0.02094185, 0.53757769, 0.48080891, ..., 0.55688024,
#          0.54338837, 0.55742316],
#         [0.19114172, 0.47221273, 0.34016225, ..., 0.63151795,
#          0.43581176, 0.48030338],
#         ...,
#         [0.46464425, 0.49159396, 0.36009547, ..., 0.55938774,
#          0.42548728, 0.44890365],
#         [0.46792549, 0.50985813, 0.33038729, ..., 0.47706351,
#          0.40889534, 0.45020048],
#         [0.48512626, 0.50881296, 0.33999783, ..., 0.44166297,
#          0.33910498, 0.42894007]],
#
#        [[0.70478338, 0.79120028, 0.58331972, ..., 0.48871115,
#          0.42061213, 0.13519012],
#         [0.71130258, 0.77527118, 0.54398525, ..., 0.55816066,
#          0.49556312, 0.12938562],
#         [0.61466712, 0.74740255, 0.60672379, ..., 0.62072307,
#          0.52423811, 0.08993516],
#         ...,
#         [0.62319624, 0.71127313, 0.67235225, ..., 0.73649263,
#          0.62420797, 0.19031238],
#         [0.62555897, 0.72974569, 0.68608969, ..., 0.64584386,
#          0.54353023, 0.20836148],
#         [0.62834322, 0.73358506, 0.69936126, ..., 0.71059561,
#          0.54381758, 0.18866565]],
#
#        ...,
#
#        [[0.21232843, 0.50565416, 0.53848362, ..., 0.44392207,
#          0.32891846, 0.59364351],
#         [0.18918383, 0.47696787, 0.48546806, ..., 0.53096414,
#          0.39892709, 0.57250442],
#         [0.18889385, 0.46165472, 0.49905002, ..., 0.56151217,
#          0.44452658, 0.55244865],
#         ...,
#         [0.23163903, 0.40094036, 0.51470047, ..., 0.61173582,
#          0.43710482, 0.52202197],
#         [0.24128944, 0.40316302, 0.47045222, ..., 0.52380311,
#          0.41380581, 0.50137548],
#         [0.2519635 , 0.40364349, 0.49215075, ..., 0.59089351,
#          0.43870094, 0.50264623]],
#
#        [[0.73500824, 0.67937571, 0.36775231, ..., 0.43342009,
#          0.46941707, 0.30842605],
#         [0.72632223, 0.66176921, 0.33811408, ..., 0.4787305 ,
#          0.47082561, 0.31101515],
#         [0.68609428, 0.61750817, 0.36775792, ..., 0.48672393,
#          0.38489062, 0.32727988],
#         ...,
#         [0.66731352, 0.62139243, 0.46979403, ..., 0.53701514,
#          0.37462148, 0.35313858],
#         [0.6732626 , 0.6353789 , 0.45923656, ..., 0.4744063 ,
#          0.37806824, 0.36144402],
#         [0.6788246 , 0.63156939, 0.47706696, ..., 0.56890577,
#          0.38024384, 0.34962412]],
#
#        [[0.72578764, 0.82353163, 0.66120869, ..., 0.56684524,
#          0.53783631, 0.14102383],
#         [0.72348392, 0.78951371, 0.60052341, ..., 0.58473307,
#          0.5809409 , 0.16343288],
#         [0.69117761, 0.74431884, 0.63975877, ..., 0.58926588,
#          0.59131777, 0.17790208],
#         ...,
#         [0.64536965, 0.77339047, 0.62916797, ..., 0.67133087,
#          0.49175021, 0.17384796],
#         [0.67905456, 0.7232691 , 0.66068232, ..., 0.61073655,
#          0.55632514, 0.26671358],
#         [0.72213292, 0.65376759, 0.65448451, ..., 0.71492308,
#          0.5670476 , 0.35156235]]])

# %%
validation_features.shape
# Out:
# (2430, 251, 21)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_features,
                    learning_rate=0.001)

history = model.fit(
   x=training_features,
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(validation_features,
                    audio_df['val']['label'],
                    validation_sample_weights
                    ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Audio_Features (InputLayer  [(None, 251, 21)]         0
#  )
#
#  conv_1 (Conv1D)             (None, 251, 32)           3392
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)           0
#
#  conv_2 (Conv1D)             (None, 125, 64)           10304
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)            0
#
#  flatten (Flatten)           (None, 3968)              0
#
#  fc_1 (Dense)                (None, 1024)              4064256
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 3)                 3075
#
# =================================================================
# Total params: 4081027 (15.57 MB)
# Trainable params: 4081027 (15.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 16s 96ms/step - loss: 1.1095 - accuracy: 0.5568 - weighted_accuracy: 0.5692 - val_loss: 0.7968 - val_accuracy: 0.5366 - val_weighted_accuracy: 0.5447
# Epoch 2/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.6421 - accuracy: 0.7008 - weighted_accuracy: 0.7157 - val_loss: 0.6855 - val_accuracy: 0.6947 - val_weighted_accuracy: 0.7051
# Epoch 3/100
# 149/149 [==============================] - 16s 105ms/step - loss: 0.5279 - accuracy: 0.7575 - weighted_accuracy: 0.7681 - val_loss: 0.6131 - val_accuracy: 0.7107 - val_weighted_accuracy: 0.7131
# Epoch 4/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.4673 - accuracy: 0.7961 - weighted_accuracy: 0.8034 - val_loss: 0.6369 - val_accuracy: 0.6778 - val_weighted_accuracy: 0.6868
# Epoch 5/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.4024 - accuracy: 0.8400 - weighted_accuracy: 0.8455 - val_loss: 0.5157 - val_accuracy: 0.7601 - val_weighted_accuracy: 0.7718
# Epoch 6/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.3674 - accuracy: 0.8476 - weighted_accuracy: 0.8555 - val_loss: 0.5417 - val_accuracy: 0.7329 - val_weighted_accuracy: 0.7553
# Epoch 7/100
# 149/149 [==============================] - 17s 112ms/step - loss: 0.3363 - accuracy: 0.8709 - weighted_accuracy: 0.8763 - val_loss: 0.4483 - val_accuracy: 0.8037 - val_weighted_accuracy: 0.8055
# Epoch 8/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.3056 - accuracy: 0.8879 - weighted_accuracy: 0.8932 - val_loss: 0.4028 - val_accuracy: 0.8230 - val_weighted_accuracy: 0.8266
# Epoch 9/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.2927 - accuracy: 0.8986 - weighted_accuracy: 0.9037 - val_loss: 0.4546 - val_accuracy: 0.7749 - val_weighted_accuracy: 0.7909
# Epoch 10/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.2809 - accuracy: 0.8944 - weighted_accuracy: 0.8994 - val_loss: 0.4690 - val_accuracy: 0.8008 - val_weighted_accuracy: 0.8078
# Epoch 11/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.2724 - accuracy: 0.8984 - weighted_accuracy: 0.9040 - val_loss: 0.3527 - val_accuracy: 0.8230 - val_weighted_accuracy: 0.8392
# Epoch 12/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.2407 - accuracy: 0.9175 - weighted_accuracy: 0.9225 - val_loss: 0.3507 - val_accuracy: 0.8407 - val_weighted_accuracy: 0.8519
# Epoch 13/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.2204 - accuracy: 0.9242 - weighted_accuracy: 0.9290 - val_loss: 0.3642 - val_accuracy: 0.8572 - val_weighted_accuracy: 0.8633
# Epoch 14/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2029 - accuracy: 0.9353 - weighted_accuracy: 0.9394 - val_loss: 0.3430 - val_accuracy: 0.8498 - val_weighted_accuracy: 0.8589
# Epoch 15/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1955 - accuracy: 0.9343 - weighted_accuracy: 0.9390 - val_loss: 0.3209 - val_accuracy: 0.8774 - val_weighted_accuracy: 0.8833
# Epoch 16/100
# 149/149 [==============================] - 15s 102ms/step - loss: 0.1897 - accuracy: 0.9347 - weighted_accuracy: 0.9401 - val_loss: 0.3335 - val_accuracy: 0.8605 - val_weighted_accuracy: 0.8645
# Epoch 17/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1858 - accuracy: 0.9368 - weighted_accuracy: 0.9420 - val_loss: 0.2870 - val_accuracy: 0.8728 - val_weighted_accuracy: 0.8765
# Epoch 18/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1783 - accuracy: 0.9387 - weighted_accuracy: 0.9428 - val_loss: 0.3389 - val_accuracy: 0.8531 - val_weighted_accuracy: 0.8586
# Epoch 19/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1721 - accuracy: 0.9372 - weighted_accuracy: 0.9431 - val_loss: 0.3361 - val_accuracy: 0.8650 - val_weighted_accuracy: 0.8691
# Epoch 20/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1927 - accuracy: 0.9271 - weighted_accuracy: 0.9324 - val_loss: 0.3774 - val_accuracy: 0.8202 - val_weighted_accuracy: 0.8287
# Epoch 21/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1685 - accuracy: 0.9412 - weighted_accuracy: 0.9463 - val_loss: 0.3625 - val_accuracy: 0.8292 - val_weighted_accuracy: 0.8437
# Epoch 22/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1508 - accuracy: 0.9484 - weighted_accuracy: 0.9528 - val_loss: 0.3076 - val_accuracy: 0.8733 - val_weighted_accuracy: 0.8768
# Epoch 23/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.1485 - accuracy: 0.9515 - weighted_accuracy: 0.9556 - val_loss: 0.3226 - val_accuracy: 0.8428 - val_weighted_accuracy: 0.8534
# Epoch 24/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1757 - accuracy: 0.9292 - weighted_accuracy: 0.9340 - val_loss: 0.2839 - val_accuracy: 0.8568 - val_weighted_accuracy: 0.8592
# Epoch 25/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1477 - accuracy: 0.9477 - weighted_accuracy: 0.9523 - val_loss: 0.2818 - val_accuracy: 0.8852 - val_weighted_accuracy: 0.8906
# Epoch 26/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1464 - accuracy: 0.9471 - weighted_accuracy: 0.9518 - val_loss: 0.3052 - val_accuracy: 0.8449 - val_weighted_accuracy: 0.8595
# Epoch 27/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1329 - accuracy: 0.9536 - weighted_accuracy: 0.9586 - val_loss: 0.3021 - val_accuracy: 0.8547 - val_weighted_accuracy: 0.8662
# Epoch 28/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1259 - accuracy: 0.9580 - weighted_accuracy: 0.9622 - val_loss: 0.3072 - val_accuracy: 0.8613 - val_weighted_accuracy: 0.8682
# Epoch 29/100
# 149/149 [==============================] - 14s 97ms/step - loss: 0.1297 - accuracy: 0.9540 - weighted_accuracy: 0.9581 - val_loss: 0.3103 - val_accuracy: 0.8609 - val_weighted_accuracy: 0.8713
# Epoch 30/100
# 149/149 [==============================] - 16s 109ms/step - loss: 0.1123 - accuracy: 0.9660 - weighted_accuracy: 0.9702 - val_loss: 0.2699 - val_accuracy: 0.8881 - val_weighted_accuracy: 0.8932
# Epoch 31/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1560 - accuracy: 0.9267 - weighted_accuracy: 0.9322 - val_loss: 0.2793 - val_accuracy: 0.8560 - val_weighted_accuracy: 0.8633
# Epoch 32/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1187 - accuracy: 0.9599 - weighted_accuracy: 0.9632 - val_loss: 0.2681 - val_accuracy: 0.8807 - val_weighted_accuracy: 0.8891
# Epoch 33/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1053 - accuracy: 0.9654 - weighted_accuracy: 0.9689 - val_loss: 0.3799 - val_accuracy: 0.8222 - val_weighted_accuracy: 0.8345
# Epoch 34/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1121 - accuracy: 0.9588 - weighted_accuracy: 0.9632 - val_loss: 0.3184 - val_accuracy: 0.8444 - val_weighted_accuracy: 0.8622
# Epoch 35/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1049 - accuracy: 0.9633 - weighted_accuracy: 0.9670 - val_loss: 0.2804 - val_accuracy: 0.8835 - val_weighted_accuracy: 0.8882
# Epoch 36/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1127 - accuracy: 0.9547 - weighted_accuracy: 0.9591 - val_loss: 0.2833 - val_accuracy: 0.8753 - val_weighted_accuracy: 0.8791
# Epoch 37/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1025 - accuracy: 0.9651 - weighted_accuracy: 0.9688 - val_loss: 0.2775 - val_accuracy: 0.8695 - val_weighted_accuracy: 0.8735
# Epoch 38/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.0957 - accuracy: 0.9675 - weighted_accuracy: 0.9707 - val_loss: 0.2854 - val_accuracy: 0.8642 - val_weighted_accuracy: 0.8754
# Epoch 39/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.0898 - accuracy: 0.9708 - weighted_accuracy: 0.9738 - val_loss: 0.2948 - val_accuracy: 0.8613 - val_weighted_accuracy: 0.8726
# Epoch 40/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.0969 - accuracy: 0.9649 - weighted_accuracy: 0.9683 - val_loss: 0.3160 - val_accuracy: 0.8527 - val_weighted_accuracy: 0.8679
# best_epoch:  29

# %%
train_yhat = model.predict(training_features)

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_spectral_centroid'] = model.evaluate(training_features, audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 2s 14ms/step
# 149/149 [==============================] - 3s 16ms/step - loss: 0.1626 - accuracy: 0.9683 - weighted_accuracy: 0.9683

# %%
val_yhat = model.predict(validation_features)

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_spectral_centroid'] = model.evaluate(validation_features, audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 2s 23ms/step
# 76/76 [==============================] - 1s 16ms/step - loss: 0.4644 - accuracy: 0.8881 - weighted_accuracy: 0.8881

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.95      0.98      0.96      1603
#       comsan       0.96      0.97      0.97      1578
#      eaywag1       1.00      0.95      0.98      1582
#
#     accuracy                           0.97      4763
#    macro avg       0.97      0.97      0.97      4763
# weighted avg       0.97      0.97      0.97      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.87      0.89      0.88      1032
#       comsan       0.87      0.89      0.88       618
#      eaywag1       0.93      0.88      0.90       780
#
#     accuracy                           0.89      2430
#    macro avg       0.89      0.89      0.89      2430
# weighted avg       0.89      0.89      0.89      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# ## With mfcc & rms & spectral_centroid

# %% [markdown]
# ### create features

# %%
training_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['rms'], audio_df['train']['spectral_centroid']), axis=-1)

training_features
# Out:
# array([[[0.68316633, 0.59291363, 0.53691167, ..., 0.5300293 ,
#          0.01766523, 0.48459963],
#         [0.68208945, 0.57179201, 0.50458699, ..., 0.53811288,
#          0.02395274, 0.51239413],
#         [0.6526171 , 0.55147213, 0.55114627, ..., 0.57414222,
#          0.0286761 , 0.55377329],
#         ...,
#         [0.63545215, 0.51672482, 0.72968334, ..., 0.7061733 ,
#          0.05134375, 0.6423274 ],
#         [0.64894331, 0.51310462, 0.72684944, ..., 0.59251463,
#          0.04667601, 0.64443749],
#         [0.65161562, 0.51605314, 0.67196417, ..., 0.41794068,
#          0.03258164, 0.60034007]],
#
#        [[0.77090144, 0.56333971, 0.44750988, ..., 0.60667121,
#          0.02495077, 0.46375164],
#         [0.76870942, 0.55716461, 0.43611079, ..., 0.67083639,
#          0.03008876, 0.44663405],
#         [0.73958874, 0.53581363, 0.49239874, ..., 0.6061154 ,
#          0.03161712, 0.45759842],
#         ...,
#         [0.69683993, 0.5428623 , 0.58974713, ..., 0.64704943,
#          0.01856191, 0.48608021],
#         [0.69118834, 0.56308669, 0.59943759, ..., 0.48460883,
#          0.01758861, 0.48488517],
#         [0.68436086, 0.5415647 , 0.59406155, ..., 0.41306552,
#          0.01379679, 0.48098449]],
#
#        [[0.75341856, 0.33436739, 0.44527382, ..., 0.43145433,
#          0.20626543, 0.5092699 ],
#         [0.79357547, 0.26852542, 0.42530921, ..., 0.59302372,
#          0.28964704, 0.54444934],
#         [0.78716105, 0.23256648, 0.47526145, ..., 0.58878636,
#          0.3565841 , 0.57766578],
#         ...,
#         [0.50628686, 0.6297636 , 0.55561578, ..., 0.56162953,
#          0.00710791, 0.33065641],
#         [0.51167381, 0.63981414, 0.57361501, ..., 0.5742805 ,
#          0.00532044, 0.34356091],
#         [0.51984173, 0.63319826, 0.6013931 , ..., 0.63937485,
#          0.00379898, 0.33158849]],
#
#        ...,
#
#        [[0.75839806, 0.73890197, 0.45989856, ..., 0.4124774 ,
#          0.0231342 , 0.24081867],
#         [0.74586451, 0.71836329, 0.42753008, ..., 0.47466549,
#          0.02917222, 0.24125327],
#         [0.75839871, 0.58011323, 0.55841541, ..., 0.433525  ,
#          0.08086979, 0.45421178],
#         ...,
#         [0.63716823, 0.62857109, 0.53005832, ..., 0.40220731,
#          0.01109741, 0.37071089],
#         [0.66542506, 0.6158067 , 0.53074467, ..., 0.35186639,
#          0.00946815, 0.42920803],
#         [0.65818405, 0.63215637, 0.55590814, ..., 0.34379011,
#          0.00824792, 0.38910207]],
#
#        [[0.69039929, 0.27471635, 0.20926896, ..., 0.49891511,
#          0.02759135, 0.56738513],
#         [0.65170419, 0.26937437, 0.13883993, ..., 0.52308011,
#          0.02848949, 0.53871955],
#         [0.59383672, 0.24614182, 0.13279641, ..., 0.51421726,
#          0.03389978, 0.52246208],
#         ...,
#         [0.61014241, 0.24159512, 0.13504323, ..., 0.31478655,
#          0.03445767, 0.46416792],
#         [0.62687308, 0.2898204 , 0.13103324, ..., 0.31412172,
#          0.03460433, 0.4812604 ],
#         [0.63534236, 0.32786077, 0.17737713, ..., 0.39471531,
#          0.02899204, 0.46897234]],
#
#        [[0.57134223, 0.35829791, 0.59592283, ..., 0.41801837,
#          0.02310807, 0.6671895 ],
#         [0.52887601, 0.30040449, 0.56698322, ..., 0.39213565,
#          0.02121984, 0.69059374],
#         [0.45296973, 0.28502917, 0.52970201, ..., 0.44583637,
#          0.02436587, 0.73152152],
#         ...,
#         [0.35696495, 0.5035879 , 0.35562232, ..., 0.41010246,
#          0.00126841, 0.43124377],
#         [0.36979246, 0.5072726 , 0.26958677, ..., 0.36484334,
#          0.00116942, 0.41420753],
#         [0.37493837, 0.49631387, 0.28284302, ..., 0.39267009,
#          0.0011289 , 0.40765066]]])

# %%
training_features.shape
# Out:
# (4763, 251, 22)

# %%
validation_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['rms'], audio_df['val']['spectral_centroid']), axis=-1)

validation_features
# Out:
# array([[[6.07361555e-01, 5.23688197e-01, 5.01659334e-01, ...,
#          3.59843671e-01, 4.57111094e-03, 5.15450535e-01],
#         [6.06135845e-01, 5.30239284e-01, 4.42839682e-01, ...,
#          4.01087344e-01, 4.72569047e-03, 4.98740553e-01],
#         [5.73102593e-01, 5.24997473e-01, 4.99376684e-01, ...,
#          4.29599553e-01, 4.88307094e-03, 5.14566375e-01],
#         ...,
#         [5.64846277e-01, 5.33843935e-01, 5.36033750e-01, ...,
#          4.36523736e-01, 5.69090201e-03, 4.91105920e-01],
#         [5.82205534e-01, 5.45521021e-01, 5.14685750e-01, ...,
#          4.12854791e-01, 5.48938056e-03, 4.75827340e-01],
#         [5.89024425e-01, 5.16762257e-01, 5.20404458e-01, ...,
#          4.52947706e-01, 4.83821239e-03, 4.75768375e-01]],
#
#        [[4.75732088e-02, 5.53378284e-01, 5.23608625e-01, ...,
#          4.73462880e-01, 2.78365405e-07, 5.59082662e-01],
#         [2.09418535e-02, 5.37577689e-01, 4.80808914e-01, ...,
#          5.43388367e-01, 4.39661926e-05, 5.57423164e-01],
#         [1.91141725e-01, 4.72212732e-01, 3.40162247e-01, ...,
#          4.35811758e-01, 9.04211251e-04, 4.80303378e-01],
#         ...,
#         [4.64644253e-01, 4.91593957e-01, 3.60095471e-01, ...,
#          4.25487280e-01, 2.31666211e-03, 4.48903654e-01],
#         [4.67925489e-01, 5.09858131e-01, 3.30387294e-01, ...,
#          4.08895344e-01, 2.13860231e-03, 4.50200479e-01],
#         [4.85126257e-01, 5.08812964e-01, 3.39997828e-01, ...,
#          3.39104980e-01, 1.70903362e-03, 4.28940073e-01]],
#
#        [[7.04783380e-01, 7.91200280e-01, 5.83319724e-01, ...,
#          4.20612127e-01, 5.83346300e-02, 1.35190116e-01],
#         [7.11302578e-01, 7.75271177e-01, 5.43985248e-01, ...,
#          4.95563120e-01, 6.16376810e-02, 1.29385624e-01],
#         [6.14667118e-01, 7.47402549e-01, 6.06723785e-01, ...,
#          5.24238110e-01, 7.72752166e-02, 8.99351637e-02],
#         ...,
#         [6.23196244e-01, 7.11273134e-01, 6.72352254e-01, ...,
#          6.24207973e-01, 3.40738967e-02, 1.90312378e-01],
#         [6.25558972e-01, 7.29745686e-01, 6.86089694e-01, ...,
#          5.43530226e-01, 3.22043374e-02, 2.08361484e-01],
#         [6.28343225e-01, 7.33585060e-01, 6.99361265e-01, ...,
#          5.43817580e-01, 2.40894184e-02, 1.88665654e-01]],
#
#        ...,
#
#        [[2.12328434e-01, 5.05654156e-01, 5.38483620e-01, ...,
#          3.28918457e-01, 1.21362347e-04, 5.93643507e-01],
#         [1.89183831e-01, 4.76967871e-01, 4.85468060e-01, ...,
#          3.98927093e-01, 1.48656516e-04, 5.72504424e-01],
#         [1.88893855e-01, 4.61654723e-01, 4.99050021e-01, ...,
#          4.44526583e-01, 1.45938626e-04, 5.52448647e-01],
#         ...,
#         [2.31639028e-01, 4.00940359e-01, 5.14700472e-01, ...,
#          4.37104821e-01, 5.30444202e-04, 5.22021974e-01],
#         [2.41289437e-01, 4.03163016e-01, 4.70452219e-01, ...,
#          4.13805813e-01, 5.35602216e-04, 5.01375478e-01],
#         [2.51963496e-01, 4.03643489e-01, 4.92150754e-01, ...,
#          4.38700944e-01, 4.86365228e-04, 5.02646233e-01]],
#
#        [[7.35008240e-01, 6.79375708e-01, 3.67752314e-01, ...,
#          4.69417065e-01, 1.32603273e-02, 3.08426054e-01],
#         [7.26322234e-01, 6.61769211e-01, 3.38114083e-01, ...,
#          4.70825613e-01, 1.46202845e-02, 3.11015150e-01],
#         [6.86094284e-01, 6.17508173e-01, 3.67757916e-01, ...,
#          3.84890616e-01, 1.56203359e-02, 3.27279882e-01],
#         ...,
#         [6.67313516e-01, 6.21392429e-01, 4.69794035e-01, ...,
#          3.74621481e-01, 1.34100476e-02, 3.53138584e-01],
#         [6.73262596e-01, 6.35378897e-01, 4.59236562e-01, ...,
#          3.78068238e-01, 1.21065136e-02, 3.61444016e-01],
#         [6.78824604e-01, 6.31569386e-01, 4.77066964e-01, ...,
#          3.80243838e-01, 9.85576771e-03, 3.49624117e-01]],
#
#        [[7.25787640e-01, 8.23531628e-01, 6.61208689e-01, ...,
#          5.37836313e-01, 3.56985964e-02, 1.41023833e-01],
#         [7.23483920e-01, 7.89513707e-01, 6.00523412e-01, ...,
#          5.80940902e-01, 3.79531085e-02, 1.63432885e-01],
#         [6.91177607e-01, 7.44318843e-01, 6.39758766e-01, ...,
#          5.91317773e-01, 3.92461866e-02, 1.77902082e-01],
#         ...,
#         [6.45369649e-01, 7.73390472e-01, 6.29167974e-01, ...,
#          4.91750211e-01, 2.48103216e-02, 1.73847956e-01],
#         [6.79054558e-01, 7.23269105e-01, 6.60682321e-01, ...,
#          5.56325138e-01, 2.18358468e-02, 2.66713581e-01],
#         [7.22132921e-01, 6.53767586e-01, 6.54484510e-01, ...,
#          5.67047596e-01, 1.78664420e-02, 3.51562348e-01]]])

# %%
validation_features.shape
# Out:
# (2430, 251, 22)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_features,
                    learning_rate=0.001)

history = model.fit(
   x=training_features,
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(validation_features,
                    audio_df['val']['label'],
                    validation_sample_weights
                    ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Audio_Features (InputLayer  [(None, 251, 22)]         0
#  )
#
#  conv_1 (Conv1D)             (None, 251, 32)           3552
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)           0
#
#  conv_2 (Conv1D)             (None, 125, 64)           10304
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)            0
#
#  flatten (Flatten)           (None, 3968)              0
#
#  fc_1 (Dense)                (None, 1024)              4064256
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 3)                 3075
#
# =================================================================
# Total params: 4081187 (15.57 MB)
# Trainable params: 4081187 (15.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 17s 105ms/step - loss: 1.1421 - accuracy: 0.5564 - weighted_accuracy: 0.5696 - val_loss: 0.8283 - val_accuracy: 0.5663 - val_weighted_accuracy: 0.5900
# Epoch 2/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.6518 - accuracy: 0.7143 - weighted_accuracy: 0.7297 - val_loss: 0.6344 - val_accuracy: 0.6979 - val_weighted_accuracy: 0.7181
# Epoch 3/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.5146 - accuracy: 0.7955 - weighted_accuracy: 0.8049 - val_loss: 0.5550 - val_accuracy: 0.7350 - val_weighted_accuracy: 0.7510
# Epoch 4/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.4176 - accuracy: 0.8352 - weighted_accuracy: 0.8434 - val_loss: 0.4754 - val_accuracy: 0.7872 - val_weighted_accuracy: 0.7899
# Epoch 5/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.3707 - accuracy: 0.8579 - weighted_accuracy: 0.8650 - val_loss: 0.4596 - val_accuracy: 0.7922 - val_weighted_accuracy: 0.7905
# Epoch 6/100
# 149/149 [==============================] - 15s 98ms/step - loss: 0.3463 - accuracy: 0.8637 - weighted_accuracy: 0.8707 - val_loss: 0.4592 - val_accuracy: 0.8292 - val_weighted_accuracy: 0.8349
# Epoch 7/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.3104 - accuracy: 0.8833 - weighted_accuracy: 0.8904 - val_loss: 0.3925 - val_accuracy: 0.8440 - val_weighted_accuracy: 0.8442
# Epoch 8/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.2905 - accuracy: 0.8894 - weighted_accuracy: 0.8969 - val_loss: 0.3861 - val_accuracy: 0.8481 - val_weighted_accuracy: 0.8512
# Epoch 9/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.2558 - accuracy: 0.9129 - weighted_accuracy: 0.9181 - val_loss: 0.3723 - val_accuracy: 0.8514 - val_weighted_accuracy: 0.8507
# Epoch 10/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.2492 - accuracy: 0.9070 - weighted_accuracy: 0.9135 - val_loss: 0.3554 - val_accuracy: 0.8189 - val_weighted_accuracy: 0.8286
# Epoch 11/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.2236 - accuracy: 0.9229 - weighted_accuracy: 0.9290 - val_loss: 0.3876 - val_accuracy: 0.8337 - val_weighted_accuracy: 0.8513
# Epoch 12/100
# 149/149 [==============================] - 14s 97ms/step - loss: 0.2168 - accuracy: 0.9204 - weighted_accuracy: 0.9251 - val_loss: 0.2926 - val_accuracy: 0.8716 - val_weighted_accuracy: 0.8812
# Epoch 13/100
# 149/149 [==============================] - 14s 97ms/step - loss: 0.2100 - accuracy: 0.9265 - weighted_accuracy: 0.9314 - val_loss: 0.3346 - val_accuracy: 0.8638 - val_weighted_accuracy: 0.8736
# Epoch 14/100
# 149/149 [==============================] - 14s 97ms/step - loss: 0.2031 - accuracy: 0.9280 - weighted_accuracy: 0.9334 - val_loss: 0.3527 - val_accuracy: 0.8494 - val_weighted_accuracy: 0.8533
# Epoch 15/100
# 149/149 [==============================] - 16s 104ms/step - loss: 0.1965 - accuracy: 0.9253 - weighted_accuracy: 0.9316 - val_loss: 0.3030 - val_accuracy: 0.8716 - val_weighted_accuracy: 0.8754
# Epoch 16/100
# 149/149 [==============================] - 14s 97ms/step - loss: 0.1824 - accuracy: 0.9387 - weighted_accuracy: 0.9422 - val_loss: 0.4448 - val_accuracy: 0.7728 - val_weighted_accuracy: 0.7971
# Epoch 17/100
# 149/149 [==============================] - 15s 98ms/step - loss: 0.1999 - accuracy: 0.9194 - weighted_accuracy: 0.9251 - val_loss: 0.3188 - val_accuracy: 0.8786 - val_weighted_accuracy: 0.8823
# Epoch 18/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1636 - accuracy: 0.9442 - weighted_accuracy: 0.9487 - val_loss: 0.3517 - val_accuracy: 0.8263 - val_weighted_accuracy: 0.8428
# Epoch 19/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1652 - accuracy: 0.9379 - weighted_accuracy: 0.9430 - val_loss: 0.2943 - val_accuracy: 0.8794 - val_weighted_accuracy: 0.8829
# Epoch 20/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1485 - accuracy: 0.9473 - weighted_accuracy: 0.9525 - val_loss: 0.3296 - val_accuracy: 0.8741 - val_weighted_accuracy: 0.8791
# Epoch 21/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1505 - accuracy: 0.9439 - weighted_accuracy: 0.9487 - val_loss: 0.2888 - val_accuracy: 0.8774 - val_weighted_accuracy: 0.8844
# Epoch 22/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1501 - accuracy: 0.9454 - weighted_accuracy: 0.9505 - val_loss: 0.3107 - val_accuracy: 0.8239 - val_weighted_accuracy: 0.8419
# Epoch 23/100
# 149/149 [==============================] - 15s 102ms/step - loss: 0.1399 - accuracy: 0.9502 - weighted_accuracy: 0.9543 - val_loss: 0.2862 - val_accuracy: 0.8778 - val_weighted_accuracy: 0.8844
# Epoch 24/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1468 - accuracy: 0.9414 - weighted_accuracy: 0.9459 - val_loss: 0.2885 - val_accuracy: 0.8679 - val_weighted_accuracy: 0.8760
# Epoch 25/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1334 - accuracy: 0.9523 - weighted_accuracy: 0.9560 - val_loss: 0.2895 - val_accuracy: 0.8926 - val_weighted_accuracy: 0.8949
# Epoch 26/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1416 - accuracy: 0.9450 - weighted_accuracy: 0.9504 - val_loss: 0.2711 - val_accuracy: 0.8605 - val_weighted_accuracy: 0.8695
# Epoch 27/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1497 - accuracy: 0.9358 - weighted_accuracy: 0.9409 - val_loss: 0.3070 - val_accuracy: 0.8728 - val_weighted_accuracy: 0.8792
# Epoch 28/100
# 149/149 [==============================] - 15s 103ms/step - loss: 0.1286 - accuracy: 0.9555 - weighted_accuracy: 0.9600 - val_loss: 0.3012 - val_accuracy: 0.8687 - val_weighted_accuracy: 0.8750
# Epoch 29/100
# 149/149 [==============================] - 13s 84ms/step - loss: 0.1260 - accuracy: 0.9507 - weighted_accuracy: 0.9560 - val_loss: 0.3358 - val_accuracy: 0.8296 - val_weighted_accuracy: 0.8448
# Epoch 30/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1183 - accuracy: 0.9593 - weighted_accuracy: 0.9627 - val_loss: 0.2761 - val_accuracy: 0.8844 - val_weighted_accuracy: 0.8914
# Epoch 31/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1291 - accuracy: 0.9532 - weighted_accuracy: 0.9564 - val_loss: 0.2665 - val_accuracy: 0.8815 - val_weighted_accuracy: 0.8885
# Epoch 32/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1270 - accuracy: 0.9509 - weighted_accuracy: 0.9547 - val_loss: 0.2757 - val_accuracy: 0.8765 - val_weighted_accuracy: 0.8804
# Epoch 33/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1151 - accuracy: 0.9580 - weighted_accuracy: 0.9616 - val_loss: 0.3230 - val_accuracy: 0.8728 - val_weighted_accuracy: 0.8765
# Epoch 34/100
# 149/149 [==============================] - 13s 91ms/step - loss: 0.1076 - accuracy: 0.9618 - weighted_accuracy: 0.9649 - val_loss: 0.2908 - val_accuracy: 0.8502 - val_weighted_accuracy: 0.8630
# Epoch 35/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1019 - accuracy: 0.9656 - weighted_accuracy: 0.9692 - val_loss: 0.3072 - val_accuracy: 0.8708 - val_weighted_accuracy: 0.8800
# best_epoch:  24

# %%
train_yhat = model.predict(training_features)

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_rms_spectral_centroid'] = model.evaluate(training_features, audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 2s 15ms/step
# 149/149 [==============================] - 3s 15ms/step - loss: 0.1551 - accuracy: 0.9714 - weighted_accuracy: 0.9714

# %%
val_yhat = model.predict(validation_features)

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_rms_spectral_centroid'] = model.evaluate(validation_features, audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 2s 25ms/step
# 76/76 [==============================] - 2s 25ms/step - loss: 0.4788 - accuracy: 0.8926 - weighted_accuracy: 0.8926

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.96      0.98      0.97      1603
#       comsan       0.97      0.97      0.97      1578
#      eaywag1       0.98      0.97      0.98      1582
#
#     accuracy                           0.97      4763
#    macro avg       0.97      0.97      0.97      4763
# weighted avg       0.97      0.97      0.97      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.90      0.87      0.89      1032
#       comsan       0.84      0.90      0.87       618
#      eaywag1       0.92      0.91      0.92       780
#
#     accuracy                           0.89      2430
#    macro avg       0.89      0.90      0.89      2430
# weighted avg       0.89      0.89      0.89      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# ## With mfcc & rms & chroma & rms & spectral_centroid

# %% [markdown]
# ### create features

# %%
training_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['chroma'], audio_df['train']['rms'], audio_df['train']['spectral_centroid']), axis=-1)

training_features
# Out:
# array([[[0.68316633, 0.59291363, 0.53691167, ..., 0.28842098,
#          0.01766523, 0.48459963],
#         [0.68208945, 0.57179201, 0.50458699, ..., 0.11062346,
#          0.02395274, 0.51239413],
#         [0.6526171 , 0.55147213, 0.55114627, ..., 0.03657101,
#          0.0286761 , 0.55377329],
#         ...,
#         [0.63545215, 0.51672482, 0.72968334, ..., 0.00633229,
#          0.05134375, 0.6423274 ],
#         [0.64894331, 0.51310462, 0.72684944, ..., 0.0137417 ,
#          0.04667601, 0.64443749],
#         [0.65161562, 0.51605314, 0.67196417, ..., 0.02791071,
#          0.03258164, 0.60034007]],
#
#        [[0.77090144, 0.56333971, 0.44750988, ..., 0.43214661,
#          0.02495077, 0.46375164],
#         [0.76870942, 0.55716461, 0.43611079, ..., 0.68306273,
#          0.03008876, 0.44663405],
#         [0.73958874, 0.53581363, 0.49239874, ..., 0.5532968 ,
#          0.03161712, 0.45759842],
#         ...,
#         [0.69683993, 0.5428623 , 0.58974713, ..., 1.        ,
#          0.01856191, 0.48608021],
#         [0.69118834, 0.56308669, 0.59943759, ..., 1.        ,
#          0.01758861, 0.48488517],
#         [0.68436086, 0.5415647 , 0.59406155, ..., 0.73957705,
#          0.01379679, 0.48098449]],
#
#        [[0.75341856, 0.33436739, 0.44527382, ..., 0.64900815,
#          0.20626543, 0.5092699 ],
#         [0.79357547, 0.26852542, 0.42530921, ..., 0.91524512,
#          0.28964704, 0.54444934],
#         [0.78716105, 0.23256648, 0.47526145, ..., 0.53247851,
#          0.3565841 , 0.57766578],
#         ...,
#         [0.50628686, 0.6297636 , 0.55561578, ..., 0.44254601,
#          0.00710791, 0.33065641],
#         [0.51167381, 0.63981414, 0.57361501, ..., 0.18677777,
#          0.00532044, 0.34356091],
#         [0.51984173, 0.63319826, 0.6013931 , ..., 0.21063809,
#          0.00379898, 0.33158849]],
#
#        ...,
#
#        [[0.75839806, 0.73890197, 0.45989856, ..., 0.34553298,
#          0.0231342 , 0.24081867],
#         [0.74586451, 0.71836329, 0.42753008, ..., 0.40422282,
#          0.02917222, 0.24125327],
#         [0.75839871, 0.58011323, 0.55841541, ..., 0.58897692,
#          0.08086979, 0.45421178],
#         ...,
#         [0.63716823, 0.62857109, 0.53005832, ..., 0.4144288 ,
#          0.01109741, 0.37071089],
#         [0.66542506, 0.6158067 , 0.53074467, ..., 0.59813249,
#          0.00946815, 0.42920803],
#         [0.65818405, 0.63215637, 0.55590814, ..., 0.63178533,
#          0.00824792, 0.38910207]],
#
#        [[0.69039929, 0.27471635, 0.20926896, ..., 0.13937107,
#          0.02759135, 0.56738513],
#         [0.65170419, 0.26937437, 0.13883993, ..., 0.34827796,
#          0.02848949, 0.53871955],
#         [0.59383672, 0.24614182, 0.13279641, ..., 0.47954434,
#          0.03389978, 0.52246208],
#         ...,
#         [0.61014241, 0.24159512, 0.13504323, ..., 0.2059934 ,
#          0.03445767, 0.46416792],
#         [0.62687308, 0.2898204 , 0.13103324, ..., 0.18316865,
#          0.03460433, 0.4812604 ],
#         [0.63534236, 0.32786077, 0.17737713, ..., 0.47528321,
#          0.02899204, 0.46897234]],
#
#        [[0.57134223, 0.35829791, 0.59592283, ..., 0.65278697,
#          0.02310807, 0.6671895 ],
#         [0.52887601, 0.30040449, 0.56698322, ..., 0.85635519,
#          0.02121984, 0.69059374],
#         [0.45296973, 0.28502917, 0.52970201, ..., 0.44490317,
#          0.02436587, 0.73152152],
#         ...,
#         [0.35696495, 0.5035879 , 0.35562232, ..., 0.31914431,
#          0.00126841, 0.43124377],
#         [0.36979246, 0.5072726 , 0.26958677, ..., 0.08482651,
#          0.00116942, 0.41420753],
#         [0.37493837, 0.49631387, 0.28284302, ..., 0.03683891,
#          0.0011289 , 0.40765066]]])

# %%
training_features.shape
# Out:
# (4763, 251, 34)

# %%
validation_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['chroma'], audio_df['val']['rms'], audio_df['val']['spectral_centroid']), axis=-1)

validation_features
# Out:
# array([[[6.07361555e-01, 5.23688197e-01, 5.01659334e-01, ...,
#          3.10212404e-01, 4.57111094e-03, 5.15450535e-01],
#         [6.06135845e-01, 5.30239284e-01, 4.42839682e-01, ...,
#          4.09293443e-01, 4.72569047e-03, 4.98740553e-01],
#         [5.73102593e-01, 5.24997473e-01, 4.99376684e-01, ...,
#          8.37558389e-01, 4.88307094e-03, 5.14566375e-01],
#         ...,
#         [5.64846277e-01, 5.33843935e-01, 5.36033750e-01, ...,
#          2.05210298e-01, 5.69090201e-03, 4.91105920e-01],
#         [5.82205534e-01, 5.45521021e-01, 5.14685750e-01, ...,
#          1.57568440e-01, 5.48938056e-03, 4.75827340e-01],
#         [5.89024425e-01, 5.16762257e-01, 5.20404458e-01, ...,
#          1.68823615e-01, 4.83821239e-03, 4.75768375e-01]],
#
#        [[4.75732088e-02, 5.53378284e-01, 5.23608625e-01, ...,
#          6.71788275e-01, 2.78365405e-07, 5.59082662e-01],
#         [2.09418535e-02, 5.37577689e-01, 4.80808914e-01, ...,
#          6.19439662e-01, 4.39661926e-05, 5.57423164e-01],
#         [1.91141725e-01, 4.72212732e-01, 3.40162247e-01, ...,
#          5.07847369e-01, 9.04211251e-04, 4.80303378e-01],
#         ...,
#         [4.64644253e-01, 4.91593957e-01, 3.60095471e-01, ...,
#          6.09176636e-01, 2.31666211e-03, 4.48903654e-01],
#         [4.67925489e-01, 5.09858131e-01, 3.30387294e-01, ...,
#          7.98292041e-01, 2.13860231e-03, 4.50200479e-01],
#         [4.85126257e-01, 5.08812964e-01, 3.39997828e-01, ...,
#          8.33110452e-01, 1.70903362e-03, 4.28940073e-01]],
#
#        [[7.04783380e-01, 7.91200280e-01, 5.83319724e-01, ...,
#          8.59635293e-01, 5.83346300e-02, 1.35190116e-01],
#         [7.11302578e-01, 7.75271177e-01, 5.43985248e-01, ...,
#          7.13699698e-01, 6.16376810e-02, 1.29385624e-01],
#         [6.14667118e-01, 7.47402549e-01, 6.06723785e-01, ...,
#          7.27037489e-01, 7.72752166e-02, 8.99351637e-02],
#         ...,
#         [6.23196244e-01, 7.11273134e-01, 6.72352254e-01, ...,
#          1.00000000e+00, 3.40738967e-02, 1.90312378e-01],
#         [6.25558972e-01, 7.29745686e-01, 6.86089694e-01, ...,
#          1.00000000e+00, 3.22043374e-02, 2.08361484e-01],
#         [6.28343225e-01, 7.33585060e-01, 6.99361265e-01, ...,
#          7.58609772e-01, 2.40894184e-02, 1.88665654e-01]],
#
#        ...,
#
#        [[2.12328434e-01, 5.05654156e-01, 5.38483620e-01, ...,
#          3.95972908e-01, 1.21362347e-04, 5.93643507e-01],
#         [1.89183831e-01, 4.76967871e-01, 4.85468060e-01, ...,
#          5.17444849e-01, 1.48656516e-04, 5.72504424e-01],
#         [1.88893855e-01, 4.61654723e-01, 4.99050021e-01, ...,
#          3.45607966e-01, 1.45938626e-04, 5.52448647e-01],
#         ...,
#         [2.31639028e-01, 4.00940359e-01, 5.14700472e-01, ...,
#          5.04105091e-01, 5.30444202e-04, 5.22021974e-01],
#         [2.41289437e-01, 4.03163016e-01, 4.70452219e-01, ...,
#          1.34643584e-01, 5.35602216e-04, 5.01375478e-01],
#         [2.51963496e-01, 4.03643489e-01, 4.92150754e-01, ...,
#          2.45159999e-01, 4.86365228e-04, 5.02646233e-01]],
#
#        [[7.35008240e-01, 6.79375708e-01, 3.67752314e-01, ...,
#          1.92446694e-01, 1.32603273e-02, 3.08426054e-01],
#         [7.26322234e-01, 6.61769211e-01, 3.38114083e-01, ...,
#          5.26969492e-01, 1.46202845e-02, 3.11015150e-01],
#         [6.86094284e-01, 6.17508173e-01, 3.67757916e-01, ...,
#          6.39311790e-01, 1.56203359e-02, 3.27279882e-01],
#         ...,
#         [6.67313516e-01, 6.21392429e-01, 4.69794035e-01, ...,
#          6.52197003e-01, 1.34100476e-02, 3.53138584e-01],
#         [6.73262596e-01, 6.35378897e-01, 4.59236562e-01, ...,
#          7.17136741e-01, 1.21065136e-02, 3.61444016e-01],
#         [6.78824604e-01, 6.31569386e-01, 4.77066964e-01, ...,
#          5.22119939e-01, 9.85576771e-03, 3.49624117e-01]],
#
#        [[7.25787640e-01, 8.23531628e-01, 6.61208689e-01, ...,
#          5.95236897e-01, 3.56985964e-02, 1.41023833e-01],
#         [7.23483920e-01, 7.89513707e-01, 6.00523412e-01, ...,
#          4.08037394e-01, 3.79531085e-02, 1.63432885e-01],
#         [6.91177607e-01, 7.44318843e-01, 6.39758766e-01, ...,
#          4.35045630e-01, 3.92461866e-02, 1.77902082e-01],
#         ...,
#         [6.45369649e-01, 7.73390472e-01, 6.29167974e-01, ...,
#          4.18777674e-01, 2.48103216e-02, 1.73847956e-01],
#         [6.79054558e-01, 7.23269105e-01, 6.60682321e-01, ...,
#          4.92326558e-01, 2.18358468e-02, 2.66713581e-01],
#         [7.22132921e-01, 6.53767586e-01, 6.54484510e-01, ...,
#          4.25765187e-01, 1.78664420e-02, 3.51562348e-01]]])

# %%
validation_features.shape
# Out:
# (2430, 251, 34)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_features,
                    learning_rate=0.001)

history = model.fit(
   x=training_features,
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(validation_features,
                    audio_df['val']['label'],
                    validation_sample_weights
                    ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Audio_Features (InputLayer  [(None, 251, 34)]         0
#  )
#
#  conv_1 (Conv1D)             (None, 251, 32)           5472
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)           0
#
#  conv_2 (Conv1D)             (None, 125, 64)           10304
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)            0
#
#  flatten (Flatten)           (None, 3968)              0
#
#  fc_1 (Dense)                (None, 1024)              4064256
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 3)                 3075
#
# =================================================================
# Total params: 4083107 (15.58 MB)
# Trainable params: 4083107 (15.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 18s 116ms/step - loss: 1.2439 - accuracy: 0.5696 - weighted_accuracy: 0.5810 - val_loss: 0.8831 - val_accuracy: 0.5914 - val_weighted_accuracy: 0.6149
# Epoch 2/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.6826 - accuracy: 0.7269 - weighted_accuracy: 0.7391 - val_loss: 0.6218 - val_accuracy: 0.7704 - val_weighted_accuracy: 0.7785
# Epoch 3/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.4901 - accuracy: 0.8146 - weighted_accuracy: 0.8242 - val_loss: 0.4954 - val_accuracy: 0.8074 - val_weighted_accuracy: 0.8135
# Epoch 4/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.4218 - accuracy: 0.8230 - weighted_accuracy: 0.8308 - val_loss: 0.5003 - val_accuracy: 0.7263 - val_weighted_accuracy: 0.7442
# Epoch 5/100
# 149/149 [==============================] - 15s 102ms/step - loss: 0.3693 - accuracy: 0.8543 - weighted_accuracy: 0.8616 - val_loss: 0.4994 - val_accuracy: 0.7502 - val_weighted_accuracy: 0.7575
# Epoch 6/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.3232 - accuracy: 0.8696 - weighted_accuracy: 0.8782 - val_loss: 0.4113 - val_accuracy: 0.8251 - val_weighted_accuracy: 0.8308
# Epoch 7/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.3008 - accuracy: 0.8778 - weighted_accuracy: 0.8838 - val_loss: 0.3917 - val_accuracy: 0.8251 - val_weighted_accuracy: 0.8284
# Epoch 8/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2705 - accuracy: 0.8923 - weighted_accuracy: 0.8986 - val_loss: 0.3754 - val_accuracy: 0.8103 - val_weighted_accuracy: 0.8228
# Epoch 9/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.2740 - accuracy: 0.8776 - weighted_accuracy: 0.8832 - val_loss: 0.3839 - val_accuracy: 0.8156 - val_weighted_accuracy: 0.8207
# Epoch 10/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.2395 - accuracy: 0.8967 - weighted_accuracy: 0.9020 - val_loss: 0.3432 - val_accuracy: 0.8465 - val_weighted_accuracy: 0.8531
# Epoch 11/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.2377 - accuracy: 0.8938 - weighted_accuracy: 0.8996 - val_loss: 0.3614 - val_accuracy: 0.8214 - val_weighted_accuracy: 0.8267
# Epoch 12/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.2202 - accuracy: 0.9072 - weighted_accuracy: 0.9116 - val_loss: 0.3686 - val_accuracy: 0.8078 - val_weighted_accuracy: 0.8107
# Epoch 13/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1981 - accuracy: 0.9179 - weighted_accuracy: 0.9229 - val_loss: 0.3075 - val_accuracy: 0.8531 - val_weighted_accuracy: 0.8601
# Epoch 14/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1921 - accuracy: 0.9208 - weighted_accuracy: 0.9258 - val_loss: 0.3098 - val_accuracy: 0.8477 - val_weighted_accuracy: 0.8550
# Epoch 15/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1928 - accuracy: 0.9162 - weighted_accuracy: 0.9207 - val_loss: 0.3180 - val_accuracy: 0.8333 - val_weighted_accuracy: 0.8457
# Epoch 16/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1734 - accuracy: 0.9297 - weighted_accuracy: 0.9334 - val_loss: 0.3063 - val_accuracy: 0.8358 - val_weighted_accuracy: 0.8437
# Epoch 17/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1518 - accuracy: 0.9387 - weighted_accuracy: 0.9427 - val_loss: 0.3161 - val_accuracy: 0.8465 - val_weighted_accuracy: 0.8559
# Epoch 18/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1430 - accuracy: 0.9448 - weighted_accuracy: 0.9483 - val_loss: 0.3025 - val_accuracy: 0.8547 - val_weighted_accuracy: 0.8628
# Epoch 19/100
# 149/149 [==============================] - 15s 104ms/step - loss: 0.1591 - accuracy: 0.9339 - weighted_accuracy: 0.9385 - val_loss: 0.2969 - val_accuracy: 0.8519 - val_weighted_accuracy: 0.8587
# Epoch 20/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1428 - accuracy: 0.9425 - weighted_accuracy: 0.9462 - val_loss: 0.2917 - val_accuracy: 0.8527 - val_weighted_accuracy: 0.8589
# Epoch 21/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1410 - accuracy: 0.9429 - weighted_accuracy: 0.9472 - val_loss: 0.2994 - val_accuracy: 0.8465 - val_weighted_accuracy: 0.8565
# Epoch 22/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1441 - accuracy: 0.9385 - weighted_accuracy: 0.9429 - val_loss: 0.2822 - val_accuracy: 0.8654 - val_weighted_accuracy: 0.8727
# Epoch 23/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1267 - accuracy: 0.9534 - weighted_accuracy: 0.9565 - val_loss: 0.2923 - val_accuracy: 0.8588 - val_weighted_accuracy: 0.8689
# Epoch 24/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1262 - accuracy: 0.9494 - weighted_accuracy: 0.9534 - val_loss: 0.2786 - val_accuracy: 0.8490 - val_weighted_accuracy: 0.8595
# Epoch 25/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1312 - accuracy: 0.9463 - weighted_accuracy: 0.9500 - val_loss: 0.2695 - val_accuracy: 0.8605 - val_weighted_accuracy: 0.8704
# Epoch 26/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1213 - accuracy: 0.9536 - weighted_accuracy: 0.9566 - val_loss: 0.3099 - val_accuracy: 0.8440 - val_weighted_accuracy: 0.8574
# Epoch 27/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1191 - accuracy: 0.9519 - weighted_accuracy: 0.9556 - val_loss: 0.3503 - val_accuracy: 0.8239 - val_weighted_accuracy: 0.8377
# Epoch 28/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1247 - accuracy: 0.9509 - weighted_accuracy: 0.9550 - val_loss: 0.3769 - val_accuracy: 0.8181 - val_weighted_accuracy: 0.8311
# Epoch 29/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1081 - accuracy: 0.9620 - weighted_accuracy: 0.9653 - val_loss: 0.2930 - val_accuracy: 0.8527 - val_weighted_accuracy: 0.8636
# Epoch 30/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1000 - accuracy: 0.9626 - weighted_accuracy: 0.9659 - val_loss: 0.3269 - val_accuracy: 0.8230 - val_weighted_accuracy: 0.8374
# Epoch 31/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1093 - accuracy: 0.9580 - weighted_accuracy: 0.9613 - val_loss: 0.2784 - val_accuracy: 0.8667 - val_weighted_accuracy: 0.8750
# Epoch 32/100
# 149/149 [==============================] - 15s 100ms/step - loss: 0.0963 - accuracy: 0.9679 - weighted_accuracy: 0.9702 - val_loss: 0.2933 - val_accuracy: 0.8634 - val_weighted_accuracy: 0.8729
# Epoch 33/100
# 149/149 [==============================] - 15s 101ms/step - loss: 0.1076 - accuracy: 0.9570 - weighted_accuracy: 0.9603 - val_loss: 0.2868 - val_accuracy: 0.8568 - val_weighted_accuracy: 0.8636
# Epoch 34/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1126 - accuracy: 0.9570 - weighted_accuracy: 0.9598 - val_loss: 0.3176 - val_accuracy: 0.8490 - val_weighted_accuracy: 0.8627
# Epoch 35/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.0954 - accuracy: 0.9698 - weighted_accuracy: 0.9721 - val_loss: 0.3294 - val_accuracy: 0.8329 - val_weighted_accuracy: 0.8486
# Epoch 36/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1016 - accuracy: 0.9624 - weighted_accuracy: 0.9654 - val_loss: 0.3310 - val_accuracy: 0.8539 - val_weighted_accuracy: 0.8583
# Epoch 37/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.0852 - accuracy: 0.9748 - weighted_accuracy: 0.9772 - val_loss: 0.3912 - val_accuracy: 0.8177 - val_weighted_accuracy: 0.8375
# Epoch 38/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.0920 - accuracy: 0.9679 - weighted_accuracy: 0.9701 - val_loss: 0.3325 - val_accuracy: 0.8300 - val_weighted_accuracy: 0.8452
# Epoch 39/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.0916 - accuracy: 0.9668 - weighted_accuracy: 0.9694 - val_loss: 0.3737 - val_accuracy: 0.8152 - val_weighted_accuracy: 0.8314
# Epoch 40/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.0844 - accuracy: 0.9740 - weighted_accuracy: 0.9760 - val_loss: 0.3294 - val_accuracy: 0.8519 - val_weighted_accuracy: 0.8609
# Epoch 41/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.0840 - accuracy: 0.9725 - weighted_accuracy: 0.9744 - val_loss: 0.3163 - val_accuracy: 0.8543 - val_weighted_accuracy: 0.8647
# best_epoch:  30

# %%
train_yhat = model.predict(training_features)

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_chroma_rms_spectral_centroid'] = model.evaluate(training_features, audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 2s 15ms/step
# 149/149 [==============================] - 4s 25ms/step - loss: 0.1302 - accuracy: 0.9746 - weighted_accuracy: 0.9746

# %%
val_yhat = model.predict(validation_features)

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_chroma_rms_spectral_centroid'] = model.evaluate(validation_features, audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 1s 15ms/step
# 76/76 [==============================] - 1s 16ms/step - loss: 0.4881 - accuracy: 0.8667 - weighted_accuracy: 0.8667

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.96      0.99      0.98      1603
#       comsan       0.98      0.97      0.97      1578
#      eaywag1       0.98      0.97      0.98      1582
#
#     accuracy                           0.97      4763
#    macro avg       0.97      0.97      0.97      4763
# weighted avg       0.97      0.97      0.97      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.86      0.90      0.88      1032
#       comsan       0.86      0.82      0.84       618
#      eaywag1       0.88      0.86      0.87       780
#
#     accuracy                           0.87      2430
#    macro avg       0.87      0.86      0.86      2430
# weighted avg       0.87      0.87      0.87      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# # Review results from all models

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(2)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(2)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Val_Accuracy')
result_df
# Out:
#                             Features  Train_Accuracy  Val_Accuracy
# 0                        mfcc_chroma            0.96          0.85
# 4  mfcc_chroma_rms_spectral_centroid            0.97          0.87
# 1                           mfcc_rms            0.95          0.88
# 2             mfcc_spectral_centroid            0.97          0.89
# 3         mfcc_rms_spectral_centroid            0.97          0.89
