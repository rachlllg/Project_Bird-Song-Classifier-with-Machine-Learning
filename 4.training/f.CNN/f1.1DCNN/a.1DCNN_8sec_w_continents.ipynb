# %% [markdown]
# # Import Libraries

# %%
# For drive access
from google.colab import drive
drive.mount('/content/drive')

# Standard libraries
import numpy as np
import pandas as pd

# for loading the pickle files with features and labels
import pickle

# For audio
from IPython.display import Audio
import librosa

# For modeling
import tensorflow as tf
from sklearn.metrics import classification_report

# For visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load features and labels from train and val pickle

# %%
with open('/content/drive/MyDrive/Projects/train_val_features_pkl/train_val_8_sec_audio_features_not_avgpooled.pkl', 'rb') as file:
  audio_df = pickle.load(file)

# %%
audio_df
# Out:
# {'train': {'mfcc': array([[[0.2926833 , 0.5472208 , 0.51762646, ..., 0.42902297,
#            0.5246572 , 0.39747417],
#           [0.38219857, 0.63193434, 0.4692648 , ..., 0.4789598 ,
#            0.5143834 , 0.35231233],
#           [0.4352324 , 0.62795496, 0.4937711 , ..., 0.53823024,
#            0.5205363 , 0.36665156],
#           ...,
#           [0.6295364 , 0.3740691 , 0.4684327 , ..., 0.74904454,
#            0.6659465 , 0.13212648],
#           [0.6729512 , 0.37194872, 0.47004578, ..., 0.63276273,
#            0.6894711 , 0.25973636],
#           [0.6984098 , 0.35604227, 0.50428545, ..., 0.49908003,
#            0.694181  , 0.40737295]],
#
#          [[0.571982  , 0.52721703, 0.35377806, ..., 0.31411108,
#            0.45345846, 0.5325761 ],
#           [0.57278824, 0.51283437, 0.33133256, ..., 0.44663262,
#            0.59104645, 0.5540432 ],
#           [0.5442881 , 0.50030595, 0.39622635, ..., 0.4177069 ,
#            0.63780564, 0.5152073 ],
#           ...,
#           [0.65820706, 0.30996823, 0.5541669 , ..., 0.3272183 ,
#            0.67594415, 0.37952572],
#           [0.55198324, 0.45880285, 0.6117153 , ..., 0.3045411 ,
#            0.6040039 , 0.2133086 ],
#           [0.47530848, 0.5978474 , 0.5095156 , ..., 0.32938066,
#            0.5845121 , 0.43895328]],
#
#          [[0.7978938 , 0.2568429 , 0.43546572, ..., 0.43030724,
#            0.43849736, 0.42188978],
#           [0.7662014 , 0.25891137, 0.39701158, ..., 0.5694269 ,
#            0.5710539 , 0.42619675],
#           [0.7192114 , 0.23281348, 0.49096993, ..., 0.72567195,
#            0.55556244, 0.33746177],
#           ...,
#           [0.5616844 , 0.47193855, 0.47496653, ..., 0.40325606,
#            0.6460507 , 0.3992835 ],
#           [0.637675  , 0.43434197, 0.44582096, ..., 0.28660327,
#            0.72113395, 0.4044888 ],
#           [0.6874016 , 0.41598967, 0.45974106, ..., 0.2920211 ,
#            0.8479563 , 0.3843705 ]],
#
#          ...,
#
#          [[0.3217525 , 0.6881845 , 0.48000094, ..., 0.59206927,
#            0.74486995, 0.55143815],
#           [0.5426938 , 0.6778939 , 0.41601896, ..., 0.7395768 ,
#            0.7553704 , 0.47949517],
#           [0.59666324, 0.6607961 , 0.4709517 , ..., 0.73276883,
#            0.7016298 , 0.4657311 ],
#           ...,
#           [0.6395872 , 0.71056587, 0.5853568 , ..., 0.46401277,
#            0.64115125, 0.48693323],
#           [0.63390076, 0.7141628 , 0.5673788 , ..., 0.47245952,
#            0.48211706, 0.5692038 ],
#           [0.63172424, 0.69852054, 0.5903194 , ..., 0.50481737,
#            0.5573676 , 0.66070366]],
#
#          [[0.6914642 , 0.71377504, 0.39913929, ..., 0.57215583,
#            0.45173353, 0.49472663],
#           [0.69487584, 0.70868874, 0.40198043, ..., 0.69470924,
#            0.53920835, 0.6262043 ],
#           [0.66651314, 0.6739543 , 0.46362418, ..., 0.70973766,
#            0.5931354 , 0.61188835],
#           ...,
#           [0.60295427, 0.707848  , 0.536386  , ..., 0.53722155,
#            0.57293046, 0.47105172],
#           [0.6006154 , 0.72017705, 0.50518787, ..., 0.4792548 ,
#            0.51115537, 0.49641013],
#           [0.5960094 , 0.70707476, 0.48459497, ..., 0.45196575,
#            0.6186346 , 0.60358286]],
#
#          [[0.67346656, 0.7210153 , 0.5060047 , ..., 0.5705455 ,
#            0.49910307, 0.4772731 ],
#           [0.6678432 , 0.720808  , 0.45569578, ..., 0.65077525,
#            0.53326356, 0.5335313 ],
#           [0.63857067, 0.6967014 , 0.4817975 , ..., 0.675209  ,
#            0.6000869 , 0.59436566],
#           ...,
#           [0.61522543, 0.6990228 , 0.5028586 , ..., 0.4935642 ,
#            0.61613715, 0.5054803 ],
#           [0.6177405 , 0.7108036 , 0.4846519 , ..., 0.44536754,
#            0.53255624, 0.5205585 ],
#           [0.6179831 , 0.70123994, 0.48564783, ..., 0.43177015,
#            0.5783832 , 0.5263324 ]]], dtype=float32),
#   'chroma': array([[[0.73383594, 0.69802487, 0.54096204, ..., 1.        ,
#            0.608227  , 0.48766178],
#           [1.        , 0.9552251 , 0.97629696, ..., 0.819532  ,
#            0.46592206, 0.4471012 ],
#           [0.70929813, 0.856629  , 1.        , ..., 0.9266538 ,
#            0.5471759 , 0.3217781 ],
#           ...,
#           [0.88756543, 0.4946972 , 0.0864549 , ..., 0.22002427,
#            0.10811816, 0.53788805],
#           [1.        , 0.20042695, 0.16474293, ..., 0.17202397,
#            0.26110023, 0.83525467],
#           [0.90538883, 0.38594005, 0.5073254 , ..., 0.5220612 ,
#            0.7847499 , 1.        ]],
#
#          [[0.229046  , 0.16785018, 0.31864116, ..., 0.418515  ,
#            0.38013583, 0.45450932],
#           [0.10696242, 0.05362201, 0.17352895, ..., 0.13921109,
#            0.12649179, 0.19284795],
#           [0.09754786, 0.03310031, 0.07604828, ..., 0.05064095,
#            0.06268156, 0.09602583],
#           ...,
#           [0.24475525, 0.45408043, 0.83302605, ..., 0.05314327,
#            0.18526138, 0.2805035 ],
#           [0.08646167, 0.38773277, 0.8255288 , ..., 0.0313557 ,
#            0.06599664, 0.08877482],
#           [0.6355827 , 0.49046612, 0.4782703 , ..., 0.61005807,
#            1.        , 0.62264   ]],
#
#          [[0.9527174 , 0.6517912 , 1.        , ..., 0.20430964,
#            0.53656095, 0.91746473],
#           [0.6809198 , 0.79247546, 1.        , ..., 0.20608044,
#            0.3752266 , 0.6624584 ],
#           [0.22394416, 0.9766228 , 1.        , ..., 0.29581028,
#            0.16772322, 0.17033473],
#           ...,
#           [0.7538224 , 0.20673002, 0.14345545, ..., 0.5413501 ,
#            0.42209476, 0.43086848],
#           [0.2879784 , 0.0433191 , 0.0333375 , ..., 0.16351902,
#            0.14486517, 0.21927443],
#           [0.2606343 , 0.02818089, 0.02646846, ..., 0.08534104,
#            0.08157288, 0.22000772]],
#
#          ...,
#
#          [[1.        , 0.5075606 , 0.3643616 , ..., 0.46753508,
#            0.5181549 , 0.82220215],
#           [0.75011694, 0.40670243, 0.23636323, ..., 0.34903422,
#            0.33158213, 0.5658228 ],
#           [0.6620617 , 0.49264944, 0.37212887, ..., 0.42530674,
#            0.48871762, 0.50091463],
#           ...,
#           [0.47907886, 0.5681733 , 0.6849798 , ..., 0.9351088 ,
#            0.6223058 , 0.4530788 ],
#           [0.6037054 , 0.57480985, 0.8478139 , ..., 1.0000001 ,
#            0.9806911 , 0.8639272 ],
#           [0.330637  , 0.46738312, 1.0000001 , ..., 0.5264327 ,
#            0.6019139 , 0.47685713]],
#
#          [[0.7212241 , 0.6510515 , 0.49622202, ..., 0.42471525,
#            0.62083757, 0.54442513],
#           [0.7963582 , 0.9396931 , 0.7933524 , ..., 0.8130368 ,
#            0.8064168 , 0.7425875 ],
#           [0.60769   , 0.89288026, 1.        , ..., 0.96361125,
#            0.7946369 , 0.6225406 ],
#           ...,
#           [0.7738935 , 0.55971414, 0.7861116 , ..., 1.        ,
#            0.72889286, 0.82642055],
#           [0.6680029 , 0.4654429 , 0.5945168 , ..., 1.0000001 ,
#            0.5256816 , 0.5611079 ],
#           [0.90391827, 0.71218765, 0.71311766, ..., 0.99999994,
#            0.664123  , 0.67750007]],
#
#          [[1.        , 0.7363702 , 0.75878894, ..., 0.5759158 ,
#            0.5487739 , 0.9241918 ],
#           [1.        , 0.90941614, 0.7891846 , ..., 0.7688592 ,
#            0.5679903 , 0.8910592 ],
#           [0.47667533, 0.51785684, 0.59323484, ..., 0.7292442 ,
#            0.5910429 , 0.5156206 ],
#           ...,
#           [0.7927784 , 0.8835067 , 1.        , ..., 0.54843056,
#            0.36869946, 0.6075551 ],
#           [0.8109695 , 1.        , 0.89819205, ..., 0.82382023,
#            0.53969693, 0.7465627 ],
#           [0.5711932 , 0.5911646 , 0.7132408 , ..., 0.6430262 ,
#            0.5621957 , 0.6215854 ]]], dtype=float32),
#   'rms': array([[[0.00066166],
#           [0.00108187],
#           [0.00132881],
#           ...,
#           [0.04247803],
#           [0.04479152],
#           [0.04258918]],
#
#          [[0.00843364],
#           [0.00863268],
#           [0.00953967],
#           ...,
#           [0.04465197],
#           [0.04720594],
#           [0.00180491]],
#
#          [[0.0945745 ],
#           [0.12310638],
#           [0.15316504],
#           ...,
#           [0.02636078],
#           [0.02628713],
#           [0.02671736]],
#
#          ...,
#
#          [[0.00261697],
#           [0.00429666],
#           [0.00528861],
#           ...,
#           [0.02439404],
#           [0.0186677 ],
#           [0.01447811]],
#
#          [[0.01063585],
#           [0.01215442],
#           [0.01393843],
#           ...,
#           [0.00716951],
#           [0.00646511],
#           [0.00508991]],
#
#          [[0.0099481 ],
#           [0.01280325],
#           [0.01470958],
#           ...,
#           [0.00779135],
#           [0.00702508],
#           [0.00562738]]], dtype=float32),
#   'spectral_centroid': array([[[0.43021879],
#           [0.35183347],
#           [0.34781837],
#           ...,
#           [0.52712466],
#           [0.55913132],
#           [0.57462391]],
#
#          [[0.43822888],
#           [0.43232722],
#           [0.44510553],
#           ...,
#           [0.62451555],
#           [0.61696158],
#           [0.40656783]],
#
#          [[0.64503138],
#           [0.62792118],
#           [0.66633629],
#           ...,
#           [0.49295281],
#           [0.50166412],
#           [0.4961109 ]],
#
#          ...,
#
#          [[0.33329476],
#           [0.31788902],
#           [0.31750112],
#           ...,
#           [0.26185072],
#           [0.27195403],
#           [0.28777192]],
#
#          [[0.28686683],
#           [0.27937374],
#           [0.2835901 ],
#           ...,
#           [0.29240491],
#           [0.29233926],
#           [0.28699176]],
#
#          [[0.27946243],
#           [0.26233429],
#           [0.24775679],
#           ...,
#           [0.28449501],
#           [0.29198551],
#           [0.29002803]]]),
#   'melspectrogram': array([[[0.24356848, 0.19709486, 0.19181323, ..., 0.14215577,
#            0.14264905, 0.16532534],
#           [0.40376735, 0.3655113 , 0.42287964, ..., 0.23766714,
#            0.1897651 , 0.1521129 ],
#           [0.45815992, 0.46074304, 0.4943219 , ..., 0.2976507 ,
#            0.25157702, 0.2118563 ],
#           ...,
#           [0.49117148, 0.43984422, 0.43819213, ..., 0.6310359 ,
#            0.56908995, 0.5044948 ],
#           [0.46418417, 0.4439577 , 0.45830843, ..., 0.6673047 ,
#            0.62528354, 0.5652833 ],
#           [0.4987093 , 0.456418  , 0.46511737, ..., 0.6581471 ,
#            0.6399298 , 0.5732062 ]],
#
#          [[0.4543748 , 0.4756736 , 0.4632044 , ..., 0.41978696,
#            0.3437417 , 0.3016634 ],
#           [0.45686582, 0.45135322, 0.46586612, ..., 0.41686812,
#            0.36826977, 0.29667157],
#           [0.45796975, 0.44600147, 0.44945693, ..., 0.42953232,
#            0.3780449 , 0.31478083],
#           ...,
#           [0.53641915, 0.46677327, 0.46015307, ..., 0.7154856 ,
#            0.7200803 , 0.60636497],
#           [0.51489085, 0.44360733, 0.45077553, ..., 0.54932797,
#            0.59599185, 0.46856165],
#           [0.50560594, 0.42767835, 0.43264443, ..., 0.3394151 ,
#            0.31403804, 0.25334805]],
#
#          [[0.4970015 , 0.4928741 , 0.47974336, ..., 0.78759706,
#            0.7498659 , 0.7231643 ],
#           [0.4755374 , 0.46717736, 0.4660268 , ..., 0.7653399 ,
#            0.7495806 , 0.694723  ],
#           [0.45806897, 0.47078794, 0.4709153 , ..., 0.8058598 ,
#            0.7909299 , 0.7564884 ],
#           ...,
#           [0.49385324, 0.44783697, 0.46114796, ..., 0.4956058 ,
#            0.46170318, 0.38592994],
#           [0.4859912 , 0.46393633, 0.47618708, ..., 0.55451417,
#            0.5702215 , 0.4863054 ],
#           [0.5273504 , 0.5001548 , 0.50836205, ..., 0.5773054 ,
#            0.60384905, 0.5157382 ]],
#
#          ...,
#
#          [[0.3514245 , 0.34866   , 0.32154053, ..., 0.15999717,
#            0.13954413, 0.17613167],
#           [0.50815594, 0.50543916, 0.5237822 , ..., 0.3366097 ,
#            0.32153517, 0.32495368],
#           [0.558628  , 0.5878562 , 0.6032868 , ..., 0.39959395,
#            0.38615382, 0.3934602 ],
#           ...,
#           [0.780533  , 0.6560871 , 0.6240686 , ..., 0.5234435 ,
#            0.49361798, 0.38953286],
#           [0.7499489 , 0.613906  , 0.59531116, ..., 0.5071019 ,
#            0.43975508, 0.3849932 ],
#           [0.7196118 , 0.5921148 , 0.565887  , ..., 0.4851054 ,
#            0.4135834 , 0.38994557]],
#
#          [[0.6109494 , 0.6206902 , 0.61200386, ..., 0.42749023,
#            0.41519445, 0.43781918],
#           [0.6411831 , 0.6318178 , 0.63249946, ..., 0.429544  ,
#            0.41518798, 0.42299882],
#           [0.6684967 , 0.6355276 , 0.63343793, ..., 0.44025874,
#            0.41929087, 0.43441528],
#           ...,
#           [0.6507423 , 0.61017406, 0.6335789 , ..., 0.3631066 ,
#            0.38515967, 0.42551026],
#           [0.61023897, 0.5893043 , 0.615956  , ..., 0.35835356,
#            0.4061381 , 0.42431673],
#           [0.5904546 , 0.578876  , 0.5727197 , ..., 0.3613688 ,
#            0.40224642, 0.40074635]],
#
#          [[0.6635772 , 0.62118745, 0.64088583, ..., 0.45560822,
#            0.39278215, 0.41715443],
#           [0.6625777 , 0.6242373 , 0.64697003, ..., 0.43134996,
#            0.39039868, 0.3984837 ],
#           [0.6775949 , 0.6223249 , 0.6149095 , ..., 0.4144279 ,
#            0.39025593, 0.40155146],
#           ...,
#           [0.6397346 , 0.613194  , 0.62155163, ..., 0.3954093 ,
#            0.39272565, 0.38059273],
#           [0.6048291 , 0.62069327, 0.62521505, ..., 0.39358556,
#            0.40497494, 0.38601157],
#           [0.5949067 , 0.5863329 , 0.590046  , ..., 0.3845084 ,
#            0.40410328, 0.38128677]]], dtype=float32),
#   'label': array([0, 0, 0, ..., 2, 2, 2])},
#  'val': {'mfcc': array([[[0.03438473, 0.5409663 , 0.49516892, ..., 0.47214267,
#            0.54059166, 0.31063035],
#           [0.156398  , 0.5936351 , 0.34219292, ..., 0.5281046 ,
#            0.4928256 , 0.45432433],
#           [0.27276182, 0.5529174 , 0.35612273, ..., 0.520854  ,
#            0.5686558 , 0.47363648],
#           ...,
#           [0.53652716, 0.533416  , 0.3665663 , ..., 0.36028466,
#            0.5355693 , 0.3084178 ],
#           [0.54577094, 0.54470825, 0.35483423, ..., 0.40590182,
#            0.4965055 , 0.34188586],
#           [0.5508863 , 0.53994864, 0.3564601 , ..., 0.43862337,
#            0.47689667, 0.32920602]],
#
#          [[0.41281384, 0.67141247, 0.65520215, ..., 0.37753204,
#            0.5337289 , 0.45304573],
#           [0.61477315, 0.7969459 , 0.4981349 , ..., 0.59867835,
#            0.59102464, 0.68530947],
#           [0.67084944, 0.77747846, 0.53579843, ..., 0.7273464 ,
#            0.61758906, 0.62314296],
#           ...,
#           [0.7601433 , 0.66117793, 0.5779958 , ..., 0.6609509 ,
#            0.68418646, 0.5143307 ],
#           [0.7423201 , 0.725596  , 0.5517128 , ..., 0.62154275,
#            0.6082248 , 0.5371979 ],
#           [0.74019575, 0.74327356, 0.53127474, ..., 0.54929096,
#            0.6353032 , 0.44752052]],
#
#          [[0.34304124, 0.7915419 , 0.598637  , ..., 0.38757032,
#            0.44805235, 0.3161977 ],
#           [0.59942603, 0.7608812 , 0.5384848 , ..., 0.53995186,
#            0.54124606, 0.5021793 ],
#           [0.65236187, 0.71998066, 0.5805178 , ..., 0.6230264 ,
#            0.60933435, 0.5061622 ],
#           ...,
#           [0.64055467, 0.7219373 , 0.6331161 , ..., 0.46207854,
#            0.5755408 , 0.49926198],
#           [0.6480728 , 0.74492353, 0.6308691 , ..., 0.47223875,
#            0.5534381 , 0.5032821 ],
#           [0.6469756 , 0.7327585 , 0.6370018 , ..., 0.5462244 ,
#            0.59276986, 0.4655675 ]],
#
#          ...,
#
#          [[0.74778503, 0.7209703 , 0.40612832, ..., 0.5918846 ,
#            0.6513869 , 0.5332755 ],
#           [0.7457434 , 0.7114381 , 0.39589864, ..., 0.6633295 ,
#            0.64677393, 0.5809252 ],
#           [0.7131096 , 0.6798183 , 0.44682613, ..., 0.6490638 ,
#            0.59542394, 0.5189707 ],
#           ...,
#           [0.69847393, 0.71101874, 0.5096783 , ..., 0.65995574,
#            0.56425035, 0.47228584],
#           [0.7035257 , 0.7315591 , 0.48594677, ..., 0.60101634,
#            0.5738688 , 0.4946204 ],
#           [0.7055297 , 0.70799476, 0.46933103, ..., 0.49718615,
#            0.6547618 , 0.5425098 ]],
#
#          [[0.2908501 , 0.7189217 , 0.4210609 , ..., 0.34758058,
#            0.3391745 , 0.6465228 ],
#           [0.4968081 , 0.7353206 , 0.38010958, ..., 0.48473963,
#            0.43648642, 0.6562871 ],
#           [0.5429973 , 0.701936  , 0.42638344, ..., 0.54729   ,
#            0.49788263, 0.548462  ],
#           ...,
#           [0.53224087, 0.7414206 , 0.5025408 , ..., 0.48724097,
#            0.5497386 , 0.5259569 ],
#           [0.5396178 , 0.76640326, 0.49725193, ..., 0.4311356 ,
#            0.49491715, 0.4492576 ],
#           [0.5452116 , 0.76659644, 0.5120657 , ..., 0.43508086,
#            0.5092749 , 0.39250734]],
#
#          [[0.35528255, 0.5790772 , 0.56944543, ..., 0.45860705,
#            0.5517407 , 0.4264643 ],
#           [0.41365486, 0.7147431 , 0.52766097, ..., 0.6032357 ,
#            0.5893611 , 0.46952924],
#           [0.47077656, 0.7510897 , 0.5992972 , ..., 0.6085386 ,
#            0.64177614, 0.5471046 ],
#           ...,
#           [0.5042781 , 0.92240477, 0.73465073, ..., 0.42743266,
#            0.6194316 , 0.4052591 ],
#           [0.4641732 , 0.8738564 , 0.76589763, ..., 0.391493  ,
#            0.59199184, 0.43708456],
#           [0.44472247, 0.78773165, 0.7542114 , ..., 0.35484043,
#            0.6443579 , 0.5087153 ]]], dtype=float32),
#   'chroma': array([[[0.7646548 , 0.6593877 , 1.        , ..., 0.7147495 ,
#            0.7372933 , 0.5769873 ],
#           [1.        , 0.9776191 , 0.7299414 , ..., 0.20515485,
#            0.25375524, 0.4779138 ],
#           [1.0000001 , 0.9596754 , 0.82782555, ..., 0.5209368 ,
#            0.5438989 , 0.7936685 ],
#           ...,
#           [0.16291276, 0.14363815, 0.17468452, ..., 0.20659253,
#            0.23780039, 0.16433807],
#           [0.2022269 , 0.16572295, 0.19001824, ..., 0.13031365,
#            0.15897165, 0.1746402 ],
#           [0.14170276, 0.14602776, 0.20580296, ..., 0.14098944,
#            0.10827189, 0.16469386]],
#
#          [[0.8470788 , 1.        , 0.9584479 , ..., 0.5541986 ,
#            0.60589206, 0.7429723 ],
#           [0.73648524, 0.7767946 , 0.95988184, ..., 0.79856175,
#            0.68244904, 0.71300286],
#           [0.7221496 , 0.60955745, 0.710658  , ..., 0.96438843,
#            0.8706302 , 0.85046685],
#           ...,
#           [0.67400604, 0.63110614, 0.8122476 , ..., 0.7028029 ,
#            0.6089538 , 0.49003288],
#           [0.60263884, 0.40273157, 0.5151347 , ..., 0.6125045 ,
#            0.5007707 , 0.49264178],
#           [0.75435615, 0.35312733, 0.3339029 , ..., 0.50700265,
#            0.6434145 , 0.6333055 ]],
#
#          [[0.21815085, 0.24457382, 0.286702  , ..., 1.        ,
#            0.816597  , 0.49451017],
#           [0.14038104, 0.203232  , 0.36619595, ..., 0.84946656,
#            0.42996433, 0.30546373],
#           [0.26832697, 0.38324547, 0.59156364, ..., 0.85665125,
#            0.5147319 , 0.47055075],
#           ...,
#           [0.213635  , 0.22972344, 0.38984865, ..., 0.32367027,
#            0.3919436 , 0.24894355],
#           [0.2586603 , 0.286459  , 0.35752532, ..., 0.21823199,
#            0.23316927, 0.2673995 ],
#           [0.43330297, 0.5084328 , 0.33426496, ..., 0.20642486,
#            0.11039441, 0.2744891 ]],
#
#          ...,
#
#          [[0.7150665 , 0.6856525 , 0.72564256, ..., 0.5490038 ,
#            0.9175502 , 0.7872274 ],
#           [0.78217745, 0.7306153 , 0.73654264, ..., 0.70680183,
#            1.        , 0.94257677],
#           [0.79001683, 0.87175167, 0.8301966 , ..., 0.9434979 ,
#            0.9721074 , 1.        ],
#           ...,
#           [0.72140193, 0.6670173 , 0.6496824 , ..., 0.7078034 ,
#            0.6309728 , 0.811846  ],
#           [0.54813915, 0.5793646 , 0.7561379 , ..., 0.51952004,
#            0.6629236 , 0.94050825],
#           [0.35745636, 0.37443233, 0.60613006, ..., 0.34727755,
#            0.6361132 , 0.60757905]],
#
#          [[0.12920445, 0.24731807, 0.5391454 , ..., 0.50280094,
#            0.3234261 , 0.10417072],
#           [0.3272184 , 0.37468094, 0.49829358, ..., 0.5354412 ,
#            0.5043049 , 0.2658642 ],
#           [0.63557154, 0.5032978 , 0.67034566, ..., 0.7182885 ,
#            0.78906685, 0.6150083 ],
#           ...,
#           [0.5055485 , 0.62709343, 0.45350704, ..., 0.5924449 ,
#            1.        , 0.9164598 ],
#           [0.20694374, 0.32452282, 0.28471586, ..., 0.48183307,
#            1.0000001 , 0.49888673],
#           [0.18903567, 0.2551217 , 0.31590292, ..., 0.54448265,
#            1.        , 0.45031857]],
#
#          [[0.6099855 , 0.52973676, 0.4314404 , ..., 0.88568044,
#            0.8219632 , 0.76208293],
#           [0.65957516, 0.6353318 , 0.5847457 , ..., 0.93063444,
#            0.7951908 , 0.7416253 ],
#           [0.5383141 , 0.57087344, 0.45381156, ..., 1.        ,
#            0.63993496, 0.60679996],
#           ...,
#           [0.55252045, 0.72652733, 1.        , ..., 0.9905569 ,
#            0.9756369 , 0.8603448 ],
#           [0.90918326, 0.7175546 , 0.5232939 , ..., 0.448994  ,
#            0.69994086, 1.        ],
#           [0.7308196 , 0.539653  , 0.53606564, ..., 0.771013  ,
#            0.8287663 , 0.8902378 ]]], dtype=float32),
#   'rms': array([[[6.8254682e-05],
#           [2.1939805e-04],
#           [4.2839046e-04],
#           ...,
#           [5.1447935e-03],
#           [4.9803653e-03],
#           [4.1735838e-03]],
#
#          [[4.2074233e-02],
#           [1.0621951e-01],
#           [1.3893212e-01],
#           ...,
#           [3.8427278e-02],
#           [3.5975665e-02],
#           [2.7774476e-02]],
#
#          [[8.2113249e-03],
#           [1.2631006e-02],
#           [1.4442490e-02],
#           ...,
#           [1.4388610e-02],
#           [1.3500358e-02],
#           [1.0931141e-02]],
#
#          ...,
#
#          [[1.6571838e-02],
#           [1.7655212e-02],
#           [1.8854775e-02],
#           ...,
#           [1.8490607e-02],
#           [1.7254055e-02],
#           [1.4439104e-02]],
#
#          [[2.1392710e-03],
#           [3.3970729e-03],
#           [3.9917743e-03],
#           ...,
#           [5.4435227e-03],
#           [4.9514584e-03],
#           [4.2695017e-03]],
#
#          [[3.7546651e-03],
#           [4.8651174e-03],
#           [2.3346646e-02],
#           ...,
#           [5.7112973e-02],
#           [3.4126684e-02],
#           [2.2383185e-02]]], dtype=float32),
#   'spectral_centroid': array([[[0.54656741],
#           [0.37865166],
#           [0.39853728],
#           ...,
#           [0.40867808],
#           [0.42846209],
#           [0.40883235]],
#
#          [[0.16096673],
#           [0.09768898],
#           [0.09134934],
#           ...,
#           [0.36211678],
#           [0.27002135],
#           [0.2145442 ]],
#
#          [[0.1888723 ],
#           [0.21536217],
#           [0.2383076 ],
#           ...,
#           [0.26032311],
#           [0.25610704],
#           [0.25796355]],
#
#          ...,
#
#          [[0.27016079],
#           [0.2702707 ],
#           [0.28097238],
#           ...,
#           [0.26516819],
#           [0.26124954],
#           [0.27352084]],
#
#          [[0.26946555],
#           [0.24700455],
#           [0.25418389],
#           ...,
#           [0.22423094],
#           [0.21413   ],
#           [0.20466403]],
#
#          [[0.2321004 ],
#           [0.15440951],
#           [0.11527369],
#           ...,
#           [0.03329018],
#           [0.03617943],
#           [0.02736049]]]),
#   'melspectrogram': array([[[0.08103681, 0.06281257, 0.04899508, ..., 0.0126223 ,
#            0.01625842, 0.02704358],
#           [0.16806442, 0.15293223, 0.20864499, ..., 0.06657875,
#            0.05336493, 0.05504674],
#           [0.2551819 , 0.26873422, 0.27525806, ..., 0.1596486 ,
#            0.15128297, 0.15508932],
#           ...,
#           [0.43946368, 0.43952537, 0.46801436, ..., 0.3903185 ,
#            0.38137046, 0.37939993],
#           [0.4319826 , 0.45017073, 0.4815686 , ..., 0.39779127,
#            0.3901048 , 0.37982506],
#           [0.43024457, 0.43739873, 0.4742092 , ..., 0.37816513,
#            0.39697692, 0.37451804]],
#
#          [[0.53607374, 0.4760657 , 0.40242267, ..., 0.18058312,
#            0.15626639, 0.16649419],
#           [0.7286438 , 0.675462  , 0.6663515 , ..., 0.34260413,
#            0.3336767 , 0.32324892],
#           [0.79932505, 0.74715483, 0.7510541 , ..., 0.4049864 ,
#            0.38409263, 0.38859048],
#           ...,
#           [0.7754409 , 0.7459701 , 0.7681694 , ..., 0.6363764 ,
#            0.60821825, 0.5042228 ],
#           [0.75374657, 0.74040216, 0.7729754 , ..., 0.53729707,
#            0.54528797, 0.48106566],
#           [0.74752945, 0.72839457, 0.7563726 , ..., 0.47744092,
#            0.50094575, 0.43916273]],
#
#          [[0.47513065, 0.4804721 , 0.48405796, ..., 0.14679098,
#            0.14400697, 0.17451447],
#           [0.6261809 , 0.6455195 , 0.6954016 , ..., 0.36581507,
#            0.36516973, 0.38317612],
#           [0.6764163 , 0.70619637, 0.72770447, ..., 0.44338867,
#            0.44211918, 0.4616505 ],
#           ...,
#           [0.74071205, 0.7133362 , 0.7141671 , ..., 0.43368593,
#            0.43644074, 0.4478911 ],
#           [0.71385306, 0.7088312 , 0.7003579 , ..., 0.41723558,
#            0.44375277, 0.45729327],
#           [0.70436656, 0.6966621 , 0.66690505, ..., 0.41670942,
#            0.44353658, 0.44696856]],
#
#          ...,
#
#          [[0.65482044, 0.6923055 , 0.6991818 , ..., 0.4506169 ,
#            0.45181042, 0.45589545],
#           [0.6723259 , 0.6762383 , 0.70000386, ..., 0.4615677 ,
#            0.44838136, 0.4410908 ],
#           [0.6718765 , 0.67232054, 0.69023204, ..., 0.47749022,
#            0.44604304, 0.4478292 ],
#           ...,
#           [0.741146  , 0.68560064, 0.716449  , ..., 0.4458004 ,
#            0.45347685, 0.4565132 ],
#           [0.71345043, 0.6707683 , 0.7173933 , ..., 0.43744653,
#            0.45205736, 0.45527977],
#           [0.6896811 , 0.6387804 , 0.67879313, ..., 0.43941015,
#            0.4580866 , 0.44885725]],
#
#          [[0.3551227 , 0.36077967, 0.3018945 , ..., 0.11696076,
#            0.10553074, 0.09938878],
#           [0.48231995, 0.51379275, 0.4967989 , ..., 0.267012  ,
#            0.25197464, 0.23644072],
#           [0.52727455, 0.5874976 , 0.5684792 , ..., 0.32170337,
#            0.29986417, 0.29666954],
#           ...,
#           [0.56999373, 0.59020483, 0.63190985, ..., 0.31018773,
#            0.30086726, 0.2727328 ],
#           [0.566043  , 0.59311724, 0.6545093 , ..., 0.30493787,
#            0.30859476, 0.27837676],
#           [0.5720775 , 0.58068264, 0.6326221 , ..., 0.3074007 ,
#            0.31826603, 0.28362423]],
#
#          [[0.44032022, 0.32846272, 0.27843177, ..., 0.20607656,
#            0.20754921, 0.23159951],
#           [0.5932946 , 0.4400355 , 0.41283402, ..., 0.21269244,
#            0.19590807, 0.20477784],
#           [0.6576391 , 0.61296743, 0.5495226 , ..., 0.26351595,
#            0.24070883, 0.24391842],
#           ...,
#           [0.8416464 , 0.7804614 , 0.7176689 , ..., 0.20745748,
#            0.19683123, 0.18305326],
#           [0.76600313, 0.70242727, 0.63311094, ..., 0.20600492,
#            0.20316136, 0.18749917],
#           [0.7492351 , 0.6074891 , 0.4814969 , ..., 0.20228267,
#            0.2117855 , 0.20504546]]], dtype=float32),
#   'label': array([0, 0, 1, ..., 2, 1, 2])}}

# %%
with open('/content/drive/MyDrive/Projects/train_val_features_pkl/train_val_8_sec_non_audio_features.pkl', 'rb') as file:
  non_audio_df = pickle.load(file)

# %%
non_audio_df
# Out:
# {'train': {'type': array(['blank', 'blank', 'blank', ..., 'blank', 'blank', 'blank'],
#         dtype='<U5'),
#   'continent': array(['AFRICA', 'AFRICA', 'AFRICA', ..., 'EUROPE', 'EUROPE', 'EUROPE'],
#         dtype='<U8'),
#   'rating': array([5., 5., 5., ..., 5., 5., 5.]),
#   'label': array([0, 0, 0, ..., 2, 2, 2])},
#  'val': {'type': array(['song', 'call', 'call', ..., 'blank', 'call', 'call'], dtype='<U5'),
#   'continent': array(['EUROPE', 'EUROPE', 'EUROPE', ..., 'EUROPE', 'EUROPE', 'EUROPE'],
#         dtype='<U8'),
#   'rating': array([3.5, 5. , 4. , ..., 5. , 3. , 3. ]),
#   'label': array([0, 0, 1, ..., 2, 1, 2])}}

# %% [markdown]
# ## confirm the audio features and non_audio features labels line-up

# %%
assert np.array_equal(audio_df['train']['label'], non_audio_df['train']['label'])

# %%
assert np.array_equal(audio_df['val']['label'], non_audio_df['val']['label'])

# %% [markdown]
# # Shuffle the data

# %%
def shuffle_data(audio_features, non_audio_features):
  input_len = len(audio_features['label'])
  input_indices = np.random.permutation(input_len)
  audio_features = {key: np.array([audio_features[key][i] for i in input_indices]) for key in audio_features}
  non_audio_features = {key: np.array([non_audio_features[key][i] for i in input_indices]) for key in non_audio_features}

  return audio_features, non_audio_features

# %%
audio_df['train'], non_audio_df['train'] = shuffle_data(audio_df['train'], non_audio_df['train'])

# %%
for key in audio_df['train'].keys():
  display(key)
  display(audio_df['train'][key].shape)
  display(audio_df['train'][key][:5])
# Out:
# 'mfcc'
# (4763, 251, 20)
# array([[[0.85715145, 0.7720915 , 0.32343465, ..., 0.4627957 ,
#          0.4473845 , 0.32348067],
#         [0.8489596 , 0.76405644, 0.3270986 , ..., 0.5947814 ,
#          0.5059513 , 0.46025   ],
#         [0.81306714, 0.7316643 , 0.38121283, ..., 0.63395506,
#          0.5094435 , 0.5133219 ],
#         ...,
#         [0.7543671 , 0.7431457 , 0.45161688, ..., 0.50562835,
#          0.51767015, 0.45690683],
#         [0.76071984, 0.76519793, 0.4317957 , ..., 0.42903662,
#          0.44919658, 0.41896337],
#         [0.7671031 , 0.7618209 , 0.4211259 , ..., 0.47511977,
#          0.51402247, 0.39780954]],
#
#        [[0.5781203 , 0.5110686 , 0.33823726, ..., 0.52381957,
#          0.46471834, 0.5171151 ],
#         [0.5865296 , 0.45980272, 0.378568  , ..., 0.6007547 ,
#          0.5952264 , 0.4887229 ],
#         [0.5609155 , 0.42990237, 0.425897  , ..., 0.5988201 ,
#          0.60503346, 0.40780362],
#         ...,
#         [0.58505166, 0.5116478 , 0.3250974 , ..., 0.48268813,
#          0.7202647 , 0.46407914],
#         [0.5940592 , 0.5139758 , 0.24707577, ..., 0.46852088,
#          0.6594661 , 0.37247282],
#         [0.59488356, 0.5147029 , 0.20010453, ..., 0.57878554,
#          0.77573484, 0.33499646]],
#
#        [[0.6043193 , 0.7780733 , 0.60488605, ..., 0.33324915,
#          0.5239149 , 0.40213192],
#         [0.5917373 , 0.7511689 , 0.54849744, ..., 0.46353245,
#          0.5887091 , 0.45853385],
#         [0.562474  , 0.70484036, 0.58358085, ..., 0.5766291 ,
#          0.6264296 , 0.4719776 ],
#         ...,
#         [0.58100474, 0.6679153 , 0.7316952 , ..., 0.39408955,
#          0.54233015, 0.6030581 ],
#         [0.6164744 , 0.6296945 , 0.83395606, ..., 0.05136418,
#          0.79644823, 0.33529326],
#         [0.63556254, 0.5964014 , 0.8894726 , ..., 0.        ,
#          0.94916236, 0.230663  ]],
#
#        [[0.74608165, 0.33884275, 0.15200052, ..., 0.57078767,
#          0.5318768 , 0.30514815],
#         [0.7271358 , 0.3101201 , 0.11332184, ..., 0.67516005,
#          0.5756412 , 0.41457334],
#         [0.69422966, 0.2802127 , 0.14877123, ..., 0.69227016,
#          0.66241807, 0.4961506 ],
#         ...,
#         [0.6998559 , 0.2787769 , 0.3011582 , ..., 0.67484474,
#          0.6391965 , 0.3841657 ],
#         [0.69830555, 0.3045356 , 0.25619015, ..., 0.6257194 ,
#          0.52638745, 0.3976808 ],
#         [0.6927521 , 0.29797557, 0.29551214, ..., 0.5987357 ,
#          0.49262634, 0.47920552]],
#
#        [[0.63590205, 0.5834134 , 0.47288403, ..., 0.3822597 ,
#          0.47920302, 0.29290533],
#         [0.6308555 , 0.59697294, 0.43569967, ..., 0.5564761 ,
#          0.5198047 , 0.38683024],
#         [0.6075468 , 0.58278245, 0.46086764, ..., 0.6650758 ,
#          0.50509876, 0.43690193],
#         ...,
#         [0.4980947 , 0.7025469 , 0.55527663, ..., 0.49345133,
#          0.5968952 , 0.44845107],
#         [0.50184214, 0.7131361 , 0.54354584, ..., 0.4150017 ,
#          0.49944848, 0.3355209 ],
#         [0.51381844, 0.7002591 , 0.5434155 , ..., 0.44409478,
#          0.4732476 , 0.33341014]]], dtype=float32)
# 'chroma'
# (4763, 251, 12)
# array([[[1.        , 0.67948276, 0.38636434, ..., 0.98987585,
#          0.68978775, 0.83134496],
#         [0.9365189 , 0.86361027, 0.6880753 , ..., 0.8102504 ,
#          0.8809118 , 1.        ],
#         [0.69427866, 0.8022555 , 0.97591805, ..., 0.70719653,
#          0.93877065, 0.9885331 ],
#         ...,
#         [0.581803  , 0.5688891 , 0.55725527, ..., 0.528907  ,
#          0.553877  , 0.59809744],
#         [0.74900013, 0.71288157, 0.7521465 , ..., 0.5829789 ,
#          0.46056142, 0.56461316],
#         [0.99249464, 0.87807006, 0.9470556 , ..., 0.37735045,
#          0.3723486 , 0.7029264 ]],
#
#        [[0.25761706, 0.24098776, 0.28586698, ..., 0.6872681 ,
#          0.42638066, 0.15715972],
#         [0.10877731, 0.09324979, 0.12926278, ..., 0.3797066 ,
#          0.17075238, 0.10151878],
#         [0.06695791, 0.07760001, 0.14264478, ..., 0.0613028 ,
#          0.03944778, 0.06087872],
#         ...,
#         [0.358598  , 0.32282797, 0.24548182, ..., 0.14550054,
#          0.15939614, 0.2811762 ],
#         [0.6899902 , 0.49147475, 0.40180174, ..., 0.14397934,
#          0.18547806, 0.5166032 ],
#         [0.3470691 , 0.26333925, 0.3036691 , ..., 0.10808729,
#          0.1174261 , 0.345927  ]],
#
#        [[0.4080126 , 0.32782456, 0.4887683 , ..., 0.65422094,
#          0.6043084 , 0.55286145],
#         [0.545758  , 0.36815378, 0.39153042, ..., 0.75122964,
#          0.42707282, 0.3701036 ],
#         [0.50589466, 0.37992823, 0.3210879 , ..., 0.723672  ,
#          0.48231018, 0.5295095 ],
#         ...,
#         [0.0457939 , 0.18426473, 0.4061314 , ..., 0.03272589,
#          0.04833433, 0.03998072],
#         [0.01832183, 0.01821429, 0.05202032, ..., 0.01154848,
#          0.02209033, 0.0244415 ],
#         [0.01739355, 0.00863946, 0.01103965, ..., 0.01471471,
#          0.03679242, 0.03625474]],
#
#        [[0.6839943 , 1.        , 0.37176952, ..., 0.18966782,
#          0.26140663, 0.34894642],
#         [0.28613934, 1.        , 0.32560837, ..., 0.09158924,
#          0.11450791, 0.13715076],
#         [0.37895283, 1.0000001 , 0.29521364, ..., 0.11140618,
#          0.13663763, 0.13391143],
#         ...,
#         [0.58531094, 1.        , 0.58337843, ..., 0.08280392,
#          0.06416409, 0.1745194 ],
#         [0.24490088, 0.9080198 , 1.        , ..., 0.0126225 ,
#          0.01571731, 0.04956784],
#         [0.04795495, 0.56210464, 1.0000001 , ..., 0.0036403 ,
#          0.00467888, 0.00687738]],
#
#        [[0.92217165, 0.68012446, 0.13202943, ..., 0.40980473,
#          0.7797572 , 0.99999994],
#         [0.8687044 , 0.56007004, 0.1655791 , ..., 0.93819404,
#          0.8979514 , 0.9001438 ],
#         [0.12035107, 0.082243  , 0.04226534, ..., 0.96744114,
#          0.29592454, 0.15567353],
#         ...,
#         [0.8453154 , 0.51700854, 0.42376345, ..., 1.        ,
#          0.8945777 , 0.62828964],
#         [1.        , 0.7204025 , 0.58681965, ..., 0.69455624,
#          0.7420653 , 0.8335192 ],
#         [1.0000001 , 0.834956  , 0.5041415 , ..., 0.6440801 ,
#          0.6935473 , 0.93933433]]], dtype=float32)
# 'rms'
# (4763, 251, 1)
# array([[[0.05045145],
#         [0.05636971],
#         [0.05972068],
#         ...,
#         [0.03885968],
#         [0.03439789],
#         [0.02821541]],
#
#        [[0.0078186 ],
#         [0.00876402],
#         [0.00845237],
#         ...,
#         [0.00980887],
#         [0.00998901],
#         [0.00893118]],
#
#        [[0.00691423],
#         [0.00731169],
#         [0.00816986],
#         ...,
#         [0.02820133],
#         [0.02959021],
#         [0.02945004]],
#
#        [[0.04994319],
#         [0.05487683],
#         [0.05380242],
#         ...,
#         [0.11983096],
#         [0.12415573],
#         [0.12293412]],
#
#        [[0.00775298],
#         [0.01128183],
#         [0.01306387],
#         ...,
#         [0.00304884],
#         [0.00288241],
#         [0.00228231]]], dtype=float32)
# 'spectral_centroid'
# (4763, 251, 1)
# array([[[0.22281198],
#         [0.22631334],
#         [0.23361687],
#         ...,
#         [0.23204755],
#         [0.22768157],
#         [0.2244155 ]],
#
#        [[0.58009442],
#         [0.66959631],
#         [0.67599949],
#         ...,
#         [0.42379785],
#         [0.41740986],
#         [0.36134405]],
#
#        [[0.20033525],
#         [0.22573477],
#         [0.25117208],
#         ...,
#         [0.56223134],
#         [0.64126956],
#         [0.64483953]],
#
#        [[0.49360794],
#         [0.49043139],
#         [0.50589098],
#         ...,
#         [0.5702963 ],
#         [0.58224016],
#         [0.60040612]],
#
#        [[0.46283044],
#         [0.43683113],
#         [0.43575181],
#         ...,
#         [0.26072145],
#         [0.27471655],
#         [0.28395115]]])
# 'melspectrogram'
# (4763, 251, 20)
# array([[[0.77038056, 0.8076456 , 0.76979077, ..., 0.5232589 ,
#          0.4696084 , 0.45702112],
#         [0.7523828 , 0.8023445 , 0.7821677 , ..., 0.5267849 ,
#          0.46980914, 0.4358638 ],
#         [0.74157596, 0.8139287 , 0.7887269 , ..., 0.54203755,
#          0.4719389 , 0.43807688],
#         ...,
#         [0.77877706, 0.77418697, 0.76804096, ..., 0.4960717 ,
#          0.44385907, 0.39965418],
#         [0.77332777, 0.7718588 , 0.75035226, ..., 0.49207217,
#          0.45385388, 0.39824712],
#         [0.770144  , 0.7571013 , 0.701986  , ..., 0.49004683,
#          0.4585627 , 0.3874891 ]],
#
#        [[0.35032544, 0.44006032, 0.4510223 , ..., 0.40243188,
#          0.47118682, 0.5540558 ],
#         [0.3691654 , 0.42986336, 0.46933907, ..., 0.53760207,
#          0.5881294 , 0.5739269 ],
#         [0.37127778, 0.4399287 , 0.4685046 , ..., 0.6111051 ,
#          0.6087723 , 0.5418744 ],
#         ...,
#         [0.42538065, 0.41896388, 0.46407104, ..., 0.5253241 ,
#          0.4480068 , 0.3466741 ],
#         [0.39719617, 0.40748906, 0.45612004, ..., 0.49520656,
#          0.44388646, 0.34482643],
#         [0.39469674, 0.4001282 , 0.45592615, ..., 0.41658458,
#          0.40235713, 0.33427626]],
#
#        [[0.6609111 , 0.6520402 , 0.62452316, ..., 0.35390937,
#          0.35132694, 0.38060492],
#         [0.63712114, 0.62646765, 0.6435773 , ..., 0.3505019 ,
#          0.35704055, 0.36936334],
#         [0.6248777 , 0.6470742 , 0.63166374, ..., 0.36758378,
#          0.361534  , 0.37073946],
#         ...,
#         [0.7023906 , 0.66013587, 0.6339693 , ..., 0.66691154,
#          0.61307836, 0.3537288 ],
#         [0.6835824 , 0.66171974, 0.63600284, ..., 0.6974975 ,
#          0.73417723, 0.4355993 ],
#         [0.687671  , 0.6474658 , 0.61900604, ..., 0.69239175,
#          0.75561273, 0.49728286]],
#
#        [[0.40652856, 0.40232137, 0.41072157, ..., 0.62214494,
#          0.583814  , 0.5765667 ],
#         [0.34477592, 0.31937844, 0.37409505, ..., 0.6542157 ,
#          0.5810472 , 0.56063515],
#         [0.24033278, 0.29095352, 0.35364655, ..., 0.6609899 ,
#          0.59150285, 0.5920442 ],
#         ...,
#         [0.3497698 , 0.3955882 , 0.43381828, ..., 0.7206996 ,
#          0.70582664, 0.62056726],
#         [0.3614727 , 0.3654182 , 0.412682  , ..., 0.77667207,
#          0.6435194 , 0.56292075],
#         [0.4292475 , 0.37125623, 0.37491125, ..., 0.78547513,
#          0.6031401 , 0.54983467]],
#
#        [[0.52698576, 0.5502453 , 0.5582789 , ..., 0.46980318,
#          0.41277182, 0.38814417],
#         [0.5490871 , 0.560474  , 0.56914556, ..., 0.45273972,
#          0.39530373, 0.3665239 ],
#         [0.5531377 , 0.5771694 , 0.5712998 , ..., 0.4418177 ,
#          0.36334446, 0.36329645],
#         ...,
#         [0.6312447 , 0.5854534 , 0.5673332 , ..., 0.30391675,
#          0.27591866, 0.27148676],
#         [0.6119032 , 0.56638706, 0.5171678 , ..., 0.30070895,
#          0.28104496, 0.27556205],
#         [0.5960665 , 0.53852504, 0.5047827 , ..., 0.30719835,
#          0.28589553, 0.27973932]]], dtype=float32)
# 'label'
# (4763,)
# array([1, 2, 1, 2, 0])

# %%
for key in non_audio_df['train'].keys():
  display(key)
  display(non_audio_df['train'][key].shape)
  display(non_audio_df['train'][key][:5])
# Out:
# 'type'
# (4763,)
# array(['call', 'call', 'call', 'call', 'call'], dtype='<U5')
# 'continent'
# (4763,)
# array(['EUROPE', 'ASIA', 'EUROPE', 'EUROPE', 'EUROPE'], dtype='<U8')
# 'rating'
# (4763,)
# array([4., 3., 5., 3., 4.])
# 'label'
# (4763,)
# array([1, 2, 1, 2, 0])

# %%
audio_df['val'], non_audio_df['val'] = shuffle_data(audio_df['val'], non_audio_df['val'])

# %%
for key in audio_df['val'].keys():
  display(key)
  display(audio_df['val'][key].shape)
  display(audio_df['val'][key][:5])
# Out:
# 'mfcc'
# (2430, 251, 20)
# array([[[ 0.6599998 ,  0.5494846 ,  0.27689886, ...,  0.4915644 ,
#           0.56852776,  0.3612343 ],
#         [ 0.6518735 ,  0.53866065,  0.25480378, ...,  0.54915094,
#           0.53477615,  0.41227743],
#         [ 0.6241767 ,  0.51867133,  0.31393123, ...,  0.55513996,
#           0.54750955,  0.38951427],
#         ...,
#         [ 0.54487073,  0.49299687,  0.38968584, ...,  0.39025882,
#           0.45972672,  0.3182157 ],
#         [ 0.5351393 ,  0.53468007,  0.31282955, ...,  0.370607  ,
#           0.48097664,  0.23379566],
#         [ 0.5404416 ,  0.51959294,  0.3101878 , ...,  0.36740583,
#           0.56565994,  0.21219558]],
#
#        [[ 0.81219745,  0.78070503,  0.33675426, ...,  0.4198795 ,
#           0.5082685 ,  0.41963017],
#         [ 0.8088371 ,  0.77022994,  0.32918924, ...,  0.53045017,
#           0.56430113,  0.5211768 ],
#         [ 0.77478987,  0.7231244 ,  0.41145796, ...,  0.5712198 ,
#           0.49310583,  0.47525954],
#         ...,
#         [ 0.7690795 ,  0.7458089 ,  0.4245944 , ...,  0.49006045,
#           0.53903615,  0.49693877],
#         [ 0.78141445,  0.75418675,  0.40374407, ...,  0.49482775,
#           0.4447785 ,  0.41775542],
#         [ 0.7864728 ,  0.745769  ,  0.40901777, ...,  0.4992592 ,
#           0.3919807 ,  0.37834176]],
#
#        [[ 0.5459776 ,  0.33651915,  0.4417464 , ...,  0.6024573 ,
#           0.47044212,  0.33776513],
#         [ 0.51702595,  0.27412498,  0.39575452, ...,  0.691908  ,
#           0.5397764 ,  0.51594365],
#         [ 0.48143965,  0.25534728,  0.42116737, ...,  0.73279727,
#           0.5852566 ,  0.48973334],
#         ...,
#         [ 0.42984253,  0.31878698,  0.484332  , ...,  0.54925185,
#           0.49359977,  0.4591045 ],
#         [ 0.47586775,  0.26229206,  0.5086765 , ...,  0.57102615,
#           0.49455774,  0.43204355],
#         [ 0.49441916,  0.22622594,  0.5267187 , ...,  0.62236863,
#           0.5986551 ,  0.39100617]],
#
#        [[ 0.81950724,  0.49789214,  0.31805664, ...,  0.59846276,
#           0.642491  , -0.01706579],
#         [ 0.7943125 ,  0.48451775,  0.34315634, ...,  0.7302494 ,
#           0.83283466,  0.17217115],
#         [ 0.72107136,  0.4766273 ,  0.39061236, ...,  0.874717  ,
#           0.868327  ,  0.3904754 ],
#         ...,
#         [ 0.6336231 ,  0.5711652 ,  0.41342655, ...,  0.5978925 ,
#           0.69717366,  0.7278161 ],
#         [ 0.6544334 ,  0.6379639 ,  0.4376916 , ...,  0.4836388 ,
#           0.615756  ,  0.5693311 ],
#         [ 0.6752175 ,  0.634825  ,  0.5204183 , ...,  0.46637946,
#           0.71621084,  0.5750687 ]],
#
#        [[ 0.24785799,  0.5466083 ,  0.51802444, ...,  0.4321458 ,
#           0.53040135,  0.40444314],
#         [ 0.20378816,  0.5430703 ,  0.48305234, ...,  0.5381551 ,
#           0.5825609 ,  0.4708922 ],
#         [ 0.19222331,  0.5257997 ,  0.52522767, ...,  0.5774611 ,
#           0.6212441 ,  0.4827076 ],
#         ...,
#         [ 0.79691106,  0.6810833 ,  0.5350767 , ...,  0.5520609 ,
#           0.59660554,  0.6237144 ],
#         [ 0.8210425 ,  0.66652554,  0.6075634 , ...,  0.5948764 ,
#           0.5043401 ,  0.6156907 ],
#         [ 0.8316181 ,  0.64180374,  0.6542584 , ...,  0.58368456,
#           0.4609043 ,  0.61189544]]], dtype=float32)
# 'chroma'
# (2430, 251, 12)
# array([[[1.        , 0.8831042 , 0.70270246, ..., 0.5971449 ,
#          0.7415385 , 0.97376996],
#         [0.9544073 , 0.70706594, 0.571961  , ..., 0.66210085,
#          0.8251736 , 1.        ],
#         [0.7146688 , 0.529571  , 0.38448474, ..., 0.50008374,
#          0.4894424 , 0.66672474],
#         ...,
#         [0.740097  , 0.65234953, 0.89699477, ..., 0.52510536,
#          0.50554883, 0.5790142 ],
#         [0.69926107, 0.58654255, 0.5337942 , ..., 0.4456142 ,
#          0.46180114, 0.72806   ],
#         [0.56233484, 0.47947547, 0.6224214 , ..., 0.3564897 ,
#          0.41044557, 0.5454261 ]],
#
#        [[0.8567776 , 0.65116537, 0.6017872 , ..., 0.7022911 ,
#          0.57362276, 0.6050861 ],
#         [0.91404563, 0.74823666, 0.84317535, ..., 1.        ,
#          0.9246443 , 0.9011258 ],
#         [0.6338694 , 0.7090298 , 0.876596  , ..., 0.99725455,
#          1.        , 0.7734058 ],
#         ...,
#         [0.7440812 , 0.57751596, 0.65371335, ..., 0.9026282 ,
#          1.        , 0.68086237],
#         [0.7905435 , 0.8851457 , 1.        , ..., 0.9421181 ,
#          0.9776456 , 0.79483217],
#         [0.6874741 , 0.79767835, 1.0000001 , ..., 0.5356843 ,
#          0.4731486 , 0.62967145]],
#
#        [[0.28154603, 0.28798038, 0.30390415, ..., 0.44398972,
#          0.53907365, 0.30936942],
#         [0.16261628, 0.17051472, 0.27091458, ..., 0.37800184,
#          0.47954285, 0.15449522],
#         [0.17839536, 0.21093537, 0.4190675 , ..., 0.19457914,
#          0.2079471 , 0.10730284],
#         ...,
#         [0.36516026, 0.55951107, 1.        , ..., 0.4220619 ,
#          0.8872779 , 0.45499542],
#         [0.5322963 , 0.67895013, 1.        , ..., 0.16695042,
#          0.37494528, 0.44946328],
#         [0.8187802 , 0.95317763, 1.0000001 , ..., 0.19091554,
#          0.419262  , 0.5483038 ]],
#
#        [[0.27500525, 1.        , 0.16022928, ..., 0.00185554,
#          0.00215943, 0.01237454],
#         [0.41057783, 1.        , 0.14790276, ..., 0.00153501,
#          0.00172147, 0.02535485],
#         [0.63952094, 1.0000001 , 0.14778425, ..., 0.00750941,
#          0.01227527, 0.05871457],
#         ...,
#         [0.82679695, 0.39982915, 0.37690893, ..., 0.51828116,
#          0.55410355, 0.57437384],
#         [0.80697864, 0.5131193 , 0.3728397 , ..., 0.37629852,
#          0.8078402 , 1.        ],
#         [0.59617877, 0.322483  , 0.23620027, ..., 0.23926306,
#          0.8856006 , 1.        ]],
#
#        [[0.8092943 , 0.7828696 , 0.8884255 , ..., 0.84647155,
#          0.76677716, 0.68589044],
#         [0.7199486 , 0.7727649 , 0.89501643, ..., 1.        ,
#          0.8981471 , 0.81127083],
#         [0.7460946 , 0.8106727 , 0.96776396, ..., 0.93939286,
#          0.8922816 , 0.90877354],
#         ...,
#         [0.42416367, 0.45763224, 1.        , ..., 0.44858143,
#          0.38692364, 0.38363865],
#         [0.10286891, 0.16958636, 1.        , ..., 0.0844529 ,
#          0.08800361, 0.06894114],
#         [0.07436927, 0.17817509, 1.0000001 , ..., 0.08299489,
#          0.09454888, 0.06691395]]], dtype=float32)
# 'rms'
# (2430, 251, 1)
# array([[[8.1463372e-03],
#         [8.8492809e-03],
#         [9.6874647e-03],
#         ...,
#         [1.9889608e-02],
#         [4.4632307e-03],
#         [3.4424176e-03]],
#
#        [[3.4968421e-02],
#         [3.8174137e-02],
#         [4.1313805e-02],
#         ...,
#         [4.4570051e-02],
#         [4.1452404e-02],
#         [3.5889346e-02]],
#
#        [[8.4190723e-03],
#         [8.8963453e-03],
#         [1.2169915e-02],
#         ...,
#         [8.6419862e-03],
#         [9.0562617e-03],
#         [9.0040173e-03]],
#
#        [[1.7756414e-01],
#         [1.6130273e-01],
#         [1.4933008e-01],
#         ...,
#         [1.6654307e-02],
#         [1.4830051e-02],
#         [1.2244542e-02]],
#
#        [[8.0320024e-07],
#         [1.0343429e-06],
#         [2.1823071e-06],
#         ...,
#         [7.1994454e-02],
#         [7.3935375e-02],
#         [7.2182596e-02]]], dtype=float32)
# 'spectral_centroid'
# (2430, 251, 1)
# array([[[0.40451193],
#         [0.39721314],
#         [0.40787885],
#         ...,
#         [0.49332242],
#         [0.41347396],
#         [0.40296302]],
#
#        [[0.21766939],
#         [0.21872714],
#         [0.24575222],
#         ...,
#         [0.23511092],
#         [0.26691549],
#         [0.27692912]],
#
#        [[0.6056042 ],
#         [0.59274189],
#         [0.5924426 ],
#         ...,
#         [0.5740991 ],
#         [0.6070507 ],
#         [0.60412467]],
#
#        [[0.42609991],
#         [0.45002985],
#         [0.48968565],
#         ...,
#         [0.37418347],
#         [0.33185759],
#         [0.35992095]],
#
#        [[0.54260571],
#         [0.54753276],
#         [0.56873748],
#         ...,
#         [0.35346316],
#         [0.45771148],
#         [0.47673809]]])
# 'melspectrogram'
# (2430, 251, 20)
# array([[[0.5004936 , 0.49679443, 0.4629721 , ..., 0.45282778,
#          0.4489096 , 0.45806298],
#         [0.5052152 , 0.48160276, 0.467008  , ..., 0.44780323,
#          0.44543967, 0.44462925],
#         [0.5061086 , 0.5087724 , 0.465183  , ..., 0.4622883 ,
#          0.4410606 , 0.45052475],
#         ...,
#         [0.5103344 , 0.4435026 , 0.3730017 , ..., 0.50374395,
#          0.50437224, 0.4086845 ],
#         [0.48738742, 0.43121576, 0.3804701 , ..., 0.3868142 ,
#          0.417389  , 0.393461  ],
#         [0.46250695, 0.39864057, 0.3756762 , ..., 0.38826144,
#          0.41452697, 0.37400356]],
#
#        [[0.72457695, 0.7660515 , 0.7651352 , ..., 0.48745936,
#          0.44420582, 0.42545548],
#         [0.7192346 , 0.7680894 , 0.75039464, ..., 0.48961967,
#          0.44224754, 0.41236246],
#         [0.721367  , 0.7809952 , 0.7410719 , ..., 0.5408741 ,
#          0.4433544 , 0.4220589 ],
#         ...,
#         [0.78034943, 0.7694273 , 0.7851204 , ..., 0.4944491 ,
#          0.43881416, 0.39316592],
#         [0.7679799 , 0.7727173 , 0.7729743 , ..., 0.5672258 ,
#          0.44427225, 0.3986428 ],
#         [0.7672463 , 0.7664132 , 0.740644  , ..., 0.6040062 ,
#          0.45421523, 0.39230302]],
#
#        [[0.3893363 , 0.33424968, 0.31302637, ..., 0.5217479 ,
#          0.5156703 , 0.5289748 ],
#         [0.374509  , 0.2616235 , 0.2547794 , ..., 0.54245126,
#          0.53720987, 0.5213002 ],
#         [0.36682436, 0.25474793, 0.21610373, ..., 0.55674094,
#          0.5338664 , 0.52149683],
#         ...,
#         [0.4474956 , 0.25105578, 0.19113702, ..., 0.4928979 ,
#          0.42341   , 0.40041792],
#         [0.4272654 , 0.24875516, 0.20261896, ..., 0.56392765,
#          0.52840984, 0.48498893],
#         [0.43932456, 0.24677193, 0.20774007, ..., 0.5577996 ,
#          0.54758376, 0.47792378]],
#
#        [[0.49429384, 0.5599911 , 0.6891364 , ..., 0.59605014,
#          0.65864766, 0.64817846],
#         [0.43248382, 0.5757831 , 0.7123748 , ..., 0.66648114,
#          0.6973443 , 0.63695765],
#         [0.38216618, 0.592429  , 0.7075661 , ..., 0.70301825,
#          0.6725798 , 0.6116656 ],
#         ...,
#         [0.39960998, 0.5457579 , 0.6901482 , ..., 0.5571873 ,
#          0.4788071 , 0.42605978],
#         [0.4624751 , 0.5420263 , 0.6847158 , ..., 0.47332177,
#          0.4572174 , 0.43320805],
#         [0.53641796, 0.5591935 , 0.6507262 , ..., 0.47214952,
#          0.47331044, 0.45814106]],
#
#        [[0.22399503, 0.174115  , 0.14281231, ..., 0.118195  ,
#          0.11832112, 0.14048243],
#         [0.21514738, 0.1198554 , 0.1165666 , ..., 0.08952069,
#          0.08786988, 0.09258652],
#         [0.21422917, 0.1328296 , 0.10839802, ..., 0.082084  ,
#          0.08641076, 0.09124231],
#         ...,
#         [0.7925934 , 0.7813177 , 0.77231306, ..., 0.6899325 ,
#          0.5473978 , 0.5061441 ],
#         [0.78601104, 0.79055   , 0.8213301 , ..., 0.7689816 ,
#          0.5683787 , 0.60899395],
#         [0.79377556, 0.78243554, 0.7933544 , ..., 0.77596384,
#          0.58233905, 0.6293009 ]]], dtype=float32)
# 'label'
# (2430,)
# array([2, 1, 0, 0, 0])

# %%
for key in non_audio_df['val'].keys():
  display(key)
  display(non_audio_df['val'][key].shape)
  display(non_audio_df['val'][key][:5])
# Out:
# 'type'
# (2430,)
# array(['call', 'call', 'blank', 'song', 'both'], dtype='<U5')
# 'continent'
# (2430,)
# array(['EUROPE', 'EUROPE', 'AMERICAS', 'AMERICAS', 'EUROPE'], dtype='<U8')
# 'rating'
# (2430,)
# array([4. , 4. , 5. , 4.5, 4. ])
# 'label'
# (2430,)
# array([2, 1, 0, 0, 0])

# %% [markdown]
# # Create sample weights based on rating

# %%
training_sample_weights = non_audio_df['train']['rating']

training_sample_weights
# Out:
# array([4. , 3. , 5. , ..., 5. , 4.5, 4. ])

# %%
validation_sample_weights = non_audio_df['val']['rating']

validation_sample_weights
# Out:
# array([4. , 4. , 5. , ..., 3.5, 5. , 5. ])

# %%
training_sample_weights = np.where(training_sample_weights > 3.0, 0.6, 0.4)

training_sample_weights
# Out:
# array([0.6, 0.4, 0.6, ..., 0.6, 0.6, 0.6])

# %%
validation_sample_weights = np.where(validation_sample_weights > 3.0, 0.6, 0.4)

validation_sample_weights
# Out:
# array([0.6, 0.6, 0.6, ..., 0.6, 0.6, 0.6])

# %% [markdown]
# # 1D CNN Models

# %%
train_results = {}
val_results = {}

# %%
classes = ['barswa', 'comsan', 'eaywag1']

# %% [markdown]
# ## Create 1D CNN model function

# %%
np.unique(non_audio_df['train']['continent'])
# Out:
# array(['AFRICA', 'AMERICAS', 'ASIA', 'EUROPE', 'UNKNOWN'], dtype='<U8')

# %%
def build_model(audio_features,
                continent_feature,
                learning_rate=0.001):

  tf.keras.backend.clear_session()

  # set audio features input layer
  audio_features = tf.keras.layers.Input(shape=(audio_features.shape[1],audio_features.shape[2]), name='Audio_Features')

  # set continent features input layer
  location = tf.keras.layers.Input(shape=(1,), dtype=tf.string, name='Continents')
  location_binned = tf.keras.layers.StringLookup(vocabulary=np.unique(continent_feature))(location)
  location_embed = tf.keras.layers.Embedding(input_dim=(len(np.unique(continent_feature))+1), output_dim=2, input_length=1)(location_binned)

  # custom function to tile the 'Location' embeddings to match the time steps of audio features
  def tile_location_embed(x):
      return tf.keras.backend.tile(x, [1, audio_features.shape[1], 1])

  # using the Lambda layer with the custom function
  location_embed = tf.keras.layers.Lambda(tile_location_embed, name='Tile')(location_embed)

  # create features using both continents with embeddings and mfccs
  features = tf.keras.layers.Concatenate(axis=2, name='Features')([location_embed, audio_features])

  # add first convolution layer to the model
  features = tf.keras.layers.Conv1D(
              filters=32,
              kernel_size=5,
              strides=1,
              padding='same',
              data_format='channels_last',
              name='conv_1',
              activation='relu',
              kernel_regularizer=tf.keras.regularizers.l2(0.02))(features)

  # add first max pooling layer
  features = tf.keras.layers.MaxPool1D(pool_size=2, name='pool_1')(features)

  # add second convolution layer to the model
  features = tf.keras.layers.Conv1D(
              filters=64,
              kernel_size=5,
              strides=1,
              padding='same',
              name='conv_2',
              activation='relu',
              kernel_regularizer=tf.keras.regularizers.l2(0.02))(features)

  # add second max pooling layer
  features = tf.keras.layers.MaxPool1D(pool_size=2, name='pool_2')(features)

  # add a fully connected layer (need to flatten the output of the previous layers first)
  features = tf.keras.layers.Flatten()(features)

  features = tf.keras.layers.Dense(
      units=1024,
      name='fc_1',
      activation='relu')(features)

  # add dropout layer
  features = tf.keras.layers.Dropout(rate=0.5)(features)

  # add the last fully connected layer
  # this last layer sets the activation function to "None" in order to output the logits
  # note that passing activation = "softmax" will return class memembership probabilities but
  # in TensorFlow logits are prefered for numerical stability
  # set units=3 to get a 3 output unit (remember it's 3 species)
  outputs = tf.keras.layers.Dense(
      units=3,
      name='fc_2',
      activation=None)(features)

  # build model and print summary
  model = tf.keras.Model(inputs=[location, audio_features],
                          outputs=outputs,
                          name='Birds')

  print(model.summary())

  # compile model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), #set from_logits=True because our last layer does not apply softmax
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

  return model

# %%
def visualize(model_history, best_epoch):
  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
  # visualize the loss
  axes[0].plot(model_history.history['loss'][:best_epoch+1], color='purple', label='train_losses')
  axes[0].plot(model_history.history['val_loss'][:best_epoch+1], color='orange', label='val_losses')
  axes[0].set_xlabel('Epoch')
  axes[0].set_ylabel('Loss')
  axes[0].set_title('Loss Progression')
  axes[0].legend()

  # visualze the accuracy
  axes[1].plot(model_history.history['accuracy'][:best_epoch+1], color='purple', label='train_accuracy')
  axes[1].plot(model_history.history['val_accuracy'][:best_epoch+1], color='orange', label='val_accuracy')
  axes[1].set_xlabel('Epoch')
  axes[1].set_ylabel('Accuracy')
  axes[1].set_title('Accuracy Progression')
  axes[1].legend()

  plt.show()

# %% [markdown]
# ## With mfcc & chroma & continents

# %% [markdown]
# ### create features

# %%
training_audio_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['chroma']), axis=-1)

training_audio_features
# Out:
# array([[[0.85715145, 0.7720915 , 0.32343465, ..., 0.98987585,
#          0.68978775, 0.83134496],
#         [0.8489596 , 0.76405644, 0.3270986 , ..., 0.8102504 ,
#          0.8809118 , 1.        ],
#         [0.81306714, 0.7316643 , 0.38121283, ..., 0.70719653,
#          0.93877065, 0.9885331 ],
#         ...,
#         [0.7543671 , 0.7431457 , 0.45161688, ..., 0.528907  ,
#          0.553877  , 0.59809744],
#         [0.76071984, 0.76519793, 0.4317957 , ..., 0.5829789 ,
#          0.46056142, 0.56461316],
#         [0.7671031 , 0.7618209 , 0.4211259 , ..., 0.37735045,
#          0.3723486 , 0.7029264 ]],
#
#        [[0.5781203 , 0.5110686 , 0.33823726, ..., 0.6872681 ,
#          0.42638066, 0.15715972],
#         [0.5865296 , 0.45980272, 0.378568  , ..., 0.3797066 ,
#          0.17075238, 0.10151878],
#         [0.5609155 , 0.42990237, 0.425897  , ..., 0.0613028 ,
#          0.03944778, 0.06087872],
#         ...,
#         [0.58505166, 0.5116478 , 0.3250974 , ..., 0.14550054,
#          0.15939614, 0.2811762 ],
#         [0.5940592 , 0.5139758 , 0.24707577, ..., 0.14397934,
#          0.18547806, 0.5166032 ],
#         [0.59488356, 0.5147029 , 0.20010453, ..., 0.10808729,
#          0.1174261 , 0.345927  ]],
#
#        [[0.6043193 , 0.7780733 , 0.60488605, ..., 0.65422094,
#          0.6043084 , 0.55286145],
#         [0.5917373 , 0.7511689 , 0.54849744, ..., 0.75122964,
#          0.42707282, 0.3701036 ],
#         [0.562474  , 0.70484036, 0.58358085, ..., 0.723672  ,
#          0.48231018, 0.5295095 ],
#         ...,
#         [0.58100474, 0.6679153 , 0.7316952 , ..., 0.03272589,
#          0.04833433, 0.03998072],
#         [0.6164744 , 0.6296945 , 0.83395606, ..., 0.01154848,
#          0.02209033, 0.0244415 ],
#         [0.63556254, 0.5964014 , 0.8894726 , ..., 0.01471471,
#          0.03679242, 0.03625474]],
#
#        ...,
#
#        [[0.5994177 , 0.80473447, 0.5963305 , ..., 0.6910873 ,
#          0.5741815 , 0.52364665],
#         [0.56157327, 0.8159188 , 0.5344147 , ..., 0.31906694,
#          0.2963292 , 0.35363764],
#         [0.53121823, 0.7795428 , 0.56896484, ..., 0.7803816 ,
#          0.8011542 , 0.88897526],
#         ...,
#         [0.5268023 , 0.8094164 , 0.60693425, ..., 0.7151583 ,
#          0.6456867 , 0.666247  ],
#         [0.5351648 , 0.8313147 , 0.5848675 , ..., 0.80492043,
#          0.6366335 , 0.5793538 ],
#         [0.5404631 , 0.8311554 , 0.5907752 , ..., 0.73630583,
#          0.75159544, 0.873542  ]],
#
#        [[0.7122581 , 0.62532175, 0.5367607 , ..., 1.        ,
#          0.66142064, 0.41342425],
#         [0.70857346, 0.6230417 , 0.496569  , ..., 1.        ,
#          0.7834327 , 0.32252946],
#         [0.6784563 , 0.60859823, 0.53906715, ..., 1.        ,
#          0.86147535, 0.5466277 ],
#         ...,
#         [0.6177296 , 0.63298666, 0.62809634, ..., 1.        ,
#          0.9522282 , 0.92734855],
#         [0.6192949 , 0.6440301 , 0.6325279 , ..., 0.57167006,
#          0.6586536 , 0.79559356],
#         [0.62457204, 0.62281495, 0.64229745, ..., 0.72276443,
#          0.9317671 , 1.        ]],
#
#        [[0.76785225, 0.624271  , 0.65925217, ..., 0.9118525 ,
#          0.835525  , 0.72489333],
#         [0.7643945 , 0.5977831 , 0.6003218 , ..., 0.87947243,
#          1.        , 0.62662077],
#         [0.72999406, 0.5675868 , 0.6315743 , ..., 1.        ,
#          0.8959899 , 0.5904948 ],
#         ...,
#         [0.6589224 , 0.62786144, 0.6765511 , ..., 0.41054404,
#          0.42064038, 0.70860493],
#         [0.6557413 , 0.65226847, 0.70889163, ..., 0.65928787,
#          0.60327226, 0.9638371 ],
#         [0.64613295, 0.674085  , 0.71221024, ..., 0.25037828,
#          0.40080658, 0.4690259 ]]], dtype=float32)

# %%
training_audio_features.shape
# Out:
# (4763, 251, 32)

# %%
validation_audio_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['chroma']), axis=-1)

validation_audio_features
# Out:
# array([[[0.6599998 , 0.5494846 , 0.27689886, ..., 0.5971449 ,
#          0.7415385 , 0.97376996],
#         [0.6518735 , 0.53866065, 0.25480378, ..., 0.66210085,
#          0.8251736 , 1.        ],
#         [0.6241767 , 0.51867133, 0.31393123, ..., 0.50008374,
#          0.4894424 , 0.66672474],
#         ...,
#         [0.54487073, 0.49299687, 0.38968584, ..., 0.52510536,
#          0.50554883, 0.5790142 ],
#         [0.5351393 , 0.53468007, 0.31282955, ..., 0.4456142 ,
#          0.46180114, 0.72806   ],
#         [0.5404416 , 0.51959294, 0.3101878 , ..., 0.3564897 ,
#          0.41044557, 0.5454261 ]],
#
#        [[0.81219745, 0.78070503, 0.33675426, ..., 0.7022911 ,
#          0.57362276, 0.6050861 ],
#         [0.8088371 , 0.77022994, 0.32918924, ..., 1.        ,
#          0.9246443 , 0.9011258 ],
#         [0.77478987, 0.7231244 , 0.41145796, ..., 0.99725455,
#          1.        , 0.7734058 ],
#         ...,
#         [0.7690795 , 0.7458089 , 0.4245944 , ..., 0.9026282 ,
#          1.        , 0.68086237],
#         [0.78141445, 0.75418675, 0.40374407, ..., 0.9421181 ,
#          0.9776456 , 0.79483217],
#         [0.7864728 , 0.745769  , 0.40901777, ..., 0.5356843 ,
#          0.4731486 , 0.62967145]],
#
#        [[0.5459776 , 0.33651915, 0.4417464 , ..., 0.44398972,
#          0.53907365, 0.30936942],
#         [0.51702595, 0.27412498, 0.39575452, ..., 0.37800184,
#          0.47954285, 0.15449522],
#         [0.48143965, 0.25534728, 0.42116737, ..., 0.19457914,
#          0.2079471 , 0.10730284],
#         ...,
#         [0.42984253, 0.31878698, 0.484332  , ..., 0.4220619 ,
#          0.8872779 , 0.45499542],
#         [0.47586775, 0.26229206, 0.5086765 , ..., 0.16695042,
#          0.37494528, 0.44946328],
#         [0.49441916, 0.22622594, 0.5267187 , ..., 0.19091554,
#          0.419262  , 0.5483038 ]],
#
#        ...,
#
#        [[0.5813173 , 0.69507635, 0.46378428, ..., 0.2514884 ,
#          0.31146738, 0.48265484],
#         [0.5802015 , 0.6841685 , 0.42623731, ..., 0.39535558,
#          0.4680617 , 0.5719024 ],
#         [0.55313075, 0.65219563, 0.4717754 , ..., 0.5536905 ,
#          0.39577144, 0.820599  ],
#         ...,
#         [0.540529  , 0.6755358 , 0.5153094 , ..., 0.33581418,
#          0.7731354 , 1.        ],
#         [0.55107856, 0.70256686, 0.5021846 , ..., 0.21714225,
#          0.46747503, 1.        ],
#         [0.55405533, 0.69633824, 0.49307406, ..., 0.19545063,
#          0.55293554, 1.        ]],
#
#        [[0.650483  , 0.6933858 , 0.3891647 , ..., 0.3941427 ,
#          0.44311693, 0.9637991 ],
#         [0.64880353, 0.6857157 , 0.37113857, ..., 0.53648484,
#          0.3766328 , 0.53472626],
#         [0.619715  , 0.65244156, 0.41850954, ..., 0.55096316,
#          0.42159274, 0.4434214 ],
#         ...,
#         [0.79169226, 0.56107736, 0.45125517, ..., 0.539072  ,
#          0.41227952, 0.449042  ],
#         [0.78885496, 0.57590944, 0.41986766, ..., 0.5161413 ,
#          0.37928122, 0.4963375 ],
#         [0.7902298 , 0.56192625, 0.41452086, ..., 0.42437524,
#          0.3887923 , 0.5954008 ]],
#
#        [[0.7339582 , 0.7160449 , 0.42259353, ..., 0.8562739 ,
#          0.7179734 , 0.5396066 ],
#         [0.7315044 , 0.7043043 , 0.4058334 , ..., 0.7272515 ,
#          0.7098169 , 0.55671155],
#         [0.6952639 , 0.66702783, 0.46122503, ..., 0.62440914,
#          0.74991757, 0.860359  ],
#         ...,
#         [0.6980134 , 0.6813727 , 0.4866833 , ..., 0.72731256,
#          0.7195235 , 0.7258007 ],
#         [0.7057475 , 0.7020318 , 0.45942333, ..., 0.96107066,
#          0.8567721 , 0.8948946 ],
#         [0.70608556, 0.6870007 , 0.4477266 , ..., 0.7390678 ,
#          0.7587668 , 0.89549536]]], dtype=float32)

# %%
validation_audio_features.shape
# Out:
# (2430, 251, 32)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_audio_features,
                    non_audio_df['train']['continent'],
                    learning_rate=0.001)

history = model.fit(
   x={
      'Continents': non_audio_df['train']['continent'],
      'Audio_Features': training_audio_features
   },
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(
      {
      'Continents': non_audio_df['val']['continent'],
      'Audio_Features': validation_audio_features
   },
      audio_df['val']['label'],
      validation_sample_weights
   ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Continents (InputLayer)     [(None, 1)]                  0         []
#
#  string_lookup (StringLooku  (None, 1)                    0         ['Continents[0][0]']
#  p)
#
#  embedding (Embedding)       (None, 1, 2)                 12        ['string_lookup[0][0]']
#
#  Tile (Lambda)               (None, 251, 2)               0         ['embedding[0][0]']
#
#  Audio_Features (InputLayer  [(None, 251, 32)]            0         []
#  )
#
#  Features (Concatenate)      (None, 251, 34)              0         ['Tile[0][0]',
#                                                                      'Audio_Features[0][0]']
#
#  conv_1 (Conv1D)             (None, 251, 32)              5472      ['Features[0][0]']
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)              0         ['conv_1[0][0]']
#
#  conv_2 (Conv1D)             (None, 125, 64)              10304     ['pool_1[0][0]']
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)               0         ['conv_2[0][0]']
#
#  flatten (Flatten)           (None, 3968)                 0         ['pool_2[0][0]']
#
#  fc_1 (Dense)                (None, 1024)                 4064256   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['fc_1[0][0]']
#
#  fc_2 (Dense)                (None, 3)                    3075      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4083119 (15.58 MB)
# Trainable params: 4083119 (15.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 24s 139ms/step - loss: 1.3388 - accuracy: 0.4997 - weighted_accuracy: 0.5072 - val_loss: 0.9364 - val_accuracy: 0.5593 - val_weighted_accuracy: 0.5844
# Epoch 2/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.6957 - accuracy: 0.7407 - weighted_accuracy: 0.7521 - val_loss: 0.6227 - val_accuracy: 0.7358 - val_weighted_accuracy: 0.7568
# Epoch 3/100
# 149/149 [==============================] - 15s 98ms/step - loss: 0.4877 - accuracy: 0.8264 - weighted_accuracy: 0.8349 - val_loss: 0.5641 - val_accuracy: 0.7305 - val_weighted_accuracy: 0.7539
# Epoch 4/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.4077 - accuracy: 0.8467 - weighted_accuracy: 0.8539 - val_loss: 0.4739 - val_accuracy: 0.7564 - val_weighted_accuracy: 0.7741
# Epoch 5/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.3608 - accuracy: 0.8574 - weighted_accuracy: 0.8645 - val_loss: 0.5683 - val_accuracy: 0.6893 - val_weighted_accuracy: 0.7152
# Epoch 6/100
# 149/149 [==============================] - 16s 106ms/step - loss: 0.3319 - accuracy: 0.8587 - weighted_accuracy: 0.8670 - val_loss: 0.3846 - val_accuracy: 0.8354 - val_weighted_accuracy: 0.8405
# Epoch 7/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.2840 - accuracy: 0.8870 - weighted_accuracy: 0.8928 - val_loss: 0.3631 - val_accuracy: 0.8082 - val_weighted_accuracy: 0.8204
# Epoch 8/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.2842 - accuracy: 0.8801 - weighted_accuracy: 0.8866 - val_loss: 0.3613 - val_accuracy: 0.8321 - val_weighted_accuracy: 0.8401
# Epoch 9/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.2500 - accuracy: 0.8931 - weighted_accuracy: 0.8986 - val_loss: 0.3544 - val_accuracy: 0.8325 - val_weighted_accuracy: 0.8416
# Epoch 10/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.2240 - accuracy: 0.9070 - weighted_accuracy: 0.9108 - val_loss: 0.3121 - val_accuracy: 0.8444 - val_weighted_accuracy: 0.8528
# Epoch 11/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2103 - accuracy: 0.9125 - weighted_accuracy: 0.9171 - val_loss: 0.3044 - val_accuracy: 0.8391 - val_weighted_accuracy: 0.8433
# Epoch 12/100
# 149/149 [==============================] - 16s 107ms/step - loss: 0.2075 - accuracy: 0.9064 - weighted_accuracy: 0.9108 - val_loss: 0.3313 - val_accuracy: 0.7930 - val_weighted_accuracy: 0.8055
# Epoch 13/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.2031 - accuracy: 0.9118 - weighted_accuracy: 0.9161 - val_loss: 0.2940 - val_accuracy: 0.8613 - val_weighted_accuracy: 0.8663
# Epoch 14/100
# 149/149 [==============================] - 15s 104ms/step - loss: 0.1920 - accuracy: 0.9150 - weighted_accuracy: 0.9182 - val_loss: 0.2853 - val_accuracy: 0.8765 - val_weighted_accuracy: 0.8807
# Epoch 15/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1974 - accuracy: 0.9114 - weighted_accuracy: 0.9148 - val_loss: 0.3077 - val_accuracy: 0.8374 - val_weighted_accuracy: 0.8443
# Epoch 16/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1842 - accuracy: 0.9194 - weighted_accuracy: 0.9236 - val_loss: 0.2859 - val_accuracy: 0.8449 - val_weighted_accuracy: 0.8537
# Epoch 17/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1781 - accuracy: 0.9257 - weighted_accuracy: 0.9286 - val_loss: 0.2946 - val_accuracy: 0.8605 - val_weighted_accuracy: 0.8627
# Epoch 18/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1546 - accuracy: 0.9368 - weighted_accuracy: 0.9396 - val_loss: 0.3043 - val_accuracy: 0.8539 - val_weighted_accuracy: 0.8568
# Epoch 19/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1605 - accuracy: 0.9322 - weighted_accuracy: 0.9355 - val_loss: 0.3543 - val_accuracy: 0.7922 - val_weighted_accuracy: 0.8093
# Epoch 20/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1651 - accuracy: 0.9267 - weighted_accuracy: 0.9292 - val_loss: 0.2842 - val_accuracy: 0.8658 - val_weighted_accuracy: 0.8703
# Epoch 21/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1355 - accuracy: 0.9496 - weighted_accuracy: 0.9525 - val_loss: 0.3236 - val_accuracy: 0.8477 - val_weighted_accuracy: 0.8506
# Epoch 22/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1255 - accuracy: 0.9549 - weighted_accuracy: 0.9575 - val_loss: 0.3041 - val_accuracy: 0.8547 - val_weighted_accuracy: 0.8631
# Epoch 23/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1385 - accuracy: 0.9404 - weighted_accuracy: 0.9436 - val_loss: 0.3064 - val_accuracy: 0.8440 - val_weighted_accuracy: 0.8536
# Epoch 24/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1337 - accuracy: 0.9465 - weighted_accuracy: 0.9492 - val_loss: 0.3625 - val_accuracy: 0.7761 - val_weighted_accuracy: 0.7893
# Epoch 25/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1635 - accuracy: 0.9263 - weighted_accuracy: 0.9294 - val_loss: 0.3548 - val_accuracy: 0.8313 - val_weighted_accuracy: 0.8340
# Epoch 26/100
# 149/149 [==============================] - 15s 104ms/step - loss: 0.1303 - accuracy: 0.9521 - weighted_accuracy: 0.9550 - val_loss: 0.3229 - val_accuracy: 0.8416 - val_weighted_accuracy: 0.8477
# Epoch 27/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1398 - accuracy: 0.9452 - weighted_accuracy: 0.9478 - val_loss: 0.3219 - val_accuracy: 0.8477 - val_weighted_accuracy: 0.8550
# Epoch 28/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1023 - accuracy: 0.9681 - weighted_accuracy: 0.9704 - val_loss: 0.2982 - val_accuracy: 0.8716 - val_weighted_accuracy: 0.8753
# Epoch 29/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1120 - accuracy: 0.9607 - weighted_accuracy: 0.9628 - val_loss: 0.3421 - val_accuracy: 0.8420 - val_weighted_accuracy: 0.8442
# Epoch 30/100
# 149/149 [==============================] - 15s 98ms/step - loss: 0.1040 - accuracy: 0.9677 - weighted_accuracy: 0.9691 - val_loss: 0.4540 - val_accuracy: 0.7971 - val_weighted_accuracy: 0.7975
# Epoch 31/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1279 - accuracy: 0.9488 - weighted_accuracy: 0.9513 - val_loss: 0.3128 - val_accuracy: 0.8473 - val_weighted_accuracy: 0.8515
# Epoch 32/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.0923 - accuracy: 0.9731 - weighted_accuracy: 0.9750 - val_loss: 0.3285 - val_accuracy: 0.8477 - val_weighted_accuracy: 0.8553
# Epoch 33/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.0850 - accuracy: 0.9784 - weighted_accuracy: 0.9803 - val_loss: 0.4187 - val_accuracy: 0.8173 - val_weighted_accuracy: 0.8270
# Epoch 34/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1033 - accuracy: 0.9662 - weighted_accuracy: 0.9685 - val_loss: 0.3128 - val_accuracy: 0.8613 - val_weighted_accuracy: 0.8669
# Epoch 35/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.0978 - accuracy: 0.9710 - weighted_accuracy: 0.9729 - val_loss: 0.3375 - val_accuracy: 0.8502 - val_weighted_accuracy: 0.8528
# Epoch 36/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.0846 - accuracy: 0.9752 - weighted_accuracy: 0.9779 - val_loss: 0.3243 - val_accuracy: 0.8576 - val_weighted_accuracy: 0.8634
# Epoch 37/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.0874 - accuracy: 0.9738 - weighted_accuracy: 0.9754 - val_loss: 0.4304 - val_accuracy: 0.8058 - val_weighted_accuracy: 0.8195
# Epoch 38/100
# 149/149 [==============================] - 27s 180ms/step - loss: 0.1030 - accuracy: 0.9626 - weighted_accuracy: 0.9647 - val_loss: 0.3879 - val_accuracy: 0.8259 - val_weighted_accuracy: 0.8369
# best_epoch:  13

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
train_yhat = model.predict({'Continents': non_audio_df['train']['continent'],
                            'Audio_Features': training_audio_features
                            })

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_chroma_continents'] = model.evaluate({'Continents': non_audio_df['train']['continent'],
                                                          'Audio_Features': training_audio_features},
                                                         audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 4s 28ms/step
# 149/149 [==============================] - 3s 15ms/step - loss: 0.1234 - accuracy: 0.9763 - weighted_accuracy: 0.9763

# %%
val_yhat = model.predict({'Continents': non_audio_df['val']['continent'],
                          'Audio_Features': validation_audio_features
                          })

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_chroma_continents'] = model.evaluate({'Continents': non_audio_df['val']['continent'],
                                                          'Audio_Features': validation_audio_features},
                                                         audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 2s 23ms/step
# 76/76 [==============================] - 2s 20ms/step - loss: 0.5163 - accuracy: 0.8716 - weighted_accuracy: 0.8716

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.96      1.00      0.98      1603
#       comsan       0.98      0.97      0.97      1578
#      eaywag1       1.00      0.97      0.98      1582
#
#     accuracy                           0.98      4763
#    macro avg       0.98      0.98      0.98      4763
# weighted avg       0.98      0.98      0.98      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.85      0.91      0.88      1032
#       comsan       0.85      0.84      0.85       618
#      eaywag1       0.92      0.84      0.88       780
#
#     accuracy                           0.87      2430
#    macro avg       0.87      0.87      0.87      2430
# weighted avg       0.87      0.87      0.87      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# ## With mfcc & rms & continents

# %% [markdown]
# ### create features

# %%
training_audio_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['rms']), axis=-1)

training_audio_features
# Out:
# array([[[0.85715145, 0.7720915 , 0.32343465, ..., 0.4473845 ,
#          0.32348067, 0.05045145],
#         [0.8489596 , 0.76405644, 0.3270986 , ..., 0.5059513 ,
#          0.46025   , 0.05636971],
#         [0.81306714, 0.7316643 , 0.38121283, ..., 0.5094435 ,
#          0.5133219 , 0.05972068],
#         ...,
#         [0.7543671 , 0.7431457 , 0.45161688, ..., 0.51767015,
#          0.45690683, 0.03885968],
#         [0.76071984, 0.76519793, 0.4317957 , ..., 0.44919658,
#          0.41896337, 0.03439789],
#         [0.7671031 , 0.7618209 , 0.4211259 , ..., 0.51402247,
#          0.39780954, 0.02821541]],
#
#        [[0.5781203 , 0.5110686 , 0.33823726, ..., 0.46471834,
#          0.5171151 , 0.0078186 ],
#         [0.5865296 , 0.45980272, 0.378568  , ..., 0.5952264 ,
#          0.4887229 , 0.00876402],
#         [0.5609155 , 0.42990237, 0.425897  , ..., 0.60503346,
#          0.40780362, 0.00845237],
#         ...,
#         [0.58505166, 0.5116478 , 0.3250974 , ..., 0.7202647 ,
#          0.46407914, 0.00980887],
#         [0.5940592 , 0.5139758 , 0.24707577, ..., 0.6594661 ,
#          0.37247282, 0.00998901],
#         [0.59488356, 0.5147029 , 0.20010453, ..., 0.77573484,
#          0.33499646, 0.00893118]],
#
#        [[0.6043193 , 0.7780733 , 0.60488605, ..., 0.5239149 ,
#          0.40213192, 0.00691423],
#         [0.5917373 , 0.7511689 , 0.54849744, ..., 0.5887091 ,
#          0.45853385, 0.00731169],
#         [0.562474  , 0.70484036, 0.58358085, ..., 0.6264296 ,
#          0.4719776 , 0.00816986],
#         ...,
#         [0.58100474, 0.6679153 , 0.7316952 , ..., 0.54233015,
#          0.6030581 , 0.02820133],
#         [0.6164744 , 0.6296945 , 0.83395606, ..., 0.79644823,
#          0.33529326, 0.02959021],
#         [0.63556254, 0.5964014 , 0.8894726 , ..., 0.94916236,
#          0.230663  , 0.02945004]],
#
#        ...,
#
#        [[0.5994177 , 0.80473447, 0.5963305 , ..., 0.5373482 ,
#          0.45738348, 0.02550218],
#         [0.56157327, 0.8159188 , 0.5344147 , ..., 0.60402125,
#          0.49500203, 0.03051137],
#         [0.53121823, 0.7795428 , 0.56896484, ..., 0.62271655,
#          0.49318588, 0.03369534],
#         ...,
#         [0.5268023 , 0.8094164 , 0.60693425, ..., 0.64603615,
#          0.4892924 , 0.02740254],
#         [0.5351648 , 0.8313147 , 0.5848675 , ..., 0.5741919 ,
#          0.4332756 , 0.02503415],
#         [0.5404631 , 0.8311554 , 0.5907752 , ..., 0.69178987,
#          0.40777534, 0.01799533]],
#
#        [[0.7122581 , 0.62532175, 0.5367607 , ..., 0.65240675,
#          0.69232666, 0.02007527],
#         [0.70857346, 0.6230417 , 0.496569  , ..., 0.6493207 ,
#          0.76052487, 0.02048742],
#         [0.6784563 , 0.60859823, 0.53906715, ..., 0.72365993,
#          0.68320954, 0.02046571],
#         ...,
#         [0.6177296 , 0.63298666, 0.62809634, ..., 0.6703569 ,
#          0.57496494, 0.01999955],
#         [0.6192949 , 0.6440301 , 0.6325279 , ..., 0.6563479 ,
#          0.54373974, 0.01895325],
#         [0.62457204, 0.62281495, 0.64229745, ..., 0.74734735,
#          0.48835483, 0.0141823 ]],
#
#        [[0.76785225, 0.624271  , 0.65925217, ..., 0.40399116,
#          0.34238595, 0.0207934 ],
#         [0.7643945 , 0.5977831 , 0.6003218 , ..., 0.51542556,
#          0.41769126, 0.02287893],
#         [0.72999406, 0.5675868 , 0.6315743 , ..., 0.53576714,
#          0.40378967, 0.02452519],
#         ...,
#         [0.6589224 , 0.62786144, 0.6765511 , ..., 0.52155966,
#          0.5411051 , 0.01649   ],
#         [0.6557413 , 0.65226847, 0.70889163, ..., 0.47605547,
#          0.5284549 , 0.01455376],
#         [0.64613295, 0.674085  , 0.71221024, ..., 0.55726916,
#          0.56418556, 0.01183528]]], dtype=float32)

# %%
training_audio_features.shape
# Out:
# (4763, 251, 21)

# %%
validation_audio_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['rms']), axis=-1)

validation_audio_features
# Out:
# array([[[0.6599998 , 0.5494846 , 0.27689886, ..., 0.56852776,
#          0.3612343 , 0.00814634],
#         [0.6518735 , 0.53866065, 0.25480378, ..., 0.53477615,
#          0.41227743, 0.00884928],
#         [0.6241767 , 0.51867133, 0.31393123, ..., 0.54750955,
#          0.38951427, 0.00968746],
#         ...,
#         [0.54487073, 0.49299687, 0.38968584, ..., 0.45972672,
#          0.3182157 , 0.01988961],
#         [0.5351393 , 0.53468007, 0.31282955, ..., 0.48097664,
#          0.23379566, 0.00446323],
#         [0.5404416 , 0.51959294, 0.3101878 , ..., 0.56565994,
#          0.21219558, 0.00344242]],
#
#        [[0.81219745, 0.78070503, 0.33675426, ..., 0.5082685 ,
#          0.41963017, 0.03496842],
#         [0.8088371 , 0.77022994, 0.32918924, ..., 0.56430113,
#          0.5211768 , 0.03817414],
#         [0.77478987, 0.7231244 , 0.41145796, ..., 0.49310583,
#          0.47525954, 0.0413138 ],
#         ...,
#         [0.7690795 , 0.7458089 , 0.4245944 , ..., 0.53903615,
#          0.49693877, 0.04457005],
#         [0.78141445, 0.75418675, 0.40374407, ..., 0.4447785 ,
#          0.41775542, 0.0414524 ],
#         [0.7864728 , 0.745769  , 0.40901777, ..., 0.3919807 ,
#          0.37834176, 0.03588935]],
#
#        [[0.5459776 , 0.33651915, 0.4417464 , ..., 0.47044212,
#          0.33776513, 0.00841907],
#         [0.51702595, 0.27412498, 0.39575452, ..., 0.5397764 ,
#          0.51594365, 0.00889635],
#         [0.48143965, 0.25534728, 0.42116737, ..., 0.5852566 ,
#          0.48973334, 0.01216992],
#         ...,
#         [0.42984253, 0.31878698, 0.484332  , ..., 0.49359977,
#          0.4591045 , 0.00864199],
#         [0.47586775, 0.26229206, 0.5086765 , ..., 0.49455774,
#          0.43204355, 0.00905626],
#         [0.49441916, 0.22622594, 0.5267187 , ..., 0.5986551 ,
#          0.39100617, 0.00900402]],
#
#        ...,
#
#        [[0.5813173 , 0.69507635, 0.46378428, ..., 0.5388737 ,
#          0.40547934, 0.00388941],
#         [0.5802015 , 0.6841685 , 0.42623731, ..., 0.47107932,
#          0.43142903, 0.00430809],
#         [0.55313075, 0.65219563, 0.4717754 , ..., 0.47927094,
#          0.4483365 , 0.00478347],
#         ...,
#         [0.540529  , 0.6755358 , 0.5153094 , ..., 0.506101  ,
#          0.42988053, 0.0049165 ],
#         [0.55107856, 0.70256686, 0.5021846 , ..., 0.50544345,
#          0.42974877, 0.00451883],
#         [0.55405533, 0.69633824, 0.49307406, ..., 0.5914373 ,
#          0.4509887 , 0.00384084]],
#
#        [[0.650483  , 0.6933858 , 0.3891647 , ..., 0.5532568 ,
#          0.40537888, 0.0061755 ],
#         [0.64880353, 0.6857157 , 0.37113857, ..., 0.56503516,
#          0.49065983, 0.00688783],
#         [0.619715  , 0.65244156, 0.41850954, ..., 0.6653862 ,
#          0.5279736 , 0.00746608],
#         ...,
#         [0.79169226, 0.56107736, 0.45125517, ..., 0.49641812,
#          0.41606656, 0.04125094],
#         [0.78885496, 0.57590944, 0.41986766, ..., 0.487211  ,
#          0.36803234, 0.03760236],
#         [0.7902298 , 0.56192625, 0.41452086, ..., 0.5772824 ,
#          0.34245056, 0.03106061]],
#
#        [[0.7339582 , 0.7160449 , 0.42259353, ..., 0.50410235,
#          0.46671826, 0.01356566],
#         [0.7315044 , 0.7043043 , 0.4058334 , ..., 0.51382244,
#          0.5004515 , 0.01450409],
#         [0.6952639 , 0.66702783, 0.46122503, ..., 0.5685635 ,
#          0.52902746, 0.01573573],
#         ...,
#         [0.6980134 , 0.6813727 , 0.4866833 , ..., 0.5300056 ,
#          0.50151604, 0.01712802],
#         [0.7057475 , 0.7020318 , 0.45942333, ..., 0.476099  ,
#          0.43128008, 0.01584159],
#         [0.70608556, 0.6870007 , 0.4477266 , ..., 0.5427563 ,
#          0.40545058, 0.01329589]]], dtype=float32)

# %%
validation_audio_features.shape
# Out:
# (2430, 251, 21)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_audio_features,
                    non_audio_df['train']['continent'],
                    learning_rate=0.001)

history = model.fit(
   x={
      'Continents': non_audio_df['train']['continent'],
      'Audio_Features': training_audio_features
   },
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(
      {
      'Continents': non_audio_df['val']['continent'],
      'Audio_Features': validation_audio_features
   },
      audio_df['val']['label'],
      validation_sample_weights
   ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Continents (InputLayer)     [(None, 1)]                  0         []
#
#  string_lookup (StringLooku  (None, 1)                    0         ['Continents[0][0]']
#  p)
#
#  embedding (Embedding)       (None, 1, 2)                 12        ['string_lookup[0][0]']
#
#  Tile (Lambda)               (None, 251, 2)               0         ['embedding[0][0]']
#
#  Audio_Features (InputLayer  [(None, 251, 21)]            0         []
#  )
#
#  Features (Concatenate)      (None, 251, 23)              0         ['Tile[0][0]',
#                                                                      'Audio_Features[0][0]']
#
#  conv_1 (Conv1D)             (None, 251, 32)              3712      ['Features[0][0]']
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)              0         ['conv_1[0][0]']
#
#  conv_2 (Conv1D)             (None, 125, 64)              10304     ['pool_1[0][0]']
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)               0         ['conv_2[0][0]']
#
#  flatten (Flatten)           (None, 3968)                 0         ['pool_2[0][0]']
#
#  fc_1 (Dense)                (None, 1024)                 4064256   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['fc_1[0][0]']
#
#  fc_2 (Dense)                (None, 3)                    3075      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4081359 (15.57 MB)
# Trainable params: 4081359 (15.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 14s 86ms/step - loss: 1.1167 - accuracy: 0.5755 - weighted_accuracy: 0.5880 - val_loss: 0.8188 - val_accuracy: 0.6580 - val_weighted_accuracy: 0.6756
# Epoch 2/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.6463 - accuracy: 0.7189 - weighted_accuracy: 0.7304 - val_loss: 0.6281 - val_accuracy: 0.7514 - val_weighted_accuracy: 0.7547
# Epoch 3/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.4912 - accuracy: 0.8096 - weighted_accuracy: 0.8170 - val_loss: 0.5611 - val_accuracy: 0.7362 - val_weighted_accuracy: 0.7629
# Epoch 4/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.4045 - accuracy: 0.8556 - weighted_accuracy: 0.8613 - val_loss: 0.5007 - val_accuracy: 0.7938 - val_weighted_accuracy: 0.8000
# Epoch 5/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.3552 - accuracy: 0.8820 - weighted_accuracy: 0.8866 - val_loss: 0.4379 - val_accuracy: 0.8300 - val_weighted_accuracy: 0.8384
# Epoch 6/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.3217 - accuracy: 0.8887 - weighted_accuracy: 0.8942 - val_loss: 0.4321 - val_accuracy: 0.8206 - val_weighted_accuracy: 0.8292
# Epoch 7/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.3034 - accuracy: 0.8795 - weighted_accuracy: 0.8848 - val_loss: 0.3923 - val_accuracy: 0.8206 - val_weighted_accuracy: 0.8346
# Epoch 8/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.2746 - accuracy: 0.9032 - weighted_accuracy: 0.9083 - val_loss: 0.3856 - val_accuracy: 0.8329 - val_weighted_accuracy: 0.8399
# Epoch 9/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.2683 - accuracy: 0.9066 - weighted_accuracy: 0.9104 - val_loss: 0.4087 - val_accuracy: 0.8370 - val_weighted_accuracy: 0.8454
# Epoch 10/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.2476 - accuracy: 0.9137 - weighted_accuracy: 0.9186 - val_loss: 0.4058 - val_accuracy: 0.8383 - val_weighted_accuracy: 0.8413
# Epoch 11/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2234 - accuracy: 0.9236 - weighted_accuracy: 0.9279 - val_loss: 0.3897 - val_accuracy: 0.8321 - val_weighted_accuracy: 0.8343
# Epoch 12/100
# 149/149 [==============================] - 13s 91ms/step - loss: 0.2194 - accuracy: 0.9213 - weighted_accuracy: 0.9257 - val_loss: 0.4229 - val_accuracy: 0.8313 - val_weighted_accuracy: 0.8349
# Epoch 13/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.2099 - accuracy: 0.9292 - weighted_accuracy: 0.9327 - val_loss: 0.4970 - val_accuracy: 0.7996 - val_weighted_accuracy: 0.8107
# Epoch 14/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1968 - accuracy: 0.9330 - weighted_accuracy: 0.9371 - val_loss: 0.3431 - val_accuracy: 0.8560 - val_weighted_accuracy: 0.8587
# Epoch 15/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1936 - accuracy: 0.9339 - weighted_accuracy: 0.9378 - val_loss: 0.3026 - val_accuracy: 0.8790 - val_weighted_accuracy: 0.8809
# Epoch 16/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1889 - accuracy: 0.9379 - weighted_accuracy: 0.9416 - val_loss: 0.4114 - val_accuracy: 0.8058 - val_weighted_accuracy: 0.8248
# Epoch 17/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.1769 - accuracy: 0.9370 - weighted_accuracy: 0.9408 - val_loss: 0.3054 - val_accuracy: 0.8741 - val_weighted_accuracy: 0.8765
# Epoch 18/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1617 - accuracy: 0.9498 - weighted_accuracy: 0.9525 - val_loss: 0.2826 - val_accuracy: 0.8811 - val_weighted_accuracy: 0.8838
# Epoch 19/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1858 - accuracy: 0.9282 - weighted_accuracy: 0.9315 - val_loss: 0.3704 - val_accuracy: 0.8004 - val_weighted_accuracy: 0.8055
# Epoch 20/100
# 149/149 [==============================] - 15s 98ms/step - loss: 0.1736 - accuracy: 0.9311 - weighted_accuracy: 0.9378 - val_loss: 0.2877 - val_accuracy: 0.8564 - val_weighted_accuracy: 0.8701
# Epoch 21/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1561 - accuracy: 0.9456 - weighted_accuracy: 0.9494 - val_loss: 0.3520 - val_accuracy: 0.8325 - val_weighted_accuracy: 0.8399
# Epoch 22/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1592 - accuracy: 0.9448 - weighted_accuracy: 0.9483 - val_loss: 0.2922 - val_accuracy: 0.8909 - val_weighted_accuracy: 0.8933
# Epoch 23/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1464 - accuracy: 0.9517 - weighted_accuracy: 0.9553 - val_loss: 0.2870 - val_accuracy: 0.8642 - val_weighted_accuracy: 0.8686
# Epoch 24/100
# 149/149 [==============================] - 12s 84ms/step - loss: 0.1518 - accuracy: 0.9473 - weighted_accuracy: 0.9507 - val_loss: 0.2788 - val_accuracy: 0.8753 - val_weighted_accuracy: 0.8820
# Epoch 25/100
# 149/149 [==============================] - 12s 81ms/step - loss: 0.1360 - accuracy: 0.9542 - weighted_accuracy: 0.9576 - val_loss: 0.2623 - val_accuracy: 0.8963 - val_weighted_accuracy: 0.8990
# Epoch 26/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1279 - accuracy: 0.9565 - weighted_accuracy: 0.9597 - val_loss: 0.2943 - val_accuracy: 0.8527 - val_weighted_accuracy: 0.8692
# Epoch 27/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1258 - accuracy: 0.9641 - weighted_accuracy: 0.9664 - val_loss: 0.2301 - val_accuracy: 0.9082 - val_weighted_accuracy: 0.9122
# Epoch 28/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1168 - accuracy: 0.9639 - weighted_accuracy: 0.9663 - val_loss: 0.2618 - val_accuracy: 0.8901 - val_weighted_accuracy: 0.8953
# Epoch 29/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1084 - accuracy: 0.9681 - weighted_accuracy: 0.9702 - val_loss: 0.2417 - val_accuracy: 0.9078 - val_weighted_accuracy: 0.9120
# Epoch 30/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1300 - accuracy: 0.9496 - weighted_accuracy: 0.9529 - val_loss: 0.2500 - val_accuracy: 0.8774 - val_weighted_accuracy: 0.8891
# Epoch 31/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1272 - accuracy: 0.9519 - weighted_accuracy: 0.9551 - val_loss: 0.2702 - val_accuracy: 0.8840 - val_weighted_accuracy: 0.8902
# Epoch 32/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1122 - accuracy: 0.9637 - weighted_accuracy: 0.9663 - val_loss: 0.2467 - val_accuracy: 0.9053 - val_weighted_accuracy: 0.9076
# Epoch 33/100
# 149/149 [==============================] - 14s 97ms/step - loss: 0.1089 - accuracy: 0.9666 - weighted_accuracy: 0.9690 - val_loss: 0.2455 - val_accuracy: 0.9029 - val_weighted_accuracy: 0.9062
# Epoch 34/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1238 - accuracy: 0.9509 - weighted_accuracy: 0.9546 - val_loss: 0.2747 - val_accuracy: 0.8905 - val_weighted_accuracy: 0.8946
# Epoch 35/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1066 - accuracy: 0.9654 - weighted_accuracy: 0.9682 - val_loss: 0.2701 - val_accuracy: 0.8848 - val_weighted_accuracy: 0.8920
# Epoch 36/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.1219 - accuracy: 0.9523 - weighted_accuracy: 0.9562 - val_loss: 0.2650 - val_accuracy: 0.8889 - val_weighted_accuracy: 0.8950
# Epoch 37/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1089 - accuracy: 0.9620 - weighted_accuracy: 0.9647 - val_loss: 0.2975 - val_accuracy: 0.8724 - val_weighted_accuracy: 0.8785
# best_epoch:  26

# %%
train_yhat = model.predict({'Continents': non_audio_df['train']['continent'],
                            'Audio_Features': training_audio_features
                            })

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_rms_continents'] = model.evaluate({'Continents': non_audio_df['train']['continent'],
                                                          'Audio_Features': training_audio_features},
                                                         audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 2s 13ms/step
# 149/149 [==============================] - 2s 13ms/step - loss: 0.1434 - accuracy: 0.9765 - weighted_accuracy: 0.9765

# %%
val_yhat = model.predict({'Continents': non_audio_df['val']['continent'],
                          'Audio_Features': validation_audio_features
                          })

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_rms_continents'] = model.evaluate({'Continents': non_audio_df['val']['continent'],
                                                          'Audio_Features': validation_audio_features},
                                                         audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 2s 22ms/step
# 76/76 [==============================] - 2s 21ms/step - loss: 0.3789 - accuracy: 0.9082 - weighted_accuracy: 0.9082

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.97      0.98      0.98      1603
#       comsan       0.97      0.98      0.98      1578
#      eaywag1       0.99      0.96      0.98      1582
#
#     accuracy                           0.98      4763
#    macro avg       0.98      0.98      0.98      4763
# weighted avg       0.98      0.98      0.98      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.92      0.89      0.91      1032
#       comsan       0.86      0.93      0.89       618
#      eaywag1       0.94      0.91      0.92       780
#
#     accuracy                           0.91      2430
#    macro avg       0.91      0.91      0.91      2430
# weighted avg       0.91      0.91      0.91      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# ## With mfcc & spectral_centroid & continents

# %% [markdown]
# ### create features

# %%
training_audio_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['spectral_centroid']), axis=-1)

training_audio_features
# Out:
# array([[[0.85715145, 0.77209151, 0.32343465, ..., 0.44738451,
#          0.32348067, 0.22281198],
#         [0.84895962, 0.76405644, 0.32709861, ..., 0.50595129,
#          0.46024999, 0.22631334],
#         [0.81306714, 0.7316643 , 0.38121283, ..., 0.50944352,
#          0.51332188, 0.23361687],
#         ...,
#         [0.75436711, 0.7431457 , 0.45161688, ..., 0.51767015,
#          0.45690683, 0.23204755],
#         [0.76071984, 0.76519793, 0.43179569, ..., 0.44919658,
#          0.41896337, 0.22768157],
#         [0.76710308, 0.76182091, 0.42112589, ..., 0.51402247,
#          0.39780954, 0.2244155 ]],
#
#        [[0.57812029, 0.51106858, 0.33823726, ..., 0.46471834,
#          0.51711512, 0.58009442],
#         [0.58652961, 0.45980272, 0.37856799, ..., 0.59522641,
#          0.48872289, 0.66959631],
#         [0.56091553, 0.42990237, 0.425897  , ..., 0.60503346,
#          0.40780362, 0.67599949],
#         ...,
#         [0.58505166, 0.51164782, 0.32509741, ..., 0.72026467,
#          0.46407914, 0.42379785],
#         [0.59405923, 0.5139758 , 0.24707577, ..., 0.65946609,
#          0.37247282, 0.41740986],
#         [0.59488356, 0.51470292, 0.20010453, ..., 0.77573484,
#          0.33499646, 0.36134405]],
#
#        [[0.60431927, 0.77807331, 0.60488605, ..., 0.52391487,
#          0.40213192, 0.20033525],
#         [0.59173727, 0.75116891, 0.54849744, ..., 0.58870912,
#          0.45853385, 0.22573477],
#         [0.56247401, 0.70484036, 0.58358085, ..., 0.62642962,
#          0.47197759, 0.25117208],
#         ...,
#         [0.58100474, 0.66791528, 0.73169518, ..., 0.54233015,
#          0.6030581 , 0.56223134],
#         [0.61647439, 0.62969452, 0.83395606, ..., 0.79644823,
#          0.33529326, 0.64126956],
#         [0.63556254, 0.59640139, 0.8894726 , ..., 0.94916236,
#          0.230663  , 0.64483953]],
#
#        ...,
#
#        [[0.59941769, 0.80473447, 0.59633052, ..., 0.53734821,
#          0.45738348, 0.11218752],
#         [0.56157327, 0.8159188 , 0.53441471, ..., 0.60402125,
#          0.49500203, 0.08031361],
#         [0.53121823, 0.7795428 , 0.56896484, ..., 0.62271655,
#          0.49318588, 0.07496744],
#         ...,
#         [0.5268023 , 0.80941641, 0.60693425, ..., 0.64603615,
#          0.48929241, 0.0812696 ],
#         [0.53516477, 0.83131468, 0.58486748, ..., 0.57419193,
#          0.43327561, 0.08767186],
#         [0.54046309, 0.83115542, 0.59077519, ..., 0.69178987,
#          0.40777534, 0.07536668]],
#
#        [[0.7122581 , 0.62532175, 0.53676069, ..., 0.65240675,
#          0.69232666, 0.36214103],
#         [0.70857346, 0.62304169, 0.49656901, ..., 0.64932072,
#          0.76052487, 0.35261739],
#         [0.67845631, 0.60859823, 0.53906715, ..., 0.72365993,
#          0.68320954, 0.35740182],
#         ...,
#         [0.6177296 , 0.63298666, 0.62809634, ..., 0.67035693,
#          0.57496494, 0.28327202],
#         [0.61929488, 0.64403009, 0.63252789, ..., 0.65634787,
#          0.54373974, 0.31025082],
#         [0.62457204, 0.62281495, 0.64229745, ..., 0.74734735,
#          0.48835483, 0.32595072]],
#
#        [[0.76785225, 0.62427098, 0.65925217, ..., 0.40399116,
#          0.34238595, 0.50128705],
#         [0.76439452, 0.59778309, 0.60032183, ..., 0.51542556,
#          0.41769126, 0.53403121],
#         [0.72999406, 0.56758678, 0.63157427, ..., 0.53576714,
#          0.40378967, 0.55417103],
#         ...,
#         [0.65892237, 0.62786144, 0.6765511 , ..., 0.52155966,
#          0.54110509, 0.42159834],
#         [0.65574127, 0.65226847, 0.70889163, ..., 0.47605547,
#          0.5284549 , 0.41314442],
#         [0.64613295, 0.67408502, 0.71221024, ..., 0.55726916,
#          0.56418556, 0.33940383]]])

# %%
training_audio_features.shape
# Out:
# (4763, 251, 21)

# %%
validation_audio_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['spectral_centroid']), axis=-1)

validation_audio_features
# Out:
# array([[[0.65999979, 0.54948461, 0.27689886, ..., 0.56852776,
#          0.36123431, 0.40451193],
#         [0.65187353, 0.53866065, 0.25480378, ..., 0.53477615,
#          0.41227743, 0.39721314],
#         [0.62417668, 0.51867133, 0.31393123, ..., 0.54750955,
#          0.38951427, 0.40787885],
#         ...,
#         [0.54487073, 0.49299687, 0.38968584, ..., 0.45972672,
#          0.3182157 , 0.49332242],
#         [0.53513932, 0.53468007, 0.31282955, ..., 0.48097664,
#          0.23379566, 0.41347396],
#         [0.54044157, 0.51959294, 0.31018779, ..., 0.56565994,
#          0.21219558, 0.40296302]],
#
#        [[0.81219745, 0.78070503, 0.33675426, ..., 0.50826848,
#          0.41963017, 0.21766939],
#         [0.80883712, 0.77022994, 0.32918924, ..., 0.56430113,
#          0.52117682, 0.21872714],
#         [0.77478987, 0.72312438, 0.41145796, ..., 0.49310583,
#          0.47525954, 0.24575222],
#         ...,
#         [0.76907951, 0.7458089 , 0.4245944 , ..., 0.53903615,
#          0.49693877, 0.23511092],
#         [0.78141445, 0.75418675, 0.40374407, ..., 0.4447785 ,
#          0.41775542, 0.26691549],
#         [0.7864728 , 0.74576902, 0.40901777, ..., 0.39198071,
#          0.37834176, 0.27692912]],
#
#        [[0.54597759, 0.33651915, 0.44174641, ..., 0.47044212,
#          0.33776513, 0.6056042 ],
#         [0.51702595, 0.27412498, 0.39575452, ..., 0.53977638,
#          0.51594365, 0.59274189],
#         [0.48143965, 0.25534728, 0.42116737, ..., 0.58525658,
#          0.48973334, 0.5924426 ],
#         ...,
#         [0.42984253, 0.31878698, 0.484332  , ..., 0.49359977,
#          0.45910451, 0.5740991 ],
#         [0.47586775, 0.26229206, 0.50867653, ..., 0.49455774,
#          0.43204355, 0.6070507 ],
#         [0.49441916, 0.22622594, 0.52671868, ..., 0.5986551 ,
#          0.39100617, 0.60412467]],
#
#        ...,
#
#        [[0.58131731, 0.69507635, 0.46378428, ..., 0.53887367,
#          0.40547934, 0.30700718],
#         [0.58020151, 0.68416852, 0.42623731, ..., 0.47107932,
#          0.43142903, 0.30614033],
#         [0.55313075, 0.65219563, 0.47177541, ..., 0.47927094,
#          0.44833651, 0.31277205],
#         ...,
#         [0.54052901, 0.6755358 , 0.51530939, ..., 0.50610101,
#          0.42988053, 0.29725835],
#         [0.55107856, 0.70256686, 0.50218463, ..., 0.50544345,
#          0.42974877, 0.29492284],
#         [0.55405533, 0.69633824, 0.49307406, ..., 0.59143728,
#          0.45098871, 0.28840631]],
#
#        [[0.65048301, 0.69338578, 0.38916469, ..., 0.55325681,
#          0.40537888, 0.30134342],
#         [0.64880353, 0.68571568, 0.37113857, ..., 0.56503516,
#          0.49065983, 0.30055721],
#         [0.61971498, 0.65244156, 0.41850954, ..., 0.6653862 ,
#          0.52797359, 0.30942507],
#         ...,
#         [0.79169226, 0.56107736, 0.45125517, ..., 0.49641812,
#          0.41606656, 0.44398849],
#         [0.78885496, 0.57590944, 0.41986766, ..., 0.48721099,
#          0.36803234, 0.4380031 ],
#         [0.7902298 , 0.56192625, 0.41452086, ..., 0.57728243,
#          0.34245056, 0.43047983]],
#
#        [[0.73395818, 0.7160449 , 0.42259353, ..., 0.50410235,
#          0.46671826, 0.27410806],
#         [0.73150438, 0.70430428, 0.40583339, ..., 0.51382244,
#          0.50045151, 0.28427061],
#         [0.69526392, 0.66702783, 0.46122503, ..., 0.56856352,
#          0.52902746, 0.30852543],
#         ...,
#         [0.69801342, 0.6813727 , 0.48668331, ..., 0.53000557,
#          0.50151604, 0.30213925],
#         [0.70574749, 0.70203179, 0.45942333, ..., 0.47609901,
#          0.43128008, 0.2956972 ],
#         [0.70608556, 0.68700069, 0.44772661, ..., 0.54275632,
#          0.40545058, 0.29011169]]])

# %%
validation_audio_features.shape
# Out:
# (2430, 251, 21)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_audio_features,
                    non_audio_df['train']['continent'],
                    learning_rate=0.001)

history = model.fit(
   x={
      'Continents': non_audio_df['train']['continent'],
      'Audio_Features': training_audio_features
   },
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(
      {
      'Continents': non_audio_df['val']['continent'],
      'Audio_Features': validation_audio_features
   },
      audio_df['val']['label'],
      validation_sample_weights
   ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Continents (InputLayer)     [(None, 1)]                  0         []
#
#  string_lookup (StringLooku  (None, 1)                    0         ['Continents[0][0]']
#  p)
#
#  embedding (Embedding)       (None, 1, 2)                 12        ['string_lookup[0][0]']
#
#  Tile (Lambda)               (None, 251, 2)               0         ['embedding[0][0]']
#
#  Audio_Features (InputLayer  [(None, 251, 21)]            0         []
#  )
#
#  Features (Concatenate)      (None, 251, 23)              0         ['Tile[0][0]',
#                                                                      'Audio_Features[0][0]']
#
#  conv_1 (Conv1D)             (None, 251, 32)              3712      ['Features[0][0]']
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)              0         ['conv_1[0][0]']
#
#  conv_2 (Conv1D)             (None, 125, 64)              10304     ['pool_1[0][0]']
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)               0         ['conv_2[0][0]']
#
#  flatten (Flatten)           (None, 3968)                 0         ['pool_2[0][0]']
#
#  fc_1 (Dense)                (None, 1024)                 4064256   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['fc_1[0][0]']
#
#  fc_2 (Dense)                (None, 3)                    3075      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4081359 (15.57 MB)
# Trainable params: 4081359 (15.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 14s 88ms/step - loss: 1.1014 - accuracy: 0.5870 - weighted_accuracy: 0.5988 - val_loss: 0.7918 - val_accuracy: 0.5757 - val_weighted_accuracy: 0.5996
# Epoch 2/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.6268 - accuracy: 0.7296 - weighted_accuracy: 0.7424 - val_loss: 0.6170 - val_accuracy: 0.6930 - val_weighted_accuracy: 0.7166
# Epoch 3/100
# 149/149 [==============================] - 13s 91ms/step - loss: 0.4929 - accuracy: 0.7999 - weighted_accuracy: 0.8098 - val_loss: 0.5747 - val_accuracy: 0.7560 - val_weighted_accuracy: 0.7657
# Epoch 4/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.4273 - accuracy: 0.8301 - weighted_accuracy: 0.8385 - val_loss: 0.4715 - val_accuracy: 0.7967 - val_weighted_accuracy: 0.8116
# Epoch 5/100
# 149/149 [==============================] - 12s 80ms/step - loss: 0.3793 - accuracy: 0.8484 - weighted_accuracy: 0.8558 - val_loss: 0.4845 - val_accuracy: 0.7494 - val_weighted_accuracy: 0.7700
# Epoch 6/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.3447 - accuracy: 0.8709 - weighted_accuracy: 0.8757 - val_loss: 0.4563 - val_accuracy: 0.8160 - val_weighted_accuracy: 0.8267
# Epoch 7/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.3112 - accuracy: 0.8789 - weighted_accuracy: 0.8853 - val_loss: 0.4362 - val_accuracy: 0.8181 - val_weighted_accuracy: 0.8216
# Epoch 8/100
# 149/149 [==============================] - 13s 84ms/step - loss: 0.2964 - accuracy: 0.8814 - weighted_accuracy: 0.8871 - val_loss: 0.3847 - val_accuracy: 0.8387 - val_weighted_accuracy: 0.8451
# Epoch 9/100
# 149/149 [==============================] - 13s 84ms/step - loss: 0.2783 - accuracy: 0.8889 - weighted_accuracy: 0.8944 - val_loss: 0.4038 - val_accuracy: 0.8436 - val_weighted_accuracy: 0.8537
# Epoch 10/100
# 149/149 [==============================] - 12s 84ms/step - loss: 0.2664 - accuracy: 0.8929 - weighted_accuracy: 0.8975 - val_loss: 0.3385 - val_accuracy: 0.8745 - val_weighted_accuracy: 0.8785
# Epoch 11/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.2544 - accuracy: 0.9001 - weighted_accuracy: 0.9051 - val_loss: 0.3621 - val_accuracy: 0.8593 - val_weighted_accuracy: 0.8635
# Epoch 12/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.2256 - accuracy: 0.9185 - weighted_accuracy: 0.9224 - val_loss: 0.3776 - val_accuracy: 0.8551 - val_weighted_accuracy: 0.8595
# Epoch 13/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.2220 - accuracy: 0.9133 - weighted_accuracy: 0.9174 - val_loss: 0.3233 - val_accuracy: 0.8819 - val_weighted_accuracy: 0.8862
# Epoch 14/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.2043 - accuracy: 0.9284 - weighted_accuracy: 0.9319 - val_loss: 0.3264 - val_accuracy: 0.8634 - val_weighted_accuracy: 0.8660
# Epoch 15/100
# 149/149 [==============================] - 12s 83ms/step - loss: 0.1882 - accuracy: 0.9347 - weighted_accuracy: 0.9391 - val_loss: 0.4098 - val_accuracy: 0.8239 - val_weighted_accuracy: 0.8389
# Epoch 16/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.2043 - accuracy: 0.9202 - weighted_accuracy: 0.9248 - val_loss: 0.3680 - val_accuracy: 0.8078 - val_weighted_accuracy: 0.8273
# Epoch 17/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.2100 - accuracy: 0.9164 - weighted_accuracy: 0.9205 - val_loss: 0.3006 - val_accuracy: 0.8654 - val_weighted_accuracy: 0.8659
# Epoch 18/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1788 - accuracy: 0.9387 - weighted_accuracy: 0.9425 - val_loss: 0.3117 - val_accuracy: 0.8794 - val_weighted_accuracy: 0.8832
# Epoch 19/100
# 149/149 [==============================] - 15s 102ms/step - loss: 0.1785 - accuracy: 0.9324 - weighted_accuracy: 0.9374 - val_loss: 0.3184 - val_accuracy: 0.8342 - val_weighted_accuracy: 0.8525
# Epoch 20/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1763 - accuracy: 0.9318 - weighted_accuracy: 0.9363 - val_loss: 0.2881 - val_accuracy: 0.8753 - val_weighted_accuracy: 0.8824
# Epoch 21/100
# 149/149 [==============================] - 15s 101ms/step - loss: 0.1659 - accuracy: 0.9433 - weighted_accuracy: 0.9467 - val_loss: 0.3072 - val_accuracy: 0.8630 - val_weighted_accuracy: 0.8739
# Epoch 22/100
# 149/149 [==============================] - 24s 159ms/step - loss: 0.1468 - accuracy: 0.9486 - weighted_accuracy: 0.9525 - val_loss: 0.3053 - val_accuracy: 0.8852 - val_weighted_accuracy: 0.8892
# Epoch 23/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1430 - accuracy: 0.9494 - weighted_accuracy: 0.9528 - val_loss: 0.3794 - val_accuracy: 0.8374 - val_weighted_accuracy: 0.8531
# Epoch 24/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1459 - accuracy: 0.9469 - weighted_accuracy: 0.9502 - val_loss: 0.3034 - val_accuracy: 0.8687 - val_weighted_accuracy: 0.8806
# Epoch 25/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1356 - accuracy: 0.9553 - weighted_accuracy: 0.9584 - val_loss: 0.3049 - val_accuracy: 0.8864 - val_weighted_accuracy: 0.8923
# Epoch 26/100
# 149/149 [==============================] - 13s 84ms/step - loss: 0.1232 - accuracy: 0.9635 - weighted_accuracy: 0.9666 - val_loss: 0.3377 - val_accuracy: 0.8514 - val_weighted_accuracy: 0.8645
# Epoch 27/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1336 - accuracy: 0.9544 - weighted_accuracy: 0.9571 - val_loss: 0.3728 - val_accuracy: 0.8510 - val_weighted_accuracy: 0.8589
# Epoch 28/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1587 - accuracy: 0.9339 - weighted_accuracy: 0.9373 - val_loss: 0.2693 - val_accuracy: 0.8926 - val_weighted_accuracy: 0.8973
# Epoch 29/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1358 - accuracy: 0.9460 - weighted_accuracy: 0.9501 - val_loss: 0.2831 - val_accuracy: 0.8835 - val_weighted_accuracy: 0.8914
# Epoch 30/100
# 149/149 [==============================] - 17s 114ms/step - loss: 0.1195 - accuracy: 0.9612 - weighted_accuracy: 0.9644 - val_loss: 0.2911 - val_accuracy: 0.8700 - val_weighted_accuracy: 0.8794
# Epoch 31/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1184 - accuracy: 0.9614 - weighted_accuracy: 0.9649 - val_loss: 0.2960 - val_accuracy: 0.8984 - val_weighted_accuracy: 0.9034
# Epoch 32/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1085 - accuracy: 0.9662 - weighted_accuracy: 0.9679 - val_loss: 0.3350 - val_accuracy: 0.8737 - val_weighted_accuracy: 0.8791
# Epoch 33/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1056 - accuracy: 0.9670 - weighted_accuracy: 0.9694 - val_loss: 0.2754 - val_accuracy: 0.8979 - val_weighted_accuracy: 0.9015
# Epoch 34/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1149 - accuracy: 0.9618 - weighted_accuracy: 0.9644 - val_loss: 0.2976 - val_accuracy: 0.8695 - val_weighted_accuracy: 0.8795
# Epoch 35/100
# 149/149 [==============================] - 13s 87ms/step - loss: 0.1179 - accuracy: 0.9580 - weighted_accuracy: 0.9607 - val_loss: 0.3220 - val_accuracy: 0.8667 - val_weighted_accuracy: 0.8716
# Epoch 36/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1074 - accuracy: 0.9628 - weighted_accuracy: 0.9662 - val_loss: 0.3714 - val_accuracy: 0.8280 - val_weighted_accuracy: 0.8457
# Epoch 37/100
# 149/149 [==============================] - 12s 83ms/step - loss: 0.0998 - accuracy: 0.9704 - weighted_accuracy: 0.9732 - val_loss: 0.3527 - val_accuracy: 0.8716 - val_weighted_accuracy: 0.8767
# Epoch 38/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.0981 - accuracy: 0.9683 - weighted_accuracy: 0.9711 - val_loss: 0.2938 - val_accuracy: 0.8774 - val_weighted_accuracy: 0.8888
# Epoch 39/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1156 - accuracy: 0.9565 - weighted_accuracy: 0.9601 - val_loss: 0.3120 - val_accuracy: 0.8444 - val_weighted_accuracy: 0.8598
# Epoch 40/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.0974 - accuracy: 0.9706 - weighted_accuracy: 0.9728 - val_loss: 0.3392 - val_accuracy: 0.8346 - val_weighted_accuracy: 0.8527
# Epoch 41/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1035 - accuracy: 0.9643 - weighted_accuracy: 0.9669 - val_loss: 0.2729 - val_accuracy: 0.8955 - val_weighted_accuracy: 0.8996
# best_epoch:  30

# %%
train_yhat = model.predict({'Continents': non_audio_df['train']['continent'],
                            'Audio_Features': training_audio_features
                            })

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_spectral_centroid_continents'] = model.evaluate({'Continents': non_audio_df['train']['continent'],
                                                          'Audio_Features': training_audio_features},
                                                         audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 2s 13ms/step
# 149/149 [==============================] - 2s 13ms/step - loss: 0.1246 - accuracy: 0.9796 - weighted_accuracy: 0.9796

# %%
val_yhat = model.predict({'Continents': non_audio_df['val']['continent'],
                          'Audio_Features': validation_audio_features
                          })

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_spectral_centroid_continents'] = model.evaluate({'Continents': non_audio_df['val']['continent'],
                                                          'Audio_Features': validation_audio_features},
                                                         audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 2s 22ms/step
# 76/76 [==============================] - 1s 19ms/step - loss: 0.5118 - accuracy: 0.8984 - weighted_accuracy: 0.8984

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.98      0.98      0.98      1603
#       comsan       0.97      0.98      0.98      1578
#      eaywag1       0.99      0.97      0.98      1582
#
#     accuracy                           0.98      4763
#    macro avg       0.98      0.98      0.98      4763
# weighted avg       0.98      0.98      0.98      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.89      0.90      0.89      1032
#       comsan       0.87      0.91      0.89       618
#      eaywag1       0.93      0.89      0.91       780
#
#     accuracy                           0.90      2430
#    macro avg       0.90      0.90      0.90      2430
# weighted avg       0.90      0.90      0.90      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# ## With mfcc & rms & spectral_centroid & continents

# %% [markdown]
# ### create features

# %%
training_audio_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['rms'], audio_df['train']['spectral_centroid']), axis=-1)

training_audio_features
# Out:
# array([[[0.85715145, 0.77209151, 0.32343465, ..., 0.32348067,
#          0.05045145, 0.22281198],
#         [0.84895962, 0.76405644, 0.32709861, ..., 0.46024999,
#          0.05636971, 0.22631334],
#         [0.81306714, 0.7316643 , 0.38121283, ..., 0.51332188,
#          0.05972068, 0.23361687],
#         ...,
#         [0.75436711, 0.7431457 , 0.45161688, ..., 0.45690683,
#          0.03885968, 0.23204755],
#         [0.76071984, 0.76519793, 0.43179569, ..., 0.41896337,
#          0.03439789, 0.22768157],
#         [0.76710308, 0.76182091, 0.42112589, ..., 0.39780954,
#          0.02821541, 0.2244155 ]],
#
#        [[0.57812029, 0.51106858, 0.33823726, ..., 0.51711512,
#          0.0078186 , 0.58009442],
#         [0.58652961, 0.45980272, 0.37856799, ..., 0.48872289,
#          0.00876402, 0.66959631],
#         [0.56091553, 0.42990237, 0.425897  , ..., 0.40780362,
#          0.00845237, 0.67599949],
#         ...,
#         [0.58505166, 0.51164782, 0.32509741, ..., 0.46407914,
#          0.00980887, 0.42379785],
#         [0.59405923, 0.5139758 , 0.24707577, ..., 0.37247282,
#          0.00998901, 0.41740986],
#         [0.59488356, 0.51470292, 0.20010453, ..., 0.33499646,
#          0.00893118, 0.36134405]],
#
#        [[0.60431927, 0.77807331, 0.60488605, ..., 0.40213192,
#          0.00691423, 0.20033525],
#         [0.59173727, 0.75116891, 0.54849744, ..., 0.45853385,
#          0.00731169, 0.22573477],
#         [0.56247401, 0.70484036, 0.58358085, ..., 0.47197759,
#          0.00816986, 0.25117208],
#         ...,
#         [0.58100474, 0.66791528, 0.73169518, ..., 0.6030581 ,
#          0.02820133, 0.56223134],
#         [0.61647439, 0.62969452, 0.83395606, ..., 0.33529326,
#          0.02959021, 0.64126956],
#         [0.63556254, 0.59640139, 0.8894726 , ..., 0.230663  ,
#          0.02945004, 0.64483953]],
#
#        ...,
#
#        [[0.59941769, 0.80473447, 0.59633052, ..., 0.45738348,
#          0.02550218, 0.11218752],
#         [0.56157327, 0.8159188 , 0.53441471, ..., 0.49500203,
#          0.03051137, 0.08031361],
#         [0.53121823, 0.7795428 , 0.56896484, ..., 0.49318588,
#          0.03369534, 0.07496744],
#         ...,
#         [0.5268023 , 0.80941641, 0.60693425, ..., 0.48929241,
#          0.02740254, 0.0812696 ],
#         [0.53516477, 0.83131468, 0.58486748, ..., 0.43327561,
#          0.02503415, 0.08767186],
#         [0.54046309, 0.83115542, 0.59077519, ..., 0.40777534,
#          0.01799533, 0.07536668]],
#
#        [[0.7122581 , 0.62532175, 0.53676069, ..., 0.69232666,
#          0.02007527, 0.36214103],
#         [0.70857346, 0.62304169, 0.49656901, ..., 0.76052487,
#          0.02048742, 0.35261739],
#         [0.67845631, 0.60859823, 0.53906715, ..., 0.68320954,
#          0.02046571, 0.35740182],
#         ...,
#         [0.6177296 , 0.63298666, 0.62809634, ..., 0.57496494,
#          0.01999955, 0.28327202],
#         [0.61929488, 0.64403009, 0.63252789, ..., 0.54373974,
#          0.01895325, 0.31025082],
#         [0.62457204, 0.62281495, 0.64229745, ..., 0.48835483,
#          0.0141823 , 0.32595072]],
#
#        [[0.76785225, 0.62427098, 0.65925217, ..., 0.34238595,
#          0.0207934 , 0.50128705],
#         [0.76439452, 0.59778309, 0.60032183, ..., 0.41769126,
#          0.02287893, 0.53403121],
#         [0.72999406, 0.56758678, 0.63157427, ..., 0.40378967,
#          0.02452519, 0.55417103],
#         ...,
#         [0.65892237, 0.62786144, 0.6765511 , ..., 0.54110509,
#          0.01649   , 0.42159834],
#         [0.65574127, 0.65226847, 0.70889163, ..., 0.5284549 ,
#          0.01455376, 0.41314442],
#         [0.64613295, 0.67408502, 0.71221024, ..., 0.56418556,
#          0.01183528, 0.33940383]]])

# %%
training_audio_features.shape
# Out:
# (4763, 251, 22)

# %%
validation_audio_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['rms'], audio_df['val']['spectral_centroid']), axis=-1)

validation_audio_features
# Out:
# array([[[0.65999979, 0.54948461, 0.27689886, ..., 0.36123431,
#          0.00814634, 0.40451193],
#         [0.65187353, 0.53866065, 0.25480378, ..., 0.41227743,
#          0.00884928, 0.39721314],
#         [0.62417668, 0.51867133, 0.31393123, ..., 0.38951427,
#          0.00968746, 0.40787885],
#         ...,
#         [0.54487073, 0.49299687, 0.38968584, ..., 0.3182157 ,
#          0.01988961, 0.49332242],
#         [0.53513932, 0.53468007, 0.31282955, ..., 0.23379566,
#          0.00446323, 0.41347396],
#         [0.54044157, 0.51959294, 0.31018779, ..., 0.21219558,
#          0.00344242, 0.40296302]],
#
#        [[0.81219745, 0.78070503, 0.33675426, ..., 0.41963017,
#          0.03496842, 0.21766939],
#         [0.80883712, 0.77022994, 0.32918924, ..., 0.52117682,
#          0.03817414, 0.21872714],
#         [0.77478987, 0.72312438, 0.41145796, ..., 0.47525954,
#          0.0413138 , 0.24575222],
#         ...,
#         [0.76907951, 0.7458089 , 0.4245944 , ..., 0.49693877,
#          0.04457005, 0.23511092],
#         [0.78141445, 0.75418675, 0.40374407, ..., 0.41775542,
#          0.0414524 , 0.26691549],
#         [0.7864728 , 0.74576902, 0.40901777, ..., 0.37834176,
#          0.03588935, 0.27692912]],
#
#        [[0.54597759, 0.33651915, 0.44174641, ..., 0.33776513,
#          0.00841907, 0.6056042 ],
#         [0.51702595, 0.27412498, 0.39575452, ..., 0.51594365,
#          0.00889635, 0.59274189],
#         [0.48143965, 0.25534728, 0.42116737, ..., 0.48973334,
#          0.01216992, 0.5924426 ],
#         ...,
#         [0.42984253, 0.31878698, 0.484332  , ..., 0.45910451,
#          0.00864199, 0.5740991 ],
#         [0.47586775, 0.26229206, 0.50867653, ..., 0.43204355,
#          0.00905626, 0.6070507 ],
#         [0.49441916, 0.22622594, 0.52671868, ..., 0.39100617,
#          0.00900402, 0.60412467]],
#
#        ...,
#
#        [[0.58131731, 0.69507635, 0.46378428, ..., 0.40547934,
#          0.00388941, 0.30700718],
#         [0.58020151, 0.68416852, 0.42623731, ..., 0.43142903,
#          0.00430809, 0.30614033],
#         [0.55313075, 0.65219563, 0.47177541, ..., 0.44833651,
#          0.00478347, 0.31277205],
#         ...,
#         [0.54052901, 0.6755358 , 0.51530939, ..., 0.42988053,
#          0.0049165 , 0.29725835],
#         [0.55107856, 0.70256686, 0.50218463, ..., 0.42974877,
#          0.00451883, 0.29492284],
#         [0.55405533, 0.69633824, 0.49307406, ..., 0.45098871,
#          0.00384084, 0.28840631]],
#
#        [[0.65048301, 0.69338578, 0.38916469, ..., 0.40537888,
#          0.0061755 , 0.30134342],
#         [0.64880353, 0.68571568, 0.37113857, ..., 0.49065983,
#          0.00688783, 0.30055721],
#         [0.61971498, 0.65244156, 0.41850954, ..., 0.52797359,
#          0.00746608, 0.30942507],
#         ...,
#         [0.79169226, 0.56107736, 0.45125517, ..., 0.41606656,
#          0.04125094, 0.44398849],
#         [0.78885496, 0.57590944, 0.41986766, ..., 0.36803234,
#          0.03760236, 0.4380031 ],
#         [0.7902298 , 0.56192625, 0.41452086, ..., 0.34245056,
#          0.03106061, 0.43047983]],
#
#        [[0.73395818, 0.7160449 , 0.42259353, ..., 0.46671826,
#          0.01356566, 0.27410806],
#         [0.73150438, 0.70430428, 0.40583339, ..., 0.50045151,
#          0.01450409, 0.28427061],
#         [0.69526392, 0.66702783, 0.46122503, ..., 0.52902746,
#          0.01573573, 0.30852543],
#         ...,
#         [0.69801342, 0.6813727 , 0.48668331, ..., 0.50151604,
#          0.01712802, 0.30213925],
#         [0.70574749, 0.70203179, 0.45942333, ..., 0.43128008,
#          0.01584159, 0.2956972 ],
#         [0.70608556, 0.68700069, 0.44772661, ..., 0.40545058,
#          0.01329589, 0.29011169]]])

# %%
validation_audio_features.shape
# Out:
# (2430, 251, 22)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_audio_features,
                    non_audio_df['train']['continent'],
                    learning_rate=0.001)

history = model.fit(
   x={
      'Continents': non_audio_df['train']['continent'],
      'Audio_Features': training_audio_features
   },
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(
      {
      'Continents': non_audio_df['val']['continent'],
      'Audio_Features': validation_audio_features
   },
      audio_df['val']['label'],
      validation_sample_weights
   ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Continents (InputLayer)     [(None, 1)]                  0         []
#
#  string_lookup (StringLooku  (None, 1)                    0         ['Continents[0][0]']
#  p)
#
#  embedding (Embedding)       (None, 1, 2)                 12        ['string_lookup[0][0]']
#
#  Tile (Lambda)               (None, 251, 2)               0         ['embedding[0][0]']
#
#  Audio_Features (InputLayer  [(None, 251, 22)]            0         []
#  )
#
#  Features (Concatenate)      (None, 251, 24)              0         ['Tile[0][0]',
#                                                                      'Audio_Features[0][0]']
#
#  conv_1 (Conv1D)             (None, 251, 32)              3872      ['Features[0][0]']
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)              0         ['conv_1[0][0]']
#
#  conv_2 (Conv1D)             (None, 125, 64)              10304     ['pool_1[0][0]']
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)               0         ['conv_2[0][0]']
#
#  flatten (Flatten)           (None, 3968)                 0         ['pool_2[0][0]']
#
#  fc_1 (Dense)                (None, 1024)                 4064256   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['fc_1[0][0]']
#
#  fc_2 (Dense)                (None, 3)                    3075      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4081519 (15.57 MB)
# Trainable params: 4081519 (15.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 16s 96ms/step - loss: 1.1678 - accuracy: 0.5669 - weighted_accuracy: 0.5796 - val_loss: 0.8316 - val_accuracy: 0.5947 - val_weighted_accuracy: 0.6219
# Epoch 2/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.6624 - accuracy: 0.7109 - weighted_accuracy: 0.7277 - val_loss: 0.6400 - val_accuracy: 0.6877 - val_weighted_accuracy: 0.7095
# Epoch 3/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.5237 - accuracy: 0.7869 - weighted_accuracy: 0.7967 - val_loss: 0.5281 - val_accuracy: 0.7630 - val_weighted_accuracy: 0.7774
# Epoch 4/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.4083 - accuracy: 0.8560 - weighted_accuracy: 0.8622 - val_loss: 0.4570 - val_accuracy: 0.8292 - val_weighted_accuracy: 0.8331
# Epoch 5/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.3692 - accuracy: 0.8640 - weighted_accuracy: 0.8694 - val_loss: 0.4682 - val_accuracy: 0.7527 - val_weighted_accuracy: 0.7507
# Epoch 6/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.3459 - accuracy: 0.8747 - weighted_accuracy: 0.8797 - val_loss: 0.4721 - val_accuracy: 0.7572 - val_weighted_accuracy: 0.7730
# Epoch 7/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.3107 - accuracy: 0.8942 - weighted_accuracy: 0.8998 - val_loss: 0.4093 - val_accuracy: 0.8062 - val_weighted_accuracy: 0.8211
# Epoch 8/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.2930 - accuracy: 0.8929 - weighted_accuracy: 0.8979 - val_loss: 0.3828 - val_accuracy: 0.8251 - val_weighted_accuracy: 0.8404
# Epoch 9/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.2592 - accuracy: 0.9162 - weighted_accuracy: 0.9207 - val_loss: 0.3975 - val_accuracy: 0.8062 - val_weighted_accuracy: 0.8239
# Epoch 10/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2566 - accuracy: 0.9053 - weighted_accuracy: 0.9103 - val_loss: 0.3421 - val_accuracy: 0.8572 - val_weighted_accuracy: 0.8594
# Epoch 11/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.2435 - accuracy: 0.9141 - weighted_accuracy: 0.9184 - val_loss: 0.3340 - val_accuracy: 0.8675 - val_weighted_accuracy: 0.8754
# Epoch 12/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2334 - accuracy: 0.9145 - weighted_accuracy: 0.9186 - val_loss: 0.3197 - val_accuracy: 0.8440 - val_weighted_accuracy: 0.8442
# Epoch 13/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.2026 - accuracy: 0.9318 - weighted_accuracy: 0.9346 - val_loss: 0.3079 - val_accuracy: 0.8737 - val_weighted_accuracy: 0.8788
# Epoch 14/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.2005 - accuracy: 0.9307 - weighted_accuracy: 0.9346 - val_loss: 0.2856 - val_accuracy: 0.8951 - val_weighted_accuracy: 0.8974
# Epoch 15/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1849 - accuracy: 0.9381 - weighted_accuracy: 0.9415 - val_loss: 0.3130 - val_accuracy: 0.8918 - val_weighted_accuracy: 0.8962
# Epoch 16/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.1790 - accuracy: 0.9355 - weighted_accuracy: 0.9390 - val_loss: 0.2674 - val_accuracy: 0.8881 - val_weighted_accuracy: 0.8942
# Epoch 17/100
# 149/149 [==============================] - 12s 80ms/step - loss: 0.1746 - accuracy: 0.9364 - weighted_accuracy: 0.9404 - val_loss: 0.3216 - val_accuracy: 0.8506 - val_weighted_accuracy: 0.8507
# Epoch 18/100
# 149/149 [==============================] - 12s 83ms/step - loss: 0.1707 - accuracy: 0.9410 - weighted_accuracy: 0.9439 - val_loss: 0.3016 - val_accuracy: 0.8498 - val_weighted_accuracy: 0.8656
# Epoch 19/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1627 - accuracy: 0.9423 - weighted_accuracy: 0.9466 - val_loss: 0.2976 - val_accuracy: 0.8634 - val_weighted_accuracy: 0.8777
# Epoch 20/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1656 - accuracy: 0.9410 - weighted_accuracy: 0.9443 - val_loss: 0.3034 - val_accuracy: 0.8695 - val_weighted_accuracy: 0.8748
# Epoch 21/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1585 - accuracy: 0.9418 - weighted_accuracy: 0.9459 - val_loss: 0.2649 - val_accuracy: 0.8864 - val_weighted_accuracy: 0.8892
# Epoch 22/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1415 - accuracy: 0.9515 - weighted_accuracy: 0.9550 - val_loss: 0.3547 - val_accuracy: 0.8523 - val_weighted_accuracy: 0.8574
# Epoch 23/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1642 - accuracy: 0.9328 - weighted_accuracy: 0.9371 - val_loss: 0.3086 - val_accuracy: 0.8449 - val_weighted_accuracy: 0.8460
# Epoch 24/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1420 - accuracy: 0.9505 - weighted_accuracy: 0.9541 - val_loss: 0.2897 - val_accuracy: 0.8724 - val_weighted_accuracy: 0.8747
# Epoch 25/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.1239 - accuracy: 0.9633 - weighted_accuracy: 0.9660 - val_loss: 0.2799 - val_accuracy: 0.8926 - val_weighted_accuracy: 0.8974
# Epoch 26/100
# 149/149 [==============================] - 14s 95ms/step - loss: 0.1232 - accuracy: 0.9626 - weighted_accuracy: 0.9642 - val_loss: 0.2775 - val_accuracy: 0.8889 - val_weighted_accuracy: 0.8970
# Epoch 27/100
# 149/149 [==============================] - 12s 83ms/step - loss: 0.1165 - accuracy: 0.9654 - weighted_accuracy: 0.9676 - val_loss: 0.3421 - val_accuracy: 0.8523 - val_weighted_accuracy: 0.8595
# Epoch 28/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1520 - accuracy: 0.9385 - weighted_accuracy: 0.9428 - val_loss: 0.2641 - val_accuracy: 0.8679 - val_weighted_accuracy: 0.8815
# Epoch 29/100
# 149/149 [==============================] - 13s 86ms/step - loss: 0.1189 - accuracy: 0.9603 - weighted_accuracy: 0.9633 - val_loss: 0.3053 - val_accuracy: 0.8519 - val_weighted_accuracy: 0.8683
# Epoch 30/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1152 - accuracy: 0.9630 - weighted_accuracy: 0.9654 - val_loss: 0.2717 - val_accuracy: 0.8621 - val_weighted_accuracy: 0.8753
# Epoch 31/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1177 - accuracy: 0.9599 - weighted_accuracy: 0.9635 - val_loss: 0.2831 - val_accuracy: 0.8556 - val_weighted_accuracy: 0.8697
# Epoch 32/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1227 - accuracy: 0.9595 - weighted_accuracy: 0.9629 - val_loss: 0.2525 - val_accuracy: 0.9012 - val_weighted_accuracy: 0.9052
# Epoch 33/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1013 - accuracy: 0.9714 - weighted_accuracy: 0.9741 - val_loss: 0.2784 - val_accuracy: 0.8942 - val_weighted_accuracy: 0.8996
# Epoch 34/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.0997 - accuracy: 0.9685 - weighted_accuracy: 0.9710 - val_loss: 0.3197 - val_accuracy: 0.8728 - val_weighted_accuracy: 0.8800
# Epoch 35/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1225 - accuracy: 0.9530 - weighted_accuracy: 0.9551 - val_loss: 0.2344 - val_accuracy: 0.9053 - val_weighted_accuracy: 0.9088
# Epoch 36/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1137 - accuracy: 0.9599 - weighted_accuracy: 0.9622 - val_loss: 0.2737 - val_accuracy: 0.8679 - val_weighted_accuracy: 0.8712
# Epoch 37/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1085 - accuracy: 0.9637 - weighted_accuracy: 0.9668 - val_loss: 0.2378 - val_accuracy: 0.8938 - val_weighted_accuracy: 0.8990
# Epoch 38/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.0959 - accuracy: 0.9698 - weighted_accuracy: 0.9725 - val_loss: 0.2746 - val_accuracy: 0.8823 - val_weighted_accuracy: 0.8871
# Epoch 39/100
# 149/149 [==============================] - 15s 99ms/step - loss: 0.1068 - accuracy: 0.9630 - weighted_accuracy: 0.9655 - val_loss: 0.3225 - val_accuracy: 0.8292 - val_weighted_accuracy: 0.8475
# Epoch 40/100
# 149/149 [==============================] - 13s 84ms/step - loss: 0.1203 - accuracy: 0.9530 - weighted_accuracy: 0.9563 - val_loss: 0.2820 - val_accuracy: 0.8337 - val_weighted_accuracy: 0.8524
# Epoch 41/100
# 149/149 [==============================] - 13s 85ms/step - loss: 0.1028 - accuracy: 0.9683 - weighted_accuracy: 0.9706 - val_loss: 0.2617 - val_accuracy: 0.8889 - val_weighted_accuracy: 0.8944
# Epoch 42/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.0915 - accuracy: 0.9714 - weighted_accuracy: 0.9739 - val_loss: 0.2456 - val_accuracy: 0.9008 - val_weighted_accuracy: 0.9044
# Epoch 43/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.0952 - accuracy: 0.9670 - weighted_accuracy: 0.9688 - val_loss: 0.2577 - val_accuracy: 0.8955 - val_weighted_accuracy: 0.9011
# Epoch 44/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.0840 - accuracy: 0.9767 - weighted_accuracy: 0.9788 - val_loss: 0.2908 - val_accuracy: 0.8856 - val_weighted_accuracy: 0.8927
# Epoch 45/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.0830 - accuracy: 0.9765 - weighted_accuracy: 0.9782 - val_loss: 0.2721 - val_accuracy: 0.8885 - val_weighted_accuracy: 0.8932
# best_epoch:  34

# %%
train_yhat = model.predict({'Continents': non_audio_df['train']['continent'],
                            'Audio_Features': training_audio_features
                            })

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_rms_spectral_centroid_continents'] = model.evaluate({'Continents': non_audio_df['train']['continent'],
                                                          'Audio_Features': training_audio_features},
                                                         audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 3s 21ms/step
# 149/149 [==============================] - 2s 12ms/step - loss: 0.1408 - accuracy: 0.9742 - weighted_accuracy: 0.9742

# %%
val_yhat = model.predict({'Continents': non_audio_df['val']['continent'],
                          'Audio_Features': validation_audio_features
                          })

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_rms_spectral_centroid_continents'] = model.evaluate({'Continents': non_audio_df['val']['continent'],
                                                          'Audio_Features': validation_audio_features},
                                                         audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 1s 13ms/step
# 76/76 [==============================] - 1s 13ms/step - loss: 0.3994 - accuracy: 0.9053 - weighted_accuracy: 0.9053

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.97      0.98      0.98      1603
#       comsan       0.96      0.98      0.97      1578
#      eaywag1       1.00      0.96      0.98      1582
#
#     accuracy                           0.97      4763
#    macro avg       0.97      0.97      0.97      4763
# weighted avg       0.97      0.97      0.97      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.90      0.91      0.91      1032
#       comsan       0.86      0.92      0.89       618
#      eaywag1       0.95      0.88      0.92       780
#
#     accuracy                           0.91      2430
#    macro avg       0.90      0.91      0.90      2430
# weighted avg       0.91      0.91      0.91      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# ## With mfcc & rms & chroma & rms & spectral_centroid & continents

# %% [markdown]
# ### create features

# %%
training_audio_features = np.concatenate((audio_df['train']['mfcc'], audio_df['train']['chroma'], audio_df['train']['rms'], audio_df['train']['spectral_centroid']), axis=-1)

training_audio_features
# Out:
# array([[[0.85715145, 0.77209151, 0.32343465, ..., 0.83134496,
#          0.05045145, 0.22281198],
#         [0.84895962, 0.76405644, 0.32709861, ..., 1.        ,
#          0.05636971, 0.22631334],
#         [0.81306714, 0.7316643 , 0.38121283, ..., 0.98853308,
#          0.05972068, 0.23361687],
#         ...,
#         [0.75436711, 0.7431457 , 0.45161688, ..., 0.59809744,
#          0.03885968, 0.23204755],
#         [0.76071984, 0.76519793, 0.43179569, ..., 0.56461316,
#          0.03439789, 0.22768157],
#         [0.76710308, 0.76182091, 0.42112589, ..., 0.7029264 ,
#          0.02821541, 0.2244155 ]],
#
#        [[0.57812029, 0.51106858, 0.33823726, ..., 0.15715972,
#          0.0078186 , 0.58009442],
#         [0.58652961, 0.45980272, 0.37856799, ..., 0.10151878,
#          0.00876402, 0.66959631],
#         [0.56091553, 0.42990237, 0.425897  , ..., 0.06087872,
#          0.00845237, 0.67599949],
#         ...,
#         [0.58505166, 0.51164782, 0.32509741, ..., 0.28117621,
#          0.00980887, 0.42379785],
#         [0.59405923, 0.5139758 , 0.24707577, ..., 0.51660317,
#          0.00998901, 0.41740986],
#         [0.59488356, 0.51470292, 0.20010453, ..., 0.345927  ,
#          0.00893118, 0.36134405]],
#
#        [[0.60431927, 0.77807331, 0.60488605, ..., 0.55286145,
#          0.00691423, 0.20033525],
#         [0.59173727, 0.75116891, 0.54849744, ..., 0.3701036 ,
#          0.00731169, 0.22573477],
#         [0.56247401, 0.70484036, 0.58358085, ..., 0.52950948,
#          0.00816986, 0.25117208],
#         ...,
#         [0.58100474, 0.66791528, 0.73169518, ..., 0.03998072,
#          0.02820133, 0.56223134],
#         [0.61647439, 0.62969452, 0.83395606, ..., 0.0244415 ,
#          0.02959021, 0.64126956],
#         [0.63556254, 0.59640139, 0.8894726 , ..., 0.03625474,
#          0.02945004, 0.64483953]],
#
#        ...,
#
#        [[0.59941769, 0.80473447, 0.59633052, ..., 0.52364665,
#          0.02550218, 0.11218752],
#         [0.56157327, 0.8159188 , 0.53441471, ..., 0.35363764,
#          0.03051137, 0.08031361],
#         [0.53121823, 0.7795428 , 0.56896484, ..., 0.88897526,
#          0.03369534, 0.07496744],
#         ...,
#         [0.5268023 , 0.80941641, 0.60693425, ..., 0.66624701,
#          0.02740254, 0.0812696 ],
#         [0.53516477, 0.83131468, 0.58486748, ..., 0.57935381,
#          0.02503415, 0.08767186],
#         [0.54046309, 0.83115542, 0.59077519, ..., 0.87354201,
#          0.01799533, 0.07536668]],
#
#        [[0.7122581 , 0.62532175, 0.53676069, ..., 0.41342425,
#          0.02007527, 0.36214103],
#         [0.70857346, 0.62304169, 0.49656901, ..., 0.32252946,
#          0.02048742, 0.35261739],
#         [0.67845631, 0.60859823, 0.53906715, ..., 0.5466277 ,
#          0.02046571, 0.35740182],
#         ...,
#         [0.6177296 , 0.63298666, 0.62809634, ..., 0.92734855,
#          0.01999955, 0.28327202],
#         [0.61929488, 0.64403009, 0.63252789, ..., 0.79559356,
#          0.01895325, 0.31025082],
#         [0.62457204, 0.62281495, 0.64229745, ..., 1.        ,
#          0.0141823 , 0.32595072]],
#
#        [[0.76785225, 0.62427098, 0.65925217, ..., 0.72489333,
#          0.0207934 , 0.50128705],
#         [0.76439452, 0.59778309, 0.60032183, ..., 0.62662077,
#          0.02287893, 0.53403121],
#         [0.72999406, 0.56758678, 0.63157427, ..., 0.59049481,
#          0.02452519, 0.55417103],
#         ...,
#         [0.65892237, 0.62786144, 0.6765511 , ..., 0.70860493,
#          0.01649   , 0.42159834],
#         [0.65574127, 0.65226847, 0.70889163, ..., 0.96383709,
#          0.01455376, 0.41314442],
#         [0.64613295, 0.67408502, 0.71221024, ..., 0.46902591,
#          0.01183528, 0.33940383]]])

# %%
training_audio_features.shape
# Out:
# (4763, 251, 34)

# %%
validation_audio_features = np.concatenate((audio_df['val']['mfcc'], audio_df['val']['chroma'], audio_df['val']['rms'], audio_df['val']['spectral_centroid']), axis=-1)

validation_audio_features
# Out:
# array([[[0.65999979, 0.54948461, 0.27689886, ..., 0.97376996,
#          0.00814634, 0.40451193],
#         [0.65187353, 0.53866065, 0.25480378, ..., 1.        ,
#          0.00884928, 0.39721314],
#         [0.62417668, 0.51867133, 0.31393123, ..., 0.66672474,
#          0.00968746, 0.40787885],
#         ...,
#         [0.54487073, 0.49299687, 0.38968584, ..., 0.57901418,
#          0.01988961, 0.49332242],
#         [0.53513932, 0.53468007, 0.31282955, ..., 0.72806001,
#          0.00446323, 0.41347396],
#         [0.54044157, 0.51959294, 0.31018779, ..., 0.54542607,
#          0.00344242, 0.40296302]],
#
#        [[0.81219745, 0.78070503, 0.33675426, ..., 0.60508609,
#          0.03496842, 0.21766939],
#         [0.80883712, 0.77022994, 0.32918924, ..., 0.90112579,
#          0.03817414, 0.21872714],
#         [0.77478987, 0.72312438, 0.41145796, ..., 0.77340579,
#          0.0413138 , 0.24575222],
#         ...,
#         [0.76907951, 0.7458089 , 0.4245944 , ..., 0.68086237,
#          0.04457005, 0.23511092],
#         [0.78141445, 0.75418675, 0.40374407, ..., 0.79483217,
#          0.0414524 , 0.26691549],
#         [0.7864728 , 0.74576902, 0.40901777, ..., 0.62967145,
#          0.03588935, 0.27692912]],
#
#        [[0.54597759, 0.33651915, 0.44174641, ..., 0.30936942,
#          0.00841907, 0.6056042 ],
#         [0.51702595, 0.27412498, 0.39575452, ..., 0.15449522,
#          0.00889635, 0.59274189],
#         [0.48143965, 0.25534728, 0.42116737, ..., 0.10730284,
#          0.01216992, 0.5924426 ],
#         ...,
#         [0.42984253, 0.31878698, 0.484332  , ..., 0.45499542,
#          0.00864199, 0.5740991 ],
#         [0.47586775, 0.26229206, 0.50867653, ..., 0.44946328,
#          0.00905626, 0.6070507 ],
#         [0.49441916, 0.22622594, 0.52671868, ..., 0.54830378,
#          0.00900402, 0.60412467]],
#
#        ...,
#
#        [[0.58131731, 0.69507635, 0.46378428, ..., 0.48265484,
#          0.00388941, 0.30700718],
#         [0.58020151, 0.68416852, 0.42623731, ..., 0.57190239,
#          0.00430809, 0.30614033],
#         [0.55313075, 0.65219563, 0.47177541, ..., 0.82059902,
#          0.00478347, 0.31277205],
#         ...,
#         [0.54052901, 0.6755358 , 0.51530939, ..., 1.        ,
#          0.0049165 , 0.29725835],
#         [0.55107856, 0.70256686, 0.50218463, ..., 1.        ,
#          0.00451883, 0.29492284],
#         [0.55405533, 0.69633824, 0.49307406, ..., 1.        ,
#          0.00384084, 0.28840631]],
#
#        [[0.65048301, 0.69338578, 0.38916469, ..., 0.96379912,
#          0.0061755 , 0.30134342],
#         [0.64880353, 0.68571568, 0.37113857, ..., 0.53472626,
#          0.00688783, 0.30055721],
#         [0.61971498, 0.65244156, 0.41850954, ..., 0.44342139,
#          0.00746608, 0.30942507],
#         ...,
#         [0.79169226, 0.56107736, 0.45125517, ..., 0.44904199,
#          0.04125094, 0.44398849],
#         [0.78885496, 0.57590944, 0.41986766, ..., 0.4963375 ,
#          0.03760236, 0.4380031 ],
#         [0.7902298 , 0.56192625, 0.41452086, ..., 0.59540081,
#          0.03106061, 0.43047983]],
#
#        [[0.73395818, 0.7160449 , 0.42259353, ..., 0.53960657,
#          0.01356566, 0.27410806],
#         [0.73150438, 0.70430428, 0.40583339, ..., 0.55671155,
#          0.01450409, 0.28427061],
#         [0.69526392, 0.66702783, 0.46122503, ..., 0.86035901,
#          0.01573573, 0.30852543],
#         ...,
#         [0.69801342, 0.6813727 , 0.48668331, ..., 0.72580069,
#          0.01712802, 0.30213925],
#         [0.70574749, 0.70203179, 0.45942333, ..., 0.8948946 ,
#          0.01584159, 0.2956972 ],
#         [0.70608556, 0.68700069, 0.44772661, ..., 0.89549536,
#          0.01329589, 0.29011169]]])

# %%
validation_audio_features.shape
# Out:
# (2430, 251, 34)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_audio_features,
                    non_audio_df['train']['continent'],
                    learning_rate=0.001)

history = model.fit(
   x={
      'Continents': non_audio_df['train']['continent'],
      'Audio_Features': training_audio_features
   },
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(
      {
      'Continents': non_audio_df['val']['continent'],
      'Audio_Features': validation_audio_features
   },
      audio_df['val']['label'],
      validation_sample_weights
   ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Continents (InputLayer)     [(None, 1)]                  0         []
#
#  string_lookup (StringLooku  (None, 1)                    0         ['Continents[0][0]']
#  p)
#
#  embedding (Embedding)       (None, 1, 2)                 12        ['string_lookup[0][0]']
#
#  Tile (Lambda)               (None, 251, 2)               0         ['embedding[0][0]']
#
#  Audio_Features (InputLayer  [(None, 251, 34)]            0         []
#  )
#
#  Features (Concatenate)      (None, 251, 36)              0         ['Tile[0][0]',
#                                                                      'Audio_Features[0][0]']
#
#  conv_1 (Conv1D)             (None, 251, 32)              5792      ['Features[0][0]']
#
#  pool_1 (MaxPooling1D)       (None, 125, 32)              0         ['conv_1[0][0]']
#
#  conv_2 (Conv1D)             (None, 125, 64)              10304     ['pool_1[0][0]']
#
#  pool_2 (MaxPooling1D)       (None, 62, 64)               0         ['conv_2[0][0]']
#
#  flatten (Flatten)           (None, 3968)                 0         ['pool_2[0][0]']
#
#  fc_1 (Dense)                (None, 1024)                 4064256   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['fc_1[0][0]']
#
#  fc_2 (Dense)                (None, 3)                    3075      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 4083439 (15.58 MB)
# Trainable params: 4083439 (15.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 15s 89ms/step - loss: 1.2418 - accuracy: 0.5505 - weighted_accuracy: 0.5611 - val_loss: 0.8926 - val_accuracy: 0.5695 - val_weighted_accuracy: 0.5926
# Epoch 2/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.6602 - accuracy: 0.7159 - weighted_accuracy: 0.7280 - val_loss: 0.6508 - val_accuracy: 0.6432 - val_weighted_accuracy: 0.6483
# Epoch 3/100
# 149/149 [==============================] - 15s 102ms/step - loss: 0.5095 - accuracy: 0.7831 - weighted_accuracy: 0.7931 - val_loss: 0.5148 - val_accuracy: 0.7494 - val_weighted_accuracy: 0.7692
# Epoch 4/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.4111 - accuracy: 0.8272 - weighted_accuracy: 0.8339 - val_loss: 0.4679 - val_accuracy: 0.7486 - val_weighted_accuracy: 0.7618
# Epoch 5/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.3453 - accuracy: 0.8600 - weighted_accuracy: 0.8653 - val_loss: 0.4452 - val_accuracy: 0.7704 - val_weighted_accuracy: 0.7826
# Epoch 6/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.3301 - accuracy: 0.8593 - weighted_accuracy: 0.8650 - val_loss: 0.3911 - val_accuracy: 0.8189 - val_weighted_accuracy: 0.8263
# Epoch 7/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.2988 - accuracy: 0.8732 - weighted_accuracy: 0.8780 - val_loss: 0.3961 - val_accuracy: 0.7979 - val_weighted_accuracy: 0.8116
# Epoch 8/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.2859 - accuracy: 0.8717 - weighted_accuracy: 0.8782 - val_loss: 0.3815 - val_accuracy: 0.7770 - val_weighted_accuracy: 0.7962
# Epoch 9/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.2623 - accuracy: 0.8852 - weighted_accuracy: 0.8900 - val_loss: 0.3396 - val_accuracy: 0.8193 - val_weighted_accuracy: 0.8345
# Epoch 10/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.2481 - accuracy: 0.8875 - weighted_accuracy: 0.8922 - val_loss: 0.2923 - val_accuracy: 0.8712 - val_weighted_accuracy: 0.8748
# Epoch 11/100
# 149/149 [==============================] - 13s 91ms/step - loss: 0.2329 - accuracy: 0.8967 - weighted_accuracy: 0.9010 - val_loss: 0.3155 - val_accuracy: 0.8453 - val_weighted_accuracy: 0.8550
# Epoch 12/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.2356 - accuracy: 0.8896 - weighted_accuracy: 0.8951 - val_loss: 0.3473 - val_accuracy: 0.7749 - val_weighted_accuracy: 0.7949
# Epoch 13/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1908 - accuracy: 0.9236 - weighted_accuracy: 0.9280 - val_loss: 0.3287 - val_accuracy: 0.8198 - val_weighted_accuracy: 0.8325
# Epoch 14/100
# 149/149 [==============================] - 14s 96ms/step - loss: 0.1838 - accuracy: 0.9253 - weighted_accuracy: 0.9285 - val_loss: 0.3166 - val_accuracy: 0.8288 - val_weighted_accuracy: 0.8380
# Epoch 15/100
# 149/149 [==============================] - 14s 94ms/step - loss: 0.1703 - accuracy: 0.9309 - weighted_accuracy: 0.9346 - val_loss: 0.3177 - val_accuracy: 0.8543 - val_weighted_accuracy: 0.8621
# Epoch 16/100
# 149/149 [==============================] - 14s 93ms/step - loss: 0.1601 - accuracy: 0.9353 - weighted_accuracy: 0.9384 - val_loss: 0.2985 - val_accuracy: 0.8593 - val_weighted_accuracy: 0.8657
# Epoch 17/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1537 - accuracy: 0.9397 - weighted_accuracy: 0.9432 - val_loss: 0.3149 - val_accuracy: 0.8449 - val_weighted_accuracy: 0.8522
# Epoch 18/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1482 - accuracy: 0.9395 - weighted_accuracy: 0.9428 - val_loss: 0.3013 - val_accuracy: 0.8519 - val_weighted_accuracy: 0.8606
# Epoch 19/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1578 - accuracy: 0.9337 - weighted_accuracy: 0.9370 - val_loss: 0.3049 - val_accuracy: 0.8403 - val_weighted_accuracy: 0.8498
# Epoch 20/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1480 - accuracy: 0.9410 - weighted_accuracy: 0.9440 - val_loss: 0.3300 - val_accuracy: 0.8300 - val_weighted_accuracy: 0.8439
# Epoch 21/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.1375 - accuracy: 0.9469 - weighted_accuracy: 0.9500 - val_loss: 0.3000 - val_accuracy: 0.8346 - val_weighted_accuracy: 0.8357
# Epoch 22/100
# 149/149 [==============================] - 12s 82ms/step - loss: 0.1215 - accuracy: 0.9544 - weighted_accuracy: 0.9573 - val_loss: 0.2840 - val_accuracy: 0.8601 - val_weighted_accuracy: 0.8688
# Epoch 23/100
# 149/149 [==============================] - 13s 89ms/step - loss: 0.1222 - accuracy: 0.9553 - weighted_accuracy: 0.9579 - val_loss: 0.3171 - val_accuracy: 0.8481 - val_weighted_accuracy: 0.8528
# Epoch 24/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.1148 - accuracy: 0.9578 - weighted_accuracy: 0.9606 - val_loss: 0.2971 - val_accuracy: 0.8519 - val_weighted_accuracy: 0.8536
# Epoch 25/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1326 - accuracy: 0.9452 - weighted_accuracy: 0.9483 - val_loss: 0.2540 - val_accuracy: 0.8720 - val_weighted_accuracy: 0.8788
# Epoch 26/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.1064 - accuracy: 0.9675 - weighted_accuracy: 0.9698 - val_loss: 0.3092 - val_accuracy: 0.8539 - val_weighted_accuracy: 0.8642
# Epoch 27/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.1079 - accuracy: 0.9614 - weighted_accuracy: 0.9640 - val_loss: 0.2965 - val_accuracy: 0.8580 - val_weighted_accuracy: 0.8674
# Epoch 28/100
# 149/149 [==============================] - 15s 101ms/step - loss: 0.1086 - accuracy: 0.9584 - weighted_accuracy: 0.9609 - val_loss: 0.3797 - val_accuracy: 0.8095 - val_weighted_accuracy: 0.8242
# Epoch 29/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.0980 - accuracy: 0.9679 - weighted_accuracy: 0.9700 - val_loss: 0.3076 - val_accuracy: 0.8584 - val_weighted_accuracy: 0.8656
# Epoch 30/100
# 149/149 [==============================] - 13s 91ms/step - loss: 0.0945 - accuracy: 0.9683 - weighted_accuracy: 0.9708 - val_loss: 0.3100 - val_accuracy: 0.8490 - val_weighted_accuracy: 0.8562
# Epoch 31/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.0945 - accuracy: 0.9683 - weighted_accuracy: 0.9704 - val_loss: 0.2951 - val_accuracy: 0.8498 - val_weighted_accuracy: 0.8572
# Epoch 32/100
# 149/149 [==============================] - 14s 92ms/step - loss: 0.0932 - accuracy: 0.9700 - weighted_accuracy: 0.9716 - val_loss: 0.3062 - val_accuracy: 0.8490 - val_weighted_accuracy: 0.8551
# Epoch 33/100
# 149/149 [==============================] - 14s 91ms/step - loss: 0.0873 - accuracy: 0.9721 - weighted_accuracy: 0.9738 - val_loss: 0.3826 - val_accuracy: 0.8383 - val_weighted_accuracy: 0.8465
# Epoch 34/100
# 149/149 [==============================] - 13s 90ms/step - loss: 0.0793 - accuracy: 0.9786 - weighted_accuracy: 0.9807 - val_loss: 0.3250 - val_accuracy: 0.8407 - val_weighted_accuracy: 0.8472
# Epoch 35/100
# 149/149 [==============================] - 13s 88ms/step - loss: 0.0817 - accuracy: 0.9752 - weighted_accuracy: 0.9772 - val_loss: 0.2958 - val_accuracy: 0.8473 - val_weighted_accuracy: 0.8533
# best_epoch:  24

# %%
train_yhat = model.predict({'Continents': non_audio_df['train']['continent'],
                            'Audio_Features': training_audio_features
                            })

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_chroma_rms_spectral_centroid_continents'] = model.evaluate({'Continents': non_audio_df['train']['continent'],
                                                          'Audio_Features': training_audio_features},
                                                         audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 2s 14ms/step
# 149/149 [==============================] - 2s 14ms/step - loss: 0.1438 - accuracy: 0.9733 - weighted_accuracy: 0.9733

# %%
val_yhat = model.predict({'Continents': non_audio_df['val']['continent'],
                          'Audio_Features': validation_audio_features
                          })

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_chroma_rms_spectral_centroid_continents'] = model.evaluate({'Continents': non_audio_df['val']['continent'],
                                                          'Audio_Features': validation_audio_features},
                                                         audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 1s 14ms/step
# 76/76 [==============================] - 1s 19ms/step - loss: 0.4335 - accuracy: 0.8720 - weighted_accuracy: 0.8720

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.98      0.98      0.98      1603
#       comsan       0.96      0.97      0.97      1578
#      eaywag1       0.98      0.97      0.98      1582
#
#     accuracy                           0.97      4763
#    macro avg       0.97      0.97      0.97      4763
# weighted avg       0.97      0.97      0.97      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.90      0.85      0.88      1032
#       comsan       0.84      0.89      0.86       618
#      eaywag1       0.86      0.88      0.87       780
#
#     accuracy                           0.87      2430
#    macro avg       0.87      0.88      0.87      2430
# weighted avg       0.87      0.87      0.87      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# # Review results from all models

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(2)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(2)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Val_Accuracy')
result_df
# Out:
#                                        Features  Train_Accuracy  Val_Accuracy
# 0                        mfcc_chroma_continents            0.98          0.87
# 4  mfcc_chroma_rms_spectral_centroid_continents            0.97          0.87
# 2             mfcc_spectral_centroid_continents            0.98          0.90
# 1                           mfcc_rms_continents            0.98          0.91
# 3         mfcc_rms_spectral_centroid_continents            0.97          0.91
