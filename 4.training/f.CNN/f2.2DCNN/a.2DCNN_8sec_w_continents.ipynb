# %% [markdown]
# # Import Libraries

# %%
# For drive access
from google.colab import drive
drive.mount('/content/drive')

# Standard libraries
import numpy as np
import pandas as pd

# for loading the pickle files with features and labels
import pickle

# For audio
from IPython.display import Audio
import librosa

# For modeling
import tensorflow as tf
from sklearn.metrics import classification_report

# For visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load features and labels from train and val pickle

# %%
with open('/content/drive/MyDrive/Projects/train_val_features_pkl/train_val_8_sec_audio_features_not_avgpooled.pkl', 'rb') as file:
  audio_df = pickle.load(file)

# %%
audio_df
# Out:
# {'train': {'mfcc': array([[[0.2926833 , 0.5472208 , 0.51762646, ..., 0.42902297,
#            0.5246572 , 0.39747417],
#           [0.38219857, 0.63193434, 0.4692648 , ..., 0.4789598 ,
#            0.5143834 , 0.35231233],
#           [0.4352324 , 0.62795496, 0.4937711 , ..., 0.53823024,
#            0.5205363 , 0.36665156],
#           ...,
#           [0.6295364 , 0.3740691 , 0.4684327 , ..., 0.74904454,
#            0.6659465 , 0.13212648],
#           [0.6729512 , 0.37194872, 0.47004578, ..., 0.63276273,
#            0.6894711 , 0.25973636],
#           [0.6984098 , 0.35604227, 0.50428545, ..., 0.49908003,
#            0.694181  , 0.40737295]],
#
#          [[0.571982  , 0.52721703, 0.35377806, ..., 0.31411108,
#            0.45345846, 0.5325761 ],
#           [0.57278824, 0.51283437, 0.33133256, ..., 0.44663262,
#            0.59104645, 0.5540432 ],
#           [0.5442881 , 0.50030595, 0.39622635, ..., 0.4177069 ,
#            0.63780564, 0.5152073 ],
#           ...,
#           [0.65820706, 0.30996823, 0.5541669 , ..., 0.3272183 ,
#            0.67594415, 0.37952572],
#           [0.55198324, 0.45880285, 0.6117153 , ..., 0.3045411 ,
#            0.6040039 , 0.2133086 ],
#           [0.47530848, 0.5978474 , 0.5095156 , ..., 0.32938066,
#            0.5845121 , 0.43895328]],
#
#          [[0.7978938 , 0.2568429 , 0.43546572, ..., 0.43030724,
#            0.43849736, 0.42188978],
#           [0.7662014 , 0.25891137, 0.39701158, ..., 0.5694269 ,
#            0.5710539 , 0.42619675],
#           [0.7192114 , 0.23281348, 0.49096993, ..., 0.72567195,
#            0.55556244, 0.33746177],
#           ...,
#           [0.5616844 , 0.47193855, 0.47496653, ..., 0.40325606,
#            0.6460507 , 0.3992835 ],
#           [0.637675  , 0.43434197, 0.44582096, ..., 0.28660327,
#            0.72113395, 0.4044888 ],
#           [0.6874016 , 0.41598967, 0.45974106, ..., 0.2920211 ,
#            0.8479563 , 0.3843705 ]],
#
#          ...,
#
#          [[0.3217525 , 0.6881845 , 0.48000094, ..., 0.59206927,
#            0.74486995, 0.55143815],
#           [0.5426938 , 0.6778939 , 0.41601896, ..., 0.7395768 ,
#            0.7553704 , 0.47949517],
#           [0.59666324, 0.6607961 , 0.4709517 , ..., 0.73276883,
#            0.7016298 , 0.4657311 ],
#           ...,
#           [0.6395872 , 0.71056587, 0.5853568 , ..., 0.46401277,
#            0.64115125, 0.48693323],
#           [0.63390076, 0.7141628 , 0.5673788 , ..., 0.47245952,
#            0.48211706, 0.5692038 ],
#           [0.63172424, 0.69852054, 0.5903194 , ..., 0.50481737,
#            0.5573676 , 0.66070366]],
#
#          [[0.6914642 , 0.71377504, 0.39913929, ..., 0.57215583,
#            0.45173353, 0.49472663],
#           [0.69487584, 0.70868874, 0.40198043, ..., 0.69470924,
#            0.53920835, 0.6262043 ],
#           [0.66651314, 0.6739543 , 0.46362418, ..., 0.70973766,
#            0.5931354 , 0.61188835],
#           ...,
#           [0.60295427, 0.707848  , 0.536386  , ..., 0.53722155,
#            0.57293046, 0.47105172],
#           [0.6006154 , 0.72017705, 0.50518787, ..., 0.4792548 ,
#            0.51115537, 0.49641013],
#           [0.5960094 , 0.70707476, 0.48459497, ..., 0.45196575,
#            0.6186346 , 0.60358286]],
#
#          [[0.67346656, 0.7210153 , 0.5060047 , ..., 0.5705455 ,
#            0.49910307, 0.4772731 ],
#           [0.6678432 , 0.720808  , 0.45569578, ..., 0.65077525,
#            0.53326356, 0.5335313 ],
#           [0.63857067, 0.6967014 , 0.4817975 , ..., 0.675209  ,
#            0.6000869 , 0.59436566],
#           ...,
#           [0.61522543, 0.6990228 , 0.5028586 , ..., 0.4935642 ,
#            0.61613715, 0.5054803 ],
#           [0.6177405 , 0.7108036 , 0.4846519 , ..., 0.44536754,
#            0.53255624, 0.5205585 ],
#           [0.6179831 , 0.70123994, 0.48564783, ..., 0.43177015,
#            0.5783832 , 0.5263324 ]]], dtype=float32),
#   'chroma': array([[[0.73383594, 0.69802487, 0.54096204, ..., 1.        ,
#            0.608227  , 0.48766178],
#           [1.        , 0.9552251 , 0.97629696, ..., 0.819532  ,
#            0.46592206, 0.4471012 ],
#           [0.70929813, 0.856629  , 1.        , ..., 0.9266538 ,
#            0.5471759 , 0.3217781 ],
#           ...,
#           [0.88756543, 0.4946972 , 0.0864549 , ..., 0.22002427,
#            0.10811816, 0.53788805],
#           [1.        , 0.20042695, 0.16474293, ..., 0.17202397,
#            0.26110023, 0.83525467],
#           [0.90538883, 0.38594005, 0.5073254 , ..., 0.5220612 ,
#            0.7847499 , 1.        ]],
#
#          [[0.229046  , 0.16785018, 0.31864116, ..., 0.418515  ,
#            0.38013583, 0.45450932],
#           [0.10696242, 0.05362201, 0.17352895, ..., 0.13921109,
#            0.12649179, 0.19284795],
#           [0.09754786, 0.03310031, 0.07604828, ..., 0.05064095,
#            0.06268156, 0.09602583],
#           ...,
#           [0.24475525, 0.45408043, 0.83302605, ..., 0.05314327,
#            0.18526138, 0.2805035 ],
#           [0.08646167, 0.38773277, 0.8255288 , ..., 0.0313557 ,
#            0.06599664, 0.08877482],
#           [0.6355827 , 0.49046612, 0.4782703 , ..., 0.61005807,
#            1.        , 0.62264   ]],
#
#          [[0.9527174 , 0.6517912 , 1.        , ..., 0.20430964,
#            0.53656095, 0.91746473],
#           [0.6809198 , 0.79247546, 1.        , ..., 0.20608044,
#            0.3752266 , 0.6624584 ],
#           [0.22394416, 0.9766228 , 1.        , ..., 0.29581028,
#            0.16772322, 0.17033473],
#           ...,
#           [0.7538224 , 0.20673002, 0.14345545, ..., 0.5413501 ,
#            0.42209476, 0.43086848],
#           [0.2879784 , 0.0433191 , 0.0333375 , ..., 0.16351902,
#            0.14486517, 0.21927443],
#           [0.2606343 , 0.02818089, 0.02646846, ..., 0.08534104,
#            0.08157288, 0.22000772]],
#
#          ...,
#
#          [[1.        , 0.5075606 , 0.3643616 , ..., 0.46753508,
#            0.5181549 , 0.82220215],
#           [0.75011694, 0.40670243, 0.23636323, ..., 0.34903422,
#            0.33158213, 0.5658228 ],
#           [0.6620617 , 0.49264944, 0.37212887, ..., 0.42530674,
#            0.48871762, 0.50091463],
#           ...,
#           [0.47907886, 0.5681733 , 0.6849798 , ..., 0.9351088 ,
#            0.6223058 , 0.4530788 ],
#           [0.6037054 , 0.57480985, 0.8478139 , ..., 1.0000001 ,
#            0.9806911 , 0.8639272 ],
#           [0.330637  , 0.46738312, 1.0000001 , ..., 0.5264327 ,
#            0.6019139 , 0.47685713]],
#
#          [[0.7212241 , 0.6510515 , 0.49622202, ..., 0.42471525,
#            0.62083757, 0.54442513],
#           [0.7963582 , 0.9396931 , 0.7933524 , ..., 0.8130368 ,
#            0.8064168 , 0.7425875 ],
#           [0.60769   , 0.89288026, 1.        , ..., 0.96361125,
#            0.7946369 , 0.6225406 ],
#           ...,
#           [0.7738935 , 0.55971414, 0.7861116 , ..., 1.        ,
#            0.72889286, 0.82642055],
#           [0.6680029 , 0.4654429 , 0.5945168 , ..., 1.0000001 ,
#            0.5256816 , 0.5611079 ],
#           [0.90391827, 0.71218765, 0.71311766, ..., 0.99999994,
#            0.664123  , 0.67750007]],
#
#          [[1.        , 0.7363702 , 0.75878894, ..., 0.5759158 ,
#            0.5487739 , 0.9241918 ],
#           [1.        , 0.90941614, 0.7891846 , ..., 0.7688592 ,
#            0.5679903 , 0.8910592 ],
#           [0.47667533, 0.51785684, 0.59323484, ..., 0.7292442 ,
#            0.5910429 , 0.5156206 ],
#           ...,
#           [0.7927784 , 0.8835067 , 1.        , ..., 0.54843056,
#            0.36869946, 0.6075551 ],
#           [0.8109695 , 1.        , 0.89819205, ..., 0.82382023,
#            0.53969693, 0.7465627 ],
#           [0.5711932 , 0.5911646 , 0.7132408 , ..., 0.6430262 ,
#            0.5621957 , 0.6215854 ]]], dtype=float32),
#   'rms': array([[[0.00066166],
#           [0.00108187],
#           [0.00132881],
#           ...,
#           [0.04247803],
#           [0.04479152],
#           [0.04258918]],
#
#          [[0.00843364],
#           [0.00863268],
#           [0.00953967],
#           ...,
#           [0.04465197],
#           [0.04720594],
#           [0.00180491]],
#
#          [[0.0945745 ],
#           [0.12310638],
#           [0.15316504],
#           ...,
#           [0.02636078],
#           [0.02628713],
#           [0.02671736]],
#
#          ...,
#
#          [[0.00261697],
#           [0.00429666],
#           [0.00528861],
#           ...,
#           [0.02439404],
#           [0.0186677 ],
#           [0.01447811]],
#
#          [[0.01063585],
#           [0.01215442],
#           [0.01393843],
#           ...,
#           [0.00716951],
#           [0.00646511],
#           [0.00508991]],
#
#          [[0.0099481 ],
#           [0.01280325],
#           [0.01470958],
#           ...,
#           [0.00779135],
#           [0.00702508],
#           [0.00562738]]], dtype=float32),
#   'spectral_centroid': array([[[0.43021879],
#           [0.35183347],
#           [0.34781837],
#           ...,
#           [0.52712466],
#           [0.55913132],
#           [0.57462391]],
#
#          [[0.43822888],
#           [0.43232722],
#           [0.44510553],
#           ...,
#           [0.62451555],
#           [0.61696158],
#           [0.40656783]],
#
#          [[0.64503138],
#           [0.62792118],
#           [0.66633629],
#           ...,
#           [0.49295281],
#           [0.50166412],
#           [0.4961109 ]],
#
#          ...,
#
#          [[0.33329476],
#           [0.31788902],
#           [0.31750112],
#           ...,
#           [0.26185072],
#           [0.27195403],
#           [0.28777192]],
#
#          [[0.28686683],
#           [0.27937374],
#           [0.2835901 ],
#           ...,
#           [0.29240491],
#           [0.29233926],
#           [0.28699176]],
#
#          [[0.27946243],
#           [0.26233429],
#           [0.24775679],
#           ...,
#           [0.28449501],
#           [0.29198551],
#           [0.29002803]]]),
#   'melspectrogram': array([[[0.24356848, 0.19709486, 0.19181323, ..., 0.14215577,
#            0.14264905, 0.16532534],
#           [0.40376735, 0.3655113 , 0.42287964, ..., 0.23766714,
#            0.1897651 , 0.1521129 ],
#           [0.45815992, 0.46074304, 0.4943219 , ..., 0.2976507 ,
#            0.25157702, 0.2118563 ],
#           ...,
#           [0.49117148, 0.43984422, 0.43819213, ..., 0.6310359 ,
#            0.56908995, 0.5044948 ],
#           [0.46418417, 0.4439577 , 0.45830843, ..., 0.6673047 ,
#            0.62528354, 0.5652833 ],
#           [0.4987093 , 0.456418  , 0.46511737, ..., 0.6581471 ,
#            0.6399298 , 0.5732062 ]],
#
#          [[0.4543748 , 0.4756736 , 0.4632044 , ..., 0.41978696,
#            0.3437417 , 0.3016634 ],
#           [0.45686582, 0.45135322, 0.46586612, ..., 0.41686812,
#            0.36826977, 0.29667157],
#           [0.45796975, 0.44600147, 0.44945693, ..., 0.42953232,
#            0.3780449 , 0.31478083],
#           ...,
#           [0.53641915, 0.46677327, 0.46015307, ..., 0.7154856 ,
#            0.7200803 , 0.60636497],
#           [0.51489085, 0.44360733, 0.45077553, ..., 0.54932797,
#            0.59599185, 0.46856165],
#           [0.50560594, 0.42767835, 0.43264443, ..., 0.3394151 ,
#            0.31403804, 0.25334805]],
#
#          [[0.4970015 , 0.4928741 , 0.47974336, ..., 0.78759706,
#            0.7498659 , 0.7231643 ],
#           [0.4755374 , 0.46717736, 0.4660268 , ..., 0.7653399 ,
#            0.7495806 , 0.694723  ],
#           [0.45806897, 0.47078794, 0.4709153 , ..., 0.8058598 ,
#            0.7909299 , 0.7564884 ],
#           ...,
#           [0.49385324, 0.44783697, 0.46114796, ..., 0.4956058 ,
#            0.46170318, 0.38592994],
#           [0.4859912 , 0.46393633, 0.47618708, ..., 0.55451417,
#            0.5702215 , 0.4863054 ],
#           [0.5273504 , 0.5001548 , 0.50836205, ..., 0.5773054 ,
#            0.60384905, 0.5157382 ]],
#
#          ...,
#
#          [[0.3514245 , 0.34866   , 0.32154053, ..., 0.15999717,
#            0.13954413, 0.17613167],
#           [0.50815594, 0.50543916, 0.5237822 , ..., 0.3366097 ,
#            0.32153517, 0.32495368],
#           [0.558628  , 0.5878562 , 0.6032868 , ..., 0.39959395,
#            0.38615382, 0.3934602 ],
#           ...,
#           [0.780533  , 0.6560871 , 0.6240686 , ..., 0.5234435 ,
#            0.49361798, 0.38953286],
#           [0.7499489 , 0.613906  , 0.59531116, ..., 0.5071019 ,
#            0.43975508, 0.3849932 ],
#           [0.7196118 , 0.5921148 , 0.565887  , ..., 0.4851054 ,
#            0.4135834 , 0.38994557]],
#
#          [[0.6109494 , 0.6206902 , 0.61200386, ..., 0.42749023,
#            0.41519445, 0.43781918],
#           [0.6411831 , 0.6318178 , 0.63249946, ..., 0.429544  ,
#            0.41518798, 0.42299882],
#           [0.6684967 , 0.6355276 , 0.63343793, ..., 0.44025874,
#            0.41929087, 0.43441528],
#           ...,
#           [0.6507423 , 0.61017406, 0.6335789 , ..., 0.3631066 ,
#            0.38515967, 0.42551026],
#           [0.61023897, 0.5893043 , 0.615956  , ..., 0.35835356,
#            0.4061381 , 0.42431673],
#           [0.5904546 , 0.578876  , 0.5727197 , ..., 0.3613688 ,
#            0.40224642, 0.40074635]],
#
#          [[0.6635772 , 0.62118745, 0.64088583, ..., 0.45560822,
#            0.39278215, 0.41715443],
#           [0.6625777 , 0.6242373 , 0.64697003, ..., 0.43134996,
#            0.39039868, 0.3984837 ],
#           [0.6775949 , 0.6223249 , 0.6149095 , ..., 0.4144279 ,
#            0.39025593, 0.40155146],
#           ...,
#           [0.6397346 , 0.613194  , 0.62155163, ..., 0.3954093 ,
#            0.39272565, 0.38059273],
#           [0.6048291 , 0.62069327, 0.62521505, ..., 0.39358556,
#            0.40497494, 0.38601157],
#           [0.5949067 , 0.5863329 , 0.590046  , ..., 0.3845084 ,
#            0.40410328, 0.38128677]]], dtype=float32),
#   'label': array([0, 0, 0, ..., 2, 2, 2])},
#  'val': {'mfcc': array([[[0.03438473, 0.5409663 , 0.49516892, ..., 0.47214267,
#            0.54059166, 0.31063035],
#           [0.156398  , 0.5936351 , 0.34219292, ..., 0.5281046 ,
#            0.4928256 , 0.45432433],
#           [0.27276182, 0.5529174 , 0.35612273, ..., 0.520854  ,
#            0.5686558 , 0.47363648],
#           ...,
#           [0.53652716, 0.533416  , 0.3665663 , ..., 0.36028466,
#            0.5355693 , 0.3084178 ],
#           [0.54577094, 0.54470825, 0.35483423, ..., 0.40590182,
#            0.4965055 , 0.34188586],
#           [0.5508863 , 0.53994864, 0.3564601 , ..., 0.43862337,
#            0.47689667, 0.32920602]],
#
#          [[0.41281384, 0.67141247, 0.65520215, ..., 0.37753204,
#            0.5337289 , 0.45304573],
#           [0.61477315, 0.7969459 , 0.4981349 , ..., 0.59867835,
#            0.59102464, 0.68530947],
#           [0.67084944, 0.77747846, 0.53579843, ..., 0.7273464 ,
#            0.61758906, 0.62314296],
#           ...,
#           [0.7601433 , 0.66117793, 0.5779958 , ..., 0.6609509 ,
#            0.68418646, 0.5143307 ],
#           [0.7423201 , 0.725596  , 0.5517128 , ..., 0.62154275,
#            0.6082248 , 0.5371979 ],
#           [0.74019575, 0.74327356, 0.53127474, ..., 0.54929096,
#            0.6353032 , 0.44752052]],
#
#          [[0.34304124, 0.7915419 , 0.598637  , ..., 0.38757032,
#            0.44805235, 0.3161977 ],
#           [0.59942603, 0.7608812 , 0.5384848 , ..., 0.53995186,
#            0.54124606, 0.5021793 ],
#           [0.65236187, 0.71998066, 0.5805178 , ..., 0.6230264 ,
#            0.60933435, 0.5061622 ],
#           ...,
#           [0.64055467, 0.7219373 , 0.6331161 , ..., 0.46207854,
#            0.5755408 , 0.49926198],
#           [0.6480728 , 0.74492353, 0.6308691 , ..., 0.47223875,
#            0.5534381 , 0.5032821 ],
#           [0.6469756 , 0.7327585 , 0.6370018 , ..., 0.5462244 ,
#            0.59276986, 0.4655675 ]],
#
#          ...,
#
#          [[0.74778503, 0.7209703 , 0.40612832, ..., 0.5918846 ,
#            0.6513869 , 0.5332755 ],
#           [0.7457434 , 0.7114381 , 0.39589864, ..., 0.6633295 ,
#            0.64677393, 0.5809252 ],
#           [0.7131096 , 0.6798183 , 0.44682613, ..., 0.6490638 ,
#            0.59542394, 0.5189707 ],
#           ...,
#           [0.69847393, 0.71101874, 0.5096783 , ..., 0.65995574,
#            0.56425035, 0.47228584],
#           [0.7035257 , 0.7315591 , 0.48594677, ..., 0.60101634,
#            0.5738688 , 0.4946204 ],
#           [0.7055297 , 0.70799476, 0.46933103, ..., 0.49718615,
#            0.6547618 , 0.5425098 ]],
#
#          [[0.2908501 , 0.7189217 , 0.4210609 , ..., 0.34758058,
#            0.3391745 , 0.6465228 ],
#           [0.4968081 , 0.7353206 , 0.38010958, ..., 0.48473963,
#            0.43648642, 0.6562871 ],
#           [0.5429973 , 0.701936  , 0.42638344, ..., 0.54729   ,
#            0.49788263, 0.548462  ],
#           ...,
#           [0.53224087, 0.7414206 , 0.5025408 , ..., 0.48724097,
#            0.5497386 , 0.5259569 ],
#           [0.5396178 , 0.76640326, 0.49725193, ..., 0.4311356 ,
#            0.49491715, 0.4492576 ],
#           [0.5452116 , 0.76659644, 0.5120657 , ..., 0.43508086,
#            0.5092749 , 0.39250734]],
#
#          [[0.35528255, 0.5790772 , 0.56944543, ..., 0.45860705,
#            0.5517407 , 0.4264643 ],
#           [0.41365486, 0.7147431 , 0.52766097, ..., 0.6032357 ,
#            0.5893611 , 0.46952924],
#           [0.47077656, 0.7510897 , 0.5992972 , ..., 0.6085386 ,
#            0.64177614, 0.5471046 ],
#           ...,
#           [0.5042781 , 0.92240477, 0.73465073, ..., 0.42743266,
#            0.6194316 , 0.4052591 ],
#           [0.4641732 , 0.8738564 , 0.76589763, ..., 0.391493  ,
#            0.59199184, 0.43708456],
#           [0.44472247, 0.78773165, 0.7542114 , ..., 0.35484043,
#            0.6443579 , 0.5087153 ]]], dtype=float32),
#   'chroma': array([[[0.7646548 , 0.6593877 , 1.        , ..., 0.7147495 ,
#            0.7372933 , 0.5769873 ],
#           [1.        , 0.9776191 , 0.7299414 , ..., 0.20515485,
#            0.25375524, 0.4779138 ],
#           [1.0000001 , 0.9596754 , 0.82782555, ..., 0.5209368 ,
#            0.5438989 , 0.7936685 ],
#           ...,
#           [0.16291276, 0.14363815, 0.17468452, ..., 0.20659253,
#            0.23780039, 0.16433807],
#           [0.2022269 , 0.16572295, 0.19001824, ..., 0.13031365,
#            0.15897165, 0.1746402 ],
#           [0.14170276, 0.14602776, 0.20580296, ..., 0.14098944,
#            0.10827189, 0.16469386]],
#
#          [[0.8470788 , 1.        , 0.9584479 , ..., 0.5541986 ,
#            0.60589206, 0.7429723 ],
#           [0.73648524, 0.7767946 , 0.95988184, ..., 0.79856175,
#            0.68244904, 0.71300286],
#           [0.7221496 , 0.60955745, 0.710658  , ..., 0.96438843,
#            0.8706302 , 0.85046685],
#           ...,
#           [0.67400604, 0.63110614, 0.8122476 , ..., 0.7028029 ,
#            0.6089538 , 0.49003288],
#           [0.60263884, 0.40273157, 0.5151347 , ..., 0.6125045 ,
#            0.5007707 , 0.49264178],
#           [0.75435615, 0.35312733, 0.3339029 , ..., 0.50700265,
#            0.6434145 , 0.6333055 ]],
#
#          [[0.21815085, 0.24457382, 0.286702  , ..., 1.        ,
#            0.816597  , 0.49451017],
#           [0.14038104, 0.203232  , 0.36619595, ..., 0.84946656,
#            0.42996433, 0.30546373],
#           [0.26832697, 0.38324547, 0.59156364, ..., 0.85665125,
#            0.5147319 , 0.47055075],
#           ...,
#           [0.213635  , 0.22972344, 0.38984865, ..., 0.32367027,
#            0.3919436 , 0.24894355],
#           [0.2586603 , 0.286459  , 0.35752532, ..., 0.21823199,
#            0.23316927, 0.2673995 ],
#           [0.43330297, 0.5084328 , 0.33426496, ..., 0.20642486,
#            0.11039441, 0.2744891 ]],
#
#          ...,
#
#          [[0.7150665 , 0.6856525 , 0.72564256, ..., 0.5490038 ,
#            0.9175502 , 0.7872274 ],
#           [0.78217745, 0.7306153 , 0.73654264, ..., 0.70680183,
#            1.        , 0.94257677],
#           [0.79001683, 0.87175167, 0.8301966 , ..., 0.9434979 ,
#            0.9721074 , 1.        ],
#           ...,
#           [0.72140193, 0.6670173 , 0.6496824 , ..., 0.7078034 ,
#            0.6309728 , 0.811846  ],
#           [0.54813915, 0.5793646 , 0.7561379 , ..., 0.51952004,
#            0.6629236 , 0.94050825],
#           [0.35745636, 0.37443233, 0.60613006, ..., 0.34727755,
#            0.6361132 , 0.60757905]],
#
#          [[0.12920445, 0.24731807, 0.5391454 , ..., 0.50280094,
#            0.3234261 , 0.10417072],
#           [0.3272184 , 0.37468094, 0.49829358, ..., 0.5354412 ,
#            0.5043049 , 0.2658642 ],
#           [0.63557154, 0.5032978 , 0.67034566, ..., 0.7182885 ,
#            0.78906685, 0.6150083 ],
#           ...,
#           [0.5055485 , 0.62709343, 0.45350704, ..., 0.5924449 ,
#            1.        , 0.9164598 ],
#           [0.20694374, 0.32452282, 0.28471586, ..., 0.48183307,
#            1.0000001 , 0.49888673],
#           [0.18903567, 0.2551217 , 0.31590292, ..., 0.54448265,
#            1.        , 0.45031857]],
#
#          [[0.6099855 , 0.52973676, 0.4314404 , ..., 0.88568044,
#            0.8219632 , 0.76208293],
#           [0.65957516, 0.6353318 , 0.5847457 , ..., 0.93063444,
#            0.7951908 , 0.7416253 ],
#           [0.5383141 , 0.57087344, 0.45381156, ..., 1.        ,
#            0.63993496, 0.60679996],
#           ...,
#           [0.55252045, 0.72652733, 1.        , ..., 0.9905569 ,
#            0.9756369 , 0.8603448 ],
#           [0.90918326, 0.7175546 , 0.5232939 , ..., 0.448994  ,
#            0.69994086, 1.        ],
#           [0.7308196 , 0.539653  , 0.53606564, ..., 0.771013  ,
#            0.8287663 , 0.8902378 ]]], dtype=float32),
#   'rms': array([[[6.8254682e-05],
#           [2.1939805e-04],
#           [4.2839046e-04],
#           ...,
#           [5.1447935e-03],
#           [4.9803653e-03],
#           [4.1735838e-03]],
#
#          [[4.2074233e-02],
#           [1.0621951e-01],
#           [1.3893212e-01],
#           ...,
#           [3.8427278e-02],
#           [3.5975665e-02],
#           [2.7774476e-02]],
#
#          [[8.2113249e-03],
#           [1.2631006e-02],
#           [1.4442490e-02],
#           ...,
#           [1.4388610e-02],
#           [1.3500358e-02],
#           [1.0931141e-02]],
#
#          ...,
#
#          [[1.6571838e-02],
#           [1.7655212e-02],
#           [1.8854775e-02],
#           ...,
#           [1.8490607e-02],
#           [1.7254055e-02],
#           [1.4439104e-02]],
#
#          [[2.1392710e-03],
#           [3.3970729e-03],
#           [3.9917743e-03],
#           ...,
#           [5.4435227e-03],
#           [4.9514584e-03],
#           [4.2695017e-03]],
#
#          [[3.7546651e-03],
#           [4.8651174e-03],
#           [2.3346646e-02],
#           ...,
#           [5.7112973e-02],
#           [3.4126684e-02],
#           [2.2383185e-02]]], dtype=float32),
#   'spectral_centroid': array([[[0.54656741],
#           [0.37865166],
#           [0.39853728],
#           ...,
#           [0.40867808],
#           [0.42846209],
#           [0.40883235]],
#
#          [[0.16096673],
#           [0.09768898],
#           [0.09134934],
#           ...,
#           [0.36211678],
#           [0.27002135],
#           [0.2145442 ]],
#
#          [[0.1888723 ],
#           [0.21536217],
#           [0.2383076 ],
#           ...,
#           [0.26032311],
#           [0.25610704],
#           [0.25796355]],
#
#          ...,
#
#          [[0.27016079],
#           [0.2702707 ],
#           [0.28097238],
#           ...,
#           [0.26516819],
#           [0.26124954],
#           [0.27352084]],
#
#          [[0.26946555],
#           [0.24700455],
#           [0.25418389],
#           ...,
#           [0.22423094],
#           [0.21413   ],
#           [0.20466403]],
#
#          [[0.2321004 ],
#           [0.15440951],
#           [0.11527369],
#           ...,
#           [0.03329018],
#           [0.03617943],
#           [0.02736049]]]),
#   'melspectrogram': array([[[0.08103681, 0.06281257, 0.04899508, ..., 0.0126223 ,
#            0.01625842, 0.02704358],
#           [0.16806442, 0.15293223, 0.20864499, ..., 0.06657875,
#            0.05336493, 0.05504674],
#           [0.2551819 , 0.26873422, 0.27525806, ..., 0.1596486 ,
#            0.15128297, 0.15508932],
#           ...,
#           [0.43946368, 0.43952537, 0.46801436, ..., 0.3903185 ,
#            0.38137046, 0.37939993],
#           [0.4319826 , 0.45017073, 0.4815686 , ..., 0.39779127,
#            0.3901048 , 0.37982506],
#           [0.43024457, 0.43739873, 0.4742092 , ..., 0.37816513,
#            0.39697692, 0.37451804]],
#
#          [[0.53607374, 0.4760657 , 0.40242267, ..., 0.18058312,
#            0.15626639, 0.16649419],
#           [0.7286438 , 0.675462  , 0.6663515 , ..., 0.34260413,
#            0.3336767 , 0.32324892],
#           [0.79932505, 0.74715483, 0.7510541 , ..., 0.4049864 ,
#            0.38409263, 0.38859048],
#           ...,
#           [0.7754409 , 0.7459701 , 0.7681694 , ..., 0.6363764 ,
#            0.60821825, 0.5042228 ],
#           [0.75374657, 0.74040216, 0.7729754 , ..., 0.53729707,
#            0.54528797, 0.48106566],
#           [0.74752945, 0.72839457, 0.7563726 , ..., 0.47744092,
#            0.50094575, 0.43916273]],
#
#          [[0.47513065, 0.4804721 , 0.48405796, ..., 0.14679098,
#            0.14400697, 0.17451447],
#           [0.6261809 , 0.6455195 , 0.6954016 , ..., 0.36581507,
#            0.36516973, 0.38317612],
#           [0.6764163 , 0.70619637, 0.72770447, ..., 0.44338867,
#            0.44211918, 0.4616505 ],
#           ...,
#           [0.74071205, 0.7133362 , 0.7141671 , ..., 0.43368593,
#            0.43644074, 0.4478911 ],
#           [0.71385306, 0.7088312 , 0.7003579 , ..., 0.41723558,
#            0.44375277, 0.45729327],
#           [0.70436656, 0.6966621 , 0.66690505, ..., 0.41670942,
#            0.44353658, 0.44696856]],
#
#          ...,
#
#          [[0.65482044, 0.6923055 , 0.6991818 , ..., 0.4506169 ,
#            0.45181042, 0.45589545],
#           [0.6723259 , 0.6762383 , 0.70000386, ..., 0.4615677 ,
#            0.44838136, 0.4410908 ],
#           [0.6718765 , 0.67232054, 0.69023204, ..., 0.47749022,
#            0.44604304, 0.4478292 ],
#           ...,
#           [0.741146  , 0.68560064, 0.716449  , ..., 0.4458004 ,
#            0.45347685, 0.4565132 ],
#           [0.71345043, 0.6707683 , 0.7173933 , ..., 0.43744653,
#            0.45205736, 0.45527977],
#           [0.6896811 , 0.6387804 , 0.67879313, ..., 0.43941015,
#            0.4580866 , 0.44885725]],
#
#          [[0.3551227 , 0.36077967, 0.3018945 , ..., 0.11696076,
#            0.10553074, 0.09938878],
#           [0.48231995, 0.51379275, 0.4967989 , ..., 0.267012  ,
#            0.25197464, 0.23644072],
#           [0.52727455, 0.5874976 , 0.5684792 , ..., 0.32170337,
#            0.29986417, 0.29666954],
#           ...,
#           [0.56999373, 0.59020483, 0.63190985, ..., 0.31018773,
#            0.30086726, 0.2727328 ],
#           [0.566043  , 0.59311724, 0.6545093 , ..., 0.30493787,
#            0.30859476, 0.27837676],
#           [0.5720775 , 0.58068264, 0.6326221 , ..., 0.3074007 ,
#            0.31826603, 0.28362423]],
#
#          [[0.44032022, 0.32846272, 0.27843177, ..., 0.20607656,
#            0.20754921, 0.23159951],
#           [0.5932946 , 0.4400355 , 0.41283402, ..., 0.21269244,
#            0.19590807, 0.20477784],
#           [0.6576391 , 0.61296743, 0.5495226 , ..., 0.26351595,
#            0.24070883, 0.24391842],
#           ...,
#           [0.8416464 , 0.7804614 , 0.7176689 , ..., 0.20745748,
#            0.19683123, 0.18305326],
#           [0.76600313, 0.70242727, 0.63311094, ..., 0.20600492,
#            0.20316136, 0.18749917],
#           [0.7492351 , 0.6074891 , 0.4814969 , ..., 0.20228267,
#            0.2117855 , 0.20504546]]], dtype=float32),
#   'label': array([0, 0, 1, ..., 2, 1, 2])}}

# %%
with open('/content/drive/MyDrive/Projects/train_val_features_pkl/train_val_8_sec_non_audio_features.pkl', 'rb') as file:
  non_audio_df = pickle.load(file)

# %%
non_audio_df
# Out:
# {'train': {'type': array(['blank', 'blank', 'blank', ..., 'blank', 'blank', 'blank'],
#         dtype='<U5'),
#   'continent': array(['AFRICA', 'AFRICA', 'AFRICA', ..., 'EUROPE', 'EUROPE', 'EUROPE'],
#         dtype='<U8'),
#   'rating': array([5., 5., 5., ..., 5., 5., 5.]),
#   'label': array([0, 0, 0, ..., 2, 2, 2])},
#  'val': {'type': array(['song', 'call', 'call', ..., 'blank', 'call', 'call'], dtype='<U5'),
#   'continent': array(['EUROPE', 'EUROPE', 'EUROPE', ..., 'EUROPE', 'EUROPE', 'EUROPE'],
#         dtype='<U8'),
#   'rating': array([3.5, 5. , 4. , ..., 5. , 3. , 3. ]),
#   'label': array([0, 0, 1, ..., 2, 1, 2])}}

# %% [markdown]
# ## confirm the audio features and non_audio features labels line-up

# %%
assert np.array_equal(audio_df['train']['label'], non_audio_df['train']['label'])

# %%
assert np.array_equal(audio_df['val']['label'], non_audio_df['val']['label'])

# %% [markdown]
# # Shuffle the data

# %%
def shuffle_data(audio_features, non_audio_features):
  input_len = len(audio_features['label'])
  input_indices = np.random.permutation(input_len)
  audio_features = {key: np.array([audio_features[key][i] for i in input_indices]) for key in audio_features}
  non_audio_features = {key: np.array([non_audio_features[key][i] for i in input_indices]) for key in non_audio_features}

  return audio_features, non_audio_features

# %%
audio_df['train'], non_audio_df['train'] = shuffle_data(audio_df['train'], non_audio_df['train'])

# %%
for key in audio_df['train'].keys():
  display(key)
  display(audio_df['train'][key].shape)
  display(audio_df['train'][key][:5])
# Out:
# 'mfcc'
# (4763, 251, 20)
# array([[[0.65801406, 0.30454502, 0.15447173, ..., 0.53940505,
#          0.56144065, 0.44627655],
#         [0.65567535, 0.2367163 , 0.15425771, ..., 0.58707696,
#          0.65343255, 0.5164797 ],
#         [0.6546088 , 0.18453664, 0.2671458 , ..., 0.6321224 ,
#          0.7116646 , 0.43258667],
#         ...,
#         [0.5429963 , 0.36427605, 0.23842716, ..., 0.5332675 ,
#          0.64005697, 0.4695527 ],
#         [0.5646185 , 0.40917885, 0.23640153, ..., 0.4986272 ,
#          0.53706026, 0.4681934 ],
#         [0.58594143, 0.42143476, 0.30789834, ..., 0.47159818,
#          0.48207557, 0.46265122]],
#
#        [[0.59633076, 0.5720545 , 0.5294397 , ..., 0.56654894,
#          0.4272784 , 0.5210057 ],
#         [0.6107385 , 0.53545517, 0.49171975, ..., 0.5974833 ,
#          0.40567833, 0.6715434 ],
#         [0.5890178 , 0.530079  , 0.5274872 , ..., 0.61094457,
#          0.45476574, 0.700225  ],
#         ...,
#         [0.5900121 , 0.53099835, 0.6280938 , ..., 0.60409117,
#          0.532933  , 0.480812  ],
#         [0.57227534, 0.588887  , 0.60528326, ..., 0.48851588,
#          0.48085526, 0.45477626],
#         [0.5668231 , 0.5796737 , 0.5861391 , ..., 0.4702564 ,
#          0.47130603, 0.4447136 ]],
#
#        [[0.81756145, 0.37361634, 0.53289676, ..., 0.44836572,
#          0.59291524, 0.331828  ],
#         [0.79096496, 0.36744076, 0.525643  , ..., 0.52484405,
#          0.611046  , 0.4257312 ],
#         [0.7248851 , 0.38462815, 0.5723711 , ..., 0.58067465,
#          0.5985064 , 0.45179152],
#         ...,
#         [0.645748  , 0.47691512, 0.76977813, ..., 0.51366776,
#          0.482374  , 0.42851454],
#         [0.648461  , 0.48340595, 0.8274497 , ..., 0.4029561 ,
#          0.45559496, 0.43494874],
#         [0.65414345, 0.46441934, 0.8796599 , ..., 0.39796814,
#          0.53126776, 0.40654576]],
#
#        [[0.40160346, 0.58527505, 0.4919167 , ..., 0.3870298 ,
#          0.56723136, 0.54033583],
#         [0.37408298, 0.59184223, 0.44209117, ..., 0.51881534,
#          0.6157935 , 0.5405054 ],
#         [0.35743165, 0.56963634, 0.49039853, ..., 0.5606155 ,
#          0.6192865 , 0.45497924],
#         ...,
#         [0.3709976 , 0.5400203 , 0.5790112 , ..., 0.3664289 ,
#          0.66434443, 0.51017267],
#         [0.37736845, 0.5568748 , 0.57124615, ..., 0.30976963,
#          0.60355496, 0.4499686 ],
#         [0.38518178, 0.5327398 , 0.5822857 , ..., 0.3336208 ,
#          0.6314761 , 0.3913087 ]],
#
#        [[0.6959399 , 0.703936  , 0.71606314, ..., 0.45246026,
#          0.60854846, 0.4218776 ],
#         [0.6914437 , 0.67092884, 0.62238044, ..., 0.564383  ,
#          0.5143696 , 0.6283211 ],
#         [0.6570537 , 0.6361466 , 0.62763566, ..., 0.6119379 ,
#          0.3963546 , 0.7755008 ],
#         ...,
#         [0.6391041 , 0.7488819 , 0.6575781 , ..., 0.67263186,
#          0.45962986, 0.71266556],
#         [0.6449784 , 0.76748574, 0.68228143, ..., 0.5040313 ,
#          0.45945418, 0.666466  ],
#         [0.648587  , 0.7837618 , 0.72593796, ..., 0.3713694 ,
#          0.5430361 , 0.57769036]]], dtype=float32)
# 'chroma'
# (4763, 251, 12)
# array([[[0.53574646, 0.5759916 , 0.51694584, ..., 0.81473416,
#          0.8299389 , 0.5822287 ],
#         [0.5058398 , 0.28599   , 0.35711312, ..., 0.49030483,
#          0.7286645 , 1.        ],
#         [0.31582987, 0.05261482, 0.09178204, ..., 0.0618949 ,
#          0.21382564, 0.8221133 ],
#         ...,
#         [0.6663317 , 1.        , 0.84521556, ..., 0.49389786,
#          0.6221393 , 0.5969356 ],
#         [0.5276316 , 0.6550814 , 0.71248394, ..., 0.58170277,
#          0.50863326, 0.4984855 ],
#         [0.4673132 , 0.6842468 , 0.6276165 , ..., 0.99999994,
#          0.60119444, 0.41897902]],
#
#        [[0.4319583 , 0.5902217 , 0.62206   , ..., 1.        ,
#          0.6678938 , 0.5642952 ],
#         [0.18372096, 0.2640369 , 0.4726521 , ..., 0.79492754,
#          0.7975538 , 1.        ],
#         [0.15877841, 0.1608275 , 0.3100057 , ..., 0.3934352 ,
#          0.5353102 , 1.        ],
#         ...,
#         [0.19185157, 0.54431814, 0.17933203, ..., 0.35234976,
#          0.2373051 , 0.18360233],
#         [0.56819075, 1.        , 0.40616548, ..., 0.60966694,
#          0.45353433, 0.5079123 ],
#         [0.752687  , 0.9746325 , 0.42791533, ..., 0.7846828 ,
#          0.57430553, 0.64308816]],
#
#        [[1.        , 0.79350287, 0.19615075, ..., 0.36575717,
#          0.372762  , 0.37907785],
#         [1.        , 0.69994956, 0.2543891 , ..., 0.60425204,
#          0.673671  , 0.6625775 ],
#         [0.8947949 , 0.63474023, 0.48950666, ..., 0.6459656 ,
#          0.8143557 , 1.        ],
#         ...,
#         [0.11583228, 0.08568417, 0.10527686, ..., 0.775226  ,
#          0.4940939 , 0.11682068],
#         [0.10918577, 0.08501217, 0.08479272, ..., 0.8790054 ,
#          0.53981495, 0.12072081],
#         [0.13329144, 0.11135518, 0.08171181, ..., 0.95198095,
#          0.5560143 , 0.13060376]],
#
#        [[0.60733974, 0.97470707, 0.8690601 , ..., 0.5469439 ,
#          0.64881545, 0.45604452],
#         [0.75032645, 1.        , 0.8713434 , ..., 0.7549372 ,
#          0.7113745 , 0.6613103 ],
#         [1.0000001 , 0.77494615, 0.475008  , ..., 0.38540202,
#          0.36623913, 0.48122397],
#         ...,
#         [0.3548537 , 0.42296198, 0.634906  , ..., 0.26261002,
#          0.28653958, 0.32458588],
#         [0.5617639 , 0.59823483, 0.72912174, ..., 0.38780123,
#          0.38827252, 0.48188388],
#         [0.46252847, 0.56982917, 0.6559879 , ..., 0.30495045,
#          0.31688005, 0.34482238]],
#
#        [[0.5213524 , 0.84301555, 0.5502554 , ..., 0.15544564,
#          0.09788267, 0.13133214],
#         [0.12975606, 0.65582085, 1.        , ..., 0.06849783,
#          0.04673304, 0.04108561],
#         [0.04391203, 0.32441628, 1.        , ..., 0.11244112,
#          0.11267781, 0.03591058],
#         ...,
#         [0.09802564, 0.13887373, 0.3571346 , ..., 0.06770821,
#          0.06561854, 0.06254578],
#         [0.17025521, 0.10939565, 0.2401018 , ..., 0.08721817,
#          0.07047033, 0.06158345],
#         [0.19196424, 0.12200537, 0.22923158, ..., 0.08136185,
#          0.06837159, 0.0799776 ]]], dtype=float32)
# 'rms'
# (4763, 251, 1)
# array([[[0.02405255],
#         [0.06905805],
#         [0.06444735],
#         ...,
#         [0.00800606],
#         [0.00733086],
#         [0.00611762]],
#
#        [[0.01406326],
#         [0.01357893],
#         [0.01359574],
#         ...,
#         [0.00979076],
#         [0.00942418],
#         [0.00462093]],
#
#        [[0.08302804],
#         [0.08060986],
#         [0.07902281],
#         ...,
#         [0.03649953],
#         [0.03302358],
#         [0.02773506]],
#
#        [[0.00039206],
#         [0.00044237],
#         [0.00046586],
#         ...,
#         [0.0009529 ],
#         [0.00078891],
#         [0.00061423]],
#
#        [[0.03042172],
#         [0.02919069],
#         [0.02839939],
#         ...,
#         [0.03282039],
#         [0.0289601 ],
#         [0.02432014]]], dtype=float32)
# 'spectral_centroid'
# (4763, 251, 1)
# array([[[0.51728423],
#         [0.55229245],
#         [0.6251452 ],
#         ...,
#         [0.48095865],
#         [0.49159954],
#         [0.5037754 ]],
#
#        [[0.48020259],
#         [0.52891495],
#         [0.54681602],
#         ...,
#         [0.51830672],
#         [0.47236517],
#         [0.45329704]],
#
#        [[0.56749027],
#         [0.57192716],
#         [0.58810011],
#         ...,
#         [0.76126019],
#         [0.77589104],
#         [0.77722686]],
#
#        [[0.3660943 ],
#         [0.38457339],
#         [0.39394221],
#         ...,
#         [0.56537704],
#         [0.54675084],
#         [0.55177975]],
#
#        [[0.42183924],
#         [0.48253283],
#         [0.48528571],
#         ...,
#         [0.39747127],
#         [0.41820015],
#         [0.38269349]]])
# 'melspectrogram'
# (4763, 251, 20)
# array([[[0.3092834 , 0.2999977 , 0.30373305, ..., 0.593808  ,
#          0.5343547 , 0.5150068 ],
#         [0.2525062 , 0.19528109, 0.23895085, ..., 0.6346495 ,
#          0.6092308 , 0.5595565 ],
#         [0.22090667, 0.14126843, 0.2061882 , ..., 0.70372534,
#          0.7372516 , 0.7170108 ],
#         ...,
#         [0.23995173, 0.14163548, 0.1830582 , ..., 0.4754113 ,
#          0.4841199 , 0.47864434],
#         [0.32413533, 0.26717556, 0.26564306, ..., 0.47067857,
#          0.50122464, 0.48357952],
#         [0.40124682, 0.3402204 , 0.3356529 , ..., 0.46193388,
#          0.50741476, 0.48683754]],
#
#        [[0.5223609 , 0.5664195 , 0.5323534 , ..., 0.5131794 ,
#          0.38827667, 0.3570615 ],
#         [0.5164697 , 0.54080474, 0.53286475, ..., 0.5917649 ,
#          0.41307303, 0.3552091 ],
#         [0.51695585, 0.55448073, 0.5457535 , ..., 0.6165432 ,
#          0.4001633 , 0.36890006],
#         ...,
#         [0.5830865 , 0.5707951 , 0.56311154, ..., 0.5083113 ,
#          0.473872  , 0.46922222],
#         [0.56439936, 0.5523938 , 0.5377073 , ..., 0.45794278,
#          0.42415884, 0.39982015],
#         [0.5760524 , 0.5521413 , 0.49557316, ..., 0.436944  ,
#          0.40048194, 0.36513254]],
#
#        [[0.64404756, 0.59531856, 0.571669  , ..., 0.7300235 ,
#          0.6796469 , 0.6752533 ],
#         [0.6435346 , 0.57841486, 0.56447566, ..., 0.7241529 ,
#          0.6788527 , 0.6666859 ],
#         [0.6117329 , 0.5782498 , 0.55995905, ..., 0.7050448 ,
#          0.64528227, 0.6433356 ],
#         ...,
#         [0.68910015, 0.5801808 , 0.5790119 , ..., 0.63186854,
#          0.7036403 , 0.70644516],
#         [0.6563749 , 0.572236  , 0.5578195 , ..., 0.613195  ,
#          0.7182504 , 0.7151556 ],
#         [0.6733527 , 0.56641775, 0.53347045, ..., 0.60631347,
#          0.7155589 , 0.6993611 ]],
#
#        [[0.35181567, 0.35369575, 0.3341791 , ..., 0.23353595,
#          0.23542929, 0.26006985],
#         [0.34843743, 0.35155576, 0.33730674, ..., 0.21777087,
#          0.21899378, 0.2148915 ],
#         [0.35689375, 0.34558848, 0.35929936, ..., 0.21912414,
#          0.21740228, 0.21685421],
#         ...,
#         [0.37337136, 0.3319438 , 0.3413015 , ..., 0.37687027,
#          0.36462787, 0.26210845],
#         [0.35562333, 0.33644006, 0.34817672, ..., 0.3511553 ,
#          0.35685697, 0.27306032],
#         [0.35459965, 0.3175537 , 0.32226622, ..., 0.35308513,
#          0.36138117, 0.2774567 ]],
#
#        [[0.75222695, 0.69503546, 0.6724447 , ..., 0.6667806 ,
#          0.586451  , 0.41737297],
#         [0.717642  , 0.6855159 , 0.6777945 , ..., 0.6717394 ,
#          0.59753424, 0.4282888 ],
#         [0.6889982 , 0.698385  , 0.671384  , ..., 0.6701511 ,
#          0.52023053, 0.4813516 ],
#         ...,
#         [0.7744591 , 0.7328421 , 0.7279213 , ..., 0.66622204,
#          0.45637497, 0.35281432],
#         [0.7430308 , 0.7276113 , 0.7293667 , ..., 0.6667629 ,
#          0.60160583, 0.37125134],
#         [0.7366742 , 0.7089617 , 0.7069419 , ..., 0.66704756,
#          0.64603317, 0.37340757]]], dtype=float32)
# 'label'
# (4763,)
# array([0, 0, 0, 2, 1])

# %%
for key in non_audio_df['train'].keys():
  display(key)
  display(non_audio_df['train'][key].shape)
  display(non_audio_df['train'][key][:5])
# Out:
# 'type'
# (4763,)
# array(['song', 'call', 'song', 'call', 'call'], dtype='<U5')
# 'continent'
# (4763,)
# array(['ASIA', 'EUROPE', 'ASIA', 'EUROPE', 'EUROPE'], dtype='<U8')
# 'rating'
# (4763,)
# array([4.5, 4. , 5. , 4.5, 5. ])
# 'label'
# (4763,)
# array([0, 0, 0, 2, 1])

# %%
audio_df['val'], non_audio_df['val'] = shuffle_data(audio_df['val'], non_audio_df['val'])

# %%
for key in audio_df['val'].keys():
  display(key)
  display(audio_df['val'][key].shape)
  display(audio_df['val'][key][:5])
# Out:
# 'mfcc'
# (2430, 251, 20)
# array([[[0.76217157, 0.6695413 , 0.278619  , ..., 0.49040303,
#          0.5270129 , 0.51067555],
#         [0.7671336 , 0.668718  , 0.28723705, ..., 0.609558  ,
#          0.5344007 , 0.5439447 ],
#         [0.74301994, 0.65569353, 0.35762066, ..., 0.647117  ,
#          0.6044686 , 0.5542205 ],
#         ...,
#         [0.72211796, 0.65433687, 0.40947178, ..., 0.5008572 ,
#          0.5623615 , 0.44762215],
#         [0.730139  , 0.6677108 , 0.3800479 , ..., 0.38962048,
#          0.5107573 , 0.44236475],
#         [0.74024737, 0.6356216 , 0.3894961 , ..., 0.30543822,
#          0.5431053 , 0.46551248]],
#
#        [[0.5969536 , 0.84857106, 0.6516876 , ..., 0.47090313,
#          0.5157508 , 0.49178737],
#         [0.62777185, 0.82720447, 0.577616  , ..., 0.57290626,
#          0.58825094, 0.6013949 ],
#         [0.61267114, 0.77860564, 0.60238206, ..., 0.6236166 ,
#          0.63125247, 0.57371086],
#         ...,
#         [0.5900388 , 0.8060298 , 0.655803  , ..., 0.46981475,
#          0.67024815, 0.5141665 ],
#         [0.5983598 , 0.8241956 , 0.66786015, ..., 0.40422374,
#          0.584419  , 0.45211616],
#         [0.6090753 , 0.821693  , 0.7025382 , ..., 0.37090394,
#          0.5894054 , 0.49668765]],
#
#        [[0.81703436, 0.7952415 , 0.37621582, ..., 0.550398  ,
#          0.50719327, 0.5164222 ],
#         [0.8104198 , 0.7809225 , 0.34626502, ..., 0.6008118 ,
#          0.52136654, 0.563933  ],
#         [0.77024245, 0.733817  , 0.39676234, ..., 0.62374526,
#          0.57128966, 0.56146383],
#         ...,
#         [0.7719075 , 0.76500005, 0.43286198, ..., 0.45671925,
#          0.56385094, 0.5693354 ],
#         [0.7869968 , 0.7877427 , 0.4210088 , ..., 0.41902375,
#          0.54789346, 0.50410396],
#         [0.79917705, 0.7684492 , 0.44774514, ..., 0.49042225,
#          0.62926996, 0.4240335 ]],
#
#        [[0.6593634 , 0.7742523 , 0.53892297, ..., 0.53616107,
#          0.62782466, 0.40082815],
#         [0.636976  , 0.7624655 , 0.4888817 , ..., 0.63318163,
#          0.6483998 , 0.49466065],
#         [0.6179105 , 0.698679  , 0.5400045 , ..., 0.70586747,
#          0.6500165 , 0.52637225],
#         ...,
#         [0.5811713 , 0.7485398 , 0.5652208 , ..., 0.5222801 ,
#          0.58349   , 0.47819263],
#         [0.5785531 , 0.76251763, 0.56354   , ..., 0.4907323 ,
#          0.5425128 , 0.42076954],
#         [0.58355564, 0.7543614 , 0.57656926, ..., 0.5501656 ,
#          0.6471148 , 0.38287768]],
#
#        [[0.48725867, 0.40229434, 0.3373847 , ..., 0.5004635 ,
#          0.39036703, 0.56890357],
#         [0.47652513, 0.38065958, 0.30472493, ..., 0.56764853,
#          0.53055656, 0.57680017],
#         [0.45440942, 0.36465618, 0.34978616, ..., 0.64458156,
#          0.5906387 , 0.5868214 ],
#         ...,
#         [0.42454374, 0.4360734 , 0.33434337, ..., 0.502598  ,
#          0.6243854 , 0.44454306],
#         [0.4360603 , 0.44534582, 0.28827885, ..., 0.44379017,
#          0.60097325, 0.37021136],
#         [0.4472167 , 0.42765975, 0.324788  , ..., 0.529247  ,
#          0.66008043, 0.35749203]]], dtype=float32)
# 'chroma'
# (2430, 251, 12)
# array([[[0.5429144 , 0.42151076, 0.31869984, ..., 0.55475223,
#          0.68755865, 0.58727556],
#         [1.        , 0.6024036 , 0.5524962 , ..., 0.7006321 ,
#          0.62659997, 0.62141794],
#         [1.0000001 , 0.69508344, 0.6938348 , ..., 0.5832805 ,
#          0.68048286, 0.7751779 ],
#         ...,
#         [0.2035434 , 0.24755801, 0.15481901, ..., 0.3040002 ,
#          0.29964885, 0.2621412 ],
#         [0.21155638, 0.19774517, 0.14985012, ..., 0.29765144,
#          0.29758364, 0.21672794],
#         [0.21109356, 0.15461819, 0.14889532, ..., 0.31567076,
#          0.320029  , 0.25781316]],
#
#        [[0.39168113, 0.34648025, 0.6394862 , ..., 0.43910035,
#          0.45826703, 0.45553327],
#         [0.48030093, 0.32385972, 0.5610308 , ..., 1.        ,
#          0.87226516, 0.6312139 ],
#         [0.46189344, 0.32693374, 0.3632646 , ..., 1.        ,
#          0.8507927 , 0.6297785 ],
#         ...,
#         [0.6576209 , 1.        , 0.98932475, ..., 0.37118325,
#          0.44254598, 0.52739656],
#         [0.59774584, 0.9415595 , 0.95965606, ..., 0.33597812,
#          0.39958447, 0.44228715],
#         [0.6864159 , 0.8621069 , 0.7940094 , ..., 0.5189252 ,
#          0.6102021 , 0.5886885 ]],
#
#        [[0.51701874, 0.6189671 , 0.7402831 , ..., 0.56550974,
#          0.8653182 , 0.6312016 ],
#         [0.6813169 , 0.8060522 , 0.7392281 , ..., 0.8776134 ,
#          0.834781  , 0.594837  ],
#         [0.7963199 , 0.77351785, 0.7723478 , ..., 0.91497195,
#          0.94016737, 0.63702196],
#         ...,
#         [0.7759226 , 0.7352285 , 0.74998856, ..., 0.6422979 ,
#          0.76076037, 1.        ],
#         [0.6083086 , 0.50235707, 0.7732682 , ..., 0.7188803 ,
#          0.6740944 , 0.71046233],
#         [0.51164335, 0.38384733, 0.62825614, ..., 0.5719978 ,
#          0.5183494 , 0.4004147 ]],
#
#        [[0.8548243 , 0.7088692 , 0.6730282 , ..., 0.98959386,
#          0.904106  , 0.8775582 ],
#         [0.94308424, 0.8822045 , 0.8563903 , ..., 0.94105685,
#          0.9221571 , 1.        ],
#         [0.8417851 , 0.78516513, 0.7381603 , ..., 0.70170695,
#          0.78075826, 0.8623053 ],
#         ...,
#         [0.88749856, 1.        , 0.8962512 , ..., 0.6003835 ,
#          0.6664063 , 0.78599626],
#         [0.98452145, 1.        , 0.87602997, ..., 0.58696127,
#          0.5945803 , 0.7625651 ],
#         [0.34300682, 0.39629436, 0.4039652 , ..., 0.53770316,
#          0.35574117, 0.28179443]],
#
#        [[0.8074261 , 0.48821107, 0.2628184 , ..., 0.29522866,
#          0.1900236 , 0.2679185 ],
#         [0.40722027, 0.2349639 , 0.2150878 , ..., 0.24584319,
#          0.17576401, 0.23342256],
#         [0.28590688, 0.14974914, 0.3628875 , ..., 0.19624978,
#          0.14689021, 0.22061676],
#         ...,
#         [0.6343168 , 0.60369307, 0.7016693 , ..., 0.70910454,
#          0.5714551 , 0.530943  ],
#         [0.60833263, 0.6326907 , 0.5232669 , ..., 0.55018353,
#          0.53808206, 0.4388034 ],
#         [0.70413995, 0.83458716, 0.59089535, ..., 0.5610126 ,
#          0.4942709 , 0.39201918]]], dtype=float32)
# 'rms'
# (2430, 251, 1)
# array([[[0.02067537],
#         [0.02339096],
#         [0.02502191],
#         ...,
#         [0.03236409],
#         [0.02915685],
#         [0.02442949]],
#
#        [[0.03091602],
#         [0.03335642],
#         [0.03362567],
#         ...,
#         [0.02173752],
#         [0.02023076],
#         [0.01472988]],
#
#        [[0.03617457],
#         [0.03926725],
#         [0.04080156],
#         ...,
#         [0.04960059],
#         [0.04648542],
#         [0.0395495 ]],
#
#        [[0.05610066],
#         [0.05984495],
#         [0.0569543 ],
#         ...,
#         [0.0282848 ],
#         [0.02415594],
#         [0.02227114]],
#
#        [[0.00301301],
#         [0.00346294],
#         [0.00377222],
#         ...,
#         [0.00178348],
#         [0.00168852],
#         [0.00142587]]], dtype=float32)
# 'spectral_centroid'
# (2430, 251, 1)
# array([[[0.30348429],
#         [0.29903925],
#         [0.3000155 ],
#         ...,
#         [0.33903516],
#         [0.34518194],
#         [0.36802432]],
#
#        [[0.09303037],
#         [0.10476277],
#         [0.12347893],
#         ...,
#         [0.1296336 ],
#         [0.13985378],
#         [0.13118556]],
#
#        [[0.20594163],
#         [0.21095852],
#         [0.22982148],
#         ...,
#         [0.21005532],
#         [0.20496274],
#         [0.21354251]],
#
#        [[0.11906206],
#         [0.09795518],
#         [0.14688691],
#         ...,
#         [0.13266195],
#         [0.12999983],
#         [0.13054655]],
#
#        [[0.61435831],
#         [0.62559032],
#         [0.65037709],
#         ...,
#         [0.50816179],
#         [0.51429104],
#         [0.52374904]]])
# 'melspectrogram'
# (2430, 251, 20)
# array([[[0.5835182 , 0.62555575, 0.64228815, ..., 0.48561683,
#          0.46686992, 0.45553976],
#         [0.59014475, 0.6219088 , 0.665331  , ..., 0.49336615,
#          0.4677983 , 0.44844177],
#         [0.60244375, 0.64463985, 0.6832824 , ..., 0.5068605 ,
#          0.46743023, 0.4487776 ],
#         ...,
#         [0.6556926 , 0.6111552 , 0.6765348 , ..., 0.6861459 ,
#          0.58308005, 0.42413098],
#         [0.6296552 , 0.61262965, 0.6903441 , ..., 0.6709765 ,
#          0.59496033, 0.43546087],
#         [0.61801666, 0.5932814 , 0.6791457 , ..., 0.66883856,
#          0.5923271 , 0.45120394]],
#
#        [[0.7346395 , 0.7212382 , 0.6525172 , ..., 0.33783075,
#          0.3260932 , 0.35801953],
#         [0.7534403 , 0.7252271 , 0.68739724, ..., 0.36110666,
#          0.35254958, 0.36585546],
#         [0.75140464, 0.6947311 , 0.66978735, ..., 0.3746803 ,
#          0.36597538, 0.38172135],
#         ...,
#         [0.788037  , 0.70992357, 0.6864386 , ..., 0.34455085,
#          0.35303506, 0.33906415],
#         [0.7550412 , 0.69428575, 0.67327464, ..., 0.33982491,
#          0.3732311 , 0.35134822],
#         [0.75542897, 0.6826005 , 0.6623307 , ..., 0.349137  ,
#          0.37979567, 0.3615216 ]],
#
#        [[0.7318816 , 0.7946733 , 0.772067  , ..., 0.49152848,
#          0.42396304, 0.42801312],
#         [0.722318  , 0.78737813, 0.77574056, ..., 0.49107674,
#          0.42528403, 0.40416747],
#         [0.71008515, 0.7847532 , 0.75006855, ..., 0.5050428 ,
#          0.42443147, 0.41509864],
#         ...,
#         [0.79584813, 0.81055605, 0.7903453 , ..., 0.49816862,
#          0.42580736, 0.39142618],
#         [0.7890154 , 0.80417037, 0.7863394 , ..., 0.49126485,
#          0.45061636, 0.41309464],
#         [0.77649564, 0.7700554 , 0.755383  , ..., 0.48952916,
#          0.4821972 , 0.4484626 ]],
#
#        [[0.7392231 , 0.6422466 , 0.6079293 , ..., 0.37939444,
#          0.37658113, 0.3968308 ],
#         [0.7409156 , 0.6053752 , 0.6098038 , ..., 0.36400405,
#          0.34972587, 0.3519732 ],
#         [0.73898655, 0.59478384, 0.6011948 , ..., 0.42413607,
#          0.36972687, 0.37372085],
#         ...,
#         [0.77116525, 0.5962417 , 0.5933079 , ..., 0.36269295,
#          0.33811316, 0.32789484],
#         [0.7486863 , 0.5856428 , 0.5709834 , ..., 0.34362918,
#          0.3443096 , 0.3228944 ],
#         [0.7409475 , 0.56749666, 0.5372305 , ..., 0.34495863,
#          0.3534636 , 0.32677436]],
#
#        [[0.25106102, 0.23084915, 0.32608283, ..., 0.43059185,
#          0.4521833 , 0.4946607 ],
#         [0.21344292, 0.20356244, 0.32124257, ..., 0.46498847,
#          0.48069468, 0.49529052],
#         [0.20194858, 0.2176528 , 0.29898512, ..., 0.4984129 ,
#          0.49598062, 0.5163927 ],
#         ...,
#         [0.18027419, 0.2226494 , 0.3226735 , ..., 0.36364716,
#          0.38055226, 0.36291286],
#         [0.1749013 , 0.21497929, 0.33727294, ..., 0.3590128 ,
#          0.39562005, 0.3718864 ],
#         [0.22796875, 0.22086382, 0.30630225, ..., 0.36106613,
#          0.3959467 , 0.36798814]]], dtype=float32)
# 'label'
# (2430,)
# array([1, 2, 1, 0, 2])

# %%
for key in non_audio_df['val'].keys():
  display(key)
  display(non_audio_df['val'][key].shape)
  display(non_audio_df['val'][key][:5])
# Out:
# 'type'
# (2430,)
# array(['blank', 'call', 'call', 'call', 'call'], dtype='<U5')
# 'continent'
# (2430,)
# array(['EUROPE', 'EUROPE', 'EUROPE', 'EUROPE', 'EUROPE'], dtype='<U8')
# 'rating'
# (2430,)
# array([5. , 4. , 4. , 4. , 3.5])
# 'label'
# (2430,)
# array([1, 2, 1, 0, 2])

# %% [markdown]
# # Create sample weights based on rating

# %%
training_sample_weights = non_audio_df['train']['rating']

training_sample_weights
# Out:
# array([4.5, 4. , 5. , ..., 4.5, 4. , 3. ])

# %%
validation_sample_weights = non_audio_df['val']['rating']

validation_sample_weights
# Out:
# array([5., 4., 4., ..., 4., 3., 5.])

# %%
training_sample_weights = np.where(training_sample_weights > 3.0, 0.6, 0.4)

training_sample_weights
# Out:
# array([0.6, 0.6, 0.6, ..., 0.6, 0.6, 0.4])

# %%
validation_sample_weights = np.where(validation_sample_weights > 3.0, 0.6, 0.4)

validation_sample_weights
# Out:
# array([0.6, 0.6, 0.6, ..., 0.6, 0.4, 0.6])

# %% [markdown]
# # 2D CNN Models

# %%
train_results = {}
val_results = {}

# %%
classes = ['barswa', 'comsan', 'eaywag1']

# %% [markdown]
# ## Create 2D CNN model function

# %%
np.unique(non_audio_df['train']['continent'])
# Out:
# array(['AFRICA', 'AMERICAS', 'ASIA', 'EUROPE', 'UNKNOWN'], dtype='<U8')

# %%
def build_model(audio_features,
                continent_feature,
                learning_rate=0.001):

  tf.keras.backend.clear_session()

  # set audio features input layer
  audio_features = tf.keras.layers.Input(shape=(audio_features.shape[1],audio_features.shape[2],audio_features.shape[3]), name='Audio_Features')

  # set continent features input layer
  location = tf.keras.layers.Input(shape=(1,), dtype=tf.string, name='Continents')
  location_binned = tf.keras.layers.StringLookup(vocabulary=np.unique(continent_feature))(location)
  location_embed = tf.keras.layers.Embedding(input_dim=(len(np.unique(continent_feature))+1), output_dim=2, input_length=1)(location_binned)

  # custom function to tile the 'Location' embeddings to match the time and n_feature steps of audio features
  def tile_location_embed(x):
      x = tf.keras.backend.tile(x, [1, audio_features.shape[1], 1])
      x = tf.keras.backend.tile(x, [1, 1, 10])
      return tf.expand_dims(x, axis=-1)

  # using the Lambda layer with the custom function
  location_embed = tf.keras.layers.Lambda(tile_location_embed, name='Tile')(location_embed)

  # create features using both continents with embeddings and mfccs
  features = tf.keras.layers.Concatenate(axis=-1, name='Features')([location_embed, audio_features])

  # add first convolution layer to the model
  features = tf.keras.layers.Conv2D(
              filters=64,
              kernel_size=(5,5),
              strides=(1,1),
              padding='same',
              data_format='channels_last',
              name='conv_1',
              activation='relu',
              kernel_regularizer=tf.keras.regularizers.l2(0.02))(features)

  # add first max pooling layer
  features = tf.keras.layers.MaxPool2D(pool_size=(2,2), name='pool_1')(features)

  # add second convolution layer to the model
  features = tf.keras.layers.Conv2D(
              filters=32,
              kernel_size=(5,5),
              strides=(1,1),
              padding='same',
              name='conv_2',
              activation='relu',
              kernel_regularizer=tf.keras.regularizers.l2(0.02))(features)

  # add second max pooling layer
  features = tf.keras.layers.MaxPool2D(pool_size=(2,2), name='pool_2')(features)

  # add third convolution layer to the model
  features = tf.keras.layers.Conv2D(
              filters=32,
              kernel_size=(5,5),
              strides=(1,1),
              padding='same',
              name='conv_3',
              activation='relu',
              kernel_regularizer=tf.keras.regularizers.l2(0.02))(features)

  # add second max pooling layer
  features = tf.keras.layers.MaxPool2D(pool_size=(2,2), name='pool_3')(features)

  # add a fully connected layer (need to flatten the output of the previous layers first)
  features = tf.keras.layers.Flatten()(features)

  features = tf.keras.layers.Dense(
      units=1024,
      name='fc_1',
      activation='relu')(features)

  # add dropout layer
  features = tf.keras.layers.Dropout(rate=0.5)(features)

  # add the last fully connected layer
  # this last layer sets the activation function to "None" in order to output the logits
  # note that passing activation = "softmax" will return class memembership probabilities but
  # in TensorFlow logits are prefered for numerical stability
  # set units=3 to get a 3 output unit (remember it's 3 species)
  outputs = tf.keras.layers.Dense(
      units=3,
      name='fc_2',
      activation=None)(features)

  # build model and print summary
  model = tf.keras.Model(inputs=[location, audio_features],
                          outputs=outputs,
                          name='Birds')

  print(model.summary())

  # compile model
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), #set from_logits=True because our last layer does not apply softmax
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

  return model

# %%
def visualize(model_history, best_epoch):
  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
  # visualize the loss
  axes[0].plot(model_history.history['loss'][:best_epoch+1], color='purple', label='train_losses')
  axes[0].plot(model_history.history['val_loss'][:best_epoch+1], color='orange', label='val_losses')
  axes[0].set_xlabel('Epoch')
  axes[0].set_ylabel('Loss')
  axes[0].set_title('Loss Progression')
  axes[0].legend()

  # visualze the accuracy
  axes[1].plot(model_history.history['accuracy'][:best_epoch+1], color='purple', label='train_accuracy')
  axes[1].plot(model_history.history['val_accuracy'][:best_epoch+1], color='orange', label='val_accuracy')
  axes[1].set_xlabel('Epoch')
  axes[1].set_ylabel('Accuracy')
  axes[1].set_title('Accuracy Progression')
  axes[1].legend()

  plt.show()

# %% [markdown]
# ## With mfcc & rms & spectral_centroid & continents

# %% [markdown]
# ### create features

# %%
training_audio_features = np.stack((audio_df['train']['mfcc'], np.tile(audio_df['train']['rms'], (1,1,20)), np.tile(audio_df['train']['spectral_centroid'], (1,1,20))), axis=-1)

training_audio_features
# Out:
# array([[[[0.65801406, 0.02405255, 0.51728423],
#          [0.30454502, 0.02405255, 0.51728423],
#          [0.15447173, 0.02405255, 0.51728423],
#          ...,
#          [0.53940505, 0.02405255, 0.51728423],
#          [0.56144065, 0.02405255, 0.51728423],
#          [0.44627655, 0.02405255, 0.51728423]],
#
#         [[0.65567535, 0.06905805, 0.55229245],
#          [0.2367163 , 0.06905805, 0.55229245],
#          [0.15425771, 0.06905805, 0.55229245],
#          ...,
#          [0.58707696, 0.06905805, 0.55229245],
#          [0.65343255, 0.06905805, 0.55229245],
#          [0.51647967, 0.06905805, 0.55229245]],
#
#         [[0.65460879, 0.06444735, 0.6251452 ],
#          [0.18453664, 0.06444735, 0.6251452 ],
#          [0.26714581, 0.06444735, 0.6251452 ],
#          ...,
#          [0.6321224 , 0.06444735, 0.6251452 ],
#          [0.71166462, 0.06444735, 0.6251452 ],
#          [0.43258667, 0.06444735, 0.6251452 ]],
#
#         ...,
#
#         [[0.54299629, 0.00800606, 0.48095865],
#          [0.36427605, 0.00800606, 0.48095865],
#          [0.23842716, 0.00800606, 0.48095865],
#          ...,
#          [0.5332675 , 0.00800606, 0.48095865],
#          [0.64005697, 0.00800606, 0.48095865],
#          [0.4695527 , 0.00800606, 0.48095865]],
#
#         [[0.56461853, 0.00733086, 0.49159954],
#          [0.40917885, 0.00733086, 0.49159954],
#          [0.23640153, 0.00733086, 0.49159954],
#          ...,
#          [0.49862719, 0.00733086, 0.49159954],
#          [0.53706026, 0.00733086, 0.49159954],
#          [0.46819341, 0.00733086, 0.49159954]],
#
#         [[0.58594143, 0.00611762, 0.5037754 ],
#          [0.42143476, 0.00611762, 0.5037754 ],
#          [0.30789834, 0.00611762, 0.5037754 ],
#          ...,
#          [0.47159818, 0.00611762, 0.5037754 ],
#          [0.48207557, 0.00611762, 0.5037754 ],
#          [0.46265122, 0.00611762, 0.5037754 ]]],
#
#
#        [[[0.59633076, 0.01406326, 0.48020259],
#          [0.57205451, 0.01406326, 0.48020259],
#          [0.52943969, 0.01406326, 0.48020259],
#          ...,
#          [0.56654894, 0.01406326, 0.48020259],
#          [0.4272784 , 0.01406326, 0.48020259],
#          [0.52100569, 0.01406326, 0.48020259]],
#
#         [[0.61073852, 0.01357893, 0.52891495],
#          [0.53545517, 0.01357893, 0.52891495],
#          [0.49171975, 0.01357893, 0.52891495],
#          ...,
#          [0.59748328, 0.01357893, 0.52891495],
#          [0.40567833, 0.01357893, 0.52891495],
#          [0.67154342, 0.01357893, 0.52891495]],
#
#         [[0.58901781, 0.01359574, 0.54681602],
#          [0.53007901, 0.01359574, 0.54681602],
#          [0.52748722, 0.01359574, 0.54681602],
#          ...,
#          [0.61094457, 0.01359574, 0.54681602],
#          [0.45476574, 0.01359574, 0.54681602],
#          [0.700225  , 0.01359574, 0.54681602]],
#
#         ...,
#
#         [[0.59001207, 0.00979076, 0.51830672],
#          [0.53099835, 0.00979076, 0.51830672],
#          [0.62809378, 0.00979076, 0.51830672],
#          ...,
#          [0.60409117, 0.00979076, 0.51830672],
#          [0.532933  , 0.00979076, 0.51830672],
#          [0.48081201, 0.00979076, 0.51830672]],
#
#         [[0.57227534, 0.00942418, 0.47236517],
#          [0.58888698, 0.00942418, 0.47236517],
#          [0.60528326, 0.00942418, 0.47236517],
#          ...,
#          [0.48851588, 0.00942418, 0.47236517],
#          [0.48085526, 0.00942418, 0.47236517],
#          [0.45477626, 0.00942418, 0.47236517]],
#
#         [[0.56682312, 0.00462093, 0.45329704],
#          [0.57967371, 0.00462093, 0.45329704],
#          [0.58613908, 0.00462093, 0.45329704],
#          ...,
#          [0.47025639, 0.00462093, 0.45329704],
#          [0.47130603, 0.00462093, 0.45329704],
#          [0.44471359, 0.00462093, 0.45329704]]],
#
#
#        [[[0.81756145, 0.08302804, 0.56749027],
#          [0.37361634, 0.08302804, 0.56749027],
#          [0.53289676, 0.08302804, 0.56749027],
#          ...,
#          [0.44836572, 0.08302804, 0.56749027],
#          [0.59291524, 0.08302804, 0.56749027],
#          [0.331828  , 0.08302804, 0.56749027]],
#
#         [[0.79096496, 0.08060986, 0.57192716],
#          [0.36744076, 0.08060986, 0.57192716],
#          [0.52564299, 0.08060986, 0.57192716],
#          ...,
#          [0.52484405, 0.08060986, 0.57192716],
#          [0.61104602, 0.08060986, 0.57192716],
#          [0.42573121, 0.08060986, 0.57192716]],
#
#         [[0.72488511, 0.07902281, 0.58810011],
#          [0.38462815, 0.07902281, 0.58810011],
#          [0.57237113, 0.07902281, 0.58810011],
#          ...,
#          [0.58067465, 0.07902281, 0.58810011],
#          [0.59850639, 0.07902281, 0.58810011],
#          [0.45179152, 0.07902281, 0.58810011]],
#
#         ...,
#
#         [[0.64574802, 0.03649953, 0.76126019],
#          [0.47691512, 0.03649953, 0.76126019],
#          [0.76977813, 0.03649953, 0.76126019],
#          ...,
#          [0.51366776, 0.03649953, 0.76126019],
#          [0.48237401, 0.03649953, 0.76126019],
#          [0.42851454, 0.03649953, 0.76126019]],
#
#         [[0.64846098, 0.03302358, 0.77589104],
#          [0.48340595, 0.03302358, 0.77589104],
#          [0.82744968, 0.03302358, 0.77589104],
#          ...,
#          [0.4029561 , 0.03302358, 0.77589104],
#          [0.45559496, 0.03302358, 0.77589104],
#          [0.43494874, 0.03302358, 0.77589104]],
#
#         [[0.65414345, 0.02773506, 0.77722686],
#          [0.46441934, 0.02773506, 0.77722686],
#          [0.87965989, 0.02773506, 0.77722686],
#          ...,
#          [0.39796814, 0.02773506, 0.77722686],
#          [0.53126776, 0.02773506, 0.77722686],
#          [0.40654576, 0.02773506, 0.77722686]]],
#
#
#        ...,
#
#
#        [[[0.76366234, 0.01519289, 0.38070505],
#          [0.63034093, 0.01519289, 0.38070505],
#          [0.4317371 , 0.01519289, 0.38070505],
#          ...,
#          [0.49666375, 0.01519289, 0.38070505],
#          [0.48389605, 0.01519289, 0.38070505],
#          [0.34512228, 0.01519289, 0.38070505]],
#
#         [[0.76027906, 0.01639944, 0.38658934],
#          [0.62477028, 0.01639944, 0.38658934],
#          [0.41996178, 0.01639944, 0.38658934],
#          ...,
#          [0.5653438 , 0.01639944, 0.38658934],
#          [0.56318694, 0.01639944, 0.38658934],
#          [0.45108357, 0.01639944, 0.38658934]],
#
#         [[0.72395241, 0.01774238, 0.40400072],
#          [0.59399277, 0.01774238, 0.40400072],
#          [0.46796337, 0.01774238, 0.40400072],
#          ...,
#          [0.55048209, 0.01774238, 0.40400072],
#          [0.59015304, 0.01774238, 0.40400072],
#          [0.49667615, 0.01774238, 0.40400072]],
#
#         ...,
#
#         [[0.70979142, 0.01695695, 0.3489655 ],
#          [0.64219546, 0.01695695, 0.3489655 ],
#          [0.51775777, 0.01695695, 0.3489655 ],
#          ...,
#          [0.46709108, 0.01695695, 0.3489655 ],
#          [0.56199455, 0.01695695, 0.3489655 ],
#          [0.41455355, 0.01695695, 0.3489655 ]],
#
#         [[0.71034694, 0.01547197, 0.36554945],
#          [0.64701748, 0.01547197, 0.36554945],
#          [0.50044113, 0.01547197, 0.36554945],
#          ...,
#          [0.39233097, 0.01547197, 0.36554945],
#          [0.49755681, 0.01547197, 0.36554945],
#          [0.40911818, 0.01547197, 0.36554945]],
#
#         [[0.71129358, 0.01262308, 0.35486302],
#          [0.63959283, 0.01262308, 0.35486302],
#          [0.51498538, 0.01262308, 0.35486302],
#          ...,
#          [0.36775509, 0.01262308, 0.35486302],
#          [0.45485806, 0.01262308, 0.35486302],
#          [0.3513585 , 0.01262308, 0.35486302]]],
#
#
#        [[[0.61509514, 0.01124181, 0.29882804],
#          [0.66126144, 0.01124181, 0.29882804],
#          [0.6230191 , 0.01124181, 0.29882804],
#          ...,
#          [0.49476188, 0.01124181, 0.29882804],
#          [0.53578573, 0.01124181, 0.29882804],
#          [0.46104205, 0.01124181, 0.29882804]],
#
#         [[0.61127949, 0.01258457, 0.30527799],
#          [0.65741128, 0.01258457, 0.30527799],
#          [0.55180627, 0.01258457, 0.30527799],
#          ...,
#          [0.60734671, 0.01258457, 0.30527799],
#          [0.61751163, 0.01258457, 0.30527799],
#          [0.55316556, 0.01258457, 0.30527799]],
#
#         [[0.58872867, 0.01271828, 0.30428461],
#          [0.63680542, 0.01271828, 0.30428461],
#          [0.58112121, 0.01271828, 0.30428461],
#          ...,
#          [0.62802404, 0.01271828, 0.30428461],
#          [0.63416988, 0.01271828, 0.30428461],
#          [0.51272452, 0.01271828, 0.30428461]],
#
#         ...,
#
#         [[0.61415756, 0.0214742 , 0.45656628],
#          [0.61811727, 0.0214742 , 0.45656628],
#          [0.63903612, 0.0214742 , 0.45656628],
#          ...,
#          [0.42846951, 0.0214742 , 0.45656628],
#          [0.55955255, 0.0214742 , 0.45656628],
#          [0.40734944, 0.0214742 , 0.45656628]],
#
#         [[0.6054318 , 0.01382834, 0.32986864],
#          [0.67899913, 0.01382834, 0.32986864],
#          [0.60314959, 0.01382834, 0.32986864],
#          ...,
#          [0.39817587, 0.01382834, 0.32986864],
#          [0.5153718 , 0.01382834, 0.32986864],
#          [0.46142024, 0.01382834, 0.32986864]],
#
#         [[0.59798467, 0.00736052, 0.30679931],
#          [0.6789465 , 0.00736052, 0.30679931],
#          [0.63821423, 0.00736052, 0.30679931],
#          ...,
#          [0.46924695, 0.00736052, 0.30679931],
#          [0.53052759, 0.00736052, 0.30679931],
#          [0.50899827, 0.00736052, 0.30679931]]],
#
#
#        [[[0.78787345, 0.02678716, 0.37583299],
#          [0.64318591, 0.02678716, 0.37583299],
#          [0.55419022, 0.02678716, 0.37583299],
#          ...,
#          [0.45115301, 0.02678716, 0.37583299],
#          [0.56302476, 0.02678716, 0.37583299],
#          [0.48208189, 0.02678716, 0.37583299]],
#
#         [[0.77945399, 0.02975959, 0.37743289],
#          [0.62656635, 0.02975959, 0.37743289],
#          [0.50775397, 0.02975959, 0.37743289],
#          ...,
#          [0.54490769, 0.02975959, 0.37743289],
#          [0.60251433, 0.02975959, 0.37743289],
#          [0.52824676, 0.02975959, 0.37743289]],
#
#         [[0.74111754, 0.03434859, 0.39220519],
#          [0.60103011, 0.03434859, 0.39220519],
#          [0.54006469, 0.03434859, 0.39220519],
#          ...,
#          [0.54268813, 0.03434859, 0.39220519],
#          [0.61692101, 0.03434859, 0.39220519],
#          [0.60910183, 0.03434859, 0.39220519]],
#
#         ...,
#
#         [[0.74654496, 0.03880184, 0.38424977],
#          [0.64404082, 0.03880184, 0.38424977],
#          [0.63725692, 0.03880184, 0.38424977],
#          ...,
#          [0.52422082, 0.03880184, 0.38424977],
#          [0.65934628, 0.03880184, 0.38424977],
#          [0.51611292, 0.03880184, 0.38424977]],
#
#         [[0.75742674, 0.03607986, 0.39962073],
#          [0.65115774, 0.03607986, 0.39962073],
#          [0.66333991, 0.03607986, 0.39962073],
#          ...,
#          [0.44177338, 0.03607986, 0.39962073],
#          [0.59848607, 0.03607986, 0.39962073],
#          [0.41816422, 0.03607986, 0.39962073]],
#
#         [[0.77079862, 0.03111077, 0.44325839],
#          [0.61147422, 0.03111077, 0.44325839],
#          [0.67935419, 0.03111077, 0.44325839],
#          ...,
#          [0.43464372, 0.03111077, 0.44325839],
#          [0.6643461 , 0.03111077, 0.44325839],
#          [0.35291636, 0.03111077, 0.44325839]]]])

# %%
training_audio_features.shape
# Out:
# (4763, 251, 20, 3)

# %%
validation_audio_features = np.stack((audio_df['val']['mfcc'], np.tile(audio_df['val']['rms'], (1,1,20)), np.tile(audio_df['val']['spectral_centroid'], (1,1,20))), axis=-1)

validation_audio_features
# Out:
# array([[[[7.62171566e-01, 2.06753667e-02, 3.03484293e-01],
#          [6.69541299e-01, 2.06753667e-02, 3.03484293e-01],
#          [2.78618991e-01, 2.06753667e-02, 3.03484293e-01],
#          ...,
#          [4.90403026e-01, 2.06753667e-02, 3.03484293e-01],
#          [5.27012885e-01, 2.06753667e-02, 3.03484293e-01],
#          [5.10675550e-01, 2.06753667e-02, 3.03484293e-01]],
#
#         [[7.67133594e-01, 2.33909581e-02, 2.99039252e-01],
#          [6.68717980e-01, 2.33909581e-02, 2.99039252e-01],
#          [2.87237048e-01, 2.33909581e-02, 2.99039252e-01],
#          ...,
#          [6.09557986e-01, 2.33909581e-02, 2.99039252e-01],
#          [5.34400702e-01, 2.33909581e-02, 2.99039252e-01],
#          [5.43944716e-01, 2.33909581e-02, 2.99039252e-01]],
#
#         [[7.43019938e-01, 2.50219069e-02, 3.00015501e-01],
#          [6.55693531e-01, 2.50219069e-02, 3.00015501e-01],
#          [3.57620656e-01, 2.50219069e-02, 3.00015501e-01],
#          ...,
#          [6.47117019e-01, 2.50219069e-02, 3.00015501e-01],
#          [6.04468584e-01, 2.50219069e-02, 3.00015501e-01],
#          [5.54220498e-01, 2.50219069e-02, 3.00015501e-01]],
#
#         ...,
#
#         [[7.22117960e-01, 3.23640853e-02, 3.39035159e-01],
#          [6.54336870e-01, 3.23640853e-02, 3.39035159e-01],
#          [4.09471780e-01, 3.23640853e-02, 3.39035159e-01],
#          ...,
#          [5.00857174e-01, 3.23640853e-02, 3.39035159e-01],
#          [5.62361479e-01, 3.23640853e-02, 3.39035159e-01],
#          [4.47622150e-01, 3.23640853e-02, 3.39035159e-01]],
#
#         [[7.30139017e-01, 2.91568525e-02, 3.45181938e-01],
#          [6.67710781e-01, 2.91568525e-02, 3.45181938e-01],
#          [3.80047888e-01, 2.91568525e-02, 3.45181938e-01],
#          ...,
#          [3.89620483e-01, 2.91568525e-02, 3.45181938e-01],
#          [5.10757327e-01, 2.91568525e-02, 3.45181938e-01],
#          [4.42364752e-01, 2.91568525e-02, 3.45181938e-01]],
#
#         [[7.40247369e-01, 2.44294945e-02, 3.68024321e-01],
#          [6.35621607e-01, 2.44294945e-02, 3.68024321e-01],
#          [3.89496088e-01, 2.44294945e-02, 3.68024321e-01],
#          ...,
#          [3.05438221e-01, 2.44294945e-02, 3.68024321e-01],
#          [5.43105304e-01, 2.44294945e-02, 3.68024321e-01],
#          [4.65512484e-01, 2.44294945e-02, 3.68024321e-01]]],
#
#
#        [[[5.96953571e-01, 3.09160221e-02, 9.30303693e-02],
#          [8.48571062e-01, 3.09160221e-02, 9.30303693e-02],
#          [6.51687622e-01, 3.09160221e-02, 9.30303693e-02],
#          ...,
#          [4.70903128e-01, 3.09160221e-02, 9.30303693e-02],
#          [5.15750825e-01, 3.09160221e-02, 9.30303693e-02],
#          [4.91787374e-01, 3.09160221e-02, 9.30303693e-02]],
#
#         [[6.27771854e-01, 3.33564244e-02, 1.04762773e-01],
#          [8.27204466e-01, 3.33564244e-02, 1.04762773e-01],
#          [5.77615976e-01, 3.33564244e-02, 1.04762773e-01],
#          ...,
#          [5.72906256e-01, 3.33564244e-02, 1.04762773e-01],
#          [5.88250935e-01, 3.33564244e-02, 1.04762773e-01],
#          [6.01394892e-01, 3.33564244e-02, 1.04762773e-01]],
#
#         [[6.12671137e-01, 3.36256698e-02, 1.23478930e-01],
#          [7.78605640e-01, 3.36256698e-02, 1.23478930e-01],
#          [6.02382064e-01, 3.36256698e-02, 1.23478930e-01],
#          ...,
#          [6.23616576e-01, 3.36256698e-02, 1.23478930e-01],
#          [6.31252468e-01, 3.36256698e-02, 1.23478930e-01],
#          [5.73710859e-01, 3.36256698e-02, 1.23478930e-01]],
#
#         ...,
#
#         [[5.90038776e-01, 2.17375234e-02, 1.29633597e-01],
#          [8.06029797e-01, 2.17375234e-02, 1.29633597e-01],
#          [6.55803025e-01, 2.17375234e-02, 1.29633597e-01],
#          ...,
#          [4.69814748e-01, 2.17375234e-02, 1.29633597e-01],
#          [6.70248151e-01, 2.17375234e-02, 1.29633597e-01],
#          [5.14166474e-01, 2.17375234e-02, 1.29633597e-01]],
#
#         [[5.98359823e-01, 2.02307627e-02, 1.39853784e-01],
#          [8.24195623e-01, 2.02307627e-02, 1.39853784e-01],
#          [6.67860150e-01, 2.02307627e-02, 1.39853784e-01],
#          ...,
#          [4.04223740e-01, 2.02307627e-02, 1.39853784e-01],
#          [5.84419012e-01, 2.02307627e-02, 1.39853784e-01],
#          [4.52116162e-01, 2.02307627e-02, 1.39853784e-01]],
#
#         [[6.09075308e-01, 1.47298761e-02, 1.31185562e-01],
#          [8.21693003e-01, 1.47298761e-02, 1.31185562e-01],
#          [7.02538192e-01, 1.47298761e-02, 1.31185562e-01],
#          ...,
#          [3.70903939e-01, 1.47298761e-02, 1.31185562e-01],
#          [5.89405417e-01, 1.47298761e-02, 1.31185562e-01],
#          [4.96687651e-01, 1.47298761e-02, 1.31185562e-01]]],
#
#
#        [[[8.17034364e-01, 3.61745693e-02, 2.05941635e-01],
#          [7.95241475e-01, 3.61745693e-02, 2.05941635e-01],
#          [3.76215816e-01, 3.61745693e-02, 2.05941635e-01],
#          ...,
#          [5.50397992e-01, 3.61745693e-02, 2.05941635e-01],
#          [5.07193267e-01, 3.61745693e-02, 2.05941635e-01],
#          [5.16422212e-01, 3.61745693e-02, 2.05941635e-01]],
#
#         [[8.10419798e-01, 3.92672494e-02, 2.10958524e-01],
#          [7.80922472e-01, 3.92672494e-02, 2.10958524e-01],
#          [3.46265018e-01, 3.92672494e-02, 2.10958524e-01],
#          ...,
#          [6.00811779e-01, 3.92672494e-02, 2.10958524e-01],
#          [5.21366537e-01, 3.92672494e-02, 2.10958524e-01],
#          [5.63933015e-01, 3.92672494e-02, 2.10958524e-01]],
#
#         [[7.70242453e-01, 4.08015624e-02, 2.29821482e-01],
#          [7.33816981e-01, 4.08015624e-02, 2.29821482e-01],
#          [3.96762341e-01, 4.08015624e-02, 2.29821482e-01],
#          ...,
#          [6.23745263e-01, 4.08015624e-02, 2.29821482e-01],
#          [5.71289659e-01, 4.08015624e-02, 2.29821482e-01],
#          [5.61463833e-01, 4.08015624e-02, 2.29821482e-01]],
#
#         ...,
#
#         [[7.71907508e-01, 4.96005937e-02, 2.10055324e-01],
#          [7.65000045e-01, 4.96005937e-02, 2.10055324e-01],
#          [4.32861984e-01, 4.96005937e-02, 2.10055324e-01],
#          ...,
#          [4.56719249e-01, 4.96005937e-02, 2.10055324e-01],
#          [5.63850939e-01, 4.96005937e-02, 2.10055324e-01],
#          [5.69335401e-01, 4.96005937e-02, 2.10055324e-01]],
#
#         [[7.86996782e-01, 4.64854203e-02, 2.04962743e-01],
#          [7.87742674e-01, 4.64854203e-02, 2.04962743e-01],
#          [4.21008795e-01, 4.64854203e-02, 2.04962743e-01],
#          ...,
#          [4.19023752e-01, 4.64854203e-02, 2.04962743e-01],
#          [5.47893465e-01, 4.64854203e-02, 2.04962743e-01],
#          [5.04103959e-01, 4.64854203e-02, 2.04962743e-01]],
#
#         [[7.99177051e-01, 3.95495035e-02, 2.13542510e-01],
#          [7.68449187e-01, 3.95495035e-02, 2.13542510e-01],
#          [4.47745144e-01, 3.95495035e-02, 2.13542510e-01],
#          ...,
#          [4.90422249e-01, 3.95495035e-02, 2.13542510e-01],
#          [6.29269958e-01, 3.95495035e-02, 2.13542510e-01],
#          [4.24033493e-01, 3.95495035e-02, 2.13542510e-01]]],
#
#
#        ...,
#
#
#        [[[6.59999788e-01, 8.14633723e-03, 4.04511927e-01],
#          [5.49484611e-01, 8.14633723e-03, 4.04511927e-01],
#          [2.76898861e-01, 8.14633723e-03, 4.04511927e-01],
#          ...,
#          [4.91564393e-01, 8.14633723e-03, 4.04511927e-01],
#          [5.68527758e-01, 8.14633723e-03, 4.04511927e-01],
#          [3.61234307e-01, 8.14633723e-03, 4.04511927e-01]],
#
#         [[6.51873529e-01, 8.84928089e-03, 3.97213142e-01],
#          [5.38660645e-01, 8.84928089e-03, 3.97213142e-01],
#          [2.54803777e-01, 8.84928089e-03, 3.97213142e-01],
#          ...,
#          [5.49150944e-01, 8.84928089e-03, 3.97213142e-01],
#          [5.34776151e-01, 8.84928089e-03, 3.97213142e-01],
#          [4.12277430e-01, 8.84928089e-03, 3.97213142e-01]],
#
#         [[6.24176681e-01, 9.68746468e-03, 4.07878853e-01],
#          [5.18671334e-01, 9.68746468e-03, 4.07878853e-01],
#          [3.13931227e-01, 9.68746468e-03, 4.07878853e-01],
#          ...,
#          [5.55139959e-01, 9.68746468e-03, 4.07878853e-01],
#          [5.47509551e-01, 9.68746468e-03, 4.07878853e-01],
#          [3.89514267e-01, 9.68746468e-03, 4.07878853e-01]],
#
#         ...,
#
#         [[5.44870734e-01, 1.98896080e-02, 4.93322418e-01],
#          [4.92996871e-01, 1.98896080e-02, 4.93322418e-01],
#          [3.89685839e-01, 1.98896080e-02, 4.93322418e-01],
#          ...,
#          [3.90258819e-01, 1.98896080e-02, 4.93322418e-01],
#          [4.59726721e-01, 1.98896080e-02, 4.93322418e-01],
#          [3.18215698e-01, 1.98896080e-02, 4.93322418e-01]],
#
#         [[5.35139322e-01, 4.46323073e-03, 4.13473964e-01],
#          [5.34680068e-01, 4.46323073e-03, 4.13473964e-01],
#          [3.12829554e-01, 4.46323073e-03, 4.13473964e-01],
#          ...,
#          [3.70606989e-01, 4.46323073e-03, 4.13473964e-01],
#          [4.80976641e-01, 4.46323073e-03, 4.13473964e-01],
#          [2.33795658e-01, 4.46323073e-03, 4.13473964e-01]],
#
#         [[5.40441573e-01, 3.44241760e-03, 4.02963025e-01],
#          [5.19592941e-01, 3.44241760e-03, 4.02963025e-01],
#          [3.10187787e-01, 3.44241760e-03, 4.02963025e-01],
#          ...,
#          [3.67405832e-01, 3.44241760e-03, 4.02963025e-01],
#          [5.65659940e-01, 3.44241760e-03, 4.02963025e-01],
#          [2.12195575e-01, 3.44241760e-03, 4.02963025e-01]]],
#
#
#        [[[8.83170664e-01, 8.52162316e-02, 1.97077224e-01],
#          [7.79748797e-01, 8.52162316e-02, 1.97077224e-01],
#          [5.13508439e-01, 8.52162316e-02, 1.97077224e-01],
#          ...,
#          [2.85047352e-01, 8.52162316e-02, 1.97077224e-01],
#          [4.52504277e-01, 8.52162316e-02, 1.97077224e-01],
#          [3.86417955e-01, 8.52162316e-02, 1.97077224e-01]],
#
#         [[8.83251071e-01, 1.05045035e-01, 2.14195469e-01],
#          [7.59809971e-01, 1.05045035e-01, 2.14195469e-01],
#          [4.77601260e-01, 1.05045035e-01, 2.14195469e-01],
#          ...,
#          [4.86114830e-01, 1.05045035e-01, 2.14195469e-01],
#          [4.75431859e-01, 1.05045035e-01, 2.14195469e-01],
#          [4.53073144e-01, 1.05045035e-01, 2.14195469e-01]],
#
#         [[8.50066721e-01, 1.06549017e-01, 2.38480873e-01],
#          [7.19552934e-01, 1.06549017e-01, 2.38480873e-01],
#          [5.39324641e-01, 1.06549017e-01, 2.38480873e-01],
#          ...,
#          [5.81958473e-01, 1.06549017e-01, 2.38480873e-01],
#          [4.97703671e-01, 1.06549017e-01, 2.38480873e-01],
#          [4.27133322e-01, 1.06549017e-01, 2.38480873e-01]],
#
#         ...,
#
#         [[8.28541756e-01, 1.06863454e-01, 1.99002906e-01],
#          [7.53722787e-01, 1.06863454e-01, 1.99002906e-01],
#          [5.54695606e-01, 1.06863454e-01, 1.99002906e-01],
#          ...,
#          [4.37346935e-01, 1.06863454e-01, 1.99002906e-01],
#          [4.87638533e-01, 1.06863454e-01, 1.99002906e-01],
#          [3.58844370e-01, 1.06863454e-01, 1.99002906e-01]],
#
#         [[8.29123735e-01, 1.01660982e-01, 1.89308799e-01],
#          [7.78880715e-01, 1.01660982e-01, 1.89308799e-01],
#          [5.67088902e-01, 1.01660982e-01, 1.89308799e-01],
#          ...,
#          [3.75098646e-01, 1.01660982e-01, 1.89308799e-01],
#          [3.90086085e-01, 1.01660982e-01, 1.89308799e-01],
#          [3.05756330e-01, 1.01660982e-01, 1.89308799e-01]],
#
#         [[8.33582938e-01, 8.46783742e-02, 1.92501368e-01],
#          [7.71534264e-01, 8.46783742e-02, 1.92501368e-01],
#          [5.87188721e-01, 8.46783742e-02, 1.92501368e-01],
#          ...,
#          [3.18939716e-01, 8.46783742e-02, 1.92501368e-01],
#          [3.89078796e-01, 8.46783742e-02, 1.92501368e-01],
#          [3.45806420e-01, 8.46783742e-02, 1.92501368e-01]]],
#
#
#        [[[2.49886751e-01, 9.45237582e-04, 5.88837297e-01],
#          [3.93558025e-01, 9.45237582e-04, 5.88837297e-01],
#          [5.28617859e-01, 9.45237582e-04, 5.88837297e-01],
#          ...,
#          [4.85431999e-01, 9.45237582e-04, 5.88837297e-01],
#          [4.27832037e-01, 9.45237582e-04, 5.88837297e-01],
#          [4.96696204e-01, 9.45237582e-04, 5.88837297e-01]],
#
#         [[2.56095111e-01, 9.80041805e-04, 5.63285228e-01],
#          [3.51467669e-01, 9.80041805e-04, 5.63285228e-01],
#          [4.60257411e-01, 9.80041805e-04, 5.63285228e-01],
#          ...,
#          [6.73378885e-01, 9.80041805e-04, 5.63285228e-01],
#          [4.38682079e-01, 9.80041805e-04, 5.63285228e-01],
#          [6.09209597e-01, 9.80041805e-04, 5.63285228e-01]],
#
#         [[2.48326302e-01, 9.10926028e-04, 5.37040632e-01],
#          [3.48282933e-01, 9.10926028e-04, 5.37040632e-01],
#          [4.68925238e-01, 9.10926028e-04, 5.37040632e-01],
#          ...,
#          [6.66706562e-01, 9.10926028e-04, 5.37040632e-01],
#          [5.51167011e-01, 9.10926028e-04, 5.37040632e-01],
#          [5.87313473e-01, 9.10926028e-04, 5.37040632e-01]],
#
#         ...,
#
#         [[1.61319375e-01, 2.61426583e-04, 6.22450011e-01],
#          [4.46418583e-01, 2.61426583e-04, 6.22450011e-01],
#          [6.16514206e-01, 2.61426583e-04, 6.22450011e-01],
#          ...,
#          [3.45897019e-01, 2.61426583e-04, 6.22450011e-01],
#          [6.26686275e-01, 2.61426583e-04, 6.22450011e-01],
#          [3.62509787e-01, 2.61426583e-04, 6.22450011e-01]],
#
#         [[1.53073132e-01, 1.66291575e-04, 6.27190273e-01],
#          [4.73754585e-01, 1.66291575e-04, 6.27190273e-01],
#          [6.19425952e-01, 1.66291575e-04, 6.27190273e-01],
#          ...,
#          [3.87654603e-01, 1.66291575e-04, 6.27190273e-01],
#          [5.40510476e-01, 1.66291575e-04, 6.27190273e-01],
#          [3.56335044e-01, 1.66291575e-04, 6.27190273e-01]],
#
#         [[1.74115598e-01, 1.04467028e-04, 6.38514004e-01],
#          [4.76593494e-01, 1.04467028e-04, 6.38514004e-01],
#          [6.23220623e-01, 1.04467028e-04, 6.38514004e-01],
#          ...,
#          [3.87771010e-01, 1.04467028e-04, 6.38514004e-01],
#          [5.99400759e-01, 1.04467028e-04, 6.38514004e-01],
#          [3.71908367e-01, 1.04467028e-04, 6.38514004e-01]]]])

# %%
validation_audio_features.shape
# Out:
# (2430, 251, 20, 3)

# %% [markdown]
# ### fit the model with training data

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_weighted_accuracy",
    patience=10,
    restore_best_weights=True,
    start_from_epoch=20,
)

# %%
model = build_model(training_audio_features,
                    non_audio_df['train']['continent'],
                    learning_rate=0.001)

history = model.fit(
   x={
      'Continents': non_audio_df['train']['continent'],
      'Audio_Features': training_audio_features
   },
   y=audio_df['train']['label'],
   sample_weight=training_sample_weights,
   epochs=100,
   validation_data=(
      {
      'Continents': non_audio_df['val']['continent'],
      'Audio_Features': validation_audio_features
   },
      audio_df['val']['label'],
      validation_sample_weights
   ),
   batch_size=32,
   callbacks=[callback],
   verbose=1)

best_epoch = history.history['val_weighted_accuracy'].index(max(history.history['val_weighted_accuracy']))
print('best_epoch: ', best_epoch)

visualize(history, best_epoch)
# Out:
# Model: "Birds"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Continents (InputLayer)     [(None, 1)]                  0         []
#
#  string_lookup (StringLooku  (None, 1)                    0         ['Continents[0][0]']
#  p)
#
#  embedding (Embedding)       (None, 1, 2)                 12        ['string_lookup[0][0]']
#
#  Tile (Lambda)               (None, 251, 20, 1)           0         ['embedding[0][0]']
#
#  Audio_Features (InputLayer  [(None, 251, 20, 3)]         0         []
#  )
#
#  Features (Concatenate)      (None, 251, 20, 4)           0         ['Tile[0][0]',
#                                                                      'Audio_Features[0][0]']
#
#  conv_1 (Conv2D)             (None, 251, 20, 64)          6464      ['Features[0][0]']
#
#  pool_1 (MaxPooling2D)       (None, 125, 10, 64)          0         ['conv_1[0][0]']
#
#  conv_2 (Conv2D)             (None, 125, 10, 32)          51232     ['pool_1[0][0]']
#
#  pool_2 (MaxPooling2D)       (None, 62, 5, 32)            0         ['conv_2[0][0]']
#
#  conv_3 (Conv2D)             (None, 62, 5, 32)            25632     ['pool_2[0][0]']
#
#  pool_3 (MaxPooling2D)       (None, 31, 2, 32)            0         ['conv_3[0][0]']
#
#  flatten (Flatten)           (None, 1984)                 0         ['pool_3[0][0]']
#
#  fc_1 (Dense)                (None, 1024)                 2032640   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 1024)                 0         ['fc_1[0][0]']
#
#  fc_2 (Dense)                (None, 3)                    3075      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2119055 (8.08 MB)
# Trainable params: 2119055 (8.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 149/149 [==============================] - 81s 531ms/step - loss: 0.8170 - accuracy: 0.4134 - weighted_accuracy: 0.4153 - val_loss: 0.5231 - val_accuracy: 0.6136 - val_weighted_accuracy: 0.6204
# Epoch 2/100
# 149/149 [==============================] - 78s 524ms/step - loss: 0.4665 - accuracy: 0.6385 - weighted_accuracy: 0.6409 - val_loss: 0.4490 - val_accuracy: 0.5741 - val_weighted_accuracy: 0.5995
# Epoch 3/100
# 149/149 [==============================] - 78s 524ms/step - loss: 0.3847 - accuracy: 0.7275 - weighted_accuracy: 0.7313 - val_loss: 0.4036 - val_accuracy: 0.6535 - val_weighted_accuracy: 0.6770
# Epoch 4/100
# 149/149 [==============================] - 82s 554ms/step - loss: 0.3133 - accuracy: 0.8026 - weighted_accuracy: 0.8086 - val_loss: 0.3289 - val_accuracy: 0.7988 - val_weighted_accuracy: 0.8059
# Epoch 5/100
# 149/149 [==============================] - 78s 524ms/step - loss: 0.2650 - accuracy: 0.8402 - weighted_accuracy: 0.8464 - val_loss: 0.3281 - val_accuracy: 0.7609 - val_weighted_accuracy: 0.7812
# Epoch 6/100
# 149/149 [==============================] - 77s 520ms/step - loss: 0.2282 - accuracy: 0.8686 - weighted_accuracy: 0.8752 - val_loss: 0.3564 - val_accuracy: 0.8008 - val_weighted_accuracy: 0.8091
# Epoch 7/100
# 149/149 [==============================] - 79s 533ms/step - loss: 0.2121 - accuracy: 0.8774 - weighted_accuracy: 0.8837 - val_loss: 0.3077 - val_accuracy: 0.8267 - val_weighted_accuracy: 0.8323
# Epoch 8/100
# 149/149 [==============================] - 78s 525ms/step - loss: 0.2075 - accuracy: 0.8822 - weighted_accuracy: 0.8882 - val_loss: 0.3809 - val_accuracy: 0.8082 - val_weighted_accuracy: 0.8158
# Epoch 9/100
# 149/149 [==============================] - 77s 518ms/step - loss: 0.1945 - accuracy: 0.9020 - weighted_accuracy: 0.9070 - val_loss: 0.2998 - val_accuracy: 0.8152 - val_weighted_accuracy: 0.8257
# Epoch 10/100
# 149/149 [==============================] - 78s 523ms/step - loss: 0.1744 - accuracy: 0.9101 - weighted_accuracy: 0.9150 - val_loss: 0.2816 - val_accuracy: 0.8428 - val_weighted_accuracy: 0.8499
# Epoch 11/100
# 149/149 [==============================] - 78s 522ms/step - loss: 0.1704 - accuracy: 0.9085 - weighted_accuracy: 0.9133 - val_loss: 0.3227 - val_accuracy: 0.8156 - val_weighted_accuracy: 0.8296
# Epoch 12/100
# 149/149 [==============================] - 79s 531ms/step - loss: 0.1637 - accuracy: 0.9158 - weighted_accuracy: 0.9199 - val_loss: 0.2789 - val_accuracy: 0.8498 - val_weighted_accuracy: 0.8556
# Epoch 13/100
# 149/149 [==============================] - 78s 524ms/step - loss: 0.1615 - accuracy: 0.9198 - weighted_accuracy: 0.9243 - val_loss: 0.3198 - val_accuracy: 0.7996 - val_weighted_accuracy: 0.8151
# Epoch 14/100
# 149/149 [==============================] - 78s 523ms/step - loss: 0.1478 - accuracy: 0.9278 - weighted_accuracy: 0.9320 - val_loss: 0.3088 - val_accuracy: 0.8181 - val_weighted_accuracy: 0.8228
# Epoch 15/100
# 149/149 [==============================] - 77s 520ms/step - loss: 0.1469 - accuracy: 0.9311 - weighted_accuracy: 0.9356 - val_loss: 0.3001 - val_accuracy: 0.8078 - val_weighted_accuracy: 0.8266
# Epoch 16/100
# 149/149 [==============================] - 78s 525ms/step - loss: 0.1532 - accuracy: 0.9229 - weighted_accuracy: 0.9275 - val_loss: 0.2678 - val_accuracy: 0.8510 - val_weighted_accuracy: 0.8581
# Epoch 17/100
# 149/149 [==============================] - 78s 523ms/step - loss: 0.1409 - accuracy: 0.9343 - weighted_accuracy: 0.9381 - val_loss: 0.2998 - val_accuracy: 0.8374 - val_weighted_accuracy: 0.8430
# Epoch 18/100
# 149/149 [==============================] - 78s 524ms/step - loss: 0.1341 - accuracy: 0.9404 - weighted_accuracy: 0.9439 - val_loss: 0.2884 - val_accuracy: 0.8506 - val_weighted_accuracy: 0.8574
# Epoch 19/100
# 149/149 [==============================] - 79s 534ms/step - loss: 0.1334 - accuracy: 0.9404 - weighted_accuracy: 0.9443 - val_loss: 0.2789 - val_accuracy: 0.8420 - val_weighted_accuracy: 0.8472
# Epoch 20/100
# 149/149 [==============================] - 77s 519ms/step - loss: 0.1267 - accuracy: 0.9456 - weighted_accuracy: 0.9499 - val_loss: 0.3158 - val_accuracy: 0.8379 - val_weighted_accuracy: 0.8463
# Epoch 21/100
# 149/149 [==============================] - 78s 524ms/step - loss: 0.1412 - accuracy: 0.9328 - weighted_accuracy: 0.9374 - val_loss: 0.2926 - val_accuracy: 0.8387 - val_weighted_accuracy: 0.8437
# Epoch 22/100
# 149/149 [==============================] - 80s 535ms/step - loss: 0.1275 - accuracy: 0.9433 - weighted_accuracy: 0.9468 - val_loss: 0.3091 - val_accuracy: 0.8481 - val_weighted_accuracy: 0.8569
# Epoch 23/100
# 149/149 [==============================] - 77s 519ms/step - loss: 0.1185 - accuracy: 0.9513 - weighted_accuracy: 0.9547 - val_loss: 0.2964 - val_accuracy: 0.8547 - val_weighted_accuracy: 0.8625
# Epoch 24/100
# 149/149 [==============================] - 78s 526ms/step - loss: 0.1150 - accuracy: 0.9517 - weighted_accuracy: 0.9562 - val_loss: 0.3723 - val_accuracy: 0.8358 - val_weighted_accuracy: 0.8477
# Epoch 25/100
# 149/149 [==============================] - 80s 535ms/step - loss: 0.1074 - accuracy: 0.9593 - weighted_accuracy: 0.9626 - val_loss: 0.3155 - val_accuracy: 0.8494 - val_weighted_accuracy: 0.8578
# Epoch 26/100
# 149/149 [==============================] - 78s 525ms/step - loss: 0.1331 - accuracy: 0.9391 - weighted_accuracy: 0.9426 - val_loss: 0.3268 - val_accuracy: 0.8457 - val_weighted_accuracy: 0.8556
# Epoch 27/100
# 149/149 [==============================] - 78s 522ms/step - loss: 0.1135 - accuracy: 0.9551 - weighted_accuracy: 0.9591 - val_loss: 0.3026 - val_accuracy: 0.8498 - val_weighted_accuracy: 0.8542
# Epoch 28/100
# 149/149 [==============================] - 80s 534ms/step - loss: 0.1118 - accuracy: 0.9532 - weighted_accuracy: 0.9566 - val_loss: 0.3847 - val_accuracy: 0.8169 - val_weighted_accuracy: 0.8304
# Epoch 29/100
# 149/149 [==============================] - 78s 527ms/step - loss: 0.1169 - accuracy: 0.9519 - weighted_accuracy: 0.9557 - val_loss: 0.3102 - val_accuracy: 0.8564 - val_weighted_accuracy: 0.8653
# Epoch 30/100
# 149/149 [==============================] - 78s 526ms/step - loss: 0.1001 - accuracy: 0.9633 - weighted_accuracy: 0.9666 - val_loss: 0.3054 - val_accuracy: 0.8580 - val_weighted_accuracy: 0.8647
# Epoch 31/100
# 149/149 [==============================] - 78s 527ms/step - loss: 0.1037 - accuracy: 0.9616 - weighted_accuracy: 0.9643 - val_loss: 0.2915 - val_accuracy: 0.8506 - val_weighted_accuracy: 0.8566
# Epoch 32/100
# 149/149 [==============================] - 77s 518ms/step - loss: 0.1011 - accuracy: 0.9643 - weighted_accuracy: 0.9675 - val_loss: 0.2869 - val_accuracy: 0.8626 - val_weighted_accuracy: 0.8704
# Epoch 33/100
# 149/149 [==============================] - 79s 528ms/step - loss: 0.0952 - accuracy: 0.9658 - weighted_accuracy: 0.9692 - val_loss: 0.3110 - val_accuracy: 0.8601 - val_weighted_accuracy: 0.8679
# Epoch 34/100
# 149/149 [==============================] - 80s 535ms/step - loss: 0.0973 - accuracy: 0.9654 - weighted_accuracy: 0.9687 - val_loss: 0.3156 - val_accuracy: 0.8580 - val_weighted_accuracy: 0.8641
# Epoch 35/100
# 149/149 [==============================] - 77s 521ms/step - loss: 0.1166 - accuracy: 0.9505 - weighted_accuracy: 0.9534 - val_loss: 0.3283 - val_accuracy: 0.8305 - val_weighted_accuracy: 0.8389
# Epoch 36/100
# 149/149 [==============================] - 78s 526ms/step - loss: 0.1127 - accuracy: 0.9578 - weighted_accuracy: 0.9618 - val_loss: 0.3383 - val_accuracy: 0.8523 - val_weighted_accuracy: 0.8592
# Epoch 37/100
# 149/149 [==============================] - 79s 528ms/step - loss: 0.0950 - accuracy: 0.9689 - weighted_accuracy: 0.9717 - val_loss: 0.2780 - val_accuracy: 0.8568 - val_weighted_accuracy: 0.8612
# Epoch 38/100
# 149/149 [==============================] - 78s 521ms/step - loss: 0.0916 - accuracy: 0.9691 - weighted_accuracy: 0.9723 - val_loss: 0.3335 - val_accuracy: 0.8481 - val_weighted_accuracy: 0.8569
# Epoch 39/100
# 149/149 [==============================] - 78s 524ms/step - loss: 0.0870 - accuracy: 0.9719 - weighted_accuracy: 0.9747 - val_loss: 0.3889 - val_accuracy: 0.8461 - val_weighted_accuracy: 0.8571
# Epoch 40/100
# 149/149 [==============================] - 79s 529ms/step - loss: 0.0936 - accuracy: 0.9675 - weighted_accuracy: 0.9701 - val_loss: 0.3298 - val_accuracy: 0.8613 - val_weighted_accuracy: 0.8672
# Epoch 41/100
# 149/149 [==============================] - 78s 525ms/step - loss: 0.0931 - accuracy: 0.9696 - weighted_accuracy: 0.9713 - val_loss: 0.3430 - val_accuracy: 0.8539 - val_weighted_accuracy: 0.8618
# Epoch 42/100
# 149/149 [==============================] - 78s 525ms/step - loss: 0.0974 - accuracy: 0.9645 - weighted_accuracy: 0.9673 - val_loss: 0.3419 - val_accuracy: 0.8519 - val_weighted_accuracy: 0.8578
# best_epoch:  31

# %%
train_yhat = model.predict({'Continents': non_audio_df['train']['continent'],
                            'Audio_Features': training_audio_features
                            })

train_yhat_result = np.argmax(train_yhat, axis=-1)

train_results['mfcc_rms_spectral_centroid_continents'] = model.evaluate({'Continents': non_audio_df['train']['continent'],
                                                          'Audio_Features': training_audio_features},
                                                         audio_df['train']['label'])[-1]
# Out:
# 149/149 [==============================] - 27s 181ms/step
# 149/149 [==============================] - 18s 122ms/step - loss: 0.1244 - accuracy: 0.9725 - weighted_accuracy: 0.9725

# %%
val_yhat = model.predict({'Continents': non_audio_df['val']['continent'],
                          'Audio_Features': validation_audio_features
                          })

val_yhat_result = np.argmax(val_yhat, axis=-1)

val_results['mfcc_rms_spectral_centroid_continents'] = model.evaluate({'Continents': non_audio_df['val']['continent'],
                                                          'Audio_Features': validation_audio_features},
                                                         audio_df['val']['label'])[-1]
# Out:
# 76/76 [==============================] - 10s 126ms/step
# 76/76 [==============================] - 9s 121ms/step - loss: 0.5153 - accuracy: 0.8626 - weighted_accuracy: 0.8626

# %% [markdown]
# ### evaluate the results

# %%
print('Training classification Report \n')
print(classification_report(audio_df['train']['label'], train_yhat_result, target_names=classes))
# Out:
# Training classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.98      0.97      0.97      1603
#       comsan       0.96      1.00      0.98      1578
#      eaywag1       0.98      0.96      0.97      1582
#
#     accuracy                           0.97      4763
#    macro avg       0.97      0.97      0.97      4763
# weighted avg       0.97      0.97      0.97      4763

# %%
print('Validation classification Report \n')
print(classification_report(audio_df['val']['label'], val_yhat_result, target_names=classes))
# Out:
# Validation classification Report
#
#               precision    recall  f1-score   support
#
#       barswa       0.91      0.83      0.87      1032
#       comsan       0.76      0.93      0.83       618
#      eaywag1       0.91      0.85      0.88       780
#
#     accuracy                           0.86      2430
#    macro avg       0.86      0.87      0.86      2430
# weighted avg       0.87      0.86      0.86      2430

# %%
train_cm = tf.math.confusion_matrix(audio_df['train']['label'], train_yhat_result)

ax = sns.heatmap(train_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Train Confusion Matrix')
plt.show()

# %%
val_cm = tf.math.confusion_matrix(audio_df['val']['label'], val_yhat_result)

ax = sns.heatmap(val_cm,
                 annot=True,
                 fmt='.0f',
                 cmap='Blues',
                 xticklabels=classes,
                 yticklabels=classes,
                 cbar=False)

ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.title('Validation Confusion Matrix')
plt.show()

# %% [markdown]
# # Review results from all models

# %%
train_results_df = pd.DataFrame(list(train_results.items()), columns=['Features', 'Train_Accuracy']).round(2)
val_results_df = pd.DataFrame(list(val_results.items()), columns=['Features', 'Val_Accuracy']).round(2)

result_df = train_results_df.merge(val_results_df, on='Features')
result_df = result_df.sort_values('Val_Accuracy')
result_df
# Out:
#                                 Features  Train_Accuracy  Val_Accuracy
# 0  mfcc_rms_spectral_centroid_continents            0.97          0.86
